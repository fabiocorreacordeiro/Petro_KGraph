# %% [markdown]
# ### Notebook para clusterizar as entidades

# %%
# Configurando Proxy

import os
from getpass import getpass

chave  = os.getenv('USER')
senha  = getpass('Senha: ')

os.environ['HTTP_PROXY']  = f'http://{chave}:{senha}@inet-sys.petrobras.com.br:804'
os.environ['HTTPS_PROXY'] = f'http://{chave}:{senha}@inet-sys.petrobras.com.br:804'
os.environ['NO_PROXY']    = '127.0.0.1, localhost, petrobras.com.br, petrobras.biz'
# Out:
# Senha:  ··········

# %%
import json
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt, mpld3
import pandas as pd
from collections import Counter

# %% [markdown]
# Ler todas as entidades identicadas no texto, mas que não foram linkadas a nenhuma URI existente no PetroOntoVec.

# %%
# path_json = "../../Corpora/Predicao/Prediction_json/"  # Documentos novos
path_json = "../../Corpora/Predicao - avaliação/Prediction_json/"  # PetroNER-teste para avaliação do pipeline

#listas para receber entidades não ligadas ao PetroKGraph
classe = []
entity = []
embedding = []

# Iterando por cada arquivo
for file in os.listdir(path_json):
    filename = os.fsdecode(file)
    if file.endswith(".json"):
        print(filename)
        
        with open(path_json + filename, 'r') as f:
            pred_dic = json.load(f)
        
        sentence_key = pred_dic.keys()
        
         # Iterando por cada sentença
        for key in sentence_key:
            # Iterando por entidade identificada
            for n in range(len(pred_dic[key]['NER']['Entities'])):

                # verificando se não está linkado a uma URI do PetroKGraph
                if pred_dic[key]['NER']['Grafo'][n] == None:
                    classe.append(pred_dic[key]['NER']['Classes'][n])
                    entity.append(pred_dic[key]['NER']['Entities'][n])
                    embedding.append(pred_dic[key]['NER']['Embedding'][n])
# Out:
# petroner-uri-teste.json

# %% [markdown]
# ### Clusterizando os embeddings

# %% [markdown]
# Clusterizando os embedings usando uma algoritmo de clusterização por densidade

# %%
# Algoritmo de clusterização
# alpha é o parâmetro de distância cosseno usado para treinar modelo triplet - 
# o que estiver dentro de um círculo de raio alpha é considerado um cluster
alpha = 0.01 
embedding = np.array(embedding)
clustering = DBSCAN(eps=alpha, min_samples=5, metric='cosine').fit(embedding)

# %% [markdown]
# Agora vamos reduzir a dimensionalidade para poder visualizar os vetores

# %%
PCA_embedding = PCA(n_components=2).fit_transform(embedding)

# %%
fig, ax = plt.subplots(figsize=(20, 20))#, layout='constrained')
plt.scatter(PCA_embedding.T[0], PCA_embedding.T[1], c=clustering.labels_, s=80)

for i in range(len(embedding)):
    plt.text(x=PCA_embedding.T[0][i], 
             y=PCA_embedding.T[1][i],
             s= str(clustering.labels_[i]), 
             fontdict=dict(size=10))
             #s='(' + str(clustering.labels_[i]) + ') ' + ' - ' + classe[i] + ' - ' + entity[i] + ' - ' + str(i), fontdict=dict(size=10),)
    if i > 1000:
        break
    
mpld3.display(fig)
# Out:
# <style>
#
# </style>
#
# <div id="fig_el21443475649032791361950947303"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el21443475649032791361950947303", {"width": 1440.0, "height": 1440.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [-13.568549032567383, 22.5175892097905], "ylim": [-10.577296358936039, 21.731749156826073], "xdomain": [-13.568549032567383, 22.5175892097905], "ydomain": [-10.577296358936039, 21.731749156826073], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 9, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}, {"position": "left", "nticks": 9, "tickvalues": null, "tickformat_formatter": "", "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": false}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el2144347564903317968", "lines": [], "paths": [], "markers": [], "texts": [{"text": "-1", "position": [15.804433182095305, -2.839002244651808], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564976913432"}, {"text": "-1", "position": [-2.4692177986230694, 16.966443085453207], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564976913992"}, {"text": "-1", "position": [15.830533632666574, -3.3666910708980984], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977025320"}, {"text": "-1", "position": [-8.514600497971884, -0.5371247164513595], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977025936"}, {"text": "0", "position": [-9.145385203563293, -2.1813331178002553], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977026552"}, {"text": "-1", "position": [-8.707117401016951, -5.513055289060214], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977027168"}, {"text": "-1", "position": [-9.084603253948984, -7.134850319883592], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977027784"}, {"text": "1", "position": [-8.188039438985784, -9.108703380946851], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977028400"}, {"text": "-1", "position": [-11.483511984393608, -6.778956651455915], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977029016"}, {"text": "-1", "position": [-7.442422566414327, -5.768614327115003], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977070656"}, {"text": "-1", "position": [-7.671076287910844, -6.204469373287403], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977071272"}, {"text": "-1", "position": [7.761394985829368, 0.24816834244528269], "coordinates": "data", "h_anchor": "start", "v_baseline": "auto", "rotation": -0.0, "fontsize": 10.0, "color": "#000000", "alpha": 1, "zorder": 3, "id": "el2144347564977071888"}, {"text": "-1", "position": [7.005223074793124, 1.5909748083867676], "coordinates": "data", "h_anchor": "s ...

# %%
# Criando dicionário com as informações das novas entidades clusterizadas

new_entities = {}

# Criando DataFrame 
df = pd.DataFrame({'cluster': clustering.labels_,
                   'classe': classe,
                   'label': entity})

# iterenado por todos os clusters (menos o cluster -1)
for n in set(clustering.labels_):
    if n != -1:

        # Verificando qual a classe predominante
        cluster_classes = df[df['cluster'] == n]['classe'].values
        first_cluster_class = Counter(cluster_classes).most_common(1)[0][0]

        # Filtrando apenas as labels da classe dominante
        cluster_labels = df[(df['cluster'] == n) & 
                            (df['classe'] == first_cluster_class)]['label'].values

        # Definindo como label válida, os termos que abrangem f% de todos os elementos clusterizados
        f = 0.5
        new_label = []
        count_label = 0
        f_label = f * len(cluster_labels)

        for lab in Counter(cluster_labels).most_common():
            if count_label < f_label:
                new_label.append(lab[0])
                count_label = count_label + lab[1]
            else:
                break

        new_entities[str(n)] = {'classe': first_cluster_class,
                           'label': new_label,
                           'URI': '#NEW_' + first_cluster_class + '_' + new_label[0].replace(' ','_')}

# %%
new_entities
# Out:
# {'0': {'classe': 'POÇO',
#   'label': ['14 - PC - 06',
#    '7 - CP - 252 - SE # 5',
#    '5 - PC - 29',
#    '9 - PC - 06',
#    '9 - PC - 09',
#    '14 - PC - 01',
#    '10 - PC - 03',
#    '14 - PC -',
#    '7 - CP - 252 - SE'],
#   'URI': '#NEW_POÇO_14_-_PC_-_06'},
#  '1': {'classe': 'UNIDADE_LITO',
#   'label': ['Membro Oiteirinhos.'],
#   'URI': '#NEW_UNIDADE_LITO_Membro_Oiteirinhos.'},
#  '2': {'classe': 'ROCHA',
#   'label': ['rochas geradoras'],
#   'URI': '#NEW_ROCHA_rochas_geradoras'},
#  '3': {'classe': 'FLUIDO', 'label': ['fluidos'], 'URI': '#NEW_FLUIDO_fluidos'},
#  '4': {'classe': 'BACIA',
#   'label': ['Bacia de Paris'],
#   'URI': '#NEW_BACIA_Bacia_de_Paris'},
#  '5': {'classe': 'FLUIDODATERRA_i',
#   'label': ['betume', 'betumes'],
#   'URI': '#NEW_FLUIDODATERRA_i_betume'},
#  '6': {'classe': 'UNIDADE_CRONO',
#   'label': ['Andar Rio de a Serra', 'andares Rio de a Serra'],
#   'URI': '#NEW_UNIDADE_CRONO_Andar_Rio_de_a_Serra'},
#  '7': {'classe': 'POÇO',
#   'label': ['Bu - 91 / GI - 05', 'Bu - 91 / GI - 07'],
#   'URI': '#NEW_POÇO_Bu_-_91_/_GI_-_05'},
#  '8': {'classe': 'UNIDADE_LITO',
#   'label': ['Membro Pedrão'],
#   'URI': '#NEW_UNIDADE_LITO_Membro_Pedrão'},
#  '9': {'classe': 'BACIA',
#   'label': ['Bacia de o Gabão', 'bacias de o Gabão'],
#   'URI': '#NEW_BACIA_Bacia_de_o_Gabão'},
#  '10': {'classe': 'UNIDADE_LITO',
#   'label': ['Formação Marizal'],
#   'URI': '#NEW_UNIDADE_LITO_Formação_Marizal'},
#  '11': {'classe': 'BACIA',
#   'label': ['Bacia Lusitânica'],
#   'URI': '#NEW_BACIA_Bacia_Lusitânica'},
#  '12': {'classe': 'UNIDADE_CRONO',
#   'label': ['Jurássico Inferior'],
#   'URI': '#NEW_UNIDADE_CRONO_Jurássico_Inferior'},
#  '13': {'classe': 'UNIDADE_CRONO',
#   'label': ['Pliensbaquiano –'],
#   'URI': '#NEW_UNIDADE_CRONO_Pliensbaquiano_–'},
#  '14': {'classe': 'UNIDADE_LITO',
#   'label': ['Formação Vale de as Fontes'],
#   'URI': '#NEW_UNIDADE_LITO_Formação_Vale_de_as_Fontes'},
#  '15': {'classe': 'UNIDADE_LITO',
#   'label': ['Membro Mcnb'],
#   'URI': '#NEW_UNIDADE_LITO_Membro_Mcnb'},
#  '16': {'classe': 'UNIDADE_LITO',
#   'label': ['Formação Cabo Carvoeiro'],
#   'URI': '#NEW_UNIDADE_LITO_Formação_Cabo_Carvoeiro'},
#  '17': {'classe': 'FLUIDODATERRA_i',
#   'label': ['asfaltenos'],
#   'URI': '#NEW_FLUIDODATERRA_i_asfaltenos'},
#  '18': {'classe': 'POÇO',
#   'label': ['1 - CAV - 1 - SE', '1 - CAU - 3 - SE', '1 - RPO - 1 - SE'],
#   'URI': '#NEW_POÇO_1_-_CAV_-_1_-_SE'},
#  '19': {'classe': 'POÇO',
#   'label': ['poços 1 - CR - 2 - SE',
#    '1 - SES - 30',
#    '1 - SES - 63',
#    '1 - SES - 18A',
#    '1 - SES - 64'],
#   'URI': '#NEW_POÇO_poços_1_-_CR_-_2_-_SE'},
#  '20': {'classe': 'UNIDADE_CRONO',
#   'label': ['norhopano'],
#   'URI': '#NEW_UNIDADE_CRONO_norhopano'},
#  '21': {'classe': 'CAMPO', 'label': ['Badejo'], 'URI': '#NEW_CAMPO_Badejo'},
#  '22': {'classe': 'POÇO',
#   'label': ['1 - RJS - 203'],
#   'URI': '#NEW_POÇO_1_-_RJS_-_203'}}

# %%
# path_entities = "../../Corpora/Predicao/Prediction_graph/"            # Documentos novos
path_entities = "../../Corpora/Predicao - avaliação/Prediction_graph/"  # PetroNER-teste para avaliação do pipeline
filename_entities = "New_entities"

#Salvando o arquivo as novas entidades
with open(path_entities + filename_entities, 'w+') as f:
    json.dump(new_entities, f)

# %% [markdown]
# ### Iterar novamente pelos arquivos e atualizar os JSONs com as informações das entidades novas.

# %%
#Contador para acompanhar a iteração entre as entidades clusterizadas
cluster_i = 0

# Iterando por cada arquivo
for file in os.listdir(path_json):
    filename = os.fsdecode(file)
    if file.endswith(".json"):
        print(filename)
        
        with open(path_json + filename, 'r') as f:
            pred_dic = json.load(f)
        
        sentence_key = pred_dic.keys()
        
         # Iterando por cada sentença
        for key in sentence_key:
            # Iterando por entidade identificada
            for n in range(len(pred_dic[key]['NER']['Entities'])):

                # verificando se não está linkado a uma URI do PetroKGraph
                if pred_dic[key]['NER']['Grafo'][n] == None:
                    # Verificando se a entidade foi clusterizada em algum cluster (diferente de -1)
                    clus = str(clustering.labels_[cluster_i])
                    if clus != str(-1):
                        # Verificando se a classe da sentença é a mesma do cluster
                        if pred_dic[key]['NER']['Classes'][n] == new_entities[clus]['classe']:
                            # Gravando a URI da nova entidade
                            pred_dic[key]['NER']['Grafo'][n] = new_entities[clus]['URI']
                            # Apagando os embeddings das entidades identificadas 
                            pred_dic[key]['NER']['Embedding'][n] = None
                    
                    cluster_i = cluster_i + 1
                    
        #Salvando o arquivo JSON
        with open(path_json + filename, 'w+') as f:
            json.dump(pred_dic, f)
# Out:
# petroner-uri-teste.json
