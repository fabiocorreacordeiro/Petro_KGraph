# %%
# data='/share_gamma/nethome/cristian/projects/nlp/NER/distant_supervision/data_full'

# %%
# !pip install --user --upgrade stanza

# %%
import stanza

# %%
# stanza.download('pt')
# !python --version
# Out:
# Python 3.6.9

# %%
# !cat inf_stanza/inference.py

# %%
# !python main.py --idir '../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/' --odir '../../NLP/Datasets/400_tesis/NewOutputNotTokenizer/'
# Out:
# 2021-04-29 18:42:07 INFO: Loading these models for language: pt (Portuguese):
# =======================================
# | Processor | Package                 |
# ---------------------------------------
# | tokenize  | bosque                  |
# | mwt       | bosque                  |
# | pos       | bosque                  |
# | lemma     | bosque                  |
# | depparse  | ./models/p..._parser.pt |
# =======================================
#
# /prj/parceirosbr/jose.castro2/.local/lib/python3.6/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# 2021-04-29 18:42:07 INFO: Use device: cpu
# 2021-04-29 18:42:07 INFO: Loading: tokenize
# 2021-04-29 18:42:08 INFO: Loading: mwt
# 2021-04-29 18:42:08 INFO: Loading: pos
# 2021-04-29 18:42:08 INFO: Loading: lemma
# 2021-04-29 18:42:08 INFO: Loading: depparse
# 2021-04-29 18:42:09 INFO: Done loading processors!
# 2021-04-29 18:42:09 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# =======================
#
# 2021-04-29 18:42:09 INFO: Use device: cpu
# 2021-04-29 18:42:09 INFO: Loading: tokenize
# 2021-04-29 18:42:09 INFO: Done loading processors!
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/322-20150327-TESEMSC_0.txt
# first
# 100%|####################################| 448/448 [00:00<00:00, 1658471.48it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/32-20141110-MONOGRAFIA_0.txt
# first
# 100%|####################################| 698/698 [00:00<00:00, 1770026.72it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/13-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 303/303 [00:00<00:00, 1701304.03it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/318-20160606-TESEMSC_0.txt
# first
# 100%|####################################| 557/557 [00:00<00:00, 1661612.61it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/394-20160725-MONOGRAFIA_0.txt
# first
# 100%|####################################| 249/249 [00:00<00:00, 1509222.10it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/353-20150810-MONOGRAFIA_0.txt
# first
# 100%|####################################| 363/363 [00:00<00:00, 1587624.98it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/179-20150721-TESEDSC_0.txt
# first
# 100%|####################################| 953/953 [00:00<00:00, 1483731.15it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/131-20150511-TESEDSC_0.txt
# first
# 100%|####################################| 579/579 [00:00<00:00, 1748381.58it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/321-20151204-TESEMSC_0.txt
# first
# 100%|####################################| 707/707 [00:00<00:00, 1305756.46it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/388-20160602-MONOGRAFIA_0.txt
# first
# 100%|####################################| 485/485 [00:00<00:00, 1208697.23it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/169-20121217-MONOGRAFIA_0.txt
# first
# 100%|####################################| 527/527 [00:00<00:00, 1279165.63it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/405-20160725-MONOGRAFIA_0.txt
# first
# 100%|####################################| 412/412 [00:00<00:00, 1175546.43it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/372-20150914-MONOGRAFIA_0.txt
# first
# 100%|####################################| 821/821 [00:00<00:00, 1424120.59it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/80-20140915-TESEDSC_0.txt
# first
# 100%|####################################| 714/714 [00:00<00:00, 1271109.11it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/100-20151215-MONOGRAFIA_0.txt
# first
# 100%|####################################| 542/542 [00:00<00:00, 1434266.73it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/102-20151215-MONOGRAFIA_0.txt
# first
# 100%|####################################| 231/231 [00:00<00:00, 1448257.43it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/23-20150115-MONOGRAFIA_0.txt
# first
# 100%|####################################| 349/349 [00:00<00:00, 1422557.92it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/295-20150914-TESEMSC_0.txt
# first
# 100%|####################################| 860/860 [00:00<00:00, 1552109.05it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/301-20150527-MONOGRAFIA_0.txt
# first
# 100%|####################################| 230/230 [00:00<00:00, 1332444.64it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/141-20141205-TESEDSC_1.txt
# first
# 100%|####################################| 702/702 [00:00<00:00, 1301105.35it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/178-20141015-TESEMSC_1.txt
# first
# 100%|####################################| 723/723 [00:00<00:00, 1480704.00it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/410-20150630-MONOGRAFIA_0.txt
# first
# 100%|####################################| 286/286 [00:00<00:00, 1203180.49it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/180-20140922-MONOGRAFIA_0.txt
# first
# 100%|####################################| 181/181 [00:00<00:00, 1084527.18it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/215-20140922-TESEMSC_0.txt
# first
# 100%|####################################| 374/374 [00:00<00:00, 1620526.55it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/243-20141015-MONOGRAFIA_1.txt
# first
# 100%|####################################| 301/301 [00:00<00:00, 1401204.78it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/164-20140917-MONOGRAFIA_0.txt
# first
# 100%|####################################| 279/279 [00:00<00:00, 1500270.28it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/72-20150521-MONOGRAFIA_0.txt
# first
# 100%|####################################| 782/782 [00:00<00:00, 1558168.99it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/56-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 433/433 [00:00<00:00, 1552250.97it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/287-20140609-MONOGRAFIA_0.txt
# first
# 100%|####################################| 301/301 [00:00<00:00, 1410598.33it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/200-20140327-TESEMSC_0.txt
# first
# 100%|##################################| 3231/3231 [00:00<00:00, 1595079.59it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/129-20140925-MONOGRAFIA_0.txt
# first
# 100%|####################################| 294/294 [00:00<00:00, 1334551.27it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/142-20150327-TESEDSC_0.txt
# first
# 100%|##################################| 1259/1259 [00:00<00:00, 1710048.17it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/368-20150922-TESEMSC_0.txt
# first
# 100%|####################################| 627/627 [00:00<00:00, 1437064.81it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/239-20150413-TESEMSC_0.txt
# first
# 100%|####################################| 676/676 [00:00<00:00, 1503366.65it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/349-20150917-MONOGRAFIA_0.txt
# first
# 100%|####################################| 240/240 [00:00<00:00, 1185668.98it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/39-20141024-TESEMSC_0.txt
# first
# 100%|####################################| 371/371 [00:00<00:00, 1234989.51it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/139-20141210-MONOGRAFIA_0.txt
# first
# 100%|####################################| 226/226 [00:00<00:00, 1379785.60it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/70-20150519-MONOGRAFIA_0.txt
# first
# 100%|####################################| 579/579 [00:00<00:00, 1351420.15it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/342-20150331-TESEMSC_0.txt
# first
# 100%|####################################| 945/945 [00:00<00:00, 1239017.59it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/382-20160914-TESEMSC_0.txt
# first
# 100%|####################################| 484/484 [00:00<00:00, 1258551.23it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/185-20140922-MONOGRAFIA_0.txt
# first
# 100%|####################################| 346/346 [00:00<00:00, 1196396.69it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/81-20140908-MONOGRAFIA_0.txt
# first
# 100%|####################################| 216/216 [00:00<00:00, 1393799.48it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/315-20150504-TESEMSC_0.txt
# first
# 100%|####################################| 371/371 [00:00<00:00, 1106747.36it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/246-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 279/279 [00:00<00:00, 1581365.97it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/112-20141112-TESEMSC_0.txt
# first
# 100%|####################################| 685/685 [00:00<00:00, 1467363.76it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/214-20140922-TESEMSC_0.txt
# first
# 100%|####################################| 662/662 [00:00<00:00, 1412324.13it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/84-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 702/702 [00:00<00:00, 1607206.01it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/192-20141031-MONOGRAFIA_0.txt
# first
# 100%|####################################| 191/191 [00:00<00:00, 1472632.47it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/29-20150519-TESEDSC_0.txt
# first
# 100%|##################################| 1386/1386 [00:00<00:00, 1683552.08it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/195-20150918-MONOGRAFIA_1.txt
# first
# 100%|####################################| 325/325 [00:00<00:00, 1408211.57it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/148-20121113-TESEMSC_0.txt
# first
# 100%|####################################| 540/540 [00:00<00:00, 1629441.84it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/130-20140916-MONOGRAFIA_0.txt
# first
# 100%|####################################| 276/276 [00:00<00:00, 1493713.42it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/254-20140923-MONOGRAFIA_0.txt
# first
# 100%|####################################| 396/396 [00:00<00:00, 1374953.96it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/53-20140905-TESEDSC_0.txt
# first
# 100%|#######################################| 42/42 [00:00<00:00, 898779.43it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/184-20140922-MONOGRAFIA_0.txt
# first
# 100%|####################################| 218/218 [00:00<00:00, 1184401.91it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/356-20150407-MONOGRAFIA_0.txt
# first
# 100%|####################################| 414/414 [00:00<00:00, 1546252.77it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/402-20160914-MONOGRAFIA_0.txt
# first
# 100%|####################################| 379/379 [00:00<00:00, 1164572.32it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/45-20150519-MONOGRAFIA_0.txt
# first
# 100%|####################################| 402/402 [00:00<00:00, 1252682.18it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/188-20141103-MONOGRAFIA_1.txt
# first
# 100%|####################################| 302/302 [00:00<00:00, 1484970.47it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/344-20150401-TESEMSC_0.txt
# first
# 100%|####################################| 577/577 [00:00<00:00, 1265749.69it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/314-20150407-TESEMSC_0.txt
# first
# 100%|####################################| 579/579 [00:00<00:00, 1602971.63it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/257-20131211-MONOGRAFIA_0.txt
# first
# 100%|####################################| 337/337 [00:00<00:00, 1335992.86it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/12-20150123-MONOGRAFIA_0.txt
# first
# 100%|####################################| 121/121 [00:00<00:00, 1259331.97it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/20-20140904-TESEDSC_0.txt
# first
# 100%|##################################| 1364/1364 [00:00<00:00, 1428828.84it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/308-20150413-MONOGRAFIA_0.txt
# first
# 100%|####################################| 479/479 [00:00<00:00, 1260396.25it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/269-20150126-MONOGRAFIA_0.txt
# first
# 100%|####################################| 539/539 [00:00<00:00, 1546326.85it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/297-20150811-TESEMSC_0.txt
# first
# 100%|##################################| 1048/1048 [00:00<00:00, 1541244.95it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/212-20151203-TESEDSC_0.txt
# first
# 100%|####################################| 993/993 [00:00<00:00, 1680768.31it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/147-20141017-TESEMSC_0.txt
# first
# 100%|####################################| 633/633 [00:00<00:00, 1593634.11it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/220-20140916-TESEMSC_1.txt
# first
# 100%|####################################| 960/960 [00:00<00:00, 1444236.67it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/36-20140327-TESEMSC_0.txt
# first
# 100%|####################################| 978/978 [00:00<00:00, 1591167.30it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/199-20141029-MONOGRAFIA_0.txt
# first
# 100%|####################################| 253/253 [00:00<00:00, 1486216.96it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/307-20150413-MONOGRAFIA_0.txt
# first
# 100%|####################################| 411/411 [00:00<00:00, 1298086.55it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/117-20130513-TESEMSC_0.txt
# first
# 100%|####################################| 652/652 [00:00<00:00, 1616244.80it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/133-20151112-TESEDSC_0.txt
# first
# 100%|##################################| 1057/1057 [00:00<00:00, 1460269.87it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/358-20150303-TESEDSC_0.txt
# first
# 100%|##################################| 1678/1678 [00:00<00:00, 1628422.52it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/62-20150313-TESEDSC_0.txt
# first
# 100%|####################################| 728/728 [00:00<00:00, 1448507.26it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/306-20150409-TESEMSC_0.txt
# first
# 100%|##################################| 1222/1222 [00:00<00:00, 1477071.90it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/244-20150521-MONOGRAFIA_0.txt
# first
# 100%|####################################| 566/566 [00:00<00:00, 1611660.60it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/229-20150810-TESEMSC_0.txt
# first
# 100%|####################################| 860/860 [00:00<00:00, 1727539.00it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/198-20150909-MONOGRAFIA_0.txt
# first
# 100%|####################################| 387/387 [00:00<00:00, 1124096.71it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/97-20140928-MONOGRAFIA_0.txt
# first
# 100%|####################################| 783/783 [00:00<00:00, 1241640.84it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/327-20160725-MONOGRAFIA_0.txt
# first
# 100%|####################################| 608/608 [00:00<00:00, 1360798.74it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/396-20160722-MONOGRAFIA_0.txt
# first
# 100%|####################################| 549/549 [00:00<00:00, 1527984.67it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/85-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 206/206 [00:00<00:00, 1082740.13it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/159-20150811-MONOGRAFIA_0.txt
# first
# 100%|####################################| 297/297 [00:00<00:00, 1226090.83it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/407-20160614-MONOGRAFIA_0.txt
# first
# 100%|####################################| 675/675 [00:00<00:00, 1338607.66it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/162-20150811-MONOGRAFIA_0.txt
# first
# 100%|##################################| 1343/1343 [00:00<00:00, 1351475.59it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/6-20140908-MONOGRAFIA_0.txt
# first
# 100%|####################################| 263/263 [00:00<00:00, 1317923.48it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/310-20150413-MONOGRAFIA_0.txt
# first
# 100%|####################################| 685/685 [00:00<00:00, 1362303.58it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/119-20141209-TESEMSC_0.txt
# first
# 100%|####################################| 815/815 [00:00<00:00, 1545369.69it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/176-20141015-MONOGRAFIA_0.txt
# first
# 100%|####################################| 258/258 [00:00<00:00, 1464317.23it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/340-20160602-MONOGRAFIA_0.txt
# first
# 100%|####################################| 436/436 [00:00<00:00, 1573766.39it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/150-20141031-TESEDSC_0.txt
# first
# 100%|####################################| 932/932 [00:00<00:00, 1702565.91it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/134-20151209-TESEDSC_0.txt
# first
# 100%|#######################################| 16/16 [00:00<00:00, 406720.39it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/28-20150519-TESEDSC_0.txt
# first
# 100%|##################################| 1517/1517 [00:00<00:00, 1451690.43it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/296-20150819-MONOGRAFIA_0.txt
# first
# 100%|####################################| 298/298 [00:00<00:00, 1249902.59it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/0-20150121-TESEMSC_0.txt
# first
# 100%|####################################| 701/701 [00:00<00:00, 1614611.26it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/42-20141210-TESEMSC_0.txt
# first
# 100%|####################################| 775/775 [00:00<00:00, 1413912.83it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/48-20150126-MONOGRAFIA_0.txt
# first
# 100%|####################################| 398/398 [00:00<00:00, 1230164.33it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/136-20140804-MONOGRAFIA_0.txt
# first
# 100%|#######################################| 31/31 [00:00<00:00, 684333.81it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/87-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 288/288 [00:00<00:00, 1465970.33it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/258-20160602-TESEMSC_0.txt
# first
# 100%|####################################| 532/532 [00:00<00:00, 1416742.68it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/54-20141209-TESEDSC_0.txt
# first
# 100%|##################################| 1132/1132 [00:00<00:00, 1442708.03it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/271-20150810-MONOGRAFIA_0.txt
# first
# 100%|####################################| 562/562 [00:00<00:00, 1618955.25it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/232-20150409-MONOGRAFIA_0.txt
# first
# 100%|####################################| 541/541 [00:00<00:00, 1655082.76it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/386-20150902-MONOGRAFIA_0.txt
# first
# 100%|####################################| 778/778 [00:00<00:00, 1430586.81it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/350-20150909-TESEMSC_0.txt
# first
# 100%|####################################| 410/410 [00:00<00:00, 1276662.69it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/312-20150413-MONOGRAFIA_0.txt
# first
# 100%|####################################| 396/396 [00:00<00:00, 1197508.57it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/236-20140218-MONOGRAFIA_0.txt
# first
# 100%|####################################| 402/402 [00:00<00:00, 1621259.82it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/217-20140922-TESEMSC_0.txt
# first
# 100%|####################################| 728/728 [00:00<00:00, 1787736.13it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/18-20140905-TESEDSC_0.txt
# first
# 100%|##################################| 1181/1181 [00:00<00:00, 1465958.28it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/387-20160602-MONOGRAFIA_0.txt
# first
# 100%|####################################| 550/550 [00:00<00:00, 1663206.34it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/416-20160920-MONOGRAFIA_0.txt
# first
# 100%|####################################| 374/374 [00:00<00:00, 1168034.03it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/55-20141209-TESEMSC_0.txt
# first
# 100%|####################################| 623/623 [00:00<00:00, 1527207.13it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/311-20150413-MONOGRAFIA_0.txt
# first
# 100%|####################################| 690/690 [00:00<00:00, 1657542.82it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/33-20141126-TESEMSC_1.txt
# first
# 100%|####################################| 598/598 [00:00<00:00, 1667682.04it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/16-20150122-MONOGRAFIA_0.txt
# first
# 100%|####################################| 304/304 [00:00<00:00, 1496559.17it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/2-20150126-TESEDSC_0.txt
# first
# 100%|##################################| 1075/1075 [00:00<00:00, 1556395.17it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/317-20150703-TESEMSC_0.txt
# first
# 100%|####################################| 473/473 [00:00<00:00, 1776101.87it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/332-20140804-MONOGRAFIA_0.txt
# first
# 100%|####################################| 338/338 [00:00<00:00, 1391241.17it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/138-20141210-MONOGRAFIA_0.txt
# first
# 100%|####################################| 122/122 [00:00<00:00, 1107586.77it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/221-20140915-TESEMSC_0.txt
# first
# 100%|####################################| 859/859 [00:00<00:00, 1926688.31it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/167-20130501-MONOGRAFIA_0.txt
# first
# 100%|####################################| 372/372 [00:00<00:00, 1235376.95it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/156-20140925-TESEMSC_0.txt
# first
# 100%|####################################| 526/526 [00:00<00:00, 1487662.78it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/68-20150519-MONOGRAFIA_0.txt
# first
# 100%|####################################| 572/572 [00:00<00:00, 1267375.54it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/107-20121015-TESEMSC_0.txt
# first
# 100%|####################################| 974/974 [00:00<00:00, 1436951.14it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/38-20150210-TESEDSC_0.txt
# first
# 100%|####################################| 474/474 [00:00<00:00, 1644416.95it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/252-20140916-MONOGRAFIA_0.txt
# first
# 100%|####################################| 655/655 [00:00<00:00, 1480209.66it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/206-20130226-TESEMSC_0.txt
# first
# 100%|####################################| 363/363 [00:00<00:00, 1505966.72it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/145-20140924-MONOGRAFIA_0.txt
# first
# 100%|####################################| 342/342 [00:00<00:00, 1396739.99it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/355-20150702-MONOGRAFIA_0.txt
# first
# 100%|####################################| 279/279 [00:00<00:00, 1195312.38it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/326-20150810-MONOGRAFIA_0.txt
# first
# 100%|####################################| 308/308 [00:00<00:00, 1505647.59it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/334-20150521-MONOGRAFIA_0.txt
# first
# 100%|####################################| 769/769 [00:00<00:00, 1800904.40it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/57-20150519-TESEMSC_0.txt
# first
# 100%|####################################| 784/784 [00:00<00:00, 1314282.31it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/233-20150409-TESEMSC_0.txt
# first
# 100%|##################################| 1239/1239 [00:00<00:00, 1402251.12it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/69-20150519-MONOGRAFIA_0.txt
# first
# 100%|####################################| 424/424 [00:00<00:00, 1392627.17it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/227-20150810-MONOGRAFIA_0.txt
# first
# 100%|####################################| 345/345 [00:00<00:00, 1651866.30it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/390-20150326-MONOGRAFIA_1.txt
# first
# 100%|####################################| 615/615 [00:00<00:00, 1421210.45it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/367-20150326-MONOGRAFIA_0.txt
# first
# 100%|####################################| 152/152 [00:00<00:00, 1472365.38it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/409-20150727-MONOGRAFIA_0.txt
# first
# 100%|####################################| 284/284 [00:00<00:00, 1504018.10it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/247-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 302/302 [00:00<00:00, 1219133.60it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/203-20140929-MONOGRAFIA_0.txt
# first
# 100%|####################################| 264/264 [00:00<00:00, 1335701.15it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/352-20160914-MONOGRAFIA_0.txt
# first
# 100%|####################################| 195/195 [00:00<00:00, 1181920.92it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/320-20150513-TESEMSC_0.txt
# first
# 100%|####################################| 679/679 [00:00<00:00, 1727066.35it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/73-20140916-MONOGRAFIA_0.txt
# first
# 100%|####################################| 603/603 [00:00<00:00, 1606839.46it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/267-20150709-MONOGRAFIA_0.txt
# first
# 100%|####################################| 265/265 [00:00<00:00, 1279045.52it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/253-20131018-TESEMSC_0.txt
# first
# 100%|####################################| 418/418 [00:00<00:00, 1362252.58it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/202-20140404-MONOGRAFIA_0.txt
# first
# 100%|####################################| 162/162 [00:00<00:00, 1020236.11it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/397-20160915-MONOGRAFIA_1.txt
# first
# 100%|####################################| 409/409 [00:00<00:00, 1874830.97it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/163-20140917-MONOGRAFIA_0.txt
# first
# 100%|####################################| 246/246 [00:00<00:00, 1589828.63it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/248-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 521/521 [00:00<00:00, 1284675.12it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/58-20150519-MONOGRAFIA_0.txt
# first
# 100%|####################################| 315/315 [00:00<00:00, 1633134.44it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/401-20160725-MONOGRAFIA_0.txt
# first
# 100%|#########################################| 9/9 [00:00<00:00, 251658.24it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/251-20141023-MONOGRAFIA_0.txt
# first
# 100%|####################################| 198/198 [00:00<00:00, 1414773.75it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/125-20141210-MONOGRAFIA_0.txt
# first
# 100%|#######################################| 10/10 [00:00<00:00, 325139.84it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/191-20130320-TESEMSC_0.txt
# first
# 100%|####################################| 731/731 [00:00<00:00, 1660908.03it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/208-20150407-MONOGRAFIA_0.txt
# first
# 100%|####################################| 225/225 [00:00<00:00, 1103764.21it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/75-20141125-MONOGRAFIA_0.txt
# first
# 100%|####################################| 235/235 [00:00<00:00, 1693576.36it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/174-20141015-MONOGRAFIA_1.txt
# first
# 100%|####################################| 343/343 [00:00<00:00, 1593185.24it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/31-20140915-TESEDSC_0.txt
# first
# 100%|####################################| 476/476 [00:00<00:00, 1677721.60it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/341-20150811-MONOGRAFIA_0.txt
# first
# 100%|####################################| 257/257 [00:00<00:00, 1495057.04it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/158-20150811-TESEMSC_0.txt
# first
# 100%|####################################| 784/784 [00:00<00:00, 1800840.27it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/249-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 862/862 [00:00<00:00, 1490923.73it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/333-20150528-TESEDSC_0.txt
# first
# 100%|####################################| 611/611 [00:00<00:00, 1640665.65it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/272-20141204-MONOGRAFIA_0.txt
# first
# 100%|####################################| 259/259 [00:00<00:00, 1373356.18it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/111-20140908-TESEMSC_0.txt
# first
# 100%|####################################| 267/267 [00:00<00:00, 1269704.27it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/395-20160722-MONOGRAFIA_0.txt
# first
# 100%|#######################################| 19/19 [00:00<00:00, 457998.71it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/255-20150506-MONOGRAFIA_0.txt
# first
# 100%|####################################| 414/414 [00:00<00:00, 1331627.19it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/66-20140905-TESEMSC_0.txt
# first
# 100%|####################################| 650/650 [00:00<00:00, 1715731.66it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/278-20140924-MONOGRAFIA_0.txt
# first
# 100%|####################################| 590/590 [00:00<00:00, 1731728.03it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/398-20160721-MONOGRAFIA_0.txt
# first
# 100%|####################################| 428/428 [00:00<00:00, 1465438.46it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/76-20141210-TESEMSC_0.txt
# first
# 100%|####################################| 592/592 [00:00<00:00, 1318655.32it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/400-20160721-MONOGRAFIA_0.txt
# first
# 100%|####################################| 261/261 [00:00<00:00, 1196408.03it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/345-20150331-MONOGRAFIA_0.txt
# first
# 100%|####################################| 232/232 [00:00<00:00, 1180920.54it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/82-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 384/384 [00:00<00:00, 1257308.93it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/218-20150327-TESEDSC_0.txt
# first
# 100%|####################################| 660/660 [00:00<00:00, 1555191.37it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/362-20140922-MONOGRAFIA_0.txt
# first
# 100%|####################################| 204/204 [00:00<00:00, 1345342.79it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/65-20141024-TESEMSC_0.txt
# first
# 100%|####################################| 565/565 [00:00<00:00, 1364295.77it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/52-20140910-MONOGRAFIA_0.txt
# first
# 100%|####################################| 449/449 [00:00<00:00, 1163213.40it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/24-20150122-MONOGRAFIA_0.txt
# first
# 100%|####################################| 634/634 [00:00<00:00, 1654753.41it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/404-20160721-MONOGRAFIA_0.txt
# first
# 100%|####################################| 481/481 [00:00<00:00, 1678419.49it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/222-20141015-TESEMSC_1.txt
# first
# 100%|####################################| 750/750 [00:00<00:00, 1451651.13it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/60-20150507-TESEDSC_0.txt
# first
# 100%|##################################| 1129/1129 [00:00<00:00, 1741584.85it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/124-20121105-MONOGRAFIA_0.txt
# first
# 100%|####################################| 471/471 [00:00<00:00, 1569116.11it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/242-20140530-TESEMSC_0.txt
# first
# 100%|##################################| 1908/1908 [00:00<00:00, 1702346.74it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/303-20150917-TESEMSC_0.txt
# first
# 100%|####################################| 861/861 [00:00<00:00, 1890730.76it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/181-20140922-MONOGRAFIA_0.txt
# first
# 100%|####################################| 212/212 [00:00<00:00, 1494441.09it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/302-20150811-TESEMSC_0.txt
# first
# 100%|##################################| 1222/1222 [00:00<00:00, 1572703.13it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/280-20150325-MONOGRAFIA_0.txt
# first
# 100%|####################################| 726/726 [00:00<00:00, 1337314.32it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/98-20140331-TESEDSC_0.txt
# first
# 100%|######################################| 58/58 [00:00<00:00, 1180920.54it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/7-20140908-TESEMSC_0.txt
# first
# 100%|####################################| 361/361 [00:00<00:00, 1361640.06it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/282-20150810-MONOGRAFIA_0.txt
# first
# 100%|####################################| 585/585 [00:00<00:00, 1590193.03it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/146-20121107-TESEMSC_0.txt
# first
# 100%|####################################| 598/598 [00:00<00:00, 1556917.31it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/403-20160722-MONOGRAFIA_0.txt
# first
# 100%|####################################| 350/350 [00:00<00:00, 1180069.45it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/183-20140922-MONOGRAFIA_0.txt
# first
# 100%|####################################| 367/367 [00:00<00:00, 1165260.84it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/224-20141023-MONOGRAFIA_0.txt
# first
# 100%|####################################| 387/387 [00:00<00:00, 1304819.65it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/115-20121011-MONOGRAFIA_0.txt
# first
# 100%|####################################| 411/411 [00:00<00:00, 1440149.49it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/77-20141209-TESEMSC_0.txt
# first
# 100%|####################################| 461/461 [00:00<00:00, 1626218.79it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/279-20140530-MONOGRAFIA_0.txt
# first
# 100%|####################################| 248/248 [00:00<00:00, 1229535.92it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/263-20141003-MONOGRAFIA_0.txt
# first
# 100%|####################################| 267/267 [00:00<00:00, 1344392.76it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/389-20160608-TESEMSC_0.txt
# first
# 100%|####################################| 749/749 [00:00<00:00, 1264198.67it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/228-20150810-TESEMSC_0.txt
# first
# 100%|####################################| 922/922 [00:00<00:00, 1457651.07it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/25-20150123-MONOGRAFIA_0.txt
# first
# 100%|####################################| 469/469 [00:00<00:00, 1182168.62it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/34-20141113-TESEMSC_0.txt
# first
# 100%|######################################| 78/78 [00:00<00:00, 1422416.14it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/351-20141016-MONOGRAFIA_0.txt
# first
# 100%|####################################| 242/242 [00:00<00:00, 1382863.17it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/399-20160722-MONOGRAFIA_0.txt
# first
# 100%|####################################| 379/379 [00:00<00:00, 1637117.63it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/160-20150811-MONOGRAFIA_0.txt
# first
# 100%|####################################| 682/682 [00:00<00:00, 1565689.83it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/91-20150519-MONOGRAFIA_0.txt
# first
# 100%|####################################| 701/701 [00:00<00:00, 1434247.37it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/11-20150121-TESEMSC_0.txt
# first
# 100%|####################################| 574/574 [00:00<00:00, 1375731.71it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/347-20160623-TESEDSC_0.txt
# first
# 100%|##################################| 1133/1133 [00:00<00:00, 1451037.08it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/209-20150513-MONOGRAFIA_0.txt
# first
# 100%|####################################| 806/806 [00:00<00:00, 1671913.46it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/413-20150922-TESEMSC_0.txt
# first
# 100%|####################################| 348/348 [00:00<00:00, 1185717.13it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/186-20121206-TESEDSC_1.txt
# first
# 100%|####################################| 940/940 [00:00<00:00, 1781584.17it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/14-20150519-TESEMSC_0.txt
# first
# 100%|####################################| 599/599 [00:00<00:00, 1776794.98it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/415-20160623-TESEMSC_0.txt
# first
# 100%|####################################| 816/816 [00:00<00:00, 1666286.30it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/193-20141216-TESEDSC_0.txt
# first
# 100%|####################################| 694/694 [00:00<00:00, 1773825.09it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/123-20140128-TESEMSC_0.txt
# first
# 100%|####################################| 464/464 [00:00<00:00, 1471018.18it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/265-20141024-MONOGRAFIA_0.txt
# first
# 100%|####################################| 289/289 [00:00<00:00, 1616205.14it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/121-20121130-MONOGRAFIA_0.txt
# first
# 100%|####################################| 244/244 [00:00<00:00, 2002759.64it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/286-20140827-MONOGRAFIA_0.txt
# first
# 100%|####################################| 262/262 [00:00<00:00, 1136409.15it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/114-20121011-MONOGRAFIA_0.txt
# first
# 100%|####################################| 314/314 [00:00<00:00, 1223988.34it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/226-20150810-MONOGRAFIA_0.txt
# first
# 100%|####################################| 328/328 [00:00<00:00, 1263298.17it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/41-20141210-TESEMSC_0.txt
# first
# 100%|####################################| 775/775 [00:00<00:00, 1324607.01it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/294-20150923-TESEMSC_0.txt
# first
# 100%|####################################| 783/783 [00:00<00:00, 1305821.09it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/284-20150917-MONOGRAFIA_0.txt
# first
# 100%|####################################| 425/425 [00:00<00:00, 1385065.42it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/128-20140912-MONOGRAFIA_1.txt
# first
# 100%|####################################| 305/305 [00:00<00:00, 1270370.13it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/343-20150401-TESEMSC_0.txt
# first
# 100%|####################################| 917/917 [00:00<00:00, 1624230.05it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/157-20140925-TESEMSC_0.txt
# first
# 100%|####################################| 500/500 [00:00<00:00, 1803226.14it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/381-20160602-TESEMSC_0.txt
# first
# 100%|####################################| 458/458 [00:00<00:00, 1691013.41it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/211-20141112-MONOGRAFIA_0.txt
# first
# ...
# first
# 100%|####################################| 285/285 [00:00<00:00, 1401379.41it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/93-20140923-TESEDSC_0.txt
# first
# 100%|##################################| 1082/1082 [00:00<00:00, 1591805.31it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/207-20131205-TESEMSC_0.txt
# first
# 100%|####################################| 507/507 [00:00<00:00, 1446606.89it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/108-20121011-TESEMSC_0.txt
# first
# 100%|####################################| 205/205 [00:00<00:00, 1197538.05it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/99-20160921-TESEMSC_0.txt
# first
# 100%|####################################| 573/573 [00:00<00:00, 1683008.54it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/305-20160928-MONOGRAFIA_0.txt
# first
# 100%|####################################| 647/647 [00:00<00:00, 1411188.09it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/101-20151215-MONOGRAFIA_0.txt
# first
# 100%|####################################| 305/305 [00:00<00:00, 1556280.68it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/359-20150729-TESEMSC_0.txt
# first
# 100%|####################################| 924/924 [00:00<00:00, 1645663.23it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/298-20150528-TESEMSC_0.txt
# first
# 100%|####################################| 974/974 [00:00<00:00, 1350496.56it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/71-20141222-TESEDSC_0.txt
# first
# 100%|##################################| 1367/1367 [00:00<00:00, 1279538.85it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/152-20140917-MONOGRAFIA_0.txt
# first
# 100%|####################################| 582/582 [00:00<00:00, 1359935.89it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/240-20140220-MONOGRAFIA_0.txt
# first
# 100%|####################################| 451/451 [00:00<00:00, 1535414.86it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/385-20160713-MONOGRAFIA_0.txt
# first
# 100%|####################################| 410/410 [00:00<00:00, 1626929.65it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/273-20140930-MONOGRAFIA_0.txt
# first
# 100%|####################################| 192/192 [00:00<00:00, 1566743.91it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/391-20160914-MONOGRAFIA_0.txt
# first
# 100%|####################################| 253/253 [00:00<00:00, 1080609.89it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/235-20131018-MONOGRAFIA_0.txt
# first
# 100%|####################################| 286/286 [00:00<00:00, 1292641.10it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/270-20150126-MONOGRAFIA_0.txt
# first
# 100%|####################################| 444/444 [00:00<00:00, 1221161.30it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/17-20150121-MONOGRAFIA_0.txt
# first
# 100%|####################################| 241/241 [00:00<00:00, 1460733.04it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/171-20141015-MONOGRAFIA_1.txt
# first
# 100%|####################################| 361/361 [00:00<00:00, 1631620.41it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/241-20140227-MONOGRAFIA_0.txt
# first
# 100%|####################################| 256/256 [00:00<00:00, 1287460.22it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/190-20140204-TESEMSC_0.txt
# first
# 100%|##################################| 2153/2153 [00:00<00:00, 1783594.02it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/64-20141024-TESEDSC_0.txt
# first
# 100%|##################################| 1921/1921 [00:00<00:00, 1641323.69it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/319-20150702-TESEMSC_0.txt
# first
# 100%|####################################| 347/347 [00:00<00:00, 1604656.55it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/339-20160602-TESEMSC_0.txt
# first
# 100%|####################################| 603/603 [00:00<00:00, 1574822.73it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/19-20140916-TESEDSC_0.txt
# first
# 100%|##################################| 1932/1932 [00:00<00:00, 1540569.45it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/132-20140916-TESEMSC_0.txt
# first
# 100%|####################################| 676/676 [00:00<00:00, 1728871.65it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/59-20150903-TESEMSC_0.txt
# first
# 100%|#######################################| 22/22 [00:00<00:00, 591504.41it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/219-20141031-MONOGRAFIA_0.txt
# first
# 100%|####################################| 325/325 [00:00<00:00, 1786564.61it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/260-20140804-MONOGRAFIA_0.txt
# first
# 100%|####################################| 847/847 [00:00<00:00, 1808846.99it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/189-20150410-TESEMSC_0.txt
# first
# 100%|#######################################| 30/30 [00:00<00:00, 530924.56it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/411-20150702-MONOGRAFIA_0.txt
# first
# 100%|####################################| 347/347 [00:00<00:00, 1594111.16it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/261-20140916-MONOGRAFIA_1.txt
# first
# 100%|####################################| 623/623 [00:00<00:00, 1300672.67it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/168-20121220-MONOGRAFIA_0.txt
# first
# 100%|##################################| 1146/1146 [00:00<00:00, 1812470.73it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/234-20150409-TESEMSC_0.txt
# first
# 100%|####################################| 588/588 [00:00<00:00, 1382427.55it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/309-20150408-MONOGRAFIA_0.txt
# first
# 100%|##################################| 1169/1169 [00:00<00:00, 1729503.13it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/89-20141112-TESEDSC_0.txt
# first
# 100%|##################################| 1514/1514 [00:00<00:00, 1597930.61it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/88-20140908-MONOGRAFIA_0.txt
# first
# 100%|####################################| 591/591 [00:00<00:00, 1505974.28it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/51-20140924-MONOGRAFIA_0.txt
# first
# 100%|####################################| 283/283 [00:00<00:00, 1223699.00it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/120-20121105-TESEMSC_0.txt
# first
# 100%|##################################| 1308/1308 [00:00<00:00, 1360989.74it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/408-20160614-MONOGRAFIA_0.txt
# first
# 100%|####################################| 523/523 [00:00<00:00, 1464366.48it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/79-20140905-TESEDSC_0.txt
# first
# 100%|####################################| 656/656 [00:00<00:00, 1448138.64it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/182-20140922-MONOGRAFIA_0.txt
# first
# 100%|####################################| 167/167 [00:00<00:00, 1224560.78it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/44-20150519-MONOGRAFIA_0.txt
# first
# 100%|####################################| 489/489 [00:00<00:00, 1514781.87it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/116-20141209-TESEMSC_0.txt
# first
# 100%|####################################| 467/467 [00:00<00:00, 1531462.05it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/4-20140915-TESEDSC_0.txt
# first
# 100%|####################################| 877/877 [00:00<00:00, 1462005.01it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/175-20141015-MONOGRAFIA_1.txt
# first
# 100%|####################################| 514/514 [00:00<00:00, 1516084.57it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/177-20141015-MONOGRAFIA_1.txt
# first
# 100%|####################################| 354/354 [00:00<00:00, 1518183.66it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/335-20150521-MONOGRAFIA_0.txt
# first
# 100%|####################################| 645/645 [00:00<00:00, 1489717.00it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/383-20160614-TESEDSC_0.txt
# first
# 100%|####################################| 676/676 [00:00<00:00, 1503366.65it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/313-20150917-TESEMSC_0.txt
# first
# 100%|####################################| 519/519 [00:00<00:00, 1450262.34it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/151-20140917-MONOGRAFIA_0.txt
# first
# 100%|####################################| 379/379 [00:00<00:00, 1268668.17it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/210-20141229-MONOGRAFIA_0.txt
# first
# 100%|####################################| 736/736 [00:00<00:00, 1538887.21it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/22-20150122-MONOGRAFIA_0.txt
# first
# 100%|####################################| 215/215 [00:00<00:00, 1306920.81it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/406-20160602-MONOGRAFIA_0.txt
# first
# 100%|####################################| 926/926 [00:00<00:00, 1614937.84it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/27-20150519-MONOGRAFIA_0.txt
# first
# 100%|####################################| 989/989 [00:00<00:00, 1626094.34it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/250-20140218-TESEMSC_0.txt
# first
# 100%|####################################| 724/724 [00:00<00:00, 1330708.19it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/379-20160809-TESEMSC_0.txt
# first
# 100%|####################################| 980/980 [00:00<00:00, 1349447.77it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/61-20150609-TESEDSC_0.txt
# first
# 100%|####################################| 636/636 [00:00<00:00, 1349305.69it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/277-20141016-MONOGRAFIA_0.txt
# first
# 100%|####################################| 434/434 [00:00<00:00, 1453936.05it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/274-20140915-MONOGRAFIA_0.txt
# first
# 100%|####################################| 456/456 [00:00<00:00, 1612649.77it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/348-20160602-TESEDSC_0.txt
# first
# 100%|##################################| 1256/1256 [00:00<00:00, 1603178.89it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/74-20140924-TESEMSC_0.txt
# first
# 100%|####################################| 776/776 [00:00<00:00, 1754598.33it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/418-20160701-TESEMSC_0.txt
# first
# 100%|####################################| 514/514 [00:00<00:00, 1585200.19it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/299-20150521-TESEMSC_1.txt
# first
# 100%|##################################| 1095/1095 [00:00<00:00, 1663441.83it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/360-20160602-MONOGRAFIA_0.txt
# first
# 100%|####################################| 430/430 [00:00<00:00, 1374657.56it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/328-20140905-MONOGRAFIA_0.txt
# first
# 100%|####################################| 257/257 [00:00<00:00, 1520361.25it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/26-20150121-MONOGRAFIA_0.txt
# first
# 100%|####################################| 527/527 [00:00<00:00, 1664456.48it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/170-20130607-TESEMSC_0.txt
# first
# 100%|####################################| 704/704 [00:00<00:00, 1785241.85it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/292-20150326-MONOGRAFIA_0.txt
# first
# 100%|####################################| 174/174 [00:00<00:00, 1154760.91it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/204-20140404-TESEMSC_0.txt
# first
# 100%|####################################| 383/383 [00:00<00:00, 1369495.68it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/323-20140905-MONOGRAFIA_0.txt
# first
# 100%|####################################| 409/409 [00:00<00:00, 1544077.71it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/336-20150902-TESEMSC_0.txt
# first
# 100%|####################################| 866/866 [00:00<00:00, 1356842.46it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/275-20140915-MONOGRAFIA_0.txt
# first
# 100%|####################################| 216/216 [00:00<00:00, 1535541.80it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/283-20150917-MONOGRAFIA_0.txt
# first
# 100%|####################################| 479/479 [00:00<00:00, 1413843.50it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/238-20141015-MONOGRAFIA_1.txt
# first
# 100%|####################################| 473/473 [00:00<00:00, 1580801.43it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/166-20160602-MONOGRAFIA_0.txt
# first
# 100%|####################################| 735/735 [00:00<00:00, 1328226.39it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/268-20140506-TESEMSC_0.txt
# first
# 100%|####################################| 865/865 [00:00<00:00, 1610329.76it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/417-20160914-TESEMSC_0.txt
# first
# 100%|####################################| 597/597 [00:00<00:00, 1462616.52it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/127-20140924-MONOGRAFIA_0.txt
# first
# 100%|####################################| 655/655 [00:00<00:00, 1682344.84it/s]
# loading file: ../../NLP/Datasets/400_tesis/Tokenization_jose_11_01_21/Tornando_output/106-20141201-TESEDSC_0.txt
# first
# 100%|####################################| 161/161 [00:00<00:00, 1205862.40it/s]

# %%
text = "A caracterização estrutural para a porção norte da Bacia de Pelotas foi realizada através de 17 seções sísmicas, onde foram caracterizadas falhas normais, em padrão dominó, falhas sintéticas e antitéticas e lístricas, além da identificação de estruturas como o Arco de Torres (Fonseca 2006), (Alves 1981) a Plataforma de Florianópolis individualizada por sr. Gonçalves et al. (1979), Zona de Falha do Rio Grande (Miranda 1970), (Kowsmann 1974).."

# %%
from stanza import Pipeline
tok_nlp = Pipeline(lang='pt',
                   tokenize_pretokenized=False,
                   use_gpu=True,
#                    processors='mwt,tokenize,pos,lemma,depparse',
                   depparse_model_path="./models/pt_bosquepetrolesoeg_parser.pt")
# Out:
# 2021-04-29 17:40:59 INFO: Loading these models for language: pt (Portuguese):
# =======================================
# | Processor | Package                 |
# ---------------------------------------
# | tokenize  | bosque                  |
# | mwt       | bosque                  |
# | pos       | bosque                  |
# | lemma     | bosque                  |
# | depparse  | ./models/p..._parser.pt |
# =======================================
#
# 2021-04-29 17:40:59 INFO: Use device: cpu
# 2021-04-29 17:40:59 INFO: Loading: tokenize
# 2021-04-29 17:40:59 INFO: Loading: mwt
# 2021-04-29 17:40:59 INFO: Loading: pos
# 2021-04-29 17:41:00 INFO: Loading: lemma
# 2021-04-29 17:41:00 INFO: Loading: depparse
# 2021-04-29 17:41:01 INFO: Done loading processors!

# %%
tok_nlp(text)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "A",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "misc": "start_char=0|end_char=1"
#     },
#     {
#       "id": 2,
#       "text": "caracterização",
#       "lemma": "caracterização",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 14,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=2|end_char=16"
#     },
#     {
#       "id": 3,
#       "text": "estrutural",
#       "lemma": "estrutural",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "amod",
#       "misc": "start_char=17|end_char=27"
#     },
#     {
#       "id": 4,
#       "text": "para",
#       "lemma": "para",
#       "upos": "ADP",
#       "head": 6,
#       "deprel": "case",
#       "misc": "start_char=28|end_char=32"
#     },
#     {
#       "id": 5,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "misc": "start_char=33|end_char=34"
#     },
#     {
#       "id": 6,
#       "text": "porção",
#       "lemma": "porção",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "nmod",
#       "misc": "start_char=35|end_char=41"
#     },
#     {
#       "id": 7,
#       "text": "norte",
#       "lemma": "norte",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 6,
#       "deprel": "amod",
#       "misc": "start_char=42|end_char=47"
#     },
#     {
#       "id": [
#         8,
#         9
#       ],
#       "text": "da",
#       "misc": "start_char=48|end_char=50"
#     },
#     {
#       "id": 8,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 10,
#       "deprel": "case"
#     },
#     {
#       "id": 9,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 10,
#       "deprel": "det"
#     },
#     {
#       "id": 10,
#       "text": "Bacia",
#       "lemma": "bacia",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 6,
#       "deprel": "nmod",
#       "misc": "start_char=51|end_char=56"
#     },
#     {
#       "id": 11,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 10,
#       "deprel": "flat:name",
#       "misc": "start_char=57|end_char=59"
#     },
#     {
#       "id": 12,
#       "text": "Pelotas",
#       "lemma": "Pelotas",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "flat:name",
#       "misc": "start_char=60|end_char=67"
#     },
#     {
#       "id": 13,
#       "text": "foi",
#       "lemma": "ser",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 14,
#       "deprel": "aux:pass",
#       "misc": "start_char=68|end_char=71"
#     },
#     {
#       "id": 14,
#       "text": "realizada",
#       "lemma": "realizar",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=72|end_char=81"
#     },
#     {
#       "id": 15,
#       "text": "através",
#       "lemma": "através",
#       "upos": "ADV",
#       "head": 14,
#       "deprel": "advmod",
#       "misc": "start_char=82|end_char=89"
#     },
#     {
#       "id": 16,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 18,
#       "deprel": "case",
#       "misc": "start_char=90|end_char=92"
#     },
#     {
#       "id": 17,
#       "text": "17",
#       "lemma": "17",
#       "upos": "NUM",
#       "feats": "NumType=Card",
#       "head": 18,
#       "deprel": "nummod",
#       "misc": "start_char=93|end_char=95"
#     },
#     {
#       "id": 18,
#       "text": "seções",
#       "lemma": "seção",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 15,
#       "deprel": "obl",
#       "misc": "start_char=96|end_char=102"
#     },
#     {
#       "id": 19,
#       "text": "sísmicas",
#       "lemma": "sísmico",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 18,
#       "deprel": "amod",
#       "misc": "start_char=103|end_char=111"
#     },
#     {
#       "id": 20,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=111|end_char=112"
#     },
#     {
#       "id": 21,
#       "text": "onde",
#       "lemma": "onde",
#       "upos": "PRON",
#       "feats": "Gender=Fem|Number=Sing|PronType=Rel",
#       "head": 23,
#       "deprel": "obl",
#       "misc": "start_char=113|end_char=117"
#     },
#     {
#       "id": 22,
#       "text": "foram",
#       "lemma": "ser",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Plur|Person=3|VerbForm=Fin",
#       "head": 23,
#       "deprel": "aux:pass",
#       "misc": "start_char=118|end_char=123"
#     },
#     {
#       "id": 23,
#       "text": "caracterizadas",
#       "lemma": "caracterizar",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Plur|VerbForm=Part|Voice=Pass",
#       "head": 18,
#       "deprel": "acl:relcl",
#       "misc": "start_char=124|end_char=138"
#     },
#     {
#       "id": 24,
#       "text": "falhas",
#       "lemma": "falha",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 23,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=139|end_char=145"
#     },
#     {
#       "id": 25,
#       "text": "normais",
#       "lemma": "normal",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 24,
#       "deprel": "amod",
#       "misc": "start_char=146|end_char=153"
#     },
#     {
#       "id": 26,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 28,
#       "deprel": "punct",
#       "misc": "start_char=153|end_char=154"
#     },
#     {
#       "id": 27,
#       "text": "em",
#       "lemma": "em",
#       "upos": "ADP",
#       "head": 28,
#       "deprel": "case",
#       "misc": "start_char=155|end_char=157"
#     },
#     {
#       "id": 28,
#       "text": "padrão",
#       "lemma": "padrão",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 24,
#       "deprel": "nmod",
#       "misc": "start_char=158|end_char=164"
#     },
#     {
#       "id": 29,
#       "text": "dominó",
#       "lemma": "dominó",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 28,
#       "deprel": "amod",
#       "misc": "start_char=165|end_char=171"
#     },
#     {
#       "id": 30,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 31,
#       "deprel": "punct",
#       "misc": "start_char=171|end_char=172"
#     },
#     {
#       "id": 31,
#       "text": "falhas",
#       "lemma": "falha",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 24,
#       "deprel": "conj",
#       "misc": "start_char=173|end_char=179"
#     },
#     {
#       "id": 32,
#       "text": "sintéticas",
#       "lemma": "sintético",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 31,
#       "deprel": "amod",
#       "misc": "start_char=180|end_char=190"
#     },
#     {
#       "id": 33,
#       "text": "e",
#       "lemma": "e",
#       "upos": "CCONJ",
#       "head": 34,
#       "deprel": "cc",
#       "misc": "start_char=191|end_char=192"
#     },
#     {
#       "id": 34,
#       "text": "antitéticas",
#       "lemma": "antitético",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 32,
#       "deprel": "conj",
#       "misc": "start_char=193|end_char=204"
#     },
#     {
#       "id": 35,
#       "text": "e",
#       "lemma": "e",
#       "upos": "CCONJ",
#       "head": 36,
#       "deprel": "cc",
#       "misc": "start_char=205|end_char=206"
#     },
#     {
#       "id": 36,
#       "text": "lístricas",
#       "lemma": "lístrico",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 32,
#       "deprel": "conj",
#       "misc": "start_char=207|end_char=216"
#     },
#     {
#       "id": 37,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 41,
#       "deprel": "punct",
#       "misc": "start_char=216|end_char=217"
#     },
#     {
#       "id": 38,
#       "text": "além",
#       "lemma": "além",
#       "upos": "ADV",
#       "head": 41,
#       "deprel": "cc",
#       "misc": "start_char=218|end_char=222"
#     },
#     {
#       "id": [
#         39,
#         40
#       ],
#       "text": "da",
#       "misc": "start_char=223|end_char=225"
#     },
#     {
#       "id": 39,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 38,
#       "deprel": "fixed"
#     },
#     {
#       "id": 40,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 41,
#       "deprel": "det"
#     },
#     {
#       "id": 41,
#       "text": "identificação",
#       "lemma": "identificação",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 24,
#       "deprel": "conj",
#       "misc": "start_char=226|end_char=239"
#     },
#     {
#       "id": 42,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 43,
#       "deprel": "case",
#       "misc": "start_char=240|end_char=242"
#     },
#     {
#       "id": 43,
#       "text": "estruturas",
#       "lemma": "estrutura",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 41,
#       "deprel": "nmod",
#       "misc": "start_char=243|end_char=253"
#     },
#     {
#       "id": 44,
#       "text": "como",
#       "lemma": "como",
#       "upos": "ADP",
#       "head": 46,
#       "deprel": "case",
#       "misc": "start_char=254|end_char=258"
#     },
#     {
#       "id": 45,
#       "text": "o",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 46,
#       "deprel": "det",
#       "misc": "start_char=259|end_char=260"
#     },
#     {
#       "id": 46,
#       "text": "Arco",
#       "lemma": "Arco",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 43,
#       "deprel": "nmod:appos",
#       "misc": "start_char=261|end_char=265"
#     },
#     {
#       "id": 47,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 46,
#       "deprel": "flat:name",
#       "misc": "start_char=266|end_char=268"
#     },
#     {
#       "id": 48,
#       "text": "Torres",
#       "lemma": "Torres",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 46,
#       "deprel": "flat:name",
#       "misc": "start_char=269|end_char=275"
#     },
#     {
#       "id": 49,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 50,
#       "deprel": "punct",
#       "misc": "start_char=276|end_char=277"
#     },
#     {
#       "id": 50,
#       "text": "Fonseca",
#       "lemma": "Fonseca",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 46,
#       "deprel": "appos",
#       "misc": "start_char=277|end_char=284"
#     },
#     {
#       "id": 51,
#       "text": "2006",
#       "lemma": "2006",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 50,
#       "deprel": "flat:name",
#       "misc": "start_char=285|end_char=289"
#     },
#     {
#       "id": 52,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 50,
#       "deprel": "punct",
#       "misc": "start_char=289|end_char=290"
#     },
#     {
#       "id": 53,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 55,
#       "deprel": "punct",
#       "misc": "start_char=290|end_char=291"
#     },
#     {
#       "id": 54,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 55,
#       "deprel": "punct",
#       "misc": "start_char=292|end_char=293"
#     },
#     {
#       "id": 55,
#       "text": "Alves",
#       "lemma": "Alves",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 46,
#       "deprel": "appos",
#       "misc": "start_char=293|end_char=298"
#     },
#     {
#       "id": 56,
#       "text": "1981",
#       "lemma": "1981",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 55,
#       "deprel": "flat:name",
#       "misc": "start_char=299|end_char=303"
#     },
#     {
#       "id": 57,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 55,
#       "deprel": "punct",
#       "misc": "start_char=303|end_char=304"
#     },
#     {
#       "id": 58,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 59,
#       "deprel": "det",
#       "misc": "start_char=305|end_char=306"
#     },
#     {
#       "id": 59,
#       "text": "Plataforma",
#       "lemma": "Plataforma",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 46,
#       "deprel": "conj",
#       "misc": "start_char=307|end_char=317"
#     },
#     {
#       "id": 60,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 59,
#       "deprel": "flat:name",
#       "misc": "start_char=318|end_char=320"
#     },
#     {
#       "id": 61,
#       "text": "Florianópolis",
#       "lemma": "Florianópolis",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "flat:name",
#       "misc": "start_char=321|end_char=334"
#     },
#     {
#       "id": 62,
#       "text": "individualizada",
#       "lemma": "individualizar",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass",
#       "head": 59,
#       "deprel": "acl",
#       "misc": "start_char=335|end_char=350"
#     },
#     {
#       "id": 63,
#       "text": "por",
#       "lemma": "por",
#       "upos": "ADP",
#       "head": 64,
#       "deprel": "case",
#       "misc": "start_char=351|end_char=354"
#     },
#     {
#       "id": 64,
#       "text": "sr",
#       "lemma": "sr",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 62,
#       "deprel": "obl:agent",
#       "misc": "start_char=355|end_char=357"
#     },
#     {
#       "id": 65,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=357|end_char=358"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Gonçalves",
#       "lemma": "Gonçalves",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=359|end_char=368"
#     },
#     {
#       "id": 2,
#       "text": "et",
#       "lemma": "et",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 1,
#       "deprel": "flat:name",
#       "misc": "start_char=369|end_char=371"
#     },
#     {
#       "id": 3,
#       "text": "al.",
#       "lemma": "al.",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 1,
#       "deprel": "flat:name",
#       "misc": "start_char=372|end_char=375"
#     },
#     {
#       "id": 4,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 1,
#       "deprel": "flat:name",
#       "misc": "start_char=376|end_char=377"
#     },
#     {
#       "id": 5,
#       "text": "1979",
#       "lemma": "1979",
#       "upos": "NUM",
#       "feats": "NumType=Card",
#       "head": 1,
#       "deprel": "flat:name",
#       "misc": "start_char=377|end_char=381"
#     },
#     {
#       "id": 6,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 1,
#       "deprel": "flat:name",
#       "misc": "start_char=381|end_char=382"
#     },
#     {
#       "id": 7,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 8,
#       "deprel": "punct",
#       "misc": "start_char=382|end_char=383"
#     },
#     {
#       "id": 8,
#       "text": "Zona",
#       "lemma": "Zona",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 1,
#       "deprel": "conj",
#       "misc": "start_char=384|end_char=388"
#     },
#     {
#       "id": 9,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 8,
#       "deprel": "flat:name",
#       "misc": "start_char=389|end_char=391"
#     },
#     {
#       "id": 10,
#       "text": "Falha",
#       "lemma": "Falha",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "flat:name",
#       "misc": "start_char=392|end_char=397"
#     },
#     {
#       "id": [
#         11,
#         12
#       ],
#       "text": "do",
#       "misc": "start_char=398|end_char=400"
#     },
#     {
#       "id": 11,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 8,
#       "deprel": "flat:name"
#     },
#     {
#       "id": 12,
#       "text": "o",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 8,
#       "deprel": "flat:name"
#     },
#     {
#       "id": 13,
#       "text": "Rio",
#       "lemma": "Rio",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 8,
#       "deprel": "flat:name",
#       "misc": "start_char=401|end_char=404"
#     },
#     {
#       "id": 14,
#       "text": "Grande",
#       "lemma": "Grande",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 8,
#       "deprel": "flat:name",
#       "misc": "start_char=405|end_char=411"
#     },
#     {
#       "id": 15,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 16,
#       "deprel": "punct",
#       "misc": "start_char=412|end_char=413"
#     },
#     {
#       "id": 16,
#       "text": "Miranda",
#       "lemma": "Miranda",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 8,
#       "deprel": "appos",
#       "misc": "start_char=413|end_char=420"
#     },
#     {
#       "id": 17,
#       "text": "1970",
#       "lemma": "1970",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 16,
#       "deprel": "flat:name",
#       "misc": "start_char=421|end_char=425"
#     },
#     {
#       "id": 18,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 16,
#       "deprel": "punct",
#       "misc": "start_char=425|end_char=426"
#     },
#     {
#       "id": 19,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 21,
#       "deprel": "punct",
#       "misc": "start_char=426|end_char=427"
#     },
#     {
#       "id": 20,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 21,
#       "deprel": "punct",
#       "misc": "start_char=428|end_char=429"
#     },
#     {
#       "id": 21,
#       "text": "Kowsmann",
#       "lemma": "Kowsmann",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 1,
#       "deprel": "appos",
#       "misc": "start_char=429|end_char=437"
#     },
#     {
#       "id": 22,
#       "text": "1974",
#       "lemma": "1974",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 21,
#       "deprel": "flat:name",
#       "misc": "start_char=438|end_char=442"
#     },
#     {
#       "id": 23,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 21,
#       "deprel": "punct",
#       "misc": "start_char=442|end_char=443"
#     },
#     {
#       "id": 24,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=443|end_char=444"
#     },
#     {
#       "id": 25,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 1,
#       "deprel": "punct",
#       "misc": "start_char=444|end_char=445"
#     }
#   ]
# ]

# %%
text_dict =  tok_nlp(text).to_dict()

# %%
conllu = CoNLL.convert_dict()

file = open('outconllu4.txt', 'w+', encoding='latin-1')
for line in conllu: 
    for line_ in line:
        file.write("\t".join(line_) + ' \n')
file.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-45345f0fc418> in <module>
# ----> 1 conllu = CoNLL.convert_dict()
#       2
#       3 file = open('outconllu4.txt', 'w+', encoding='latin-1')
#       4 for line in conllu:
#       5     for line_ in line:
#
# TypeError: convert_dict() missing 1 required positional argument: 'doc_dict'

# %%
pwd
# Out:
# '/scratch/parceirosbr/bigoilict/share/NLP/tokenizer'

# %%
# output = list_to_conllu_text(text, conllu, phrases)
stanza_token_sentence = merge_stanza_token_sentences(text_dict)

# %%
tokens_by_id = {token['id']:token for token in stanza_token_sentence}

# %%
mwt_cases = get_mwts(stanza_token_sentence, tokens_by_id)

# %%
tokenization_pattern = r'''al\.|[.,;:"“”'?():_`]|\w*(?:[^;"“”'?():_`\s]*\w+)+[%º°?']?|[\S]'''

# %%
sentence = re.findall(tokenization_pattern, text)

# %%
sentence
# Out:
# ['A',
#  'caracterização',
#  'estrutural',
#  'para',
#  'a',
#  'porção',
#  'norte',
#  'da',
#  'Bacia',
#  'de',
#  'Pelotas',
#  'foi',
#  'realizada',
#  'através',
#  'de',
#  '17',
#  'seções',
#  'sísmicas',
#  ',',
#  'onde',
#  'foram',
#  'caracterizadas',
#  'falhas',
#  'normais',
#  ',',
#  'em',
#  'padrão',
#  'dominó',
#  ',',
#  'falhas',
#  'sintéticas',
#  'e',
#  'antitéticas',
#  'e',
#  'lístricas',
#  ',',
#  'além',
#  'da',
#  'identificação',
#  'de',
#  'estruturas',
#  'como',
#  'o',
#  'Arco',
#  'de',
#  'Torres',
#  '(',
#  'Fonseca',
#  '2006',
#  ')',
#  ',',
#  '(',
#  'Alves',
#  '1981',
#  ')',
#  'a',
#  'Plataforma',
#  'de',
#  'Florianópolis',
#  'individualizada',
#  'por',
#  'sr',
#  '.',
#  'Gonçalves',
#  'et',
#  'al.',
#  '(',
#  '1979',
#  ')',
#  ',',
#  'Zona',
#  'de',
#  'Falha',
#  'do',
#  'Rio',
#  'Grande',
#  '(',
#  'Miranda',
#  '1970',
#  ')',
#  ',',
#  '(',
#  'Kowsmann',
#  '1974',
#  ')',
#  '.',
#  '.']

# %%
tag_nlp = Pipeline(lang='pt',
                   tokenize_pretokenized=False,
                   use_gpu=True,
#                    processors='mwt,tokenize,pos,lemma,depparse',
                   depparse_model_path="./models/pt_bosquepetrolesoeg_parser.pt"
                  )
# Out:
# 2021-04-29 17:47:43 INFO: Loading these models for language: pt (Portuguese):
# =======================================
# | Processor | Package                 |
# ---------------------------------------
# | tokenize  | bosque                  |
# | mwt       | bosque                  |
# | pos       | bosque                  |
# | lemma     | bosque                  |
# | depparse  | ./models/p..._parser.pt |
# =======================================
#
# 2021-04-29 17:47:43 INFO: Use device: cpu
# 2021-04-29 17:47:43 INFO: Loading: tokenize
# 2021-04-29 17:47:43 INFO: Loading: mwt
# 2021-04-29 17:47:43 INFO: Loading: pos
# 2021-04-29 17:47:44 INFO: Loading: lemma
# 2021-04-29 17:47:45 INFO: Loading: depparse
# 2021-04-29 17:47:45 INFO: Done loading processors!

# %%
# tagged_sentences = tag_nlp(' '.join(sentence)) 
tagged_sentences = tag_nlp(text2)

# %%
' '.join(sentence)
# Out:
# 'A caracterização estrutural para a porção norte da Bacia de Pelotas foi realizada através de 17 seções sísmicas , onde foram caracterizadas falhas normais , em padrão dominó , falhas sintéticas e antitéticas e lístricas , além da identificação de estruturas como o Arco de Torres ( Fonseca 2006 ) , ( Alves 1981 ) a Plataforma de Florianópolis individualizada por sr . Gonçalves et al. ( 1979 ) , Zona de Falha do Rio Grande ( Miranda 1970 ) , ( Kowsmann 1974 ) . .'

# %%
text2= 'A caracterização estrutural para a porção norte da Bacia de Pelotas foi realizada através de 17 seções sísmicas , onde foram caracterizadas falhas normais , em padrão dominó , falhas sintéticas e antitéticas e lístricas , além da identificação de estruturas como o Arco de Torres ( Fonseca 2006 ) , ( Alves 1981 ) a Plataforma de Florianópolis individualizada por Sr. Gonçalves et al. (1979) , Zona de Falha do Rio Grande auto-sustentável físico/químicas (Miranda 1970) , (Kowsmann 1974) . .'

# %%
tagged_sentences
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "A",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "misc": "start_char=0|end_char=1"
#     },
#     {
#       "id": 2,
#       "text": "caracterização",
#       "lemma": "caracterização",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 14,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=2|end_char=16"
#     },
#     {
#       "id": 3,
#       "text": "estrutural",
#       "lemma": "estrutural",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "amod",
#       "misc": "start_char=17|end_char=27"
#     },
#     {
#       "id": 4,
#       "text": "para",
#       "lemma": "para",
#       "upos": "ADP",
#       "head": 6,
#       "deprel": "case",
#       "misc": "start_char=28|end_char=32"
#     },
#     {
#       "id": 5,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "misc": "start_char=33|end_char=34"
#     },
#     {
#       "id": 6,
#       "text": "porção",
#       "lemma": "porção",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "nmod",
#       "misc": "start_char=35|end_char=41"
#     },
#     {
#       "id": 7,
#       "text": "norte",
#       "lemma": "norte",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 6,
#       "deprel": "amod",
#       "misc": "start_char=42|end_char=47"
#     },
#     {
#       "id": [
#         8,
#         9
#       ],
#       "text": "da",
#       "misc": "start_char=48|end_char=50"
#     },
#     {
#       "id": 8,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 10,
#       "deprel": "case"
#     },
#     {
#       "id": 9,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 10,
#       "deprel": "det"
#     },
#     {
#       "id": 10,
#       "text": "Bacia",
#       "lemma": "bacia",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 6,
#       "deprel": "nmod",
#       "misc": "start_char=51|end_char=56"
#     },
#     {
#       "id": 11,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 10,
#       "deprel": "flat:name",
#       "misc": "start_char=57|end_char=59"
#     },
#     {
#       "id": 12,
#       "text": "Pelotas",
#       "lemma": "Pelotas",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "flat:name",
#       "misc": "start_char=60|end_char=67"
#     },
#     {
#       "id": 13,
#       "text": "foi",
#       "lemma": "ser",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 14,
#       "deprel": "aux:pass",
#       "misc": "start_char=68|end_char=71"
#     },
#     {
#       "id": 14,
#       "text": "realizada",
#       "lemma": "realizar",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=72|end_char=81"
#     },
#     {
#       "id": 15,
#       "text": "através",
#       "lemma": "através",
#       "upos": "ADV",
#       "head": 14,
#       "deprel": "advmod",
#       "misc": "start_char=82|end_char=89"
#     },
#     {
#       "id": 16,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 18,
#       "deprel": "case",
#       "misc": "start_char=90|end_char=92"
#     },
#     {
#       "id": 17,
#       "text": "17",
#       "lemma": "17",
#       "upos": "NUM",
#       "feats": "NumType=Card",
#       "head": 18,
#       "deprel": "nummod",
#       "misc": "start_char=93|end_char=95"
#     },
#     {
#       "id": 18,
#       "text": "seções",
#       "lemma": "seção",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 15,
#       "deprel": "obl",
#       "misc": "start_char=96|end_char=102"
#     },
#     {
#       "id": 19,
#       "text": "sísmicas",
#       "lemma": "sísmico",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 18,
#       "deprel": "amod",
#       "misc": "start_char=103|end_char=111"
#     },
#     {
#       "id": 20,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=112|end_char=113"
#     },
#     {
#       "id": 21,
#       "text": "onde",
#       "lemma": "onde",
#       "upos": "PRON",
#       "feats": "Gender=Fem|Number=Sing|PronType=Rel",
#       "head": 23,
#       "deprel": "obl",
#       "misc": "start_char=114|end_char=118"
#     },
#     {
#       "id": 22,
#       "text": "foram",
#       "lemma": "ser",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Plur|Person=3|VerbForm=Fin",
#       "head": 23,
#       "deprel": "aux:pass",
#       "misc": "start_char=119|end_char=124"
#     },
#     {
#       "id": 23,
#       "text": "caracterizadas",
#       "lemma": "caracterizar",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Plur|VerbForm=Part|Voice=Pass",
#       "head": 18,
#       "deprel": "acl:relcl",
#       "misc": "start_char=125|end_char=139"
#     },
#     {
#       "id": 24,
#       "text": "falhas",
#       "lemma": "falha",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 23,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=140|end_char=146"
#     },
#     {
#       "id": 25,
#       "text": "normais",
#       "lemma": "normal",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 24,
#       "deprel": "amod",
#       "misc": "start_char=147|end_char=154"
#     },
#     {
#       "id": 26,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 28,
#       "deprel": "punct",
#       "misc": "start_char=155|end_char=156"
#     },
#     {
#       "id": 27,
#       "text": "em",
#       "lemma": "em",
#       "upos": "ADP",
#       "head": 28,
#       "deprel": "case",
#       "misc": "start_char=157|end_char=159"
#     },
#     {
#       "id": 28,
#       "text": "padrão",
#       "lemma": "padrão",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 24,
#       "deprel": "nmod",
#       "misc": "start_char=160|end_char=166"
#     },
#     {
#       "id": 29,
#       "text": "dominó",
#       "lemma": "dominó",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 28,
#       "deprel": "amod",
#       "misc": "start_char=167|end_char=173"
#     },
#     {
#       "id": 30,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 31,
#       "deprel": "punct",
#       "misc": "start_char=174|end_char=175"
#     },
#     {
#       "id": 31,
#       "text": "falhas",
#       "lemma": "falha",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 24,
#       "deprel": "conj",
#       "misc": "start_char=176|end_char=182"
#     },
#     {
#       "id": 32,
#       "text": "sintéticas",
#       "lemma": "sintético",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 31,
#       "deprel": "amod",
#       "misc": "start_char=183|end_char=193"
#     },
#     {
#       "id": 33,
#       "text": "e",
#       "lemma": "e",
#       "upos": "CCONJ",
#       "head": 34,
#       "deprel": "cc",
#       "misc": "start_char=194|end_char=195"
#     },
#     {
#       "id": 34,
#       "text": "antitéticas",
#       "lemma": "antitético",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 32,
#       "deprel": "conj",
#       "misc": "start_char=196|end_char=207"
#     },
#     {
#       "id": 35,
#       "text": "e",
#       "lemma": "e",
#       "upos": "CCONJ",
#       "head": 36,
#       "deprel": "cc",
#       "misc": "start_char=208|end_char=209"
#     },
#     {
#       "id": 36,
#       "text": "lístricas",
#       "lemma": "lístrico",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 32,
#       "deprel": "conj",
#       "misc": "start_char=210|end_char=219"
#     },
#     {
#       "id": 37,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 41,
#       "deprel": "punct",
#       "misc": "start_char=220|end_char=221"
#     },
#     {
#       "id": 38,
#       "text": "além",
#       "lemma": "além",
#       "upos": "ADV",
#       "head": 41,
#       "deprel": "cc",
#       "misc": "start_char=222|end_char=226"
#     },
#     {
#       "id": [
#         39,
#         40
#       ],
#       "text": "da",
#       "misc": "start_char=227|end_char=229"
#     },
#     {
#       "id": 39,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 38,
#       "deprel": "fixed"
#     },
#     {
#       "id": 40,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 41,
#       "deprel": "det"
#     },
#     {
#       "id": 41,
#       "text": "identificação",
#       "lemma": "identificação",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 24,
#       "deprel": "conj",
#       "misc": "start_char=230|end_char=243"
#     },
#     {
#       "id": 42,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 43,
#       "deprel": "case",
#       "misc": "start_char=244|end_char=246"
#     },
#     {
#       "id": 43,
#       "text": "estruturas",
#       "lemma": "estrutura",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 41,
#       "deprel": "nmod",
#       "misc": "start_char=247|end_char=257"
#     },
#     {
#       "id": 44,
#       "text": "como",
#       "lemma": "como",
#       "upos": "ADP",
#       "head": 46,
#       "deprel": "case",
#       "misc": "start_char=258|end_char=262"
#     },
#     {
#       "id": 45,
#       "text": "o",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 46,
#       "deprel": "det",
#       "misc": "start_char=263|end_char=264"
#     },
#     {
#       "id": 46,
#       "text": "Arco",
#       "lemma": "Arco",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 43,
#       "deprel": "nmod:appos",
#       "misc": "start_char=265|end_char=269"
#     },
#     {
#       "id": 47,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 46,
#       "deprel": "flat:name",
#       "misc": "start_char=270|end_char=272"
#     },
#     {
#       "id": 48,
#       "text": "Torres",
#       "lemma": "Torres",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 46,
#       "deprel": "flat:name",
#       "misc": "start_char=273|end_char=279"
#     },
#     {
#       "id": 49,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 50,
#       "deprel": "punct",
#       "misc": "start_char=280|end_char=281"
#     },
#     {
#       "id": 50,
#       "text": "Fonseca",
#       "lemma": "Fonseca",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 46,
#       "deprel": "appos",
#       "misc": "start_char=282|end_char=289"
#     },
#     {
#       "id": 51,
#       "text": "2006",
#       "lemma": "2006",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 50,
#       "deprel": "flat:name",
#       "misc": "start_char=290|end_char=294"
#     },
#     {
#       "id": 52,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 50,
#       "deprel": "punct",
#       "misc": "start_char=295|end_char=296"
#     },
#     {
#       "id": 53,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 59,
#       "deprel": "punct",
#       "misc": "start_char=297|end_char=298"
#     },
#     {
#       "id": 54,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 55,
#       "deprel": "punct",
#       "misc": "start_char=299|end_char=300"
#     },
#     {
#       "id": 55,
#       "text": "Alves",
#       "lemma": "Alves",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 46,
#       "deprel": "appos",
#       "misc": "start_char=301|end_char=306"
#     },
#     {
#       "id": 56,
#       "text": "1981",
#       "lemma": "1981",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 55,
#       "deprel": "flat:name",
#       "misc": "start_char=307|end_char=311"
#     },
#     {
#       "id": 57,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 55,
#       "deprel": "punct",
#       "misc": "start_char=312|end_char=313"
#     },
#     {
#       "id": 58,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 59,
#       "deprel": "det",
#       "misc": "start_char=314|end_char=315"
#     },
#     {
#       "id": 59,
#       "text": "Plataforma",
#       "lemma": "Plataforma",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 46,
#       "deprel": "conj",
#       "misc": "start_char=316|end_char=326"
#     },
#     {
#       "id": 60,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 59,
#       "deprel": "flat:name",
#       "misc": "start_char=327|end_char=329"
#     },
#     {
#       "id": 61,
#       "text": "Florianópolis",
#       "lemma": "Florianópolis",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "flat:name",
#       "misc": "start_char=330|end_char=343"
#     },
#     {
#       "id": 62,
#       "text": "individualizada",
#       "lemma": "individualizar",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass",
#       "head": 59,
#       "deprel": "acl",
#       "misc": "start_char=344|end_char=359"
#     },
#     {
#       "id": 63,
#       "text": "por",
#       "lemma": "por",
#       "upos": "ADP",
#       "head": 64,
#       "deprel": "case",
#       "misc": "start_char=360|end_char=363"
#     },
#     {
#       "id": 64,
#       "text": "Sr.",
#       "lemma": "sr.",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 62,
#       "deprel": "obl:agent",
#       "misc": "start_char=364|end_char=367"
#     },
#     {
#       "id": 65,
#       "text": "Gonçalves",
#       "lemma": "Gonçalves",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 64,
#       "deprel": "flat:name",
#       "misc": "start_char=368|end_char=377"
#     },
#     {
#       "id": 66,
#       "text": "et",
#       "lemma": "et",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 64,
#       "deprel": "flat:name",
#       "misc": "start_char=378|end_char=380"
#     },
#     {
#       "id": 67,
#       "text": "al.",
#       "lemma": "al.",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 64,
#       "deprel": "flat:name",
#       "misc": "start_char=381|end_char=384"
#     },
#     {
#       "id": 68,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 69,
#       "deprel": "punct",
#       "misc": "start_char=385|end_char=386"
#     },
#     {
#       "id": 69,
#       "text": "1979",
#       "lemma": "1979",
#       "upos": "NUM",
#       "feats": "NumType=Card",
#       "head": 64,
#       "deprel": "flat:name",
#       "misc": "start_char=386|end_char=390"
#     },
#     {
#       "id": 70,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 69,
#       "deprel": "punct",
#       "misc": "start_char=390|end_char=391"
#     },
#     {
#       "id": 71,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 72,
#       "deprel": "punct",
#       "misc": "start_char=392|end_char=393"
#     },
#     {
#       "id": 72,
#       "text": "Zona",
#       "lemma": "Zona",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 64,
#       "deprel": "conj",
#       "misc": "start_char=394|end_char=398"
#     },
#     {
#       "id": 73,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 72,
#       "deprel": "flat:name",
#       "misc": "start_char=399|end_char=401"
#     },
#     {
#       "id": 74,
#       "text": "Falha",
#       "lemma": "Falha",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 72,
#       "deprel": "flat:name",
#       "misc": "start_char=402|end_char=407"
#     },
#     {
#       "id": [
#         75,
#         76
#       ],
#       "text": "do",
#       "misc": "start_char=408|end_char=410"
#     },
#     {
#       "id": 75,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 72,
#       "deprel": "flat:name"
#     },
#     {
#       "id": 76,
#       "text": "o",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 72,
#       "deprel": "flat:name"
#     },
#     {
#       "id": 77,
#       "text": "Rio",
#       "lemma": "Rio",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 72,
#       "deprel": "flat:name",
#       "misc": "start_char=411|end_char=414"
#     },
#     {
#       "id": 78,
#       "text": "Grande",
#       "lemma": "Grande",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 72,
#       "deprel": "flat:name",
#       "misc": "start_char=415|end_char=421"
#     },
#     {
#       "id": 79,
#       "text": "auto-sustentável",
#       "lemma": "auto-sustentável",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 72,
#       "deprel": "amod",
#       "misc": "start_char=422|end_char=438"
#     },
#     {
#       "id": 80,
#       "text": "físico/químicas",
#       "lemma": "físico/químico",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 72,
#       "deprel": "amod",
#       "misc": "start_char=439|end_char=454"
#     },
#     {
#       "id": 81,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 82,
#       "deprel": "punct",
#       "misc": "start_char=455|end_char=456"
#     },
#     {
#       "id": 82,
#       "text": "Miranda",
#       "lemma": "Miranda",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 72,
#       "deprel": "appos",
#       "misc": "start_char=456|end_char=463"
#     },
#     {
#       "id": 83,
#       "text": "1970",
#       "lemma": "1970",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 82,
#       "deprel": "flat:name",
#       "misc": "start_char=464|end_char=468"
#     },
#     {
#       "id": 84,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 82,
#       "deprel": "punct",
#       "misc": "start_char=468|end_char=469"
#     },
#     {
#       "id": 85,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 87,
#       "deprel": "punct",
#       "misc": "start_char=470|end_char=471"
#     },
#     {
#       "id": 86,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 87,
#       "deprel": "punct",
#       "misc": "start_char=472|end_char=473"
#     },
#     {
#       "id": 87,
#       "text": "Kowsmann",
#       "lemma": "Kowsmann",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 82,
#       "deprel": "conj",
#       "misc": "start_char=473|end_char=481"
#     },
#     {
#       "id": 88,
#       "text": "1974",
#       "lemma": "1974",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 87,
#       "deprel": "flat:name",
#       "misc": "start_char=482|end_char=486"
#     },
#     {
#       "id": 89,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 87,
#       "deprel": "punct",
#       "misc": "start_char=486|end_char=487"
#     },
#     {
#       "id": 90,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=488|end_char=489"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=490|end_char=491"
#     }
#   ]
# ]

# %%
tag_nlp(text)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "A",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 2,
#       "deprel": "det",
#       "misc": "start_char=0|end_char=1"
#     },
#     {
#       "id": 2,
#       "text": "caracterização",
#       "lemma": "caracterização",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 14,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=2|end_char=16"
#     },
#     {
#       "id": 3,
#       "text": "estrutural",
#       "lemma": "estrutural",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "amod",
#       "misc": "start_char=17|end_char=27"
#     },
#     {
#       "id": 4,
#       "text": "para",
#       "lemma": "para",
#       "upos": "ADP",
#       "head": 6,
#       "deprel": "case",
#       "misc": "start_char=28|end_char=32"
#     },
#     {
#       "id": 5,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 6,
#       "deprel": "det",
#       "misc": "start_char=33|end_char=34"
#     },
#     {
#       "id": 6,
#       "text": "porção",
#       "lemma": "porção",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 2,
#       "deprel": "nmod",
#       "misc": "start_char=35|end_char=41"
#     },
#     {
#       "id": 7,
#       "text": "norte",
#       "lemma": "norte",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 6,
#       "deprel": "amod",
#       "misc": "start_char=42|end_char=47"
#     },
#     {
#       "id": [
#         8,
#         9
#       ],
#       "text": "da",
#       "misc": "start_char=48|end_char=50"
#     },
#     {
#       "id": 8,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 10,
#       "deprel": "case"
#     },
#     {
#       "id": 9,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 10,
#       "deprel": "det"
#     },
#     {
#       "id": 10,
#       "text": "Bacia",
#       "lemma": "bacia",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 6,
#       "deprel": "nmod",
#       "misc": "start_char=51|end_char=56"
#     },
#     {
#       "id": 11,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 10,
#       "deprel": "flat:name",
#       "misc": "start_char=57|end_char=59"
#     },
#     {
#       "id": 12,
#       "text": "Pelotas",
#       "lemma": "Pelotas",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "flat:name",
#       "misc": "start_char=60|end_char=67"
#     },
#     {
#       "id": 13,
#       "text": "foi",
#       "lemma": "ser",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 14,
#       "deprel": "aux:pass",
#       "misc": "start_char=68|end_char=71"
#     },
#     {
#       "id": 14,
#       "text": "realizada",
#       "lemma": "realizar",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root",
#       "misc": "start_char=72|end_char=81"
#     },
#     {
#       "id": 15,
#       "text": "através",
#       "lemma": "através",
#       "upos": "ADV",
#       "head": 14,
#       "deprel": "advmod",
#       "misc": "start_char=82|end_char=89"
#     },
#     {
#       "id": 16,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 18,
#       "deprel": "case",
#       "misc": "start_char=90|end_char=92"
#     },
#     {
#       "id": 17,
#       "text": "17",
#       "lemma": "17",
#       "upos": "NUM",
#       "feats": "NumType=Card",
#       "head": 18,
#       "deprel": "nummod",
#       "misc": "start_char=93|end_char=95"
#     },
#     {
#       "id": 18,
#       "text": "seções",
#       "lemma": "seção",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 15,
#       "deprel": "obl",
#       "misc": "start_char=96|end_char=102"
#     },
#     {
#       "id": 19,
#       "text": "sísmicas",
#       "lemma": "sísmico",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 18,
#       "deprel": "amod",
#       "misc": "start_char=103|end_char=111"
#     },
#     {
#       "id": 20,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=111|end_char=112"
#     },
#     {
#       "id": 21,
#       "text": "onde",
#       "lemma": "onde",
#       "upos": "PRON",
#       "feats": "Gender=Fem|Number=Sing|PronType=Rel",
#       "head": 23,
#       "deprel": "obl",
#       "misc": "start_char=113|end_char=117"
#     },
#     {
#       "id": 22,
#       "text": "foram",
#       "lemma": "ser",
#       "upos": "AUX",
#       "feats": "Mood=Ind|Number=Plur|Person=3|VerbForm=Fin",
#       "head": 23,
#       "deprel": "aux:pass",
#       "misc": "start_char=118|end_char=123"
#     },
#     {
#       "id": 23,
#       "text": "caracterizadas",
#       "lemma": "caracterizar",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Plur|VerbForm=Part|Voice=Pass",
#       "head": 18,
#       "deprel": "acl:relcl",
#       "misc": "start_char=124|end_char=138"
#     },
#     {
#       "id": 24,
#       "text": "falhas",
#       "lemma": "falha",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 23,
#       "deprel": "nsubj:pass",
#       "misc": "start_char=139|end_char=145"
#     },
#     {
#       "id": 25,
#       "text": "normais",
#       "lemma": "normal",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 24,
#       "deprel": "amod",
#       "misc": "start_char=146|end_char=153"
#     },
#     {
#       "id": 26,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 28,
#       "deprel": "punct",
#       "misc": "start_char=153|end_char=154"
#     },
#     {
#       "id": 27,
#       "text": "em",
#       "lemma": "em",
#       "upos": "ADP",
#       "head": 28,
#       "deprel": "case",
#       "misc": "start_char=155|end_char=157"
#     },
#     {
#       "id": 28,
#       "text": "padrão",
#       "lemma": "padrão",
#       "upos": "NOUN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 24,
#       "deprel": "nmod",
#       "misc": "start_char=158|end_char=164"
#     },
#     {
#       "id": 29,
#       "text": "dominó",
#       "lemma": "dominó",
#       "upos": "ADJ",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 28,
#       "deprel": "amod",
#       "misc": "start_char=165|end_char=171"
#     },
#     {
#       "id": 30,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 31,
#       "deprel": "punct",
#       "misc": "start_char=171|end_char=172"
#     },
#     {
#       "id": 31,
#       "text": "falhas",
#       "lemma": "falha",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 24,
#       "deprel": "conj",
#       "misc": "start_char=173|end_char=179"
#     },
#     {
#       "id": 32,
#       "text": "sintéticas",
#       "lemma": "sintético",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 31,
#       "deprel": "amod",
#       "misc": "start_char=180|end_char=190"
#     },
#     {
#       "id": 33,
#       "text": "e",
#       "lemma": "e",
#       "upos": "CCONJ",
#       "head": 34,
#       "deprel": "cc",
#       "misc": "start_char=191|end_char=192"
#     },
#     {
#       "id": 34,
#       "text": "antitéticas",
#       "lemma": "antitético",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 32,
#       "deprel": "conj",
#       "misc": "start_char=193|end_char=204"
#     },
#     {
#       "id": 35,
#       "text": "e",
#       "lemma": "e",
#       "upos": "CCONJ",
#       "head": 36,
#       "deprel": "cc",
#       "misc": "start_char=205|end_char=206"
#     },
#     {
#       "id": 36,
#       "text": "lístricas",
#       "lemma": "lístrico",
#       "upos": "ADJ",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 32,
#       "deprel": "conj",
#       "misc": "start_char=207|end_char=216"
#     },
#     {
#       "id": 37,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 41,
#       "deprel": "punct",
#       "misc": "start_char=216|end_char=217"
#     },
#     {
#       "id": 38,
#       "text": "além",
#       "lemma": "além",
#       "upos": "ADV",
#       "head": 41,
#       "deprel": "cc",
#       "misc": "start_char=218|end_char=222"
#     },
#     {
#       "id": [
#         39,
#         40
#       ],
#       "text": "da",
#       "misc": "start_char=223|end_char=225"
#     },
#     {
#       "id": 39,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 38,
#       "deprel": "fixed"
#     },
#     {
#       "id": 40,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 41,
#       "deprel": "det"
#     },
#     {
#       "id": 41,
#       "text": "identificação",
#       "lemma": "identificação",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 24,
#       "deprel": "conj",
#       "misc": "start_char=226|end_char=239"
#     },
#     {
#       "id": 42,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 43,
#       "deprel": "case",
#       "misc": "start_char=240|end_char=242"
#     },
#     {
#       "id": 43,
#       "text": "estruturas",
#       "lemma": "estrutura",
#       "upos": "NOUN",
#       "feats": "Gender=Fem|Number=Plur",
#       "head": 41,
#       "deprel": "nmod",
#       "misc": "start_char=243|end_char=253"
#     },
#     {
#       "id": 44,
#       "text": "como",
#       "lemma": "como",
#       "upos": "ADP",
#       "head": 46,
#       "deprel": "case",
#       "misc": "start_char=254|end_char=258"
#     },
#     {
#       "id": 45,
#       "text": "o",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 46,
#       "deprel": "det",
#       "misc": "start_char=259|end_char=260"
#     },
#     {
#       "id": 46,
#       "text": "Arco",
#       "lemma": "Arco",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 43,
#       "deprel": "nmod:appos",
#       "misc": "start_char=261|end_char=265"
#     },
#     {
#       "id": 47,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 46,
#       "deprel": "flat:name",
#       "misc": "start_char=266|end_char=268"
#     },
#     {
#       "id": 48,
#       "text": "Torres",
#       "lemma": "Torres",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 46,
#       "deprel": "flat:name",
#       "misc": "start_char=269|end_char=275"
#     },
#     {
#       "id": 49,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 50,
#       "deprel": "punct",
#       "misc": "start_char=276|end_char=277"
#     },
#     {
#       "id": 50,
#       "text": "Fonseca",
#       "lemma": "Fonseca",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 46,
#       "deprel": "appos",
#       "misc": "start_char=277|end_char=284"
#     },
#     {
#       "id": 51,
#       "text": "2006",
#       "lemma": "2006",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 50,
#       "deprel": "flat:name",
#       "misc": "start_char=285|end_char=289"
#     },
#     {
#       "id": 52,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 50,
#       "deprel": "punct",
#       "misc": "start_char=289|end_char=290"
#     },
#     {
#       "id": 53,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 59,
#       "deprel": "punct",
#       "misc": "start_char=290|end_char=291"
#     },
#     {
#       "id": 54,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 55,
#       "deprel": "punct",
#       "misc": "start_char=292|end_char=293"
#     },
#     {
#       "id": 55,
#       "text": "Alves",
#       "lemma": "Alves",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 46,
#       "deprel": "appos",
#       "misc": "start_char=293|end_char=298"
#     },
#     {
#       "id": 56,
#       "text": "1981",
#       "lemma": "1981",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 55,
#       "deprel": "flat:name",
#       "misc": "start_char=299|end_char=303"
#     },
#     {
#       "id": 57,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 55,
#       "deprel": "punct",
#       "misc": "start_char=303|end_char=304"
#     },
#     {
#       "id": 58,
#       "text": "a",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art",
#       "head": 59,
#       "deprel": "det",
#       "misc": "start_char=305|end_char=306"
#     },
#     {
#       "id": 59,
#       "text": "Plataforma",
#       "lemma": "Plataforma",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 46,
#       "deprel": "conj",
#       "misc": "start_char=307|end_char=317"
#     },
#     {
#       "id": 60,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 59,
#       "deprel": "flat:name",
#       "misc": "start_char=318|end_char=320"
#     },
#     {
#       "id": 61,
#       "text": "Florianópolis",
#       "lemma": "Florianópolis",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "flat:name",
#       "misc": "start_char=321|end_char=334"
#     },
#     {
#       "id": 62,
#       "text": "individualizada",
#       "lemma": "individualizar",
#       "upos": "VERB",
#       "feats": "Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass",
#       "head": 59,
#       "deprel": "acl",
#       "misc": "start_char=335|end_char=350"
#     },
#     {
#       "id": 63,
#       "text": "por",
#       "lemma": "por",
#       "upos": "ADP",
#       "head": 64,
#       "deprel": "case",
#       "misc": "start_char=351|end_char=354"
#     },
#     {
#       "id": 64,
#       "text": "Gonçalves",
#       "lemma": "Gonçalves",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 62,
#       "deprel": "obl:agent",
#       "misc": "start_char=355|end_char=364"
#     },
#     {
#       "id": 65,
#       "text": "et",
#       "lemma": "et",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 64,
#       "deprel": "flat:name",
#       "misc": "start_char=365|end_char=367"
#     },
#     {
#       "id": 66,
#       "text": "al.",
#       "lemma": "al.",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 64,
#       "deprel": "flat:name",
#       "misc": "start_char=368|end_char=371"
#     },
#     {
#       "id": 67,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 64,
#       "deprel": "flat:name",
#       "misc": "start_char=372|end_char=373"
#     },
#     {
#       "id": 68,
#       "text": "1979",
#       "lemma": "1979",
#       "upos": "NUM",
#       "feats": "NumType=Card",
#       "head": 64,
#       "deprel": "flat:name",
#       "misc": "start_char=373|end_char=377"
#     },
#     {
#       "id": 69,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 68,
#       "deprel": "punct",
#       "misc": "start_char=377|end_char=378"
#     },
#     {
#       "id": 70,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 71,
#       "deprel": "punct",
#       "misc": "start_char=378|end_char=379"
#     },
#     {
#       "id": 71,
#       "text": "Zona",
#       "lemma": "Zona",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 64,
#       "deprel": "conj",
#       "misc": "start_char=380|end_char=384"
#     },
#     {
#       "id": 72,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 71,
#       "deprel": "flat:name",
#       "misc": "start_char=385|end_char=387"
#     },
#     {
#       "id": 73,
#       "text": "Falha",
#       "lemma": "Falha",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 71,
#       "deprel": "flat:name",
#       "misc": "start_char=388|end_char=393"
#     },
#     {
#       "id": [
#         74,
#         75
#       ],
#       "text": "do",
#       "misc": "start_char=394|end_char=396"
#     },
#     {
#       "id": 74,
#       "text": "de",
#       "lemma": "de",
#       "upos": "ADP",
#       "head": 71,
#       "deprel": "flat:name"
#     },
#     {
#       "id": 75,
#       "text": "o",
#       "lemma": "o",
#       "upos": "DET",
#       "feats": "Definite=Def|Gender=Masc|Number=Sing|PronType=Art",
#       "head": 71,
#       "deprel": "flat:name"
#     },
#     {
#       "id": 76,
#       "text": "Rio",
#       "lemma": "Rio",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 71,
#       "deprel": "flat:name",
#       "misc": "start_char=397|end_char=400"
#     },
#     {
#       "id": 77,
#       "text": "Grande",
#       "lemma": "Grande",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 71,
#       "deprel": "flat:name",
#       "misc": "start_char=401|end_char=407"
#     },
#     {
#       "id": 78,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 79,
#       "deprel": "punct",
#       "misc": "start_char=408|end_char=409"
#     },
#     {
#       "id": 79,
#       "text": "Miranda",
#       "lemma": "Miranda",
#       "upos": "PROPN",
#       "feats": "Gender=Fem|Number=Sing",
#       "head": 71,
#       "deprel": "appos",
#       "misc": "start_char=409|end_char=416"
#     },
#     {
#       "id": 80,
#       "text": "1970",
#       "lemma": "1970",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 79,
#       "deprel": "flat:name",
#       "misc": "start_char=417|end_char=421"
#     },
#     {
#       "id": 81,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 79,
#       "deprel": "punct",
#       "misc": "start_char=421|end_char=422"
#     },
#     {
#       "id": 82,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "head": 84,
#       "deprel": "punct",
#       "misc": "start_char=422|end_char=423"
#     },
#     {
#       "id": 83,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "head": 84,
#       "deprel": "punct",
#       "misc": "start_char=424|end_char=425"
#     },
#     {
#       "id": 84,
#       "text": "Kowsmann",
#       "lemma": "Kowsmann",
#       "upos": "PROPN",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 79,
#       "deprel": "conj",
#       "misc": "start_char=425|end_char=433"
#     },
#     {
#       "id": 85,
#       "text": "1974",
#       "lemma": "1974",
#       "upos": "PROPN",
#       "feats": "Number=Sing",
#       "head": 84,
#       "deprel": "flat:name",
#       "misc": "start_char=434|end_char=438"
#     },
#     {
#       "id": 86,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "head": 84,
#       "deprel": "punct",
#       "misc": "start_char=438|end_char=439"
#     },
#     {
#       "id": 87,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=439|end_char=440"
#     },
#     {
#       "id": 88,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "head": 14,
#       "deprel": "punct",
#       "misc": "start_char=440|end_char=441"
#     }
#   ]
# ]

# %%
import re

# %%
def get_mwts(token_sentence, tokens_by_id):
    mwts = []
    for i in range(len(token_sentence)):
        token = token_sentence[i]
        if isinstance(token['id'], tuple):
            id_start = token['id'][0]
            id_end = token['id'][1]+1
            ids = range(id_start,id_end)
            mwts.append((token['text'] , [tokens_by_id[idx] for idx in ids]))
    return mwts

# %%
import itertools

def merge_stanza_token_sentences(stanza_token_sentences):
    offset=0
    for i in range(len(stanza_token_sentences)):
        for j in range(len(stanza_token_sentences[i])):
            if 'head' in stanza_token_sentences[i][j]:
                stanza_token_sentences[i][j]['head']=int(stanza_token_sentences[i][j]['head'])+offset
                
            if  isinstance(stanza_token_sentences[i][j]['id'], tuple):
                ids = stanza_token_sentences[i][j]['id']
                #stanza_token_sentences[i][j]['id'] = '-'.join([str(int(id)+offset) for id in ids])
                stanza_token_sentences[i][j]['id'] = tuple(list(int(id)+offset for id in ids))
            else:
                stanza_token_sentences[i][j]['id'] = int(stanza_token_sentences[i][j]['id']) + offset

        offset=int(stanza_token_sentences[i][-1]['id'])
    stanza_token_sentences = list(itertools.chain.from_iterable(stanza_token_sentences))
    return stanza_token_sentences

# %%
from utils.stanza_utils import list_to_conllu_text, text_preprocessing, portuguese_sentenciation,sentenciation_stanza
from stanza.utils.conll import CoNLL

# %%
import sys
from tqdm import tqdm
import os
import re
import datetime
import stanza
from stanza import Pipeline
from stanza.utils.conll import CoNLL
from utils.stanza_utils import list_to_conllu_text, text_preprocessing, portuguese_sentenciation
from stanza.models.common import doc
import itertools
import numpy as np

# %%
tokenization_pattern = r'''al\.|[.,;:"“”'?():_`]|\w*(?:[^;"“”'?():_`\s]*\w+)+[%º°?']?|[\S]'''

def spans(txt, tokens):
    offset = 0
    all_spans = []
    for token in tokens:
        offset = txt.find(token, offset)
        all_spans.append((token, offset, offset + len(token)))
        offset += len(token)
    return all_spans

def get_mwts(token_sentence, tokens_by_id):
    mwts = []
    for i in range(len(token_sentence)):
        token = token_sentence[i]
        if isinstance(token['id'], tuple):
            id_start = token['id'][0]
            id_end = token['id'][1]+1
            ids = range(id_start,id_end)
            mwts.append((token['text'] , [tokens_by_id[idx] for idx in ids]))
    return mwts

def merge_stanza_token_sentences(stanza_token_sentences):
    offset=0
    for i in range(len(stanza_token_sentences)):
        for j in range(len(stanza_token_sentences[i])):
            if 'head' in stanza_token_sentences[i][j]:
                stanza_token_sentences[i][j]['head']=int(stanza_token_sentences[i][j]['head'])+offset
                
            if  isinstance(stanza_token_sentences[i][j]['id'], tuple):
                ids = stanza_token_sentences[i][j]['id']
                #stanza_token_sentences[i][j]['id'] = '-'.join([str(int(id)+offset) for id in ids])
                stanza_token_sentences[i][j]['id'] = tuple(list(int(id)+offset for id in ids))
            else:
                stanza_token_sentences[i][j]['id'] = int(stanza_token_sentences[i][j]['id']) + offset

        offset=int(stanza_token_sentences[i][-1]['id'])
    stanza_token_sentences = list(itertools.chain.from_iterable(stanza_token_sentences))
    return stanza_token_sentences

def get_stanza_2_tagged(stanza_token_sentence, tagged_sentence):
    filtered_stanza_token_sentence = []
    skip_tokens_id = []
    for token in stanza_token_sentence:
        if token['id'] in skip_tokens_id:
            continue
        if isinstance(token['id'], tuple):#'-' in token['id']:
            id_start = token['id'][0]
            id_end = token['id'][1]+1
            skip_tokens_id =[idx for idx in range(id_start,id_end)]#.split('-')
        filtered_stanza_token_sentence.append(token)

    for i,token in enumerate(filtered_stanza_token_sentence):
        filtered_stanza_token_sentence[i]['start']=int(token['misc'].split('|')[0][11:])

    for i,token in enumerate(tagged_sentence):
        tagged_sentence[i]['start']=int(token['misc'].split('|')[0][11:])

    stanza_2_tagged = {}
    stanza_2_tagged[0]=0
    for ftoken in filtered_stanza_token_sentence:
        compare=[]
        for i,ttoken in enumerate(tagged_sentence):
            ftext = set(ftoken['text'])
            ttext =set(ttoken['text'])
            if min(len(ftext-ttext),len(ttext-ftext))==0:
                compare.append((i, abs(ftoken['start'] - ttoken['start'])))
        if len(compare)==0:
            continue
            
        idx = min(compare, key=lambda x:x[1])[0]
        
        if isinstance(ftoken['id'],int):
            ids = [ftoken['id']]
        else:
            id_start = ftoken['id'][0]
            id_end = ftoken['id'][1]+1
            ids = range(id_start, id_end)
            
        for f_id in ids:#.split('-')
            stanza_2_tagged[f_id] = tagged_sentence[idx]['id']
    
    return stanza_2_tagged

# %%
input_path='/share_gamma/nethome/cristian/projects/nlp/NER/distant_supervision/data_full/UFBA__24311.txt'
tok_nlp = Pipeline(lang='pt', processors='tokenize,mwt,pos,lemma,depparse',tokenize_pretokenized=False, use_gpu=True)#processors='tokenize,mwt', 
tag_nlp = Pipeline(lang='pt', tokenize_pretokenized=True, use_gpu=True)#processors='tokenize,pos,lemma,depparse',

# %%
a='r'

# %%
a[0],a
# Out:
# ('r', 'r')

# %%
print("loading file: {}".format(input_path))
#input_path='data/{}.txt'.format(input_filename)
try:
    infile = open(input_path, encoding='utf-16')
    text = infile.read()
    print('first')
except:
    try:
        infile = open(input_path, encoding='utf-16')
        text = infile.read()
        print('second')
    except Exception as e:
        infile = open(input_path, encoding='latin-1')
        text = infile.read()
        print('thrid')
        print(e)

text = text.replace('<title>','')
print('*'*500)
#text = infile.read().decode('utf-16', errors='replace')
#if text == "" or text is None:
#    text = infile.read().decode('utf-32', errors='ignore')
#print('text',text)
preprocessed_text = text_preprocessing(text)
#print('preprocessed_text',preprocessed_text)
#sentences = portuguese_sentenciation(preprocessed_text)
#tok_nlp = Pipeline(lang='pt', tokenize_pretokenized=False, use_gpu=False)#processors='tokenize,mwt', 
#tag_nlp = Pipeline(lang='pt', tokenize_pretokenized=True, use_gpu=False)#processors='tokenize,pos,lemma,depparse',

sentences = portuguese_sentenciation(preprocessed_text)

new_document=[]
raw_texts=[]
phrases = []
for phrase,rphrase in tqdm(list(sentences)):
    if not phrase.strip()=='':
        phrases.append(rphrase)
        stanza_sentence = tok_nlp(phrase)
        stanza_token_sentences2 = stanza_sentence.to_dict()
        stanza_token_sentence = merge_stanza_token_sentences(stanza_token_sentences2)
        tokens_by_id = {token['id']:token for token in stanza_token_sentence}
        mwt_cases = get_mwts(stanza_token_sentence, tokens_by_id)
        sentence = re.findall(tokenization_pattern, phrase)
        tagged_sentences = tag_nlp([sentence])     
        tagged_sentences = tagged_sentences.to_dict()
        tagged_sentence = tagged_sentences[0]
        assert len(tagged_sentence)==len(sentence)

        sentence = spans(rphrase,sentence)

        stanza_2_tagged = get_stanza_2_tagged(stanza_token_sentence, tagged_sentence)

        max_str = sentence[-1][-1]
        raw_text =" "*max_str
        sent = []
        ant2new = {}
        ant2new[0]=0
        token_id=1
        for (token,start_char,end_char),tagged_token in zip(sentence,tagged_sentence):
            idx=tagged_token['id']
            ant2new[idx]=token_id
            tagged_token.pop('key',None)
            tagged_token.pop('misc',None)
            tagged_token.pop('id',None)
            tagged_token.pop('text',None)

            if not len(mwt_cases)==0:
                mwt_token_key = mwt_cases[0][0]
                mwt_tokens = mwt_cases[0][1]

                if token == mwt_token_key:
                    token_id0 = token_id
                    token_id = token_id + len(mwt_tokens)-1
                    token_information = {doc.ID: (token_id0, token_id), doc.TEXT: token, \
                                 doc.MISC: f'start_char={start_char}|end_char={end_char}'}
                    token_information = {**token_information, **tagged_token}
                    sent.append(token_information)
                    #print(mwt_tokens)
                    for i,c in enumerate(mwt_tokens):
                        #print('c:',c)
                        try:
                            c.pop('id')
                        except: 
                            print('except:',c)
                            raise
                        #print(stanza_2_tagged)
                        #print(c)
                        c['head'] = stanza_2_tagged[c['head']]
                        token_information = {doc.ID: token_id0 + i}
                        sent.append({**token_information, **c})
                    mwt_cases = mwt_cases[1:]
                else:
                    token_information = {doc.ID: token_id, doc.TEXT: token, \
                             doc.MISC: f'start_char={start_char}|end_char={end_char}'}
                    token_information = {**token_information, **tagged_token}
                    sent.append(token_information)

            else:
                token_information = {doc.ID: token_id, doc.TEXT: token, \
                             doc.MISC: f'start_char={start_char}|end_char={end_char}'}
                token_information = {**token_information, **tagged_token}
                sent.append(token_information)

            token_id+=1

            raw_text = raw_text[:start_char] + token + raw_text[end_char:]
        raw_texts.append(raw_text)
        #print(ant2new)
        for i in range(len(sent)):
            new_head = ant2new[sent[i]['head']]
            sent[i]['head'] = int(new_head)

        new_document.append(sent)

# %%
f

# %%
raw_texts='\n\n'.join(raw_texts)
phrases_str = '\n\n'.join(phrases)
print(new_document)
print(phrases_str)
new_document=doc.Document(new_document, phrases_str)
segmented_text = new_document.to_dict()
conllu = CoNLL.convert_dict(segmented_text)
output = list_to_conllu_text('out.conllu', conllu, phrases)

# %%
file = open('out.conllu', "w", encoding='utf-8')
file.write(output)
file.close()

# %%
# !cat  ~/.local/lib/python3.7/site-packages/stanza/models/common/doc.py
