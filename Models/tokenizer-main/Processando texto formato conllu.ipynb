# %% [markdown]
# ### Preprocessando documentos par o formato CONLLU

# %% [markdown]
# O parâmetr --idir é o caminho da pasta com os arquivos brutos que serão processados, e --odir é o caminho onde os arquivos conllu serão gravados.

# %%
# !python main.py --idir ../../Corpora/Predicao/Documentos_brutos/ --odir ../../Corpora/Predicao/Documentos_conllu/
# Out:
# loading file: ../../Corpora/Predicao/Documentos_brutos/1978.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x0c in position 98278: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/27267.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x0c in position 62404: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/29067.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x0c in position 46410: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/31206.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x0c in position 32846: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/32427.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x0c in position 169600: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/44669.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/57214.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x0c in position 61282: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/58850.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x0c in position 156868: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/58909.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x0c in position 31420: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/58910.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/58911.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/58912.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/58914.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/58916.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/58920.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/Bacia de Campos.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x2e in position 3674: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/Bacia de Santos.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x5d in position 8656: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/Bacia do Parana.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x5d in position 48826: truncated data
# loading file: ../../Corpora/Predicao/Documentos_brutos/Bacia do Reconcavo.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/Campo de Peregrino.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/Petróleo.txt
# thrid
# UTF-16 stream does not start with BOM
# loading file: ../../Corpora/Predicao/Documentos_brutos/Sistema Petrolífero.txt
# thrid
# 'utf-16-le' codec can't decode byte 0x5d in position 6490: truncated data
# 2023-09-12 09:11:26 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
#
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|          | 0.00/30.1k [00:00<?, ?B/s]
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 216kB [00:00, 33.2MB/s]
# 2023-09-12 09:11:27 INFO: Loading these models for language: pt (Portuguese):
# ==========================================
# | Processor    | Package                 |
# ------------------------------------------
# | tokenize     | bosque                  |
# | mwt          | bosque                  |
# | pos          | bosque                  |
# | lemma        | bosque                  |
# | constituency | cintil                  |
# | depparse     | ./models/p..._parser.pt |
# ==========================================
#
# 2023-09-12 09:11:27 WARNING: GPU requested, but is not available!
# 2023-09-12 09:11:27 INFO: Using device: cpu
# 2023-09-12 09:11:27 INFO: Loading: tokenize
# 2023-09-12 09:11:27 INFO: Loading: mwt
# 2023-09-12 09:11:27 INFO: Loading: pos
# 2023-09-12 09:11:28 INFO: Loading: lemma
# 2023-09-12 09:11:28 INFO: Loading: constituency
# 2023-09-12 09:11:28 INFO: Loading: depparse
# 2023-09-12 09:11:29 INFO: Done loading processors!
# 2023-09-12 09:11:29 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
#
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|          | 0.00/30.1k [00:00<?, ?B/s]
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 216kB [00:00, ?B/s]
# 2023-09-12 09:11:29 WARNING: Language pt package default expects mwt, which has been added
# 2023-09-12 09:11:29 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | mwt       | bosque  |
# =======================
#
# 2023-09-12 09:11:29 INFO: Using device: cpu
# 2023-09-12 09:11:29 INFO: Loading: tokenize
# 2023-09-12 09:11:29 INFO: Loading: mwt
# 2023-09-12 09:11:29 INFO: Done loading processors!
#
#   0%|          | 0/463 [00:00<?, ?it/s]
# 100%|##########| 463/463 [00:00<?, ?it/s]
# C:\ProgramData\Anaconda3\envs\Petro_KGraph\lib\site-packages\stanza\utils\conll.py:126: UserWarning: doc2conll is deprecated.  Please use "{:C}".format(doc) and use the text format directly
#   doc_conll = CoNLL.doc2conll(doc, include_comments=False)
# C:\Users\upe2\OneDrive - PETROBRAS\Documents\Repositorios\Petro_KGraph\Models\tokenizer-main\inf_stanza\inference.py:226: UserWarning: convert_dict is deprecated.  Please use "{:C}".format(doc) and use the text format directly
#   conllu = CoNLL.convert_dict(segmented_text)
#
#   0%|          | 0/321 [00:00<?, ?it/s]
# 100%|##########| 321/321 [00:00<?, ?it/s]
#
#   0%|          | 0/374 [00:00<?, ?it/s]
# 100%|##########| 374/374 [00:00<?, ?it/s]
#
#   0%|          | 0/238 [00:00<?, ?it/s]
# 100%|##########| 238/238 [00:00<?, ?it/s]
#
#   0%|          | 0/807 [00:00<?, ?it/s]
# 100%|##########| 807/807 [00:00<?, ?it/s]
#
#   0%|          | 0/804 [00:00<?, ?it/s]
# 100%|##########| 804/804 [00:00<?, ?it/s]
#
#   0%|          | 0/356 [00:00<?, ?it/s]
# 100%|##########| 356/356 [00:00<?, ?it/s]
#
#   0%|          | 0/863 [00:00<?, ?it/s]
# 100%|##########| 863/863 [00:00<?, ?it/s]
#
#   0%|          | 0/219 [00:00<?, ?it/s]
# 100%|##########| 219/219 [00:00<?, ?it/s]
#
#   0%|          | 0/255 [00:00<?, ?it/s]
# 100%|##########| 255/255 [00:00<?, ?it/s]
#
#   0%|          | 0/203 [00:00<?, ?it/s]
# 100%|##########| 203/203 [00:00<?, ?it/s]
#
#   0%|          | 0/192 [00:00<?, ?it/s]
# 100%|##########| 192/192 [00:00<?, ?it/s]
#
#   0%|          | 0/239 [00:00<?, ?it/s]
# 100%|##########| 239/239 [00:00<?, ?it/s]
#
#   0%|          | 0/371 [00:00<?, ?it/s]
# 100%|##########| 371/371 [00:00<00:00, 184283.13it/s]
#
#   0%|          | 0/238 [00:00<?, ?it/s]
# 100%|##########| 238/238 [00:00<00:00, 238757.32it/s]
#
#   0%|          | 0/23 [00:00<?, ?it/s]
# 100%|##########| 23/23 [00:00<?, ?it/s]
#
#   0%|          | 0/57 [00:00<?, ?it/s]
# 100%|##########| 57/57 [00:00<?, ?it/s]
#
#   0%|          | 0/294 [00:00<?, ?it/s]
# 100%|##########| 294/294 [00:00<?, ?it/s]
#
#   0%|          | 0/101 [00:00<?, ?it/s]
# 100%|##########| 101/101 [00:00<?, ?it/s]
#
#   0%|          | 0/16 [00:00<?, ?it/s]
# 100%|##########| 16/16 [00:00<?, ?it/s]
#
#   0%|          | 0/257 [00:00<?, ?it/s]
# 100%|##########| 257/257 [00:00<?, ?it/s]
#
#   0%|          | 0/61 [00:00<?, ?it/s]
# 100%|##########| 61/61 [00:00<?, ?it/s]
