# %%
tokenization_pattern = r'''al\.|[.,;:"“”'?():_`]|\w*(?:[^;"“”'?():_`\s]*\w+)+[%º°?']?|[\S]'''
#pattern = r'''([.](?=[\s]+[A-Z])|[\s\.]*[\n\r]+[\s]*(?=[A-Z]))'''
pattern = r'''((?<!\d)+[.](?=[\s]*[A-Z])|[\s\.]*[\n\r]+[\s]*(?=[A-Z]))'''

# %%
import re
def list_to_conllu_text(document_filename: str, conllu_list: list, phrases: list):
    value_list = []
    for s,(sentence,text) in enumerate(zip(conllu_list, phrases)):
        #text = " ".join([token[1] for token in sentence if '-' not in token[0]])
        sent_id = str(s+1)
        content = "\n".join(["\t".join(token[:]) for token in sentence])
        value_list.append("# sent_id = {}-{}\n# text = {}\n{}".format(document_filename, sent_id, text, content))
    return "\n\n".join(value_list)

def portuguese_sentenciation(text):
    #pattern = r'''([.](?=[\s]+[A-Z])|[\s\.]*[\n\r]+[\s]*(?=[A-Z]))'''
    original_values = re.split(pattern, text)
    values = ['{} {}'.format(f1,f2) for f1,f2 in zip(original_values[::2],original_values[1::2])]
    real_values = ['{}{}'.format(f1,f2) for f1,f2 in zip(original_values[::2],original_values[1::2])]
    for value,rvalue in zip(values,real_values):
        value = recursive_space_removal(value)
        rvalue = recursive_space_removal(rvalue)
        if "\n" in value or "\r" in value:
            continue
        yield value,rvalue


def recursive_space_removal(value):
    try:
        if value[0] == " ":
            value = value[1:]
            return recursive_space_removal(value)
        else:
            return value
    except IndexError:
        return value

def text_preprocessing(text):
    # TEXTBAR PREPROCESSING
    text = text.replace(" / ", "##SPACE-BAR-SPACE##")
    text = text.replace(" \ ", "##SPACE-LBAR-SPACE##")
    text = text.replace("/ ", "/")
    text = text.replace(r"\ ", "\\")
    text = text.replace(" /", "/")
    text = text.replace(r" \\", "\\")
    text = text.replace("##SPACE-BAR-SPACE##", r" / ")
    text = text.replace("##SPACE-LBAR-SPACE##", r" \ ")
    return text

# %%
def spans(txt, tokens):
    offset = 0
    all_spans = []
    for token in tokens:
        offset = txt.find(token, offset)
        all_spans.append((token, offset, offset + len(token)))
        offset += len(token)
    return all_spans

# %%
import sys
import os
import re
import datetime
import stanza
from stanza import Pipeline
from stanza.utils.conll import CoNLL
from stanza.models.common import doc
import numpy as np
import itertools
stanza.download('pt')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.0.0.json: 115kB [00:00, 3.72MB/s]
# 2020-06-11 00:53:11 INFO: Downloading default packages for language: pt (Portuguese)...
# 2020-06-11 00:53:11 INFO: File exists: C:\Users\criss\stanza_resources\pt\default.zip.
# 2020-06-11 00:53:14 INFO: Finished downloading models and saved to C:\Users\criss\stanza_resources.

# %%
#input_file='data/6-20140908-MONOGRAFIA_0_intro.txt'

# %%
def get_mwts(token_sentence, tokens_by_id):
    mwts = []
    for i in range(len(token_sentence)):
        token = token_sentence[i]
        if '-' in token['id']:
            ids = token['id'].split('-')
            mwts.append((token['text'] , [tokens_by_id[idx] for idx in ids]))
    return mwts

# %%
#input_filename = '6-20140908-MONOGRAFIA_0_intro'
input_filename = '10-20150122-MONOGRAFIA_0_intro'
#input_filename = '0-20150121-TESEMSC_0_intro'
input_path='data/{}.txt'.format(input_filename)

# %%
def get_stanza_2_tagged(stanza_token_sentence, tagged_sentence):
    filtered_stanza_token_sentence = []
    skip_tokens_id = []
    for token in stanza_token_sentence:
        if token['id'] in skip_tokens_id:
            continue
        if '-' in token['id']:
            skip_tokens_id =[idx for idx in token['id'].split('-')]
        filtered_stanza_token_sentence.append(token)

    for i,token in enumerate(filtered_stanza_token_sentence):
        filtered_stanza_token_sentence[i]['start']=int(token['misc'].split('|')[0][11:])

    for i,token in enumerate(tagged_sentence):
        tagged_sentence[i]['start']=int(token['misc'].split('|')[0][11:])

    stanza_2_tagged = {}
    stanza_2_tagged['0']='0'
    for ftoken in filtered_stanza_token_sentence:
        compare=[]
        for i,ttoken in enumerate(tagged_sentence):
            ftext = set(ftoken['text'])
            ttext =set(ttoken['text'])
            if min(len(ftext-ttext),len(ttext-ftext))==0:
                compare.append((i, abs(ftoken['start'] - ttoken['start'])))
        if len(compare)==0:
            continue
            
        idx = min(compare, key=lambda x:x[1])[0]
        for f_id in ftoken['id'].split('-'):
            stanza_2_tagged[f_id] = tagged_sentence[idx]['id']
    
    return stanza_2_tagged

# %%
input_filename
# Out:
# '10-20150122-MONOGRAFIA_0_intro'

# %%
def merge_stanza_token_sentences(stanza_token_sentences):
    offset=0
    for i in range(len(stanza_token_sentences)):
        for j in range(len(stanza_token_sentences[i])):
            if 'head' in stanza_token_sentences[i][j]:
                stanza_token_sentences[i][j]['head']=str(int(stanza_token_sentences[i][j]['head'])+offset)

            if '-' in stanza_token_sentences[i][j]['id']:
                ids = stanza_token_sentences[i][j]['id'].split('-')
                stanza_token_sentences[i][j]['id'] = '-'.join([str(int(id)+offset) for id in ids])
            else:
                stanza_token_sentences[i][j]['id'] = str(int(stanza_token_sentences[i][j]['id']) + offset)

        offset=int(stanza_token_sentences[i][-1]['id'])
    stanza_token_sentences = list(itertools.chain.from_iterable(stanza_token_sentences))
    return stanza_token_sentences

# %%
def conllu_process_file(input_filename):
    input_path='data/{}.txt'.format(input_filename)
    infile = open(input_path, "rb")
    text = infile.read().decode('utf-8')
    preprocessed_text = text_preprocessing(text)
    #sentences = portuguese_sentenciation(preprocessed_text)
    tok_nlp = Pipeline(lang='pt', tokenize_pretokenized=False)#processors='tokenize,mwt', 
    tag_nlp = Pipeline(lang='pt', tokenize_pretokenized=True)#processors='tokenize,pos,lemma,depparse',

    sentences = portuguese_sentenciation(preprocessed_text)
    new_document=[]
    raw_texts=[]
    phrases = []
    for phrase,rphrase in sentences:
        if not phrase=='':
            phrases.append(rphrase)
            stanza_sentence = tok_nlp(phrase)
            stanza_token_sentences = stanza_sentence.to_dict()
            stanza_token_sentence = merge_stanza_token_sentences(stanza_token_sentences)
            tokens_by_id = {token['id']:token for token in stanza_token_sentence}
            mwt_cases = get_mwts(stanza_token_sentence, tokens_by_id)

            sentence = re.findall(tokenization_pattern, phrase)
            tagged_sentences = tag_nlp([sentence])     
            tagged_sentences = tagged_sentences.to_dict()
            tagged_sentence = tagged_sentences[0]
            assert len(tagged_sentence)==len(sentence)

            sentence = spans(rphrase,sentence)

            stanza_2_tagged = get_stanza_2_tagged(stanza_token_sentence, tagged_sentence)

            max_str = sentence[-1][-1]
            raw_text =" "*max_str
            sent = []
            ant2new = {}
            ant2new['0']=0
            token_id=1
            for (token,start_char,end_char),tagged_token in zip(sentence,tagged_sentence):
                idx=tagged_token['id']
                ant2new[idx]=token_id
                tagged_token.pop('key',None)
                tagged_token.pop('misc',None)
                tagged_token.pop('id',None)
                tagged_token.pop('text',None)

                if not len(mwt_cases)==0:
                    mwt_token_key = mwt_cases[0][0]
                    mwt_tokens = mwt_cases[0][1]

                    if token == mwt_token_key:
                        token_id0 = token_id
                        token_id = token_id + len(mwt_tokens)-1
                        token_information = {doc.ID: '{}-{}'.format(token_id0, token_id), doc.TEXT: token, \
                                     doc.MISC: f'start_char={start_char}|end_char={end_char}'}
                        token_information = {**token_information, **tagged_token}
                        sent.append(token_information)
                        for i,c in enumerate(mwt_tokens):
                            try:
                                c.pop('id')
                            except: 
                                print(c)

                            c['head'] = stanza_2_tagged[str(c['head'])]
                            token_information = {doc.ID: str(token_id0 + i)}
                            sent.append({**token_information, **c})
                        mwt_cases = mwt_cases[1:]
                    else:
                        token_information = {doc.ID: str(token_id), doc.TEXT: token, \
                                 doc.MISC: f'start_char={start_char}|end_char={end_char}'}
                        token_information = {**token_information, **tagged_token}
                        sent.append(token_information)

                else:
                    token_information = {doc.ID: str(token_id), doc.TEXT: token, \
                                 doc.MISC: f'start_char={start_char}|end_char={end_char}'}
                    token_information = {**token_information, **tagged_token}
                    sent.append(token_information)

                token_id+=1

                raw_text = raw_text[:start_char] + token + raw_text[end_char:]
            raw_texts.append(raw_text)
            for i in range(len(sent)):
                new_head = ant2new[str(sent[i]['head'])]
                sent[i]['head'] = int(new_head)

            new_document.append(sent)
    raw_texts='\n\n'.join(raw_texts)
    phrases_str = '\n\n'.join(phrases)
    new_document=doc.Document(new_document, phrases_str)
    segmented_text = new_document.to_dict()
    conllu = CoNLL.convert_dict(segmented_text)
    output = list_to_conllu_text(input_filename, conllu, phrases)  
    return output

# %%
output = conllu_process_file(input_filename=input_filename)
# Out:
# 2020-06-11 00:55:22 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | mwt       | bosque  |
# | pos       | bosque  |
# | lemma     | bosque  |
# | depparse  | bosque  |
# =======================
#
# 2020-06-11 00:55:22 INFO: Use device: cpu
# 2020-06-11 00:55:22 INFO: Loading: tokenize
# 2020-06-11 00:55:22 INFO: Loading: mwt
# 2020-06-11 00:55:22 INFO: Loading: pos
# 2020-06-11 00:55:23 INFO: Loading: lemma
# 2020-06-11 00:55:23 INFO: Loading: depparse
# 2020-06-11 00:55:24 INFO: Done loading processors!
# 2020-06-11 00:55:24 INFO: Loading these models for language: pt (Portuguese):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | bosque  |
# | mwt       | bosque  |
# | pos       | bosque  |
# | lemma     | bosque  |
# | depparse  | bosque  |
# =======================
#
# 2020-06-11 00:55:24 INFO: Use device: cpu
# 2020-06-11 00:55:24 INFO: Loading: tokenize
# 2020-06-11 00:55:24 INFO: Loading: mwt
# 2020-06-11 00:55:24 INFO: Loading: pos
# 2020-06-11 00:55:25 INFO: Loading: lemma
# 2020-06-11 00:55:25 INFO: Loading: depparse
# 2020-06-11 00:55:26 INFO: Done loading processors!

# %%
print(output)
# Out:
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-1
# # text = ﻿1. Introdução O princípio de funcionamento remonta à 1801, quando um gerador com célula a combustível usando uma pilha de zinco e oxigênio produzia o zincato de sódio (Sir Humphrey, Inglaterra).
# 1	﻿1	﻿1	PROPN	_	Gender=Masc|Number=Sing	8	nsubj	_	start_char=0|end_char=2
# 2	.	.	PUNCT	_	_	1	punct	_	start_char=2|end_char=3
# 3	Introdução	introdução	NOUN	_	Gender=Fem|Number=Sing	1	appos	_	start_char=4|end_char=14
# 4	O	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	5	det	_	start_char=15|end_char=16
# 5	princípio	princípio	NOUN	_	Gender=Masc|Number=Sing	8	nsubj	_	start_char=17|end_char=26
# 6	de	de	ADP	_	_	7	case	_	start_char=27|end_char=29
# 7	funcionamento	funcionamento	NOUN	_	Gender=Masc|Number=Sing	5	nmod	_	start_char=30|end_char=43
# 8	remonta	remontar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	start_char=44|end_char=51
# 9-10	à	_	_	_	_	_	_	_	start_char=52|end_char=53
# 9	a	ela	PRON	_	Case=Acc|Gender=Fem|Number=Sing|Person=3|PronType=Prs	8	obj	_	_
# 10	a	a	ADP	_	_	11	case	_	_
# 11	1801	1801	NUM	_	NumType=Card	8	obl	_	start_char=54|end_char=58
# 12	,	,	PUNCT	_	_	8	punct	_	start_char=58|end_char=59
# 13	quando	quando	ADV	_	_	27	advmod	_	start_char=60|end_char=66
# 14	um	um	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	15	det	_	start_char=67|end_char=69
# 15	gerador	gerador	NOUN	_	Gender=Masc|Number=Sing	27	nsubj	_	start_char=70|end_char=77
# 16	com	com	ADP	_	_	17	case	_	start_char=78|end_char=81
# 17	célula	célula	NOUN	_	Gender=Fem|Number=Sing	15	nmod	_	start_char=82|end_char=88
# 18	a	a	ADP	_	_	19	case	_	start_char=89|end_char=90
# 19	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	17	nmod	_	start_char=91|end_char=102
# 20	usando	usar	VERB	_	VerbForm=Ger	15	acl	_	start_char=103|end_char=109
# 21	uma	um	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	22	det	_	start_char=110|end_char=113
# 22	pilha	pilha	NOUN	_	Gender=Fem|Number=Sing	20	obj	_	start_char=114|end_char=119
# 23	de	de	ADP	_	_	24	case	_	start_char=120|end_char=122
# 24	zinco	zinco	NOUN	_	Gender=Masc|Number=Sing	22	nmod	_	start_char=123|end_char=128
# 25	e	e	CCONJ	_	_	26	cc	_	start_char=129|end_char=130
# 26	oxigênio	oxigênio	NOUN	_	Gender=Masc|Number=Sing	24	conj	_	start_char=131|end_char=139
# 27	produzia	produzir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	8	conj	_	start_char=140|end_char=148
# 28	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	29	det	_	start_char=149|end_char=150
# 29	zincato	zincato	NOUN	_	Gender=Masc|Number=Sing	27	obj	_	start_char=151|end_char=158
# 30	de	de	ADP	_	_	31	case	_	start_char=159|end_char=161
# 31	sódio	sódio	NOUN	_	Gender=Masc|Number=Sing	29	nmod	_	start_char=162|end_char=167
# 32	(	(	PUNCT	_	_	33	punct	_	start_char=168|end_char=169
# 33	Sir	sir	PROPN	_	Gender=Masc|Number=Sing	29	appos	_	start_char=169|end_char=172
# 34	Humphrey	Humphrey	PROPN	_	Number=Sing	33	flat:name	_	start_char=173|end_char=181
# 35	,	,	PUNCT	_	_	36	punct	_	start_char=181|end_char=182
# 36	Inglaterra	Inglaterra	PROPN	_	Gender=Fem|Number=Sing	33	appos	_	start_char=183|end_char=193
# 37	)	)	PUNCT	_	_	33	punct	_	start_char=193|end_char=194
# 38	.	.	PUNCT	_	_	1	punct	_	start_char=194|end_char=195
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-2
# # text = O conceito de células a combustível (CC) existe há mais de 150 anos, cuja paternidade é atribuída a Sir William Grove, que teve a idéia durante seus experimentos sobre a eletrólise de água, quando imaginou como seria o processo inverso, ou seja, a reação entre hidrogênio e oxigênio para gerar eletricidade.
# 1	O	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	_	start_char=0|end_char=1
# 2	conceito	conceito	NOUN	_	Gender=Masc|Number=Sing	10	nsubj	_	start_char=2|end_char=10
# 3	de	de	ADP	_	_	4	case	_	start_char=11|end_char=13
# 4	células	célula	NOUN	_	Gender=Fem|Number=Plur	2	nmod	_	start_char=14|end_char=21
# 5	a	a	ADP	_	_	6	case	_	start_char=22|end_char=23
# 6	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	4	nmod	_	start_char=24|end_char=35
# 7	(	(	PUNCT	_	_	8	punct	_	start_char=36|end_char=37
# 8	CC	CC	PROPN	_	Gender=Masc|Number=Sing	6	appos	_	start_char=37|end_char=39
# 9	)	)	PUNCT	_	_	8	punct	_	start_char=39|end_char=40
# 10	existe	existir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	start_char=41|end_char=47
# 11	há	há	ADP	_	_	15	case	_	start_char=48|end_char=50
# 12	mais	mais	ADV	_	_	14	advmod	_	start_char=51|end_char=55
# 13	de	de	ADP	_	_	12	fixed	_	start_char=56|end_char=58
# 14	150	150	NUM	_	NumType=Card	15	nummod	_	start_char=59|end_char=62
# 15	anos	ano	NOUN	_	Gender=Masc|Number=Plur	10	obl	_	start_char=63|end_char=67
# 16	,	,	PUNCT	_	_	10	punct	_	start_char=67|end_char=68
# 17	cuja	cujo	DET	_	Gender=Fem|Number=Sing|PronType=Rel	18	det	_	start_char=69|end_char=73
# 18	paternidade	paternidade	NOUN	_	Gender=Fem|Number=Sing	20	nsubj:pass	_	start_char=74|end_char=85
# 19	é	ser	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	20	aux:pass	_	start_char=86|end_char=87
# 20	atribuída	atribuir	VERB	_	Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass	15	acl:relcl	_	start_char=88|end_char=97
# 21	a	a	ADP	_	_	22	case	_	start_char=98|end_char=99
# 22	Sir	sir	PROPN	_	Gender=Masc|Number=Sing	20	obl	_	start_char=100|end_char=103
# 23	William	William	PROPN	_	Number=Sing	22	flat:name	_	start_char=104|end_char=111
# 24	Grove	Grove	PROPN	_	Number=Sing	22	flat:name	_	start_char=112|end_char=117
# 25	,	,	PUNCT	_	_	20	punct	_	start_char=117|end_char=118
# 26	que	que	PRON	_	Gender=Masc|Number=Sing|PronType=Rel	27	nsubj	_	start_char=119|end_char=122
# 27	teve	ter	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	22	acl:relcl	_	start_char=123|end_char=127
# 28	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	29	det	_	start_char=128|end_char=129
# 29	idéia	idéia	NOUN	_	Gender=Fem|Number=Sing	27	obj	_	start_char=130|end_char=135
# 30	durante	durante	ADP	_	_	32	case	_	start_char=136|end_char=143
# 31	seus	seu	DET	_	Gender=Masc|Number=Plur|PronType=Prs	32	det	_	start_char=144|end_char=148
# 32	experimentos	experimento	NOUN	_	Gender=Masc|Number=Plur	27	obl	_	start_char=149|end_char=161
# 33	sobre	sobre	ADP	_	_	35	case	_	start_char=162|end_char=167
# 34	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	35	det	_	start_char=168|end_char=169
# 35	eletrólise	eletrólise	NOUN	_	Gender=Fem|Number=Sing	32	nmod	_	start_char=170|end_char=180
# 36	de	de	ADP	_	_	37	case	_	start_char=181|end_char=183
# 37	água	água	NOUN	_	Gender=Fem|Number=Sing	35	nmod	_	start_char=184|end_char=188
# 38	,	,	PUNCT	_	_	27	punct	_	start_char=188|end_char=189
# 39	quando	quando	ADV	_	_	40	advmod	_	start_char=190|end_char=196
# 40	imaginou	imaginar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	27	advcl	_	start_char=197|end_char=205
# 41	como	como	ADV	_	_	44	advmod	_	start_char=206|end_char=210
# 42	seria	ser	AUX	_	Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin	44	cop	_	start_char=211|end_char=216
# 43	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	44	det	_	start_char=217|end_char=218
# 44	processo	processo	NOUN	_	Gender=Masc|Number=Sing	40	ccomp	_	start_char=219|end_char=227
# 45	inverso	inverso	ADJ	_	Gender=Masc|Number=Sing	44	amod	_	start_char=228|end_char=235
# 46	,	,	PUNCT	_	_	47	punct	_	start_char=235|end_char=236
# 47	ou	ou	CCONJ	_	_	51	cc	_	start_char=237|end_char=239
# 48	seja	ser	VERB	_	Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	47	fixed	_	start_char=240|end_char=244
# 49	,	,	PUNCT	_	_	47	punct	_	start_char=244|end_char=245
# 50	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	51	det	_	start_char=246|end_char=247
# 51	reação	reação	NOUN	_	Gender=Fem|Number=Sing	44	conj	_	start_char=248|end_char=254
# 52	entre	entre	ADP	_	_	53	case	_	start_char=255|end_char=260
# 53	hidrogênio	hidrogênio	NOUN	_	Gender=Masc|Number=Sing	51	nmod	_	start_char=261|end_char=271
# 54	e	e	CCONJ	_	_	55	cc	_	start_char=272|end_char=273
# 55	oxigênio	oxigênio	NOUN	_	Gender=Masc|Number=Sing	53	conj	_	start_char=274|end_char=282
# 56	para	para	SCONJ	_	_	57	mark	_	start_char=283|end_char=287
# 57	gerar	gerar	VERB	_	VerbForm=Inf	51	acl	_	start_char=288|end_char=293
# 58	eletricidade	eletricidade	NOUN	_	Gender=Fem|Number=Sing	57	obj	_	start_char=294|end_char=306
# 59	.	.	PUNCT	_	_	10	punct	_	start_char=306|end_char=307
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-3
# # text = O termo célula a combustível surgiu então em 1839, criado por Ludwig Mond e Charles Langer.
# 1	O	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	_	start_char=0|end_char=1
# 2	termo	termo	NOUN	_	Gender=Masc|Number=Sing	6	nsubj	_	start_char=2|end_char=7
# 3	célula	célulo	ADJ	_	Gender=Fem|Number=Sing	2	amod	_	start_char=8|end_char=14
# 4	a	a	ADP	_	_	5	case	_	start_char=15|end_char=16
# 5	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	2	nmod	_	start_char=17|end_char=28
# 6	surgiu	surgir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	_	start_char=29|end_char=35
# 7	então	então	ADV	_	_	6	advmod	_	start_char=36|end_char=41
# 8	em	em	ADP	_	_	9	case	_	start_char=42|end_char=44
# 9	1839	1839	NUM	_	NumType=Card	6	obl	_	start_char=45|end_char=49
# 10	,	,	PUNCT	_	_	11	punct	_	start_char=49|end_char=50
# 11	criado	criar	VERB	_	Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass	9	acl	_	start_char=51|end_char=57
# 12	por	por	ADP	_	_	13	case	_	start_char=58|end_char=61
# 13	Ludwig	Ludwig	PROPN	_	Gender=Masc|Number=Sing	11	obl:agent	_	start_char=62|end_char=68
# 14	Mond	Mond	PROPN	_	Number=Sing	13	flat:name	_	start_char=69|end_char=73
# 15	e	e	CCONJ	_	_	16	cc	_	start_char=74|end_char=75
# 16	Charles	Charles	PROPN	_	Gender=Masc|Number=Sing	13	nmod	_	start_char=76|end_char=83
# 17	Langer	Langer	PROPN	_	Number=Sing	16	flat:name	_	start_char=84|end_char=90
# 18	.	.	PUNCT	_	_	6	punct	_	start_char=90|end_char=91
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-4
# # text = No final dos anos 50, a NASA necessitava de geradores de energia para missões espaciais, em especial, o projeto Apollo e as missões Space Shuttle fizeram uso de células a combustível.
# 1-2	No	_	_	_	_	_	_	_	start_char=0|end_char=2
# 1	Em	em	ADP	_	_	3	case	_	_
# 2	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	3	det	_	_
# 3	final	final	NOUN	_	Gender=Masc|Number=Sing	11	obl	_	start_char=3|end_char=8
# 4-5	dos	_	_	_	_	_	_	_	start_char=9|end_char=12
# 4	de	de	ADP	_	_	6	case	_	_
# 5	os	o	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	6	det	_	_
# 6	anos	ano	NOUN	_	Gender=Masc|Number=Plur	3	nmod	_	start_char=13|end_char=17
# 7	50	50	NUM	_	NumType=Card	6	nummod	_	start_char=18|end_char=20
# 8	,	,	PUNCT	_	_	3	punct	_	start_char=20|end_char=21
# 9	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	10	det	_	start_char=22|end_char=23
# 10	NASA	NASA	PROPN	_	Gender=Fem|Number=Sing	11	nsubj	_	start_char=24|end_char=28
# 11	necessitava	necessitar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	0	root	_	start_char=29|end_char=40
# 12	de	de	ADP	_	_	13	case	_	start_char=41|end_char=43
# 13	geradores	gerador	NOUN	_	Gender=Masc|Number=Plur	11	obj	_	start_char=44|end_char=53
# 14	de	de	ADP	_	_	15	case	_	start_char=54|end_char=56
# 15	energia	energia	NOUN	_	Gender=Fem|Number=Sing	13	nmod	_	start_char=57|end_char=64
# 16	para	para	ADP	_	_	17	case	_	start_char=65|end_char=69
# 17	missões	missão	NOUN	_	Gender=Fem|Number=Plur	11	obl	_	start_char=70|end_char=77
# 18	espaciais	espacial	ADJ	_	Gender=Fem|Number=Plur	17	amod	_	start_char=78|end_char=87
# 19	,	,	PUNCT	_	_	21	punct	_	start_char=87|end_char=88
# 20	em	em	ADP	_	_	21	case	_	start_char=89|end_char=91
# 21	especial	especial	ADJ	_	Gender=Masc|Number=Sing	31	obl	_	start_char=92|end_char=100
# 22	,	,	PUNCT	_	_	21	punct	_	start_char=100|end_char=101
# 23	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	24	det	_	start_char=102|end_char=103
# 24	projeto	projeto	NOUN	_	Gender=Masc|Number=Sing	31	nsubj	_	start_char=104|end_char=111
# 25	Apollo	Apollo	PROPN	_	Gender=Masc|Number=Sing	24	appos	_	start_char=112|end_char=118
# 26	e	e	CCONJ	_	_	28	cc	_	start_char=119|end_char=120
# 27	as	o	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	28	det	_	start_char=121|end_char=123
# 28	missões	missão	NOUN	_	Gender=Fem|Number=Plur	24	conj	_	start_char=124|end_char=131
# 29	Space	Space	PROPN	_	Gender=Fem|Number=Sing	28	appos	_	start_char=132|end_char=137
# 30	Shuttle	Shuttle	PROPN	_	Number=Sing	29	flat:name	_	start_char=138|end_char=145
# 31	fizeram	fazer	VERB	_	Mood=Ind|Number=Plur|Person=3|VerbForm=Fin	11	conj	_	start_char=146|end_char=153
# 32	uso	uso	NOUN	_	Gender=Masc|Number=Sing	31	obj	_	start_char=154|end_char=157
# 33	de	de	ADP	_	_	34	case	_	start_char=158|end_char=160
# 34	células	célula	NOUN	_	Gender=Fem|Number=Plur	32	nmod	_	start_char=161|end_char=168
# 35	a	a	ADP	_	_	36	case	_	start_char=169|end_char=170
# 36	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	34	nmod	_	start_char=171|end_char=182
# 37	.	.	PUNCT	_	_	11	punct	_	start_char=182|end_char=183
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-5
# # text = As células a combustível (Figura 1) são unidades que convertem energia química (contida em um oxidante e um combustível) diretamente em energia elétrica e térmica, com a possibilidade de operação contínua graças a alimentação constante de um combustível.
# 1	As	o	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	2	det	_	start_char=0|end_char=2
# 2	células	célula	NOUN	_	Gender=Fem|Number=Plur	10	nsubj	_	start_char=3|end_char=10
# 3	a	a	ADP	_	_	4	case	_	start_char=11|end_char=12
# 4	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	2	nmod	_	start_char=13|end_char=24
# 5	(	(	PUNCT	_	_	6	punct	_	start_char=25|end_char=26
# 6	Figura	Figura	PROPN	_	Gender=Fem|Number=Sing	4	appos	_	start_char=26|end_char=32
# 7	1	1	PROPN	_	Number=Sing	6	flat:name	_	start_char=33|end_char=34
# 8	)	)	PUNCT	_	_	6	punct	_	start_char=34|end_char=35
# 9	são	ser	AUX	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	10	cop	_	start_char=36|end_char=39
# 10	unidades	unidade	NOUN	_	Gender=Fem|Number=Plur	0	root	_	start_char=40|end_char=48
# 11	que	que	PRON	_	Gender=Fem|Number=Plur|PronType=Rel	12	nsubj	_	start_char=49|end_char=52
# 12	convertem	converter	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	10	acl:relcl	_	start_char=53|end_char=62
# 13	energia	energia	NOUN	_	Gender=Fem|Number=Sing	12	obj	_	start_char=63|end_char=70
# 14	química	química	ADJ	_	Gender=Fem|Number=Sing	13	amod	_	start_char=71|end_char=78
# 15	(	(	PUNCT	_	_	16	punct	_	start_char=79|end_char=80
# 16	contida	conter	VERB	_	Gender=Fem|Number=Sing|VerbForm=Part	13	acl	_	start_char=80|end_char=87
# 17	em	em	ADP	_	_	19	case	_	start_char=88|end_char=90
# 18	um	um	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	19	det	_	start_char=91|end_char=93
# 19	oxidante	oxidante	NOUN	_	Gender=Masc|Number=Sing	16	obl	_	start_char=94|end_char=102
# 20	e	e	CCONJ	_	_	22	cc	_	start_char=103|end_char=104
# 21	um	um	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	22	det	_	start_char=105|end_char=107
# 22	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	19	conj	_	start_char=108|end_char=119
# 23	)	)	PUNCT	_	_	16	punct	_	start_char=119|end_char=120
# 24	diretamente	diretamente	ADV	_	_	26	advmod	_	start_char=121|end_char=132
# 25	em	em	ADP	_	_	26	case	_	start_char=133|end_char=135
# 26	energia	energia	NOUN	_	Gender=Fem|Number=Sing	12	obl	_	start_char=136|end_char=143
# 27	elétrica	elétrico	ADJ	_	Gender=Fem|Number=Sing	26	amod	_	start_char=144|end_char=152
# 28	e	e	CCONJ	_	_	29	cc	_	start_char=153|end_char=154
# 29	térmica	térmico	ADJ	_	Gender=Fem|Number=Sing	27	conj	_	start_char=155|end_char=162
# 30	,	,	PUNCT	_	_	33	punct	_	start_char=162|end_char=163
# 31	com	com	ADP	_	_	33	case	_	start_char=164|end_char=167
# 32	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	33	det	_	start_char=168|end_char=169
# 33	possibilidade	possibilidade	NOUN	_	Gender=Fem|Number=Sing	12	obl	_	start_char=170|end_char=183
# 34	de	de	ADP	_	_	35	case	_	start_char=184|end_char=186
# 35	operação	operação	NOUN	_	Gender=Fem|Number=Sing	33	nmod	_	start_char=187|end_char=195
# 36	contínua	contínuo	ADJ	_	Gender=Fem|Number=Sing	35	amod	_	start_char=196|end_char=204
# 37	graças	graças	ADV	_	_	39	case	_	start_char=205|end_char=211
# 38	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	37	fixed	_	start_char=212|end_char=213
# 39	alimentação	alimentação	NOUN	_	Gender=Fem|Number=Sing	33	nmod	_	start_char=214|end_char=225
# 40	constante	constante	ADJ	_	Gender=Fem|Number=Sing	39	amod	_	start_char=226|end_char=235
# 41	de	de	ADP	_	_	43	case	_	start_char=236|end_char=238
# 42	um	um	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	43	det	_	start_char=239|end_char=241
# 43	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	39	nmod	_	start_char=242|end_char=253
# 44	.	.	PUNCT	_	_	10	punct	_	start_char=253|end_char=254
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-6
# # text = A conversão ocorre por meio de duas reações eletroquímicas em dois eletrodos separados por um eletrólito apropriado: a oxidação de um combustível no anodo e a redução de um oxidante no catodo.
# 1	A	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	2	det	_	start_char=0|end_char=1
# 2	conversão	conversão	NOUN	_	Gender=Fem|Number=Sing	3	nsubj	_	start_char=2|end_char=11
# 3	ocorre	ocorrer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	start_char=12|end_char=18
# 4	por	por	ADP	_	_	5	case	_	start_char=19|end_char=22
# 5	meio	meio	NOUN	_	Gender=Masc|Number=Sing	3	obl	_	start_char=23|end_char=27
# 6	de	de	ADP	_	_	4	fixed	_	start_char=28|end_char=30
# 7	duas	dois	NUM	_	NumType=Card	8	nummod	_	start_char=31|end_char=35
# 8	reações	reação	NOUN	_	Gender=Fem|Number=Plur	5	nmod	_	start_char=36|end_char=43
# 9	eletroquímicas	eletroquímico	ADJ	_	Gender=Fem|Number=Plur	8	amod	_	start_char=44|end_char=58
# 10	em	em	ADP	_	_	12	case	_	start_char=59|end_char=61
# 11	dois	dois	NUM	_	NumType=Card	12	nummod	_	start_char=62|end_char=66
# 12	eletrodos	eletrodo	NOUN	_	Gender=Masc|Number=Plur	8	nmod	_	start_char=67|end_char=76
# 13	separados	separar	VERB	_	Gender=Masc|Number=Plur|VerbForm=Part|Voice=Pass	12	acl	_	start_char=77|end_char=86
# 14	por	por	ADP	_	_	16	case	_	start_char=87|end_char=90
# 15	um	um	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	16	det	_	start_char=91|end_char=93
# 16	eletrólito	eletrólito	NOUN	_	Gender=Masc|Number=Sing	13	obl:agent	_	start_char=94|end_char=104
# 17	apropriado	apropriar	VERB	_	Gender=Masc|Number=Sing|VerbForm=Part	16	acl	_	start_char=105|end_char=115
# 18	:	:	PUNCT	_	_	3	punct	_	start_char=115|end_char=116
# 19	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	20	det	_	start_char=117|end_char=118
# 20	oxidação	oxidação	NOUN	_	Gender=Fem|Number=Sing	16	appos	_	start_char=119|end_char=127
# 21	de	de	ADP	_	_	23	case	_	start_char=128|end_char=130
# 22	um	um	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	23	det	_	start_char=131|end_char=133
# 23	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	20	nmod	_	start_char=134|end_char=145
# 24-25	no	_	_	_	_	_	_	_	start_char=146|end_char=148
# 24	em	em	ADP	_	_	26	case	_	_
# 25	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	26	det	_	_
# 26	anodo	anodo	NOUN	_	Gender=Masc|Number=Sing	23	nmod	_	start_char=149|end_char=154
# 27	e	e	CCONJ	_	_	29	cc	_	start_char=155|end_char=156
# 28	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	29	det	_	start_char=157|end_char=158
# 29	redução	redução	NOUN	_	Gender=Fem|Number=Sing	20	conj	_	start_char=159|end_char=166
# 30	de	de	ADP	_	_	32	case	_	start_char=167|end_char=169
# 31	um	um	DET	_	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	32	det	_	start_char=170|end_char=172
# 32	oxidante	oxidante	NOUN	_	Gender=Masc|Number=Sing	29	nmod	_	start_char=173|end_char=181
# 33-34	no	_	_	_	_	_	_	_	start_char=182|end_char=184
# 33	em	em	ADP	_	_	35	case	_	_
# 34	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	35	det	_	_
# 35	catodo	catodo	NOUN	_	Gender=Masc|Number=Sing	32	nmod	_	start_char=185|end_char=191
# 36	.	.	PUNCT	_	_	3	punct	_	start_char=191|end_char=192
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-7
# # text = Em uma célula a combustível operando com hidrogênio como combustível e o oxigênio como oxidante, ocorre a formação de água, além da liberação de elétrons, que geram uma corrente contínua.
# 1	Em	em	ADP	_	_	3	case	_	start_char=0|end_char=2
# 2	uma	um	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	3	det	_	start_char=3|end_char=6
# 3	célula	célula	NOUN	_	Gender=Fem|Number=Sing	17	obl	_	start_char=7|end_char=13
# 4	a	a	ADP	_	_	5	case	_	start_char=14|end_char=15
# 5	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	3	nmod	_	start_char=16|end_char=27
# 6	operando	operar	VERB	_	VerbForm=Ger	3	acl	_	start_char=28|end_char=36
# 7	com	com	ADP	_	_	8	case	_	start_char=37|end_char=40
# 8	hidrogênio	hidrogênio	NOUN	_	Gender=Masc|Number=Sing	6	obl	_	start_char=41|end_char=51
# 9	como	como	ADP	_	_	10	case	_	start_char=52|end_char=56
# 10	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	6	xcomp	_	start_char=57|end_char=68
# 11	e	e	CCONJ	_	_	13	cc	_	start_char=69|end_char=70
# 12	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	13	det	_	start_char=71|end_char=72
# 13	oxigênio	oxigênio	NOUN	_	Gender=Masc|Number=Sing	10	conj	_	start_char=73|end_char=81
# 14	como	como	ADP	_	_	15	case	_	start_char=82|end_char=86
# 15	oxidante	oxidante	NOUN	_	Gender=Masc|Number=Sing	13	nmod	_	start_char=87|end_char=95
# 16	,	,	PUNCT	_	_	6	punct	_	start_char=95|end_char=96
# 17	ocorre	ocorrer	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	start_char=97|end_char=103
# 18	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	19	det	_	start_char=104|end_char=105
# 19	formação	formação	NOUN	_	Gender=Fem|Number=Sing	17	nsubj	_	start_char=106|end_char=114
# 20	de	de	ADP	_	_	21	case	_	start_char=115|end_char=117
# 21	água	água	NOUN	_	Gender=Fem|Number=Sing	19	nmod	_	start_char=118|end_char=122
# 22	,	,	PUNCT	_	_	24	punct	_	start_char=122|end_char=123
# 23	além	além	ADV	_	_	24	cc	_	start_char=124|end_char=128
# 24-25	da	_	_	_	_	_	_	_	start_char=129|end_char=131
# 24	de	de	ADP	_	_	26	case	_	_
# 25	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	26	det	_	_
# 26	liberação	liberação	NOUN	_	Gender=Fem|Number=Sing	24	obj	_	start_char=132|end_char=141
# 27	de	de	ADP	_	_	28	case	_	start_char=142|end_char=144
# 28	elétrons	elétron	NOUN	_	Gender=Masc|Number=Plur	26	nmod	_	start_char=145|end_char=153
# 29	,	,	PUNCT	_	_	24	punct	_	start_char=153|end_char=154
# 30	que	que	PRON	_	Gender=Fem|Number=Plur|PronType=Rel	31	nsubj	_	start_char=155|end_char=158
# 31	geram	gerar	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	28	acl:relcl	_	start_char=159|end_char=164
# 32	uma	um	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	33	det	_	start_char=165|end_char=168
# 33	corrente	corrente	NOUN	_	Gender=Fem|Number=Sing	31	obj	_	start_char=169|end_char=177
# 34	contínua	contínuo	ADJ	_	Gender=Fem|Number=Sing	33	amod	_	start_char=178|end_char=186
# 35	.	.	PUNCT	_	_	17	punct	_	start_char=186|end_char=187
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-8
# # text = Os prótons gerados na reação anódica são conduzidos pelo eletrólito até o catodo, onde participam da reação de redução do oxigênio (O2), formando água.
# 1	Os	o	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	2	det	_	start_char=0|end_char=2
# 2	prótons	prótom	NOUN	_	Gender=Masc|Number=Plur	9	nsubj:pass	_	start_char=3|end_char=10
# 3	gerados	gerar	VERB	_	Gender=Masc|Number=Plur|VerbForm=Part	2	acl	_	start_char=11|end_char=18
# 4-5	na	_	_	_	_	_	_	_	start_char=19|end_char=21
# 4	em	em	ADP	_	_	6	case	_	_
# 5	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	6	det	_	_
# 6	reação	reação	NOUN	_	Gender=Fem|Number=Sing	3	obl	_	start_char=22|end_char=28
# 7	anódica	anódico	ADJ	_	Gender=Fem|Number=Sing	6	amod	_	start_char=29|end_char=36
# 8	são	ser	AUX	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	9	aux:pass	_	start_char=37|end_char=40
# 9	conduzidos	conduzir	VERB	_	Gender=Masc|Number=Plur|VerbForm=Part|Voice=Pass	0	root	_	start_char=41|end_char=51
# 10-11	pelo	_	_	_	_	_	_	_	start_char=52|end_char=56
# 10	por	por	ADP	_	_	12	case	_	_
# 11	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	12	det	_	_
# 12	eletrólito	eletrólito	NOUN	_	Gender=Masc|Number=Sing	9	obl	_	start_char=57|end_char=67
# 13	até	até	ADP	_	_	15	case	_	start_char=68|end_char=71
# 14	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	15	det	_	start_char=72|end_char=73
# 15	catodo	catodo	NOUN	_	Gender=Masc|Number=Sing	9	obl	_	start_char=74|end_char=80
# 16	,	,	PUNCT	_	_	9	punct	_	start_char=80|end_char=81
# 17	onde	onde	PRON	_	Gender=Masc|Number=Sing|PronType=Rel	18	obl	_	start_char=82|end_char=86
# 18	participam	participar	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	15	acl:relcl	_	start_char=87|end_char=97
# 19-20	da	_	_	_	_	_	_	_	start_char=98|end_char=100
# 19	de	de	ADP	_	_	21	case	_	_
# 20	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	21	det	_	_
# 21	reação	reação	NOUN	_	Gender=Fem|Number=Sing	19	obj	_	start_char=101|end_char=107
# 22	de	de	ADP	_	_	23	case	_	start_char=108|end_char=110
# 23	redução	redução	NOUN	_	Gender=Fem|Number=Sing	21	nmod	_	start_char=111|end_char=118
# 24-25	do	_	_	_	_	_	_	_	start_char=119|end_char=121
# 24	de	de	ADP	_	_	26	case	_	_
# 25	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	26	det	_	_
# 26	oxigênio	oxigênio	NOUN	_	Gender=Masc|Number=Sing	23	nmod	_	start_char=122|end_char=130
# 27	(	(	PUNCT	_	_	28	punct	_	start_char=131|end_char=132
# 28	O2	O2	PROPN	_	Gender=Masc|Number=Sing	26	parataxis	_	start_char=132|end_char=134
# 29	)	)	PUNCT	_	_	28	punct	_	start_char=134|end_char=135
# 30	,	,	PUNCT	_	_	31	punct	_	start_char=135|end_char=136
# 31	formando	formar	VERB	_	VerbForm=Ger	19	advcl	_	start_char=137|end_char=145
# 32	água	água	NOUN	_	Gender=Fem|Number=Sing	31	obj	_	start_char=146|end_char=150
# 33	.	.	PUNCT	_	_	9	punct	_	start_char=150|end_char=151
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-9
# # text = Diferentemente dos motores de combustão, que têm sua eficiência teórica (máxima) determinada pelo ciclo de Carnot, a eficiência teórica das células a combustível (CC) é dada pelo quociente entre a energia livre da reação (G) e a entalpia da reação (H), segundo a equação: CC =G/H A eficiência dada pela equação acima tem uma fraca dependência com a temperatura quando comparada àquela dada pelo ciclo de Carnot.
# 1	Diferentemente	diferentemente	ADV	_	_	35	advmod	_	start_char=0|end_char=14
# 2-3	dos	_	_	_	_	_	_	_	start_char=15|end_char=18
# 2	de	de	ADP	_	_	4	case	_	_
# 3	os	o	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	4	det	_	_
# 4	motores	motor	NOUN	_	Gender=Masc|Number=Plur	35	obl	_	start_char=19|end_char=26
# 5	de	de	ADP	_	_	6	case	_	start_char=27|end_char=29
# 6	combustão	combustão	NOUN	_	Gender=Fem|Number=Sing	4	nmod	_	start_char=30|end_char=39
# 7	,	,	PUNCT	_	_	1	punct	_	start_char=39|end_char=40
# 8	que	que	PRON	_	Gender=Masc|Number=Plur|PronType=Rel	9	nsubj	_	start_char=41|end_char=44
# 9	têm	ter	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	4	acl:relcl	_	start_char=45|end_char=48
# 10	sua	seu	DET	_	Gender=Fem|Number=Sing|PronType=Prs	11	det	_	start_char=49|end_char=52
# 11	eficiência	eficiência	NOUN	_	Gender=Fem|Number=Sing	9	obj	_	start_char=53|end_char=63
# 12	teórica	teórico	ADJ	_	Gender=Fem|Number=Sing	11	amod	_	start_char=64|end_char=71
# 13	(	(	PUNCT	_	_	14	punct	_	start_char=72|end_char=73
# 14	máxima	grande	ADJ	_	Gender=Fem|Number=Sing	11	amod	_	start_char=73|end_char=79
# 15	)	)	PUNCT	_	_	14	punct	_	start_char=79|end_char=80
# 16	determinada	determinar	VERB	_	Gender=Fem|Number=Sing|VerbForm=Part	11	acl	_	start_char=81|end_char=92
# 17-18	pelo	_	_	_	_	_	_	_	start_char=93|end_char=97
# 17	por	por	ADP	_	_	19	case	_	_
# 18	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	19	det	_	_
# 19	ciclo	ciclo	NOUN	_	Gender=Masc|Number=Sing	9	obj	_	start_char=98|end_char=103
# 20	de	de	ADP	_	_	21	case	_	start_char=104|end_char=106
# 21	Carnot	Carnot	PROPN	_	Gender=Masc|Number=Sing	19	nmod	_	start_char=107|end_char=113
# 22	,	,	PUNCT	_	_	16	punct	_	start_char=113|end_char=114
# 23	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	24	det	_	start_char=115|end_char=116
# 24	eficiência	eficiência	NOUN	_	Gender=Fem|Number=Sing	35	nsubj:pass	_	start_char=117|end_char=127
# 25	teórica	teórico	ADJ	_	Gender=Fem|Number=Sing	24	amod	_	start_char=128|end_char=135
# 26-27	das	_	_	_	_	_	_	_	start_char=136|end_char=139
# 26	de	de	ADP	_	_	28	case	_	_
# 27	as	o	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	28	det	_	_
# 28	células	célula	NOUN	_	Gender=Fem|Number=Plur	24	nmod	_	start_char=140|end_char=147
# 29	a	a	ADP	_	_	30	case	_	start_char=148|end_char=149
# 30	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	28	nmod	_	start_char=150|end_char=161
# 31	(	(	PUNCT	_	_	32	punct	_	start_char=162|end_char=163
# 32	CC	CC	PROPN	_	Gender=Fem|Number=Sing	30	parataxis	_	start_char=163|end_char=166
# 33	)	)	PUNCT	_	_	32	punct	_	start_char=166|end_char=167
# 34	é	ser	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	35	aux:pass	_	start_char=168|end_char=169
# 35	dada	dar	VERB	_	Gender=Fem|Number=Sing|VerbForm=Part|Voice=Pass	0	root	_	start_char=170|end_char=174
# 36-37	pelo	_	_	_	_	_	_	_	start_char=175|end_char=179
# 36	por	por	ADP	_	_	38	case	_	_
# 37	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	_	_
# 38	quociente	quociente	NOUN	_	Gender=Masc|Number=Sing	35	nsubj:pass	_	start_char=180|end_char=189
# 39	entre	entre	ADP	_	_	41	case	_	start_char=190|end_char=195
# 40	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	41	det	_	start_char=196|end_char=197
# 41	energia	energia	NOUN	_	Gender=Fem|Number=Sing	38	nmod	_	start_char=198|end_char=205
# 42	livre	livre	ADJ	_	Gender=Fem|Number=Sing	41	amod	_	start_char=206|end_char=211
# 43-44	da	_	_	_	_	_	_	_	start_char=212|end_char=214
# 43	de	de	ADP	_	_	45	case	_	_
# 44	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	45	det	_	_
# 45	reação	reação	NOUN	_	Gender=Fem|Number=Sing	43	obj	_	start_char=215|end_char=221
# 46	(	(	PUNCT	_	_	47	punct	_	start_char=222|end_char=223
# 47	G	g	NOUN	_	Gender=Fem|Number=Sing	45	appos	_	start_char=223|end_char=225
# 48	)	)	PUNCT	_	_	47	punct	_	start_char=225|end_char=226
# 49	e	e	CCONJ	_	_	52	cc	_	start_char=227|end_char=228
# 50	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	51	det	_	start_char=229|end_char=230
# 51	entalpia	entalpia	NOUN	_	Gender=Fem|Number=Sing	52	nsubj	_	start_char=231|end_char=239
# 52-53	da	_	_	_	_	_	_	_	start_char=240|end_char=242
# 52	de	de	ADP	_	_	50	case	_	_
# 53	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	50	det	_	_
# 54	reação	reação	NOUN	_	Gender=Fem|Number=Sing	52	obj	_	start_char=243|end_char=249
# 55	(	(	PUNCT	_	_	56	punct	_	start_char=250|end_char=251
# 56	H	h	NOUN	_	Gender=Fem|Number=Sing	54	appos	_	start_char=251|end_char=253
# 57	)	)	PUNCT	_	_	56	punct	_	start_char=253|end_char=254
# 58	,	,	PUNCT	_	_	52	punct	_	start_char=254|end_char=255
# 59	segundo	segundo	ADP	_	_	61	case	_	start_char=256|end_char=263
# 60	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	61	det	_	start_char=264|end_char=265
# 61	equação	equação	NOUN	_	Gender=Fem|Number=Sing	52	obl	_	start_char=266|end_char=273
# 62	:	:	PUNCT	_	_	43	punct	_	start_char=273|end_char=274
# 63	CC	CC	PROPN	_	Gender=Masc|Number=Sing	72	nsubj	_	start_char=275|end_char=278
# 64	=G/H	=G/H	PROPN	_	Number=Sing	63	flat:name	_	start_char=279|end_char=285
# 65	A	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	66	det	_	start_char=286|end_char=287
# 66	eficiência	eficiência	NOUN	_	Gender=Fem|Number=Sing	63	appos	_	start_char=288|end_char=298
# 67	dada	dar	VERB	_	Gender=Fem|Number=Sing|VerbForm=Part	66	acl	_	start_char=299|end_char=303
# 68-69	pela	_	_	_	_	_	_	_	start_char=304|end_char=308
# 68	por	por	ADP	_	_	70	case	_	_
# 69	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	70	det	_	_
# 70	equação	equação	NOUN	_	Gender=Fem|Number=Sing	67	obl	_	start_char=309|end_char=316
# 71	acima	acima	ADV	_	_	72	advmod	_	start_char=317|end_char=322
# 72	tem	ter	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	61	acl:relcl	_	start_char=323|end_char=326
# 73	uma	um	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	75	det	_	start_char=327|end_char=330
# 74	fraca	fraco	ADJ	_	Gender=Fem|Number=Sing	75	amod	_	start_char=331|end_char=336
# 75	dependência	dependência	NOUN	_	Gender=Fem|Number=Sing	72	obj	_	start_char=337|end_char=348
# 76	com	com	ADP	_	_	78	case	_	start_char=349|end_char=352
# 77	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	78	det	_	start_char=353|end_char=354
# 78	temperatura	temperatura	NOUN	_	Gender=Fem|Number=Sing	75	nmod	_	start_char=355|end_char=366
# 79	quando	quando	ADV	_	_	80	advmod	_	start_char=367|end_char=373
# 80	comparada	comparar	VERB	_	Gender=Fem|Number=Sing|VerbForm=Part	72	advcl	_	start_char=374|end_char=383
# 81-82	àquela	_	_	_	_	_	_	_	start_char=384|end_char=390
# 81	a	a	ADP	_	_	80	case	_	_
# 82	aquela	aquele	DET	_	Gender=Fem|Number=Sing|PronType=Dem	80	det	_	_
# 83	dada	dar	VERB	_	Gender=Fem|Number=Sing|VerbForm=Part	81	acl	_	start_char=391|end_char=395
# 84-85	pelo	_	_	_	_	_	_	_	start_char=396|end_char=400
# 84	por	por	ADP	_	_	86	case	_	_
# 85	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	86	det	_	_
# 86	ciclo	ciclo	NOUN	_	Gender=Masc|Number=Sing	83	nsubj	_	start_char=401|end_char=406
# 87	de	de	ADP	_	_	88	case	_	start_char=407|end_char=409
# 88	Carnot	Carnot	PROPN	_	Gender=Masc|Number=Sing	86	nmod	_	start_char=410|end_char=416
# 89	.	.	PUNCT	_	_	35	punct	_	start_char=416|end_char=417
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-10
# # text = Assim, as células a combustível, mesmo e especialmente em baixas temperaturas, na prática, obtêm-se eficiências de 55% a 60%.
# 1	Assim	assim	ADV	_	_	19	advmod	_	start_char=0|end_char=5
# 2	,	,	PUNCT	_	_	1	punct	_	start_char=5|end_char=6
# 3	as	o	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	4	det	_	start_char=7|end_char=9
# 4	células	célula	NOUN	_	Gender=Fem|Number=Plur	19	nsubj	_	start_char=10|end_char=17
# 5	a	a	ADP	_	_	6	case	_	start_char=18|end_char=19
# 6	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	4	nmod	_	start_char=20|end_char=31
# 7	,	,	PUNCT	_	_	8	punct	_	start_char=31|end_char=32
# 8	mesmo	mesmo	ADV	_	_	13	advmod	_	start_char=33|end_char=38
# 9	e	e	CCONJ	_	_	13	cc	_	start_char=39|end_char=40
# 10	especialmente	especialmente	ADV	_	_	13	advmod	_	start_char=41|end_char=54
# 11	em	em	ADP	_	_	13	case	_	start_char=55|end_char=57
# 12	baixas	baixo	ADJ	_	Gender=Fem|Number=Plur	13	amod	_	start_char=58|end_char=64
# 13	temperaturas	temperatura	NOUN	_	Gender=Fem|Number=Plur	6	conj	_	start_char=65|end_char=77
# 14	,	,	PUNCT	_	_	17	punct	_	start_char=77|end_char=78
# 15-16	na	_	_	_	_	_	_	_	start_char=79|end_char=81
# 15	em	em	ADP	_	_	17	case	_	_
# 16	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	17	det	_	_
# 17	prática	prática	NOUN	_	Gender=Fem|Number=Sing	13	appos	_	start_char=82|end_char=89
# 18	,	,	PUNCT	_	_	17	punct	_	start_char=89|end_char=90
# 19-20	obtêm-se	_	_	_	_	_	_	_	start_char=91|end_char=99
# 19	obtêm	obter	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	_
# 20	se	se	PRON	_	Case=Acc|Gender=Fem|Number=Plur|Person=3|PronType=Prs	19	expl	_	_
# 21	eficiências	eficiência	NOUN	_	Gender=Fem|Number=Plur	19	obj	_	start_char=100|end_char=111
# 22	de	de	ADP	_	_	23	case	_	start_char=112|end_char=114
# 23	55%	55%	NUM	_	NumType=Card	21	nmod	_	start_char=115|end_char=118
# 24	a	a	ADP	_	_	25	case	_	start_char=119|end_char=120
# 25	60%	60%	NUM	_	NumType=Card	23	nmod	_	start_char=121|end_char=124
# 26	.	.	PUNCT	_	_	19	punct	_	start_char=124|end_char=125
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-11
# # text = Existem vários tipos de células a combustível, classificadas segundo o tipo de eletrólito que utilizam e, conseqüentemente, a sua temperatura de operação.
# 1	Existem	existir	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	start_char=0|end_char=7
# 2	vários	vários	DET	_	Gender=Masc|Number=Plur|PronType=Ind	3	det	_	start_char=8|end_char=14
# 3	tipos	tipo	NOUN	_	Gender=Masc|Number=Plur	1	nsubj	_	start_char=15|end_char=20
# 4	de	de	ADP	_	_	5	case	_	start_char=21|end_char=23
# 5	células	célula	NOUN	_	Gender=Fem|Number=Plur	3	nmod	_	start_char=24|end_char=31
# 6	a	a	ADP	_	_	7	case	_	start_char=32|end_char=33
# 7	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	5	nmod	_	start_char=34|end_char=45
# 8	,	,	PUNCT	_	_	9	punct	_	start_char=45|end_char=46
# 9	classificadas	classificar	VERB	_	Gender=Fem|Number=Plur|VerbForm=Part	3	acl	_	start_char=47|end_char=60
# 10	segundo	segundo	ADP	_	_	12	case	_	start_char=61|end_char=68
# 11	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	12	det	_	start_char=69|end_char=70
# 12	tipo	tipo	NOUN	_	Gender=Masc|Number=Sing	9	obl	_	start_char=71|end_char=75
# 13	de	de	ADP	_	_	14	case	_	start_char=76|end_char=78
# 14	eletrólito	eletrólito	NOUN	_	Gender=Masc|Number=Sing	12	nmod	_	start_char=79|end_char=89
# 15	que	que	PRON	_	Gender=Masc|Number=Sing|PronType=Rel	16	nsubj	_	start_char=90|end_char=93
# 16	utilizam	utilizar	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	12	acl:relcl	_	start_char=94|end_char=102
# 17	e	e	CCONJ	_	_	23	cc	_	start_char=103|end_char=104
# 18	,	,	PUNCT	_	_	19	punct	_	start_char=104|end_char=105
# 19	conseqüentemente	conseqüentemente	ADV	_	_	23	advmod	_	start_char=106|end_char=122
# 20	,	,	PUNCT	_	_	19	punct	_	start_char=122|end_char=123
# 21	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	23	det	_	start_char=124|end_char=125
# 22	sua	seu	DET	_	Gender=Fem|Number=Sing|PronType=Prs	23	det	_	start_char=126|end_char=129
# 23	temperatura	temperatura	NOUN	_	Gender=Fem|Number=Sing	12	conj	_	start_char=130|end_char=141
# 24	de	de	ADP	_	_	25	case	_	start_char=142|end_char=144
# 25	operação	operação	NOUN	_	Gender=Fem|Number=Sing	23	nmod	_	start_char=145|end_char=153
# 26	.	.	PUNCT	_	_	1	punct	_	start_char=153|end_char=154
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-12
# # text = Tipos, características e aplicações das células de combustível1: PEMFC (proton exchange membran fuel cell – célula a combustível de membrana de troca de próton): Eletrólito: membrana polimérica de condução protônica; Faixa de temperatura: 80oC-120oC; Vantagens: alta densidade de potência, operação flexível, mobilidade; Desvantagens: custo da membrana e catalisador, contaminação do catalisador com monóxido de carbono; Aplicações: veículos automotores, espaçonaves, unidades estacionárias.
# 1	Tipos	tipo	NOUN	_	Gender=Masc|Number=Plur	0	root	_	start_char=0|end_char=5
# 2	,	,	PUNCT	_	_	3	punct	_	start_char=5|end_char=6
# 3	características	característica	NOUN	_	Gender=Fem|Number=Plur	1	conj	_	start_char=7|end_char=22
# 4	e	e	CCONJ	_	_	5	cc	_	start_char=23|end_char=24
# 5	aplicações	aplicação	NOUN	_	Gender=Fem|Number=Plur	1	conj	_	start_char=25|end_char=35
# 6-7	das	_	_	_	_	_	_	_	start_char=36|end_char=39
# 6	de	de	ADP	_	_	8	case	_	_
# 7	as	o	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	8	det	_	_
# 8	células	célula	NOUN	_	Gender=Fem|Number=Plur	3	nmod	_	start_char=40|end_char=47
# 9	de	de	ADP	_	_	10	case	_	start_char=48|end_char=50
# 10	combustível1	combustível1	NOUN	_	Gender=Masc|Number=Sing	8	nmod	_	start_char=51|end_char=63
# 11	:	:	PUNCT	_	_	1	punct	_	start_char=63|end_char=64
# 12	PEMFC	PEMFC	PROPN	_	Gender=Masc|Number=Sing	1	appos	_	start_char=65|end_char=70
# 13	(	(	PUNCT	_	_	14	punct	_	start_char=71|end_char=72
# 14	proton	proton	X	_	_	12	appos	_	start_char=72|end_char=78
# 15	exchange	exchange	X	_	_	14	flat:foreign	_	start_char=79|end_char=87
# 16	membran	membran	X	_	_	14	flat:foreign	_	start_char=88|end_char=95
# 17	fuel	fuel	X	_	_	14	flat:foreign	_	start_char=96|end_char=100
# 18	cell	cell	X	_	_	17	flat:foreign	_	start_char=101|end_char=105
# 19	–	–	PUNCT	_	_	20	punct	_	start_char=106|end_char=107
# 20	célula	célula	NOUN	_	Gender=Fem|Number=Sing	12	appos	_	start_char=108|end_char=114
# 21	a	a	ADP	_	_	22	case	_	start_char=115|end_char=116
# 22	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	20	nmod	_	start_char=117|end_char=128
# 23	de	de	ADP	_	_	24	case	_	start_char=129|end_char=131
# 24	membrana	membrana	NOUN	_	Gender=Fem|Number=Sing	22	nmod	_	start_char=132|end_char=140
# 25	de	de	ADP	_	_	26	case	_	start_char=141|end_char=143
# 26	troca	troca	NOUN	_	Gender=Fem|Number=Sing	24	nmod	_	start_char=144|end_char=149
# 27	de	de	ADP	_	_	28	case	_	start_char=150|end_char=152
# 28	próton	próton	NOUN	_	Gender=Masc|Number=Sing	26	nmod	_	start_char=153|end_char=159
# 29	)	)	PUNCT	_	_	14	punct	_	start_char=159|end_char=160
# 30	:	:	PUNCT	_	_	1	punct	_	start_char=160|end_char=161
# 31	Eletrólito	eletrólito	NOUN	_	Gender=Masc|Number=Sing	12	appos	_	start_char=162|end_char=172
# 32	:	:	PUNCT	_	_	1	punct	_	start_char=172|end_char=173
# 33	membrana	membrana	NOUN	_	Gender=Fem|Number=Sing	31	appos	_	start_char=174|end_char=182
# 34	polimérica	polimérico	ADJ	_	Gender=Fem|Number=Sing	33	amod	_	start_char=183|end_char=193
# 35	de	de	ADP	_	_	36	case	_	start_char=194|end_char=196
# 36	condução	condução	NOUN	_	Gender=Fem|Number=Sing	33	nmod	_	start_char=197|end_char=205
# 37	protônica	protônico	ADJ	_	Gender=Fem|Number=Sing	36	amod	_	start_char=206|end_char=215
# 38	;	;	PUNCT	_	_	31	punct	_	start_char=215|end_char=216
# 39	Faixa	Faixa	NOUN	_	Gender=Fem|Number=Sing	31	appos	_	start_char=217|end_char=222
# 40	de	de	ADP	_	_	41	case	_	start_char=223|end_char=225
# 41	temperatura	temperatura	NOUN	_	Gender=Fem|Number=Sing	39	nmod	_	start_char=226|end_char=237
# 42	:	:	PUNCT	_	_	1	punct	_	start_char=237|end_char=238
# 43	80oC-120oC	80oC-120oC	NUM	_	NumType=Card	39	appos	_	start_char=239|end_char=249
# 44	;	;	PUNCT	_	_	1	punct	_	start_char=249|end_char=250
# 45	Vantagens	vantagem	NOUN	_	Gender=Fem|Number=Plur	43	appos	_	start_char=251|end_char=260
# 46	:	:	PUNCT	_	_	1	punct	_	start_char=260|end_char=261
# 47	alta	alto	ADJ	_	Gender=Fem|Number=Sing	48	amod	_	start_char=262|end_char=266
# 48	densidade	densidade	NOUN	_	Gender=Fem|Number=Sing	45	appos	_	start_char=267|end_char=276
# 49	de	de	ADP	_	_	50	case	_	start_char=277|end_char=279
# 50	potência	potência	NOUN	_	Gender=Fem|Number=Sing	48	nmod	_	start_char=280|end_char=288
# 51	,	,	PUNCT	_	_	52	punct	_	start_char=288|end_char=289
# 52	operação	operação	NOUN	_	Gender=Fem|Number=Sing	48	appos	_	start_char=290|end_char=298
# 53	flexível	flexível	ADJ	_	Gender=Fem|Number=Sing	52	amod	_	start_char=299|end_char=307
# 54	,	,	PUNCT	_	_	55	punct	_	start_char=307|end_char=308
# 55	mobilidade	mobilidade	NOUN	_	Gender=Fem|Number=Sing	48	appos	_	start_char=309|end_char=319
# 56	;	;	PUNCT	_	_	1	punct	_	start_char=319|end_char=320
# 57	Desvantagens	desvantagem	NOUN	_	Gender=Fem|Number=Plur	48	appos	_	start_char=321|end_char=333
# 58	:	:	PUNCT	_	_	1	punct	_	start_char=333|end_char=334
# 59	custo	custo	NOUN	_	Gender=Masc|Number=Sing	60	nsubj	_	start_char=335|end_char=340
# 60-61	da	_	_	_	_	_	_	_	start_char=341|end_char=343
# 60	de	de	ADP	_	_	62	case	_	_
# 61	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	62	det	_	_
# 62	membrana	membrana	NOUN	_	Gender=Fem|Number=Sing	60	obj	_	start_char=344|end_char=352
# 63	e	e	CCONJ	_	_	64	cc	_	start_char=353|end_char=354
# 64	catalisador	catalisador	NOUN	_	Gender=Masc|Number=Sing	62	conj	_	start_char=355|end_char=366
# 65	,	,	PUNCT	_	_	66	punct	_	start_char=366|end_char=367
# 66	contaminação	contaminação	NOUN	_	Gender=Fem|Number=Sing	62	conj	_	start_char=368|end_char=380
# 67-68	do	_	_	_	_	_	_	_	start_char=381|end_char=383
# 67	de	de	ADP	_	_	67	case	_	_
# 68	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	67	det	_	_
# 69	catalisador	catalisador	NOUN	_	Gender=Masc|Number=Sing	66	nmod	_	start_char=384|end_char=395
# 70	com	com	ADP	_	_	71	case	_	start_char=396|end_char=399
# 71	monóxido	monóxido	NOUN	_	Gender=Masc|Number=Sing	66	nmod	_	start_char=400|end_char=408
# 72	de	de	ADP	_	_	73	case	_	start_char=409|end_char=411
# 73	carbono	carbono	NOUN	_	Gender=Masc|Number=Sing	71	nmod	_	start_char=412|end_char=419
# 74	;	;	PUNCT	_	_	60	punct	_	start_char=419|end_char=420
# 75	Aplicações	aplicação	NOUN	_	Gender=Fem|Number=Plur	60	appos	_	start_char=421|end_char=431
# 76	:	:	PUNCT	_	_	75	punct	_	start_char=431|end_char=432
# 77	veículos	veículo	NOUN	_	Gender=Masc|Number=Plur	75	appos	_	start_char=433|end_char=441
# 78	automotores	automotor	ADJ	_	Gender=Masc|Number=Plur	77	amod	_	start_char=442|end_char=453
# 79	,	,	PUNCT	_	_	80	punct	_	start_char=453|end_char=454
# 80	espaçonaves	espaçonave	NOUN	_	Gender=Fem|Number=Plur	77	appos	_	start_char=455|end_char=466
# 81	,	,	PUNCT	_	_	82	punct	_	start_char=466|end_char=467
# 82	unidades	unidade	NOUN	_	Gender=Fem|Number=Plur	77	appos	_	start_char=468|end_char=476
# 83	estacionárias	estacionário	ADJ	_	Gender=Fem|Number=Plur	82	amod	_	start_char=477|end_char=490
# 84	.	.	PUNCT	_	_	1	punct	_	start_char=490|end_char=491
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-13
# # text = Na célula de membrana de troca protônica (PEMFC), o eletrólito consiste em uma membrana de polímero sólido que transporta os prótons entre os eletrodos.
# 1-2	Na	_	_	_	_	_	_	_	start_char=0|end_char=2
# 1	Em	em	ADP	_	_	3	case	_	_
# 2	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	3	det	_	_
# 3	célula	célula	NOUN	_	Gender=Fem|Number=Sing	15	nsubj	_	start_char=3|end_char=9
# 4	de	de	ADP	_	_	5	case	_	start_char=10|end_char=12
# 5	membrana	membrana	NOUN	_	Gender=Fem|Number=Sing	3	nmod	_	start_char=13|end_char=21
# 6	de	de	ADP	_	_	7	case	_	start_char=22|end_char=24
# 7	troca	troca	NOUN	_	Gender=Fem|Number=Sing	5	nmod	_	start_char=25|end_char=30
# 8	protônica	protônico	ADJ	_	Gender=Fem|Number=Sing	7	amod	_	start_char=31|end_char=40
# 9	(	(	PUNCT	_	_	10	punct	_	start_char=41|end_char=42
# 10	PEMFC	PEMFC	PROPN	_	Gender=Fem|Number=Sing	7	appos	_	start_char=42|end_char=47
# 11	)	)	PUNCT	_	_	10	punct	_	start_char=47|end_char=48
# 12	,	,	PUNCT	_	_	3	punct	_	start_char=48|end_char=49
# 13	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	14	det	_	start_char=50|end_char=51
# 14	eletrólito	eletrólito	NOUN	_	Gender=Masc|Number=Sing	15	nsubj	_	start_char=52|end_char=62
# 15	consiste	consistir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	start_char=63|end_char=71
# 16	em	em	ADP	_	_	18	case	_	start_char=72|end_char=74
# 17	uma	um	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	18	det	_	start_char=75|end_char=78
# 18	membrana	membrana	NOUN	_	Gender=Fem|Number=Sing	15	obj	_	start_char=79|end_char=87
# 19	de	de	ADP	_	_	20	case	_	start_char=88|end_char=90
# 20	polímero	polímero	NOUN	_	Gender=Masc|Number=Sing	18	nmod	_	start_char=91|end_char=99
# 21	sólido	sólido	ADJ	_	Gender=Masc|Number=Sing	20	amod	_	start_char=100|end_char=106
# 22	que	que	PRON	_	Gender=Masc|Number=Sing|PronType=Rel	23	nsubj	_	start_char=107|end_char=110
# 23	transporta	transportar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	18	acl:relcl	_	start_char=111|end_char=121
# 24	os	o	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	25	det	_	start_char=122|end_char=124
# 25	prótons	prótom	NOUN	_	Gender=Masc|Number=Plur	23	obj	_	start_char=125|end_char=132
# 26	entre	entre	ADP	_	_	28	case	_	start_char=133|end_char=138
# 27	os	o	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	28	det	_	start_char=139|end_char=141
# 28	eletrodos	eletrodo	NOUN	_	Gender=Masc|Number=Plur	23	obl	_	start_char=142|end_char=151
# 29	.	.	PUNCT	_	_	15	punct	_	start_char=151|end_char=152
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-14
# # text = Operam em temperaturas bem mais baixas do que outras células (cerca de 90oC) devido às impostas pelas propriedades térmicas da limitações membrana.
# 1	Operam	operar	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	start_char=0|end_char=6
# 2	em	em	ADP	_	_	3	case	_	start_char=7|end_char=9
# 3	temperaturas	temperatura	NOUN	_	Gender=Fem|Number=Plur	1	obl	_	start_char=10|end_char=22
# 4	bem	bem	ADV	_	_	5	advmod	_	start_char=23|end_char=26
# 5	mais	mais	ADV	_	_	6	advmod	_	start_char=27|end_char=31
# 6	baixas	baixo	ADJ	_	Gender=Fem|Number=Plur	3	amod	_	start_char=32|end_char=38
# 7-8	do	_	_	_	_	_	_	_	start_char=39|end_char=41
# 7	de	de	ADP	_	_	11	case	_	_
# 8	o	o	PRON	_	Gender=Masc|Number=Sing|PronType=Dem	7	fixed	_	_
# 9	que	que	PRON	_	Gender=Fem|Number=Plur|PronType=Rel	25	nsubj	_	start_char=42|end_char=45
# 10	outras	outro	DET	_	Gender=Fem|Number=Plur|PronType=Ind	11	det	_	start_char=46|end_char=52
# 11	células	célula	NOUN	_	Gender=Fem|Number=Plur	25	nsubj	_	start_char=53|end_char=60
# 12	(	(	PUNCT	_	_	15	punct	_	start_char=61|end_char=62
# 13	cerca	cerca	ADV	_	_	15	advmod	_	start_char=62|end_char=67
# 14	de	de	ADP	_	_	13	fixed	_	start_char=68|end_char=70
# 15	90oC	90oC	NOUN	_	Gender=Masc|Number=Plur	11	appos	_	start_char=71|end_char=75
# 16	)	)	PUNCT	_	_	15	punct	_	start_char=75|end_char=76
# ...
# 1	O	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	_	start_char=0|end_char=1
# 2	aumento	aumento	NOUN	_	Gender=Masc|Number=Sing	3	nsubj	_	start_char=2|end_char=9
# 3-4	da	_	_	_	_	_	_	_	start_char=10|end_char=12
# 3	de	de	ADP	_	_	5	case	_	_
# 4	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	5	det	_	_
# 5	temperatura	temperatura	NOUN	_	Gender=Fem|Number=Sing	3	obj	_	start_char=13|end_char=24
# 6	de	de	ADP	_	_	7	case	_	start_char=25|end_char=27
# 7	operação	operação	NOUN	_	Gender=Fem|Number=Sing	5	nmod	_	start_char=28|end_char=36
# 8-9	da	_	_	_	_	_	_	_	start_char=37|end_char=39
# 8	de	de	ADP	_	_	10	case	_	_
# 9	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	10	det	_	_
# 10	célula	célula	NOUN	_	Gender=Fem|Number=Sing	8	obj	_	start_char=40|end_char=46
# 11	reduz	reduzir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	3	conj	_	start_char=47|end_char=52
# 12	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	13	det	_	start_char=53|end_char=54
# 13	envenenamento	envenenamento	NOUN	_	Gender=Masc|Number=Sing	11	obj	_	start_char=55|end_char=68
# 14-15	do	_	_	_	_	_	_	_	start_char=69|end_char=71
# 14	de	de	ADP	_	_	16	case	_	_
# 15	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	16	det	_	_
# 16	catalisador	catalisador	NOUN	_	Gender=Masc|Number=Sing	11	obl	_	start_char=72|end_char=83
# 17	por	por	ADP	_	_	18	case	_	start_char=84|end_char=87
# 18	CO	CO	PROPN	_	Gender=Masc|Number=Sing	11	obl	_	start_char=88|end_char=90
# 19	em	em	ADP	_	_	20	case	_	start_char=91|end_char=93
# 20	células	célula	NOUN	_	Gender=Fem|Number=Plur	11	obl	_	start_char=94|end_char=101
# 21	com	com	ADP	_	_	22	case	_	start_char=102|end_char=105
# 22	hidrogênio	hidrogênio	NOUN	_	Gender=Masc|Number=Sing	20	nmod	_	start_char=106|end_char=116
# 23	,	,	PUNCT	_	_	32	punct	_	start_char=116|end_char=117
# 24	e	e	CCONJ	_	_	27	cc	_	start_char=118|end_char=119
# 25-26	do	_	_	_	_	_	_	_	start_char=120|end_char=122
# 25	de	de	ADP	_	_	27	case	_	_
# 26	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	27	det	_	_
# 27	anodo	anodo	NOUN	_	Gender=Masc|Number=Sing	13	conj	_	start_char=123|end_char=128
# 28-29	pelos	_	_	_	_	_	_	_	start_char=129|end_char=134
# 28	por	por	ADP	_	_	30	case	_	_
# 29	os	o	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	30	det	_	_
# 30	resíduos	resíduo	NOUN	_	Gender=Masc|Number=Plur	27	nmod	_	start_char=135|end_char=143
# 31	metanólicos	metanólico	ADJ	_	Gender=Masc|Number=Plur	30	amod	_	start_char=144|end_char=155
# 32	adsorbidos	adsorber	VERB	_	Gender=Masc|Number=Plur|VerbForm=Part	27	acl	_	start_char=156|end_char=166
# 33	em	em	ADP	_	_	34	case	_	start_char=167|end_char=169
# 34	células	célula	NOUN	_	Gender=Fem|Number=Plur	32	obl	_	start_char=170|end_char=177
# 35	a	a	ADP	_	_	36	case	_	start_char=178|end_char=179
# 36	metanol	metanol	NOUN	_	Gender=Masc|Number=Sing	34	nmod	_	start_char=180|end_char=187
# 37	.	.	PUNCT	_	_	11	punct	_	start_char=187|end_char=188
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-81
# # text = Uma maior temperatura de operação da célula aumentaria a velocidade da reação de oxidação do metanol e diminuiria o envenenamento do eletrocatalisador por CO (para o combustível H2).
# 1	Uma	um	DET	_	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	3	det	_	start_char=0|end_char=3
# 2	maior	grande	ADJ	_	Gender=Fem|Number=Sing	3	amod	_	start_char=4|end_char=9
# 3	temperatura	temperatura	NOUN	_	Gender=Fem|Number=Sing	6	nsubj	_	start_char=10|end_char=21
# 4	de	de	ADP	_	_	5	case	_	start_char=22|end_char=24
# 5	operação	operação	NOUN	_	Gender=Fem|Number=Sing	3	nmod	_	start_char=25|end_char=33
# 6-7	da	_	_	_	_	_	_	_	start_char=34|end_char=36
# 6	de	de	ADP	_	_	8	case	_	_
# 7	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	8	det	_	_
# 8	célula	célula	NOUN	_	Gender=Fem|Number=Sing	6	obj	_	start_char=37|end_char=43
# 9	aumentaria	aumentar	VERB	_	Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin	6	conj	_	start_char=44|end_char=54
# 10	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	11	det	_	start_char=55|end_char=56
# 11	velocidade	velocidade	NOUN	_	Gender=Fem|Number=Sing	9	obj	_	start_char=57|end_char=67
# 12-13	da	_	_	_	_	_	_	_	start_char=68|end_char=70
# 12	de	de	ADP	_	_	14	case	_	_
# 13	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	14	det	_	_
# 14	reação	reação	NOUN	_	Gender=Fem|Number=Sing	11	nmod	_	start_char=71|end_char=77
# 15	de	de	ADP	_	_	16	case	_	start_char=78|end_char=80
# 16	oxidação	oxidação	NOUN	_	Gender=Fem|Number=Sing	14	nmod	_	start_char=81|end_char=89
# 17-18	do	_	_	_	_	_	_	_	start_char=90|end_char=92
# 17	de	de	ADP	_	_	19	case	_	_
# 18	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	19	det	_	_
# 19	metanol	metanol	NOUN	_	Gender=Masc|Number=Sing	16	nmod	_	start_char=93|end_char=100
# 20	e	e	CCONJ	_	_	21	cc	_	start_char=101|end_char=102
# 21	diminuiria	diminuir	VERB	_	Mood=Cnd|Number=Sing|Person=3|VerbForm=Fin	6	conj	_	start_char=103|end_char=113
# 22	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	23	det	_	start_char=114|end_char=115
# 23	envenenamento	envenenamento	NOUN	_	Gender=Masc|Number=Sing	21	obj	_	start_char=116|end_char=129
# 24-25	do	_	_	_	_	_	_	_	start_char=130|end_char=132
# 24	de	de	ADP	_	_	26	case	_	_
# 25	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	26	det	_	_
# 26	eletrocatalisador	eletrocatalisador	ADJ	_	Gender=Masc|Number=Sing	23	nmod	_	start_char=133|end_char=150
# 27	por	por	ADP	_	_	28	case	_	start_char=151|end_char=154
# 28	CO	CO	PROPN	_	Gender=Masc|Number=Sing	21	obl	_	start_char=155|end_char=157
# 29	(	(	PUNCT	_	_	32	punct	_	start_char=158|end_char=159
# 30	para	para	ADP	_	_	32	case	_	start_char=159|end_char=163
# 31	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	32	det	_	start_char=164|end_char=165
# 32	combustível	combustível	NOUN	_	Gender=Masc|Number=Sing	28	nmod	_	start_char=166|end_char=177
# 33	H2	H2	PROPN	_	Gender=Masc|Number=Sing	32	appos	_	start_char=178|end_char=180
# 34	)	)	PUNCT	_	_	32	punct	_	start_char=180|end_char=181
# 35	.	.	PUNCT	_	_	6	punct	_	start_char=181|end_char=182
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-82
# # text = Sendo assim, a introdução de membranas compósitas possibilita a operação a temperaturas maiores que as membrana de Nafion® permitem sem diminuir o seu tempo de operacionalidade.
# 1	Sendo	ser	AUX	_	VerbForm=Ger	9	discourse	_	start_char=0|end_char=5
# 2	assim	assim	ADV	_	_	1	fixed	_	start_char=6|end_char=11
# 3	,	,	PUNCT	_	_	2	punct	_	start_char=11|end_char=12
# 4	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	5	det	_	start_char=13|end_char=14
# 5	introdução	introdução	NOUN	_	Gender=Fem|Number=Sing	9	nsubj	_	start_char=15|end_char=25
# 6	de	de	ADP	_	_	7	case	_	start_char=26|end_char=28
# 7	membranas	membrana	NOUN	_	Gender=Fem|Number=Plur	5	nmod	_	start_char=29|end_char=38
# 8	compósitas	compósito	ADJ	_	Gender=Fem|Number=Plur	7	amod	_	start_char=39|end_char=49
# 9	possibilita	possibilitar	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	start_char=50|end_char=61
# 10	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	11	det	_	start_char=62|end_char=63
# 11	operação	operação	NOUN	_	Gender=Fem|Number=Sing	9	obj	_	start_char=64|end_char=72
# 12	a	a	ADP	_	_	13	case	_	start_char=73|end_char=74
# 13	temperaturas	temperatura	NOUN	_	Gender=Fem|Number=Plur	9	iobj	_	start_char=75|end_char=87
# 14	maiores	grande	ADJ	_	Gender=Fem|Number=Plur	13	amod	_	start_char=88|end_char=95
# 15	que	que	PRON	_	Gender=Fem|Number=Plur|PronType=Rel	21	obj	_	start_char=96|end_char=99
# 16	as	o	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	17	det	_	start_char=100|end_char=102
# 17	membrana	membrana	NOUN	_	Gender=Fem|Number=Sing	21	nsubj	_	start_char=103|end_char=111
# 18	de	de	ADP	_	_	19	case	_	start_char=112|end_char=114
# 19	Nafion	Nafion	PROPN	_	Gender=Masc|Number=Sing	17	nmod	_	start_char=115|end_char=121
# 20	®	®	PROPN	_	Number=Sing	19	flat:name	_	start_char=121|end_char=122
# 21	permitem	permitir	VERB	_	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	13	acl:relcl	_	start_char=123|end_char=131
# 22	sem	sem	SCONJ	_	_	23	mark	_	start_char=132|end_char=135
# 23	diminuir	diminuir	VERB	_	VerbForm=Inf	21	advcl	_	start_char=136|end_char=144
# 24	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	26	det	_	start_char=145|end_char=146
# 25	seu	seu	DET	_	Gender=Masc|Number=Sing|PronType=Prs	26	det	_	start_char=147|end_char=150
# 26	tempo	tempo	NOUN	_	Gender=Masc|Number=Sing	23	obj	_	start_char=151|end_char=156
# 27	de	de	ADP	_	_	28	case	_	start_char=157|end_char=159
# 28	operacionalidade	operacionalidade	NOUN	_	Gender=Fem|Number=Sing	26	nmod	_	start_char=160|end_char=176
# 29	.	.	PUNCT	_	_	9	punct	_	start_char=176|end_char=177
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-83
# # text = Uma das possibilidades consiste na inclusão de preenchedores sólidos inorgânicos higroscópicos na matriz do Nafion® para aumentar a sua temperatura de operação, como tem sido proposto em alguns trabalhos14. Baglio e colaboradores15 prepararam com sucesso duas membranas compósitas incluindo duas zeólitas naturais, a chabazita e a clinoptilotita na matriz do Nafion®.
# 1	Uma	um	NUM	_	NumType=Card	4	nummod	_	start_char=0|end_char=3
# 2-3	das	_	_	_	_	_	_	_	start_char=4|end_char=7
# 2	de	de	ADP	_	_	4	case	_	_
# 3	as	o	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	4	det	_	_
# 4	possibilidades	possibilidade	NOUN	_	Gender=Fem|Number=Plur	5	nsubj	_	start_char=8|end_char=22
# 5	consiste	consistir	VERB	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	_	start_char=23|end_char=31
# 6-7	na	_	_	_	_	_	_	_	start_char=32|end_char=34
# 6	em	em	ADP	_	_	8	case	_	_
# 7	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	8	det	_	_
# 8	inclusão	inclusão	NOUN	_	Gender=Fem|Number=Sing	5	obj	_	start_char=35|end_char=43
# 9	de	de	ADP	_	_	10	case	_	start_char=44|end_char=46
# 10	preenchedores	preenchedor	NOUN	_	Gender=Masc|Number=Plur	8	nmod	_	start_char=47|end_char=60
# 11	sólidos	sólido	ADJ	_	Gender=Masc|Number=Plur	10	amod	_	start_char=61|end_char=68
# 12	inorgânicos	inorgânico	ADJ	_	Gender=Masc|Number=Plur	10	amod	_	start_char=69|end_char=80
# 13	higroscópicos	higroscópico	ADJ	_	Gender=Masc|Number=Plur	10	amod	_	start_char=81|end_char=94
# 14-15	na	_	_	_	_	_	_	_	start_char=95|end_char=97
# 14	em	em	ADP	_	_	16	case	_	_
# 15	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	16	det	_	_
# 16	matriz	matriz	NOUN	_	Gender=Fem|Number=Sing	10	nmod	_	start_char=98|end_char=104
# 17-18	do	_	_	_	_	_	_	_	start_char=105|end_char=107
# 17	de	de	ADP	_	_	19	case	_	_
# 18	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	19	det	_	_
# 19	Nafion	Nafion	PROPN	_	Gender=Masc|Number=Sing	16	nmod	_	start_char=108|end_char=114
# 20	®	®	PROPN	_	Number=Sing	19	flat:name	_	start_char=114|end_char=115
# 21	para	para	SCONJ	_	_	22	mark	_	start_char=116|end_char=120
# 22	aumentar	aumentar	VERB	_	VerbForm=Inf	5	advcl	_	start_char=121|end_char=129
# 23	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	25	det	_	start_char=130|end_char=131
# 24	sua	seu	DET	_	Gender=Fem|Number=Sing|PronType=Prs	25	det	_	start_char=132|end_char=135
# 25	temperatura	temperatura	NOUN	_	Gender=Fem|Number=Sing	22	obj	_	start_char=136|end_char=147
# 26	de	de	ADP	_	_	27	case	_	start_char=148|end_char=150
# 27	operação	operação	NOUN	_	Gender=Fem|Number=Sing	25	nmod	_	start_char=151|end_char=159
# 28	,	,	PUNCT	_	_	22	punct	_	start_char=159|end_char=160
# 29	como	como	ADV	_	_	32	advmod	_	start_char=161|end_char=165
# 30	tem	ter	AUX	_	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	32	aux	_	start_char=166|end_char=169
# 31	sido	ser	AUX	_	VerbForm=Part	32	aux:pass	_	start_char=170|end_char=174
# 32	proposto	propor	VERB	_	Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass	40	advcl	_	start_char=175|end_char=183
# 33	em	em	ADP	_	_	35	case	_	start_char=184|end_char=186
# 34	alguns	algum	DET	_	Gender=Masc|Number=Plur|PronType=Ind	35	det	_	start_char=187|end_char=193
# 35	trabalhos14	trabalhos14	NOUN	_	Gender=Masc|Number=Plur	32	obl	_	start_char=194|end_char=205
# 36	.	.	PUNCT	_	_	5	punct	_	start_char=205|end_char=206
# 37	Baglio	Baglio	PROPN	_	Gender=Masc|Number=Sing	40	nsubj	_	start_char=207|end_char=213
# 38	e	e	CCONJ	_	_	39	cc	_	start_char=214|end_char=215
# 39	colaboradores15	colaboradores15	NOUN	_	Gender=Masc|Number=Plur	37	conj	_	start_char=216|end_char=231
# 40	prepararam	preparar	VERB	_	Mood=Ind|Number=Plur|Person=3|VerbForm=Fin	5	conj	_	start_char=232|end_char=242
# 41	com	com	ADP	_	_	42	case	_	start_char=243|end_char=246
# 42	sucesso	sucesso	NOUN	_	Gender=Masc|Number=Sing	40	obl	_	start_char=247|end_char=254
# 43	duas	dois	NUM	_	NumType=Card	44	nummod	_	start_char=255|end_char=259
# 44	membranas	membrana	NOUN	_	Gender=Fem|Number=Plur	40	obj	_	start_char=260|end_char=269
# 45	compósitas	compósito	ADJ	_	Gender=Fem|Number=Plur	44	amod	_	start_char=270|end_char=280
# 46	incluindo	incluir	VERB	_	VerbForm=Ger	40	advcl	_	start_char=281|end_char=290
# 47	duas	dois	NUM	_	NumType=Card	48	nummod	_	start_char=291|end_char=295
# 48	zeólitas	zeólita	NOUN	_	Gender=Fem|Number=Plur	46	obj	_	start_char=296|end_char=304
# 49	naturais	natural	ADJ	_	Gender=Fem|Number=Plur	48	amod	_	start_char=305|end_char=313
# 50	,	,	PUNCT	_	_	52	punct	_	start_char=313|end_char=314
# 51	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	52	det	_	start_char=315|end_char=316
# 52	chabazita	chabazita	NOUN	_	Gender=Fem|Number=Sing	48	conj	_	start_char=317|end_char=326
# 53	e	e	CCONJ	_	_	55	cc	_	start_char=327|end_char=328
# 54	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	55	det	_	start_char=329|end_char=330
# 55	clinoptilotita	clinoptilotita	NOUN	_	Gender=Fem|Number=Sing	48	conj	_	start_char=331|end_char=345
# 56-57	na	_	_	_	_	_	_	_	start_char=346|end_char=348
# 56	em	em	ADP	_	_	58	case	_	_
# 57	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	58	det	_	_
# 58	matriz	matriz	NOUN	_	Gender=Fem|Number=Sing	55	nmod	_	start_char=349|end_char=355
# 59-60	do	_	_	_	_	_	_	_	start_char=356|end_char=358
# 59	de	de	ADP	_	_	61	case	_	_
# 60	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	61	det	_	_
# 61	Nafion	Nafion	PROPN	_	Gender=Masc|Number=Sing	55	nmod	_	start_char=359|end_char=365
# 62	®	®	PROPN	_	Number=Sing	61	flat:name	_	start_char=365|end_char=366
# 63	.	.	PUNCT	_	_	5	punct	_	start_char=366|end_char=367
#
# # sent_id = 10-20150122-MONOGRAFIA_0_intro-84
# # text = Aumentaram a condutividade protônica e a retenção de água do eletrólito a temperaturas de operação da célula de 150 °C.
# 1	Aumentaram	aumentar	VERB	_	Mood=Ind|Number=Plur|Person=3|VerbForm=Fin	0	root	_	start_char=0|end_char=10
# 2	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	3	det	_	start_char=11|end_char=12
# 3	condutividade	condutividade	NOUN	_	Gender=Fem|Number=Sing	1	obj	_	start_char=13|end_char=26
# 4	protônica	protônico	ADJ	_	Gender=Fem|Number=Sing	3	amod	_	start_char=27|end_char=36
# 5	e	e	CCONJ	_	_	17	cc	_	start_char=37|end_char=38
# 6	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	7	det	_	start_char=39|end_char=40
# 7	retenção	retenção	NOUN	_	Gender=Fem|Number=Sing	17	nsubj	_	start_char=41|end_char=49
# 8	de	de	ADP	_	_	9	case	_	start_char=50|end_char=52
# 9	água	água	NOUN	_	Gender=Fem|Number=Sing	7	nmod	_	start_char=53|end_char=57
# 10-11	do	_	_	_	_	_	_	_	start_char=58|end_char=60
# 10	de	de	ADP	_	_	12	case	_	_
# 11	o	o	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	12	det	_	_
# 12	eletrólito	eletrólito	NOUN	_	Gender=Masc|Number=Sing	7	nmod	_	start_char=61|end_char=71
# 13	a	a	ADP	_	_	14	case	_	start_char=72|end_char=73
# 14	temperaturas	temperatura	NOUN	_	Gender=Fem|Number=Plur	7	nmod	_	start_char=74|end_char=86
# 15	de	de	ADP	_	_	16	case	_	start_char=87|end_char=89
# 16	operação	operação	NOUN	_	Gender=Fem|Number=Sing	14	nmod	_	start_char=90|end_char=98
# 17-18	da	_	_	_	_	_	_	_	start_char=99|end_char=101
# 17	de	de	ADP	_	_	19	case	_	_
# 18	a	o	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	19	det	_	_
# 19	célula	célula	NOUN	_	Gender=Fem|Number=Sing	17	obj	_	start_char=102|end_char=108
# 20	de	de	ADP	_	_	22	case	_	start_char=109|end_char=111
# 21	150	150	NUM	_	NumType=Card	22	nummod	_	start_char=112|end_char=115
# 22	°C	°c	NOUN	_	Gender=Masc|Number=Plur	19	nmod	_	start_char=116|end_char=118
# 23	.	.	PUNCT	_	_	1	punct	_	start_char=118|end_char=119
