# %% [markdown]
# ### Treinando modelo PetroOntoVec (OWL2Vec) sem a utilização de modelo pretreinado (PetroVec)
#
#   **Lembrar de usar o python 3.7**

# %% [markdown]
# Parâmetros usados no arquivo 'default.cfg'
#
#   ontology_file = ../../KnowledgeGraph/OntoGeoLogicaInstanciasRelacoes.owl
#   ontology_projection = yes
#   projection_only_taxonomy = no
#   multiple_labels = yes
#   avoid_owl_constructs = no
#   axiom_reasoner = hermit
#   walker = wl  (Owl2Vec - wl)
#   walk_depth = 3
#   URI_Doc = yes
#   Lit_Doc = yes
#   Mix_Doc = yes
#   Mix_Type = random
#   pre_train_model = ../../Embeddings/PetroVec/Petrovec-OeG-100/publico-COMPLETO-100.txt.model
#   embed_size = 100  (PetroVec - 100)  (Owl2Vec - 100)
#   iteration = 10  (Owl2Vec - 10 "which is based on the observation of the loss")
#   window = 5 (PetroVec - 5)  (Owl2Vec - 5)
#   min_count = 1  (Owl2Vec - 1)
#   negative = 25
#   seed = 42
#   epoch = 100

# %%
# Se necessário retreinar, ajustar os hiperparâmetros do arquivo default.cfg
# !owl2vec_star standalone --config_file default.cfg
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\upe2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# * Owlready2 * Warning: ignoring cyclic subclass of/subproperty of, involving:
#   http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#has_beginning
#
# * Owlready2 * Warning: ignoring cyclic subclass of/subproperty of, involving:
#   http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#has_end
#
# * Owlready2 * Warning: ignoring cyclic subclass of/subproperty of, involving:
#   http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#interval_contains
#
# * Owlready2 * Warning: ignoring cyclic subclass of/subproperty of, involving:
#   http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#interval_during
#
# ...
