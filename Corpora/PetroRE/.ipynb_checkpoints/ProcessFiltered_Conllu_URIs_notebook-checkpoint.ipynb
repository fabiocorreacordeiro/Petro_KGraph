# %%
import argparse
import json
from glob import glob
import pandas as pd
import pickle
import numpy as np
import re
import os
import operator as op
import warnings 
from owlready2 import * #
import random
import unicodedata
import time
warnings.filterwarnings('ignore')
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %% [markdown]
# ## Carregar ontologia

# %%
onto_name = "OntoGeoLogicaInstanciasRelacoes"
onto = get_ontology("../../KnowledgeGraph/OntoGeoLogicaInstanciasRelacoes.owl")
onto.load()
# Out:
# get_ontology("http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#")

# %% [markdown]
# ## Funções para procurar na ontologia

# %%
# def get_relations_between_uris(uri_1, uri_2): 
#     #funcao que acessa a ontologia e procura relacao entre URIs
#     dict_relation_uris = {}
#     #Pega as relacoes que tem a URI1
#     relation_query_results = list(default_world.sparql("""
#             SELECT DISTINCT ?rel
#             WHERE{?uri ?rel ?obj
#                  FILTER(contains(str(?rel), "http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#"))
#                  FILTER (contains(str(?uri), """ + '"' + uri_1 + '"' + """))
#                  }
#             """))
    
#     relations_str = []
#     for relation_uris in relation_query_results:
#         relations_str.append(str(relation_uris[0]).rsplit(".",1)[-1])
        
#     # Para cada tipo de relação procura se existe match entre URI1 e URI2
#     for relation in relations_str:
#         relation_between_words = list(default_world.sparql("""
#                 PREFIX prefix: <http://www.semanticweb.org/bg40/ontologies/2022/5/untitled-ontology-2#>
#                 SELECT distinct ?y ?x2
#                 WHERE{?y prefix:""" +  relation  +  """ ?x1

#                       FILTER (contains(str(?y), """ + '"' + uri_1  + '"' + """))        

#                       ?x2 rdf:type ?j                                   
#                       FILTER (contains(str(?x2), """ + '"' + uri_2  + '"' + """))

#                       FILTER ( ?x2 = ?x1 )
#                     }
#                 """))
#         dict_relation_uris[relation] = relation_between_words
#     return dict_relation_uris

# def go_through_relations(uri1,uri2):
#     relation_uris = get_relations_between_uris(uri1, uri2)            
#     if relation_uris != {}: #talvez exista relacao entre URIs, dicionario pode vir vazio -> []
#         for x, y in relation_uris.items():#procurar por relacao
#             if y != []: #existe alguma relacao
# #                 print(x)
#                 return x
#     return None

# %%
def get_relations_between_uris(uri1, uri2): 
    
    # Se as duas URIs forem igual, não retorna relação
    if uri1 == uri2:
        return ([])
    
    # Verifica se as URIs estão presentes na ontologia
    if onto[uri1] == None:
        return ([])
    if onto[uri2] == None:
        return ([])    
    
    relation_query_results = list(default_world.sparql("""
        SELECT ?rel 
        WHERE { 
                {?sub ?rel ?obj .
                 <""" + onto.base_iri + uri1 + """> ?rel <""" + onto.base_iri + uri2 + """> .}
                UNION
                {?sub ?rel ?obj .
                 <""" + onto.base_iri + uri1 + """> ?rel ?obj .
                # ?obj rdf:type <""" + onto.base_iri + uri2 + """> .}
                UNION
                {?sub ?rel ?obj .
                 # ?sub ?rel <""" + onto.base_iri + uri2 + """> .
                 # ?sub rdf:type <""" + onto.base_iri + uri1 + """> .}
                UNION
                {?sub ?rel ?obj .
                 # ?sub rdf:type <""" + onto.base_iri + uri1 + """> .
                 # ?obj rdf:type <""" + onto.base_iri + uri2 + """> .}
        
        }
        """))

    return ( relation_query_results)

# %%
def go_through_relations(uri1,uri2):
    # retirando # do início da URI quando necessário
    if uri1[0] == '#':
        uri1 = uri1[1:]
    if uri2[0] == '#':
        uri2 = uri2[1:]

    rel = []
    
    if uri1 == uri2:
        return (None)
    
    # Verifica se as URIs estão presentes na ontologia
    if onto[uri1] == None:
        return (None)
    if onto[uri2] == None:
        return (None) 
    
    rel.append(get_relations_between_uris(uri1,uri2))

    # Verificando se uri1 é Unidade Crono
    if (onto[uri1].is_a == [onto['geological_age']]) | (onto[uri1].is_a == [onto['geological_time_interval']]):
        rel.append(get_relations_between_uris(uri1 + '_quality', uri2))
        rel.append(get_relations_between_uris(uri1 + '_quality_' + uri2, uri2))

    # Verificando se uri1 é Unidade Crono
    if (onto[uri2].is_a == [onto['geological_age']]) | (onto[uri2].is_a == [onto['geological_time_interval']]):
        rel.append(get_relations_between_uris(uri1, uri2 + '_quality'))
        rel.append(get_relations_between_uris(uri1, uri2 + '_quality_' + uri1))
    
    relations = []
    for r in rel:
        if r != []:
            relations = relations + r[0]
    
    if set(relations) == set():
        return None
    else:
        # Caso não retorne um objeto da ontologia (classe ou individual) retornará erro
        try:
            return (str(list(set(relations))[0]).split('.')[1])
        except:
            return None

# %% [markdown]
# ### Funções para printar informações

# %%
def print_sentence_text(sentence):
    #printa e retorna o texto original da sentenca
    size_sentence = int(sentence.iloc[-1]["end"])
    text = " "*size_sentence
    for index, row in sentence.iterrows():
        text = text[:int(row["start"])] + row["form"] +text[int(row["end"]):]
    print(text)
    print("-------------")
    return text

def print_relation_entities(word1,word2,ent1,ent2,URI_1,URI_2,relation_type,text):
    #printa as entidades e relacao entre elas
    print('Token 1 = ', word1, '--- Class 1 = ', ent1, '--- URI 1 = ', URI_1)
    print('Token 2 = ', word2, '--- Class 2 = ', ent2,'--- URI 2 = ',URI_2)
    print('Relation Type = ', relation_type)
    print(text)
    print("-------------")
    pass

# %% [markdown]
# ## Funções para gerar Jsons a serem lidos no labelstudio

# %%
class ResultRelationJson(object):
    def __init__(self, from_id, to_id, relations, direction = "right"):
        self.dict = {
            "from_id": str(from_id),
            "to_id": str(to_id),
            "type": "relation",
            "direction": direction,
            "labels": relations
        }
    def get_dict(self):
        return self.dict
class ResultNERJson(object):
    def __init__(self, row):     
        self.result_dict = {
            "value": {
            "start": row["start_word"],
            "end": row["end_word"],
            "text": row["word_join"],
            "labels": [
              row["label_word"]
            ],
            "URI": row["URI"]
            },
            
            "id": row["index_e"],
            "from_name": "label",
            "to_name": "text",
            "type": "labels",
            "origin": "prediction"
        }
    def get_dict(self):
        return self.result_dict  
class CreateOutput(object):
    def __init__(self, text, filtred_sentence, entity_name_new):
        self.filtred_sentence = filtred_sentence
        self.entity_name_new = entity_name_new
        self.main_dict = {
            "id": 1,
            "data": {
              "text": text #sentenca inteira
            },
            "annotations": []
        }
        self._add_annotations()      
    def _add_annotations(self):
        results = []
        count = 0        
        for index, row in self.entity_name_new.iterrows(): 
            results.append(ResultNERJson(row).get_dict())        
        item = [{
              "id": 1,
              "created_username": " null, 0",
              "created_ago": "",
              "result": results
            }]
        self.main_dict["annotations"] = item
    def get_output(self):
        return self.main_dict
    def add_relationship(self, from_id, to_id, relations, direction):
        results = self.main_dict.get("annotations")[0].get("result")
        relation = ResultRelationJson(from_id, to_id, [relations], direction).get_dict()
        results.append(relation)
        self.main_dict["annotations"][0]["result"] = results   
        
def combine_itens_from_lists_add_in_json(from_id_vec, to_id_vec, relation_from_vec, output):
    for idxRelation in range(0,len(from_id_vec)):
        direction = "right"
        output.add_relationship(from_id=from_id_vec[idxRelation], to_id=to_id_vec[idxRelation], relations = relation_from_vec[idxRelation], direction=direction)
    return output
def saveJsonFiles(df,from_id,to_id, lista_relacoes_sentence,sentence,SentenceNum,path):
    #cria e salva o arquivo Json para labelstudio
    text = sentence.iloc[0]['text']
    print('Saved Json ->', True)
    output = CreateOutput(text,sentence, df)
    combine_itens_from_lists_add_in_json(from_id, to_id, lista_relacoes_sentence, output)
    print("-------------")
    with open(os.path.join(path,f"{SentenceNum}.json"), "w") as outfile: 
        json.dump(output.get_output(), outfile) 
        
def get_df_forJsons(sentence,idxTokens):
    #retorna um dataframe com as informações das entidades e uma string contendo o nome completo da entidade
    df_save_words = pd.DataFrame(columns=['index_e', "LABEL", "START", "END",\
                                      "TEXT", "word_join", "start_word", "end_word", "label_word","URI"])

    index_e = sentence.iloc[idxTokens]['index_e']
    label = sentence.iloc[idxTokens]['deps']
    start = int(sentence.iloc[idxTokens]['word_join_start'])
    end = start + len(sentence.iloc[idxTokens]['form'])
    text_ent = sentence.iloc[idxTokens]['form']
    word_join = sentence.iloc[idxTokens]['word_join']
    start_word = sentence.iloc[idxTokens]['word_join_start']
    end_word = sentence.iloc[idxTokens]['word_join_end']
    label_word = label.replace("B=","")
    URI = sentence.iloc[idxTokens]['grafo']

    df_save_words.loc[len(df_save_words.index)] = [index_e, label, start, end, text_ent, word_join,
                                                   start_word,
                                                   end_word,
                                                   label_word,
                                                   URI]

    return df_save_words, word_join
        
def create_df_JsonFiles(df_entity,x,token,token2,URI_1,URI_2,idxTokens,idxTokens2,from_id,to_id,sentence):
    #retorna o dataframe utilizado para criacao dos arquivos Json para labelstudio
    entity_name_new_token1,wordjoin_1 = get_df_forJsons(sentence,idxTokens)
    entity_name_new_token2,wordjoin_2 = get_df_forJsons(sentence,idxTokens2)
    if idxTokens not in from_id and idxTokens not in to_id:
        df_entity = pd.concat([df_entity, entity_name_new_token1])
    if idxTokens2 not in from_id and idxTokens2 not in to_id:
        df_entity = pd.concat([df_entity, entity_name_new_token2])

#     print_relation_entities(wordjoin_1,wordjoin_2,token.replace('B=',''),token2.replace('B=',''),URI_1,URI_2,x)
    return df_entity

# %% [markdown]
# ### Funções para criar dataframe para modelo BERT

# %%
def create_moddedText_BERT(text,start1,end1,start2,end2,Ent1_inic,Ent1_end,Ent2_inic,Ent2_end):
    
    new_end_ent1 = int(end1) + len(Ent1_inic)
    new_start_ent2 = int(start2) + len(Ent1_inic) + len(Ent1_end)
    new_end_ent2 = int(end2) + len(Ent1_inic) + len(Ent1_end) + len(Ent2_inic) 
    
    #adicionando [E1] e [/E1]
    text_new = text[:int(start1)] + Ent1_inic + text[int(start1):]
    text_new = text_new[:new_end_ent1] + Ent1_end + text_new[new_end_ent1:]
    #adicionando [E2] e [/E2]
    text_new2 = text_new[:new_start_ent2] + Ent2_inic + text_new[new_start_ent2:]
    text_new2 = text_new2[:new_end_ent2] + Ent2_end + text_new2[new_end_ent2:]
    return text_new2

def createText_sentence_BERT(text,start_1,end_1,start_2,end_2):
    #funcao que retorna um novo texto para sentenca com [E1] e [E2] adicionados junto de cada entidade

    start_ent1, start_ent2 = int(start_1), int(start_2)
    end_ent1, end_ent2 = int(end_1), int(end_2)
    Ent1_inic, Ent1_end = '[E1] ', ' [/E1]'
    Ent2_inic, Ent2_end = '[E2] ', ' [/E2]'
    
    # text_new = create_moddedText_BERT(text,start_ent1,end_ent1,start_ent2,end_ent2,\
    #                               Ent1_inic,Ent1_end,Ent2_inic,Ent2_end)

    if start_ent1 < start_ent2: #[E1] vem antes de [E2]
        text_new = create_moddedText_BERT(text,start_ent1,end_ent1,start_ent2,end_ent2,\
                                  Ent1_inic,Ent1_end,Ent2_inic,Ent2_end)
    else: #[E2] vem antes de [E1]        
        text_new = create_moddedText_BERT(text,start_ent2,end_ent2,start_ent1,end_ent1,\
                                      Ent2_inic,Ent2_end,Ent1_inic,Ent1_end)  
    
    return text_new

def create_bert_dataframe(df_bert,idxTokens,idxTokens2,sentence,URI_1,URI_2,has_relation,relation_type,SentenceNumber):
    #retorna o dataframe com as informacoes de cada sentenca para utilizar no modelo BERT
    df_bert_temp = pd.DataFrame(columns=['#Sentence','sentence','Ent1','Ent2','URI_1','URI_2','has_relation','relation'])
    text = sentence.iloc[0]['text']
    wordjoin_1, wordjoin_2 = sentence.iloc[idxTokens]['word_join'], sentence.iloc[idxTokens2]['word_join']
    ent1, ent2 = sentence.iloc[idxTokens]['deps'], sentence.iloc[idxTokens2]['deps']
    ent1, ent2 = ent1.replace("B=",""), ent2.replace("B=","")
    start_1, start_2 = sentence.iloc[idxTokens]['word_join_start'], sentence.iloc[idxTokens2]['word_join_start']
    end_1, end_2 = sentence.iloc[idxTokens]['word_join_end'], sentence.iloc[idxTokens2]['word_join_end']
    
    text_bert_ents = createText_sentence_BERT(text,start_1,end_1,start_2,end_2) 
        
    df_bert_temp.loc[0] = [SentenceNumber,
                           text_bert_ents,
                           ent1,
                           ent2,
                           URI_1,
                           URI_2,
                           has_relation,
                           relation_type]
    df_bert = pd.concat([df_bert, df_bert_temp])
    if relation_type!='no_relation':
        print_relation_entities(wordjoin_1,wordjoin_2,ent1,ent2,URI_1,URI_2,relation_type,text_bert_ents)
    return df_bert

# %% [markdown]
# ## Funções para processar as sentenças

# %%
#utils
def create_relations_dataframe(df_relation,token,token2,URI_1,URI_2,x,originalSentenceNumber):
    #retorna dataframe das entidades e suas relações em cada linha
    #importante para contabilizar os tipos de relação
    df_relation_new = pd.DataFrame(columns=['Relation','Ent1','Ent2','URI_1','URI_2','#Sentence'])
    df_relation_new.loc[0] = [x,
                            token.replace('B=',''),
                            token2.replace('B=',''),
                            URI_1,
                            URI_2,
                            originalSentenceNumber]
    df_relation = pd.concat([df_relation, df_relation_new])
    return df_relation

# def verifica_pares_entidade_interesse(ENT_1, ENT_2,relation_type):
#     #verifica se a relacao encontrada vai ser do tipo temporal_relation CRONO->CRONO
#     #funcao talvez precise ser atualizada no futuro conforme a ontologia for povoada
#     lista_from = ['POÇO','UNIDADE_LITO','UNIDADE_LITO','CAMPO','POÇO','POÇO','UNIDADE_LITO','UNIDADE_LITO']
#     lista_to = ['UNIDADE_LITO','NÂOCONSOLID','ROCHA','BACIA','BACIA','CAMPO','BACIA','UNIDADE_CRONO']        
#     for idx in range(0,len(lista_to)):
#         if lista_from[idx] == ENT_1 and lista_to[idx] == ENT_2:
#             return relation_type
#     return 'temporal_relation'

#def go_through_sentence(sentence_df, df_relation,df_bert,sent_numb):
def go_through_sentence(sentence_df, df_relation, df_bert, originalSentenceNumber): 
    #percorre a sentenca em busca de relacoes entre entidades anotadas com URIs
    df_entity = pd.DataFrame()
    from_id, to_id = [], []
    relation_from, relation_to = [], []
    lista_relacoes_sentence = []
    lista_relacoes, lista_uris, lista_classes = [], [], []
    
    is_to_save = False
#     df_bert.to_csv(save_csv_name, encoding='utf-8',index=False)
#     df_relation.to_csv('df_relation.csv', encoding='utf-8',index=False)
    for idxTokens in range(len(sentence_df)):
        token, URI_1 = sentence_df.iloc[idxTokens]['deps'], sentence_df.iloc[idxTokens]['grafo']
        for idxTokens2 in range(len(sentence_df)):
            if idxTokens != idxTokens2:
                token2, URI_2 = sentence_df.iloc[idxTokens2]['deps'], sentence_df.iloc[idxTokens2]['grafo']
                has_relation = False
                relation_type = go_through_relations(URI_1,URI_2)
                if relation_type: 
                    print("-------------")
                    print('sentence =', originalSentenceNumber)
                    is_to_save = True
                    has_relation = True
                    Ent1, Ent2 = token.replace("B=",""), token2.replace("B=","")
                    #relation_type = verifica_pares_entidade_interesse(Ent1,Ent2,relation_type)
                    lista_relacoes_sentence.append(relation_type)

                    #criar df_bert para BERT RE com codigo do Fabio
                    df_bert = create_bert_dataframe(df_bert,idxTokens,idxTokens2,sentence_df,
                                                    URI_1,URI_2,
                                                    has_relation,relation_type,originalSentenceNumber)

                    #para contabilizar os pares de entidade por relacao
                    df_relation = create_relations_dataframe(df_relation,token,token2,
                                                             URI_1,URI_2,relation_type,originalSentenceNumber)
                    #listas para contabilizar relacoes, uris e classes
                    lista_relacoes.append(relation_type)
                    lista_uris.append(URI_1)
                    lista_uris.append(URI_2)         
                    lista_classes.append(Ent1)
                    lista_classes.append(Ent2)

                    if is_to_createJsons: #se quiser criar Jsons para LabelStudio
                        df_entity = create_df_JsonFiles(df_entity,relation_type,token,token2,URI_1,URI_2,
                                                        idxTokens,idxTokens2,from_id,to_id,sentence_df)
                        from_id.append(idxTokens)
                        to_id.append(idxTokens2) 

                else: #nao achou relacao
                    relation_type = 'no_relation'

                    df_bert = create_bert_dataframe(df_bert,idxTokens,idxTokens2,sentence_df,
                                                    URI_1,URI_2,has_relation,relation_type,originalSentenceNumber)
                        
    return lista_relacoes,lista_uris,lista_classes,\
            df_bert, df_relation, df_entity, \
            lista_relacoes_sentence, from_id, to_id, is_to_save

# %% [markdown]
# ### Ler arquivo csv (ou pkl) com as sentenças pós filtragem

# %%
# Treino
df_filtred_sentences_treino = pickle.load(open('df_filtred_petroner_uri_treino.conllu.pkl', 'rb'))
#df_filtred_sentences_treino = pd.read_csv('df_filtred_petroner_uri_treino_conllu.csv')

df_group_treino = df_filtred_sentences_treino.groupby('sentence')
print('Numero total de sentenças de treino pos-filtragem -> ',len(df_group_treino))

# Valid
df_filtred_sentences_valid = pickle.load(open('df_filtred_petroner_uri_valid.conllu.pkl', 'rb'))
#df_filtred_sentences_valid = pd.read_csv('df_filtred_petroner_uri_valid_conllu.csv')

df_group_valid = df_filtred_sentences_valid.groupby('sentence')
print('Numero total de sentenças de validação pos-filtragem -> ',len(df_group_valid))

# Teste
df_filtred_sentences_teste = pickle.load(open('df_filtred_petroner_uri_teste.conllu.pkl', 'rb'))
#df_filtred_sentences_teste = pd.read_csv('df_filtred_petroner_uri_teste_conllu.csv')

df_group_teste = df_filtred_sentences_teste.groupby('sentence')
print('Numero total de sentenças de teste pos-filtragem -> ',len(df_group_teste))
# Out:
# Numero total de sentenças de treino pos-filtragem ->  3466
# Numero total de sentenças de validação pos-filtragem ->  461
# Numero total de sentenças de teste pos-filtragem ->  775

# %% [markdown]
# ### Escolher se deseja criar Jsons para labelstudio

# %%
#is_to_createJsons = True
is_to_createJsons = False

# %% [markdown]
# ### Folder outputs

# %%
#save_folder_path = "./JSONs_04_05" #local onde são salvos os Jsons para labelstudio
save_folder_path_treino = "./JSONs_treino"
save_csv_name_bert_treino = 'df_bert_sentences_treino.csv'
save_csv_name_relation_treino = 'df_relation_treino.csv'
lista_relacoes_treino = 'lista_relacoes_treino.pkl'
lista_uris_treino = 'lista_uris_treino.pkl'
lista_classes_treino = 'lista_classes_treino.pkl'

save_folder_path_valid = "./JSONs_valid"
save_csv_name_bert_valid = 'df_bert_sentences_valid.csv'
save_csv_name_relation_valid = 'df_relation_valid.csv'
lista_relacoes_valid = 'lista_relacoes_valid.pkl'
lista_uris_valid = 'lista_uris_valid.pkl'
lista_classes_valid = 'lista_classes_valid.pkl'

save_folder_path_teste = "./JSONs_teste"
save_csv_name_bert_teste = 'df_bert_sentences_teste.csv'
save_csv_name_relation_teste = 'df_relation_teste.csv'
lista_relacoes_teste = 'lista_relacoes_teste.pkl'
lista_uris_teste = 'lista_uris_teste.pkl'
lista_classes_teste = 'lista_classes_teste.pkl'

# %% [markdown]
# ## Rotina para processar as sentenças já filtradas

# %%
def processar_sentencas_filtradas(df_filtred_sentences, 
                                  df_group, 
                                  save_csv_name_bert, 
                                  save_csv_name_relation, 
                                  save_folder_path, 
                                  lista_relacoes_file, 
                                  lista_uris_file, 
                                  lista_classes_file):

    #%%time

    numberSentences = df_filtred_sentences.iloc[-1]['sentence'] #numero de sentencas diferentes no arquivo ja filtrado
    lista_relacoes, lista_uris, lista_classes, list_sentences_dict = [], [], [], []
    df_relation, df_bert = pd.DataFrame(), pd.DataFrame()

    countJsons=0
    for idx in range(1,len(df_group)):
        filtred_sentence = df_group.get_group(idx)#aqui filtred_sentence é um dataframe da sentenca
        originalSentenceNumber = filtred_sentence.iloc[0]['#sentence_original']
        text = filtred_sentence.iloc[0]['text']
        new_relacoes,new_uris,new_classes,df_bert,\
        df_relation,df_entity,lista_relacoes_sentence,\
        from_id,to_id, is_to_save = go_through_sentence(filtred_sentence,df_relation,df_bert,originalSentenceNumber) 
                                    #go_through_sentence(sentence_df,df_relation,df_bert,sent_numb)
        
        lista_relacoes = lista_relacoes + new_relacoes
        lista_uris = lista_uris + new_uris
        lista_classes = lista_classes + new_classes
        
        df_bert.to_csv(save_csv_name_bert, encoding='utf-8',index=False)
        try:
            df_relation.to_csv(save_csv_name_relation, encoding='utf-8',index=False)
        except:
            print('falha ao tentar salvar o arquivo: ', save_csv_name_relation)
            pass
        if is_to_save and is_to_createJsons:#Jsons somente criados para sentencas com relacao
            countJsons+=1
            saveJsonFiles(df_entity,from_id,to_id, 
                          lista_relacoes_sentence,filtred_sentence,originalSentenceNumber,save_folder_path)
                
    print("-------------")
    print("Number of Jsons saved = ", countJsons)

    try:
        # pickle.dump(df_relation, open('df_relation.pkl','wb'), protocol=pickle.HIGHEST_PROTOCOL)
        df_relation.to_csv(save_csv_name_relation, encoding='utf-8',index=False)
    except:
        print('Erro ao salvar o arquivo ', save_csv_name_relation, '. Tentando novamente.')
        time.sleep(5)
        df_relation.to_csv(save_csv_name_relation, encoding='utf-8',index=False)
        
    df_bert.to_csv(save_csv_name_bert, encoding='utf-8',index=False)

    relacoes = np.unique(lista_relacoes, return_counts = True)
    pickle.dump(relacoes, open(lista_relacoes_file,'wb'),protocol = pickle.HIGHEST_PROTOCOL)

    uris = np.unique(lista_uris, return_counts = True)
    pickle.dump(uris,open(lista_uris_file,'wb'),protocol = pickle.HIGHEST_PROTOCOL)

    classes = np.unique(lista_classes, return_counts = True)
    pickle.dump(classes,open(lista_classes_file,'wb'),protocol = pickle.HIGHEST_PROTOCOL)
    
    return

# %%
processar_sentencas_filtradas(df_filtred_sentences_treino, 
                              df_group_treino, 
                              save_csv_name_bert_treino, 
                              save_csv_name_relation_treino, 
                              save_folder_path_treino,
                              lista_relacoes_treino, 
                              lista_uris_treino, 
                              lista_classes_treino)
# Out:
# -------------
# sentence = 2
# Token 1 =   Campo de Curimã --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0352
# Token 2 =   Bacia Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# Quando aplicados    [E1] Campo de Curimã [/E1] — localizado    [E2] Bacia    Ceará [/E2] e produtor de óleo em arenitos flúvio-deltaicos de idade aptiana — permitiram melhor compreensão    distribuição lateral e vertical     fácies permoporosas e, consequentemente, uma caracterização mais precisa de suas propriedades médias..
# -------------
# -------------
# sentence = 4
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# Por meio    análise discriminante, essa classificação foi estendida a todos os [E1] poços [/E1]    [E2] campo [/E2],             , assim, áreas preferenciais de ocorrência de reservatórios..
# -------------
# -------------
# sentence = 16
# Token 1 =   Campo de Curimã --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0352
# Token 2 =   Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# O [E1] Campo de Curimã [/E1]                plataforma continental    [E2] Ceará [/E2],    porção central    Sub-bacia de Mundaú, a 75 km de Fortaleza e 50 km    linha de costa, em lâmina d'água de 50 metros (fig. 1)..
# -------------
# -------------
# sentence = 16
# Token 1 =   Campo de Curimã --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0352
# Token 2 =   Sub-bacia de Mundaú --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# O [E1] Campo de Curimã [/E1]                plataforma continental    Ceará,    porção central    [E2] Sub-bacia de Mundaú [/E2], a 75 km de Fortaleza e 50 km    linha de costa, em lâmina d'água de 50 metros (fig. 1)..
# -------------
# -------------
# sentence = 17
# Token 1 =   formações Mundaú --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_296
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Seus principais reservatórios são [E2] arenitos [/E2] flúvio-deltaicos com boas características permoporosas, lateralmente contínuos, subdivididos em sete zonas produtoras pertencentes    [E1] formações Mundaú [/E1] e Paracuru (fig. 2)..
# -------------
# -------------
# sentence = 17
# Token 1 =   Paracuru --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_200
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Seus principais reservatórios são [E2] arenitos [/E2] flúvio-deltaicos com boas características permoporosas, lateralmente contínuos, subdivididos em sete zonas produtoras pertencentes    formações Mundaú e [E1] Paracuru [/E1] (fig. 2)..
# -------------
# -------------
# sentence = 18
# Token 1 =   Curima --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0352
# Token 2 =   Bacia Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# - Fig. t= Localizagao-do-campo de [E1] Curima [/E1]; [E2] Bacia    Ceará [/E2]..
# -------------
# -------------
# sentence = 23
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Curimã --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0352
# Relation Type =  located_in
# Com a aplicação        procedimentos    [E2] Campo de Curimã [/E2], foi mais fácil estabelecer os modelos eletrofaciológicos e unidades de fluxo, determinados primeiramente para os [E1] poços [/E1] testemunhados e, posteriormente, estendidos     poços não-testemunhados..
# -------------
# -------------
# sentence = 23
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Curimã --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0352
# Relation Type =  located_in
# Com a aplicação        procedimentos    [E2] Campo de Curimã [/E2], foi mais fácil estabelecer os modelos eletrofaciológicos e unidades de fluxo, determinados primeiramente para os poços testemunhados e, posteriormente, estendidos     [E1] poços [/E1] não-testemunhados..
# -------------
# -------------
# sentence = 25
# Token 1 =   Campo de Curimã --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0352
# Token 2 =   Bacia Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# --.==Q [E1] Campo de Curimã [/E1], descôberto em janeiro de 1978,            produtor de óleo     arenitos de idade aptiana pertencentes    formações Mundaú e Paracuru    [E2] Bacia    Ceará [/E2], Sub-bacia de Mundaú (fig. 2)..
# -------------
# -------------
# sentence = 25
# Token 1 =   Campo de Curimã --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0352
# Token 2 =   Sub-bacia de Mundaú --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# --.==Q [E1] Campo de Curimã [/E1], descôberto em janeiro de 1978,            produtor de óleo     arenitos de idade aptiana pertencentes    formações Mundaú e Paracuru    Bacia    Ceará, [E2] Sub-bacia de Mundaú [/E2] (fig. 2)..
# -------------
# -------------
# sentence = 25
# Token 1 =   formações Mundaú --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_296
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# --.==Q Campo de Curimã, descôberto em janeiro de 1978,            produtor de óleo     [E2] arenitos [/E2] de idade aptiana pertencentes    [E1] formações Mundaú [/E1] e Paracuru    Bacia    Ceará, Sub-bacia de Mundaú (fig. 2)..
# -------------
# -------------
# sentence = 25
# Token 1 =   formações Mundaú --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_296
# Token 2 =   Bacia Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# --.==Q Campo de Curimã, descôberto em janeiro de 1978,            produtor de óleo     arenitos de idade aptiana pertencentes    [E1] formações Mundaú [/E1] e Paracuru    [E2] Bacia    Ceará [/E2], Sub-bacia de Mundaú (fig. 2)..
# -------------
# -------------
# sentence = 25
# Token 1 =   formações Mundaú --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_296
# Token 2 =   Sub-bacia de Mundaú --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# --.==Q Campo de Curimã, descôberto em janeiro de 1978,            produtor de óleo     arenitos de idade aptiana pertencentes    [E1] formações Mundaú [/E1] e Paracuru    Bacia    Ceará, [E2] Sub-bacia de Mundaú [/E2] (fig. 2)..
# -------------
# -------------
# sentence = 25
# Token 1 =   Paracuru --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_200
# Token 2 =   óleo --- Class 2 =  FLUIDODATERRA_i --- URI 2 =  #oil
# Relation Type =  constituted_by
# --.==Q Campo de Curimã, descôberto em janeiro de 1978,            produtor de [E2] óleo [/E2]     arenitos de idade aptiana pertencentes    formações Mundaú e [E1] Paracuru [/E1]    Bacia    Ceará, Sub-bacia de Mundaú (fig. 2)..
# -------------
# -------------
# sentence = 25
# Token 1 =   Paracuru --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_200
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# --.==Q Campo de Curimã, descôberto em janeiro de 1978,            produtor de óleo     [E2] arenitos [/E2] de idade aptiana pertencentes    formações Mundaú e [E1] Paracuru [/E1]    Bacia    Ceará, Sub-bacia de Mundaú (fig. 2)..
# -------------
# -------------
# sentence = 25
# Token 1 =   Paracuru --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_200
# Token 2 =   Bacia Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# --.==Q Campo de Curimã, descôberto em janeiro de 1978,            produtor de óleo     arenitos de idade aptiana pertencentes    formações Mundaú e [E1] Paracuru [/E1]    [E2] Bacia    Ceará [/E2], Sub-bacia de Mundaú (fig. 2)..
# -------------
# -------------
# sentence = 25
# Token 1 =   Paracuru --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_200
# Token 2 =   Sub-bacia de Mundaú --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# --.==Q Campo de Curimã, descôberto em janeiro de 1978,            produtor de óleo     arenitos de idade aptiana pertencentes    formações Mundaú e [E1] Paracuru [/E1]    Bacia    Ceará, [E2] Sub-bacia de Mundaú [/E2] (fig. 2)..
# -------------
# -------------
# sentence = 46
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# Enquanto os primeiros, mais dispendiosos, em geral são obtidos somente em intervalos selecionados de alguns [E1] poços [/E1]    [E2] campo [/E2], os perfis estão disponíveis para todos eles..
# -------------
# -------------
# sentence = 47
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Curimã --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0352
# Relation Type =  located_in
# Em [E2] Curimã [/E2], apenas dois [E1] poços [/E1] foram testemunhados, totalizando 197 m de testemunhos a “partir dos-quais-foram obtidos 146-plugues que-tiveram seus valores de permeabilidade absoluta e porosidade determinados em laboratório..
# -------------
# -------------
# sentence = 123
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# Os procedimentos descritos permitiram estimar valores de permeabilidade absoluta para todos os [E1] poços [/E1]    [E2] campo [/E2], em intervalos discretos de 20 cm, tornando possível a análise     variações verticais observadas    longo     zonas produtoras..
# -------------
# -------------
# sentence = 150
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# Com uma análise discriminante, essa classificação pode ser estendida a todos os [E1] poços [/E1]    [E2] campo [/E2],            um acerto médio de 83%..
# -------------
# -------------
# sentence = 154
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# Com essas estimativas, foi possível estender as unidades de fluxo a todos os [E1] poços [/E1]    [E2] campo [/E2]..
# -------------
# -------------
# sentence = 158
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Curima --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0352
# Relation Type =  located_in
# O mapeamento     unidades de fluxo possibilitou melhor compreensão     históricos de produção     diversos [E1] poços [/E1] produtores    [E2] Campo de Curima [/E2], assim como     variações     características     reservatórios..
# -------------
# -------------
# sentence = 183
# Token 1 =   Formação Itaituba --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_187
# Token 2 =   Bacia Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# [E2] Bacia    Amazonas [/E2], em carbonatos de afloramentos atribuídos    intervalo basal    [E1] Formação Itaituba [/E1] (Fúlfaro, 1965),    Rio Tapajós, Pará, ocorrem os conodontes Gnathodus billineatus, Gnathodus girtyi e Lochriea mononodosa (fig.1)..
# -------------
# -------------
# sentence = 337
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# TENGAN, C., SHIMABUKURO, S., ROCHA-CAMPOS, A.C. Conodontes carboniferos    [E1] poço [/E1] FB 1 - AM, [E2] Bacia    Amazonas [/E2], Brasil..
# -------------
# -------------
# sentence = 347
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Membro Mucuri --- Class 2 =  UNIDADE_LITO --- URI 2 =  #membro_010
# Relation Type =  crosses
# RESUMO - A evolução diagenética     sedimentos areno-conglomeráticos    [E2] Membro Mucuri [/E2] foi definida regionalmente     bacias    Espirito Santo e de Mucuri a partir de amostras provenientes de 24 [E1] poços [/E1], com profundidades variando de 500 m a 3 000 m, aproximadamente..
# -------------
# -------------
# sentence = 347
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacias Espirito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# RESUMO - A evolução diagenética     sedimentos areno-conglomeráticos    Membro Mucuri foi definida regionalmente     [E2] bacias    Espirito Santo [/E2] e de Mucuri a partir de amostras provenientes de 24 [E1] poços [/E1], com profundidades variando de 500 m a 3 000 m, aproximadamente..
# -------------
# -------------
# sentence = 347
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Mucuri --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_260
# Relation Type =  located_in
# RESUMO - A evolução diagenética     sedimentos areno-conglomeráticos    Membro Mucuri foi definida regionalmente     bacias    Espirito Santo e de [E2] Mucuri [/E2] a partir de amostras provenientes de 24 [E1] poços [/E1], com profundidades variando de 500 m a 3 000 m, aproximadamente..
# -------------
# -------------
# sentence = 350
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   idades Alagoas --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Alagoas_Age
# Relation Type =  has_age
# O [E1] Membro Mucuri [/E1]              de sedimentos de [E2] idades Alagoas [/E2] e pré-Alagoas depositados em ambiente alúvio-flúvio-deltaico, sob clima árido, durante a fase rift     bacias    Espirito Santo e Mucuri..
# -------------
# -------------
# sentence = 350
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   pré-Alagoas --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Alagoas_Age
# Relation Type =  has_age
# O [E1] Membro Mucuri [/E1]              de sedimentos de idades Alagoas e [E2] pré-Alagoas [/E2] depositados em ambiente alúvio-flúvio-deltaico, sob clima árido, durante a fase rift     bacias    Espirito Santo e Mucuri..
# -------------
# -------------
# sentence = 354
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   idade Alagoas --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Alagoas_Age
# Relation Type =  has_age
# A maioria     reservatórios    [E1] Membro Mucuri [/E1] são de [E2] idade Alagoas [/E2], e, devido a sua melhor amostragem, estes reservatórios foram descritos mais detalhadamente..
# -------------
# -------------
# sentence = 365
# Token 1 =   campos --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Desde então, a diagênese        sedimentos foi avaliada em [E1] campos [/E1]    parte emersa    [E2] bacia [/E2],               os trabalhos de Maino et al. (1982), Milanez et al. (1985), Aranha (1987) e Leite (1990)..
# -------------
# -------------
# sentence = 377
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   Alagoas --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Alagoas_Age
# Relation Type =  has_age
# modo, foi considerada a divisão    [E1] Membro Mucuri [/E1] em [E2] Alagoas [/E2] e pré-Alagoas para considerar separadamente a evolução diagenética     sedimentos areno-conglomeráticos..
# -------------
# -------------
# sentence = 377
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   pré-Alagoas --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Alagoas_Age
# Relation Type =  has_age
# modo, foi considerada a divisão    [E1] Membro Mucuri [/E1] em Alagoas e [E2] pré-Alagoas [/E2] para considerar separadamente a evolução diagenética     sedimentos areno-conglomeráticos..
# -------------
# -------------
# sentence = 379
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacias Espirito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# Para desenvolver este trabalho, foram selecionados 20 [E1] poços [/E1]    porção emersa e quatro poços submarinos     [E2] bacias    Espirito Santo [/E2] e Mucuri (fia. 1)..
# -------------
# -------------
# sentence = 379
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Mucuri --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_260
# Relation Type =  located_in
# Para desenvolver este trabalho, foram selecionados 20 [E1] poços [/E1]    porção emersa e quatro poços submarinos     bacias    Espirito Santo e [E2] Mucuri [/E2] (fia. 1)..
# -------------
# -------------
# sentence = 379
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacias Espirito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# Para desenvolver este trabalho, foram selecionados 20 poços    porção emersa e quatro [E1] poços [/E1] submarinos     [E2] bacias    Espirito Santo [/E2] e Mucuri (fia. 1)..
# -------------
# -------------
# sentence = 379
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Mucuri --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_260
# Relation Type =  located_in
# Para desenvolver este trabalho, foram selecionados 20 poços    porção emersa e quatro [E1] poços [/E1] submarinos     bacias    Espirito Santo e [E2] Mucuri [/E2] (fia. 1)..
# -------------
# -------------
# sentence = 383
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Os [E2] arenitos [/E2] e conglomerados    [E1] Membro Mucuri [/E1] são arcóseos líticos conforme a classificação composicional proposta por McBride (1963) (fig. 3)..
# -------------
# -------------
# sentence = 383
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   conglomerados --- Class 2 =  ROCHA --- URI 2 =  #conglomerate
# Relation Type =  constituted_by
# Os arenitos e [E2] conglomerados [/E2]    [E1] Membro Mucuri [/E1] são arcóseos líticos conforme a classificação composicional proposta por McBride (1963) (fig. 3)..
# -------------
# -------------
# sentence = 385
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacias Espírito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# O estudo realizado a diferentes profundidades, em diferentes [E1] poços [/E1]     [E2] bacias    Espírito Santo [/E2]” e de Mucuri e em pacotes de diferentes idades (Alagoas e pré-Alagoas) permitiu identificar as variações diagenéticas    Membro Mucuri como um todo..
# -------------
# -------------
# sentence = 385
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Mucuri --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_260
# Relation Type =  located_in
# O estudo realizado a diferentes profundidades, em diferentes [E1] poços [/E1]     bacias    Espírito Santo” e de [E2] Mucuri [/E2] e em pacotes de diferentes idades (Alagoas e pré-Alagoas) permitiu identificar as variações diagenéticas    Membro Mucuri como um todo..
# -------------
# -------------
# sentence = 385
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Membro Mucuri --- Class 2 =  UNIDADE_LITO --- URI 2 =  #membro_010
# Relation Type =  crosses
# O estudo realizado a diferentes profundidades, em diferentes [E1] poços [/E1]     bacias    Espírito Santo” e de Mucuri e em pacotes de diferentes idades (Alagoas e pré-Alagoas) permitiu identificar as variações diagenéticas    [E2] Membro Mucuri [/E2] como um todo..
# -------------
# -------------
# sentence = 385
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   Alagoas --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Alagoas_Age
# Relation Type =  has_age
# O estudo realizado a diferentes profundidades, em diferentes poços     bacias    Espírito Santo” e de Mucuri e em pacotes de diferentes idades ([E2] Alagoas [/E2] e pré-Alagoas) permitiu identificar as variações diagenéticas    [E1] Membro Mucuri [/E1] como um todo..
# -------------
# -------------
# sentence = 385
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   pré-Alagoas --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Alagoas_Age
# Relation Type =  has_age
# O estudo realizado a diferentes profundidades, em diferentes poços     bacias    Espírito Santo” e de Mucuri e em pacotes de diferentes idades (Alagoas e [E2] pré-Alagoas [/E2]) permitiu identificar as variações diagenéticas    [E1] Membro Mucuri [/E1] como um todo..
# -------------
# -------------
# sentence = 402
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# [E2] arenitos [/E2]    [E1] Membro Mucuri [/E1], foram encontradas cutículas formadas por lamelas de argila dispostas paralelamente   superfície     grãos, apresentando pontes e meniscos (foto 1)..
# -------------
# -------------
# sentence = 448
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# [E2] arenitos [/E2]    [E1] Membro Mucuri [/E1], o processo de iltização foi reconhecido, em seção delgada,      aumento    birrefringência     argilo-minerais..
# -------------
# -------------
# sentence = 453
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# A transformação de caulinita em ilta é bem representada por booklets com birrefrigência amarela de primeira ordem, preenchendo os poros de [E2] arenitos [/E2] e conglomerados    . [E1] Membro Mucuri [/E1] a profundidades superiores a 2 500 m..
# -------------
# -------------
# sentence = 461
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   bacias --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# [E1] Membro Mucuri [/E1], a presença de franjas carbonáticas é bastante significativa, com ampla distribuição areal    parte emersa     [E2] bacias [/E2] e              apenas    pacote Alagoas..
# -------------
# -------------
# sentence = 558
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# tendência    aumento    conteúdo de cimento de quartzo com a profundidade     [E2] arenitos [/E2]    [E1] Membro Mucuri [/E1]..
# -------------
# -------------
# sentence = 588
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   anidrita --- Class 2 =  ROCHA --- URI 2 =  #anhydrite
# Relation Type =  constituted_by
# Os cimentos: evaporíticos [E2] anidrita [/E2] e gipsita não possuem expressão volumétrica     reservatórios siliciclásticos    [E1] Membro Mucuri [/E1]..
# -------------
# -------------
# sentence = 588
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   gipsita --- Class 2 =  ROCHA --- URI 2 =  #gipsita
# Relation Type =  constituted_by
# Os cimentos: evaporíticos anidrita e [E2] gipsita [/E2] não possuem expressão volumétrica     reservatórios siliciclásticos    [E1] Membro Mucuri [/E1]..
# -------------
# -------------
# sentence = 603
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   anidrita --- Class 2 =  ROCHA --- URI 2 =  #anhydrite
# Relation Type =  constituted_by
# exposto,            a associação     três cimentos encontrados    [E1] Membro Mucuri [/E1]: [E2] anidrita [/E2], calcita e dolomita..
# -------------
# -------------
# sentence = 621
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   idade pré-Alagoas --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Alagoas_Age
# Relation Type =  has_age
# Os plagioclásios com feições de albitzação    [E1] Membro Mucuri [/E1] foram encontrados     sedimentos a profundidades superiores a 2 500 m, em geral, de [E2] idade pré-Alagoas [/E2]..
# -------------
# -------------
# sentence = 636
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# A porosidade primária     [E2] arenitos [/E2]    [E1] Membro Mucuri [/E1] foi profundamente afetada      diagênese..
# -------------
# -------------
# sentence = 639
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Entre os mecanismos sugeridos para a geração de porosidade secundária sob regime eodiagenético, a dissolução por influxo de água meteórica (Bjdriykke, 1984) e mixing corrosion (Bogli, 1964, apud Giles e Marshall, 1986) são os mais prováveis de terem ocorrido     [E2] arenitos [/E2] e     conglomerados    [E1] Membro Mucuri [/E1]..
# -------------
# -------------
# sentence = 639
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   conglomerados --- Class 2 =  ROCHA --- URI 2 =  #conglomerate
# Relation Type =  constituted_by
# Entre os mecanismos sugeridos para a geração de porosidade secundária sob regime eodiagenético, a dissolução por influxo de água meteórica (Bjdriykke, 1984) e mixing corrosion (Bogli, 1964, apud Giles e Marshall, 1986) são os mais prováveis de terem ocorrido     arenitos e     [E2] conglomerados [/E2]    [E1] Membro Mucuri [/E1]..
# -------------
# -------------
# sentence = 642
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   idade Alagoas --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Alagoas_Age
# Relation Type =  has_age
# A associação de porosidade móldica e intragranular a tais cimentos induz   conclusão de que sejam resultantes    lixiviação meteórica. “Os principais reservatórios    [E1] Membro Mucuri [/E1] são de [E2] idade Alagoas [/E2] e tiveram longos tempos de residência B. Geoci..
# -------------
# -------------
# sentence = 655
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Os reservatórios    [E1] Membro Mucuri [/E1], compostos por [E2] arenitos [/E2] e conglomerados arcoseanos, estiveram submetidos a intensa diagênese, principalmente sob regime eodiagenético..
# -------------
# -------------
# sentence = 708
# Token 1 =   campos de Rio Preto --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0861
# Token 2 =   Bacia Espírito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# LEITE, M.P. Deposição e evolução diagenética     reservatórios    Membro Mucuri (Cretáceo Inferior),     [E1] campos de Rio Preto [/E1] e São Mateus, [E2] Bacia    Espírito Santo [/E2], Brasil..
# -------------
# -------------
# sentence = 708
# Token 1 =   São Mateus --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0912
# Token 2 =   Bacia Espírito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# LEITE, M.P. Deposição e evolução diagenética     reservatórios    Membro Mucuri (Cretáceo Inferior),     campos de Rio Preto e [E1] São Mateus [/E1], [E2] Bacia    Espírito Santo [/E2], Brasil..
# -------------
# -------------
# sentence = 711
# Token 1 =   Membro Mucuri --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_010
# Token 2 =   Formação Mariricu --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_013
# Relation Type =  part_of
# MAINO, V.M., WINTER, W.R., MILANEZ, D., NOVAIS, B.C., PIMENTEL, A.M.P., ALVES, D.B., ANJOS, S.M.C. Sistema deposicional, litofácies e fácies-reservatório    [E1] Membro Mucuri [/E1]    [E2] Formação Mariricu [/E2],    Campo de Rio Itaúnas..
# -------------
# -------------
# sentence = 738
# Token 1 =   poço 7-ICA-4 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_021985
# Token 2 =   Campo de Ilha Caçamba --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0545
# Relation Type =  located_in
# Análise de testemunhos    [E1] poço 7-ICA-4 [/E1]- | BA, [E2] Campo de Ilha    Caçamba [/E2], Bacia de Mucuri..
# -------------
# -------------
# sentence = 738
# Token 1 =   poço 7-ICA-4 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_021985
# Token 2 =   Bacia de Mucuri --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_260
# Relation Type =  located_in
# Análise de testemunhos    [E1] poço 7-ICA-4 [/E1]- | BA, Campo de Ilha    Caçamba, [E2] Bacia de Mucuri [/E2]..
# -------------
# -------------
# sentence = 738
# Token 1 =   Campo de Ilha Caçamba --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0545
# Token 2 =   Bacia de Mucuri --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_260
# Relation Type =  located_in
# Análise de testemunhos    poço 7-ICA-4- | BA, [E1] Campo de Ilha    Caçamba [/E1], [E2] Bacia de Mucuri [/E2]..
# -------------
# -------------
# sentence = 766
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Por meio    análise e interpretação de dados sismicos e de [E1] poços [/E1], é proposto um modelo evolutivo para a porção submersa    [E2] bacia [/E2], situada     proximidades    Campo de Ubarana..
# -------------
# -------------
# sentence = 766
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Ubarana --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0975
# Relation Type =  located_in
# Por meio    análise e interpretação de dados sismicos e de [E1] poços [/E1], é proposto um modelo evolutivo para a porção submersa    bacia, situada     proximidades    [E2] Campo de Ubarana [/E2]..
# -------------
# -------------
# sentence = 766
# Token 1 =   Campo de Ubarana --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0975
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Por meio    análise e interpretação de dados sismicos e de poços, é proposto um modelo evolutivo para a porção submersa    [E2] bacia [/E2], situada     proximidades    [E1] Campo de Ubarana [/E1]..
# -------------
# -------------
# sentence = 779
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# A partir       estudo regional,            uma campanha de perfuração    porção submersa    [E2] Bacia Potiguar [/E2], e já    terceiro [E1] poço [/E1]              o Campo de Ubarana, em 1973..
# -------------
# -------------
# sentence = 779
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Ubarana --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0975
# Relation Type =  located_in
# A partir       estudo regional,            uma campanha de perfuração    porção submersa    Bacia Potiguar, e já    terceiro [E1] poço [/E1]              o [E2] Campo de Ubarana [/E2], em 1973..
# -------------
# -------------
# sentence = 779
# Token 1 =   Campo de Ubarana --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0975
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# A partir       estudo regional,            uma campanha de perfuração    porção submersa    [E2] Bacia Potiguar [/E2], e já    terceiro poço              o [E1] Campo de Ubarana [/E1], em 1973..
# -------------
# -------------
# sentence = 780
# Token 1 =   campo --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Esse marco    prospecção    [E2] bacia [/E2] foi reforçado seis anos mais tarde com a descoberta    primeiro [E1] campo [/E1] de petróleo    sua porção emersa, próximo   cidade de Mossoró..
# -------------
# -------------
# sentence = 819
# Token 1 =   Formação Pendência --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_319
# Token 2 =   Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# É       contexto que se originou o Rift [E2] Potiguar [/E2], preenchido por espessos pacotes sedimentares associados   [E1] Formação Pendência [/E1]..
# -------------
# -------------
# sentence = 826
# Token 1 =   Formação Pendência --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_319
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Associados    estágio rift    [E2] bacia [/E2], foram rastreados o topo e um horizonte interno a [E1] Formação Pendência [/E1],    passo que outros quatro foram mapeados dentro    estágio pós-rift..
# -------------
# -------------
# sentence = 847
# Token 1 =   Membro Galinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_045
# Token 2 =   Formação Alagamar --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_056
# Relation Type =  part_of
# , portanto,      elaboração     seguintes mapas de isópacas: [E2] Formação Alagamar [/E2] ([E1] Membro Galinhos [/E1] e CPT), formações Açu (unidade Açu-1) e Alagamar (Membro Galinhos), e unidade Açu-2 (Formação Ponta    Mel)..
# -------------
# -------------
# sentence = 847
# Token 1 =   Membro Galinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_045
# Token 2 =   Alagamar --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_056
# Relation Type =  part_of
# , portanto,      elaboração     seguintes mapas de isópacas: Formação Alagamar ([E1] Membro Galinhos [/E1] e CPT), formações Açu (unidade Açu-1) e [E2] Alagamar [/E2] (Membro Galinhos), e unidade Açu-2 (Formação Ponta    Mel)..
# -------------
# -------------
# sentence = 847
# Token 1 =   Membro Galinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_045
# Token 2 =   Formação Alagamar --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_056
# Relation Type =  part_of
# , portanto,      elaboração     seguintes mapas de isópacas: [E2] Formação Alagamar [/E2] (Membro Galinhos e CPT), formações Açu (unidade Açu-1) e Alagamar ([E1] Membro Galinhos [/E1]), e unidade Açu-2 (Formação Ponta    Mel)..
# -------------
# -------------
# sentence = 847
# Token 1 =   Membro Galinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_045
# Token 2 =   Alagamar --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_056
# Relation Type =  part_of
# , portanto,      elaboração     seguintes mapas de isópacas: Formação Alagamar (Membro Galinhos e CPT), formações Açu (unidade Açu-1) e [E2] Alagamar [/E2] ([E1] Membro Galinhos [/E1]), e unidade Açu-2 (Formação Ponta    Mel)..
# -------------
# -------------
# sentence = 848
# Token 1 =   Formação Alagamar --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_056
# Token 2 =   Bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# O mapa de isópacas    [E1] Formação Alagamar [/E1] (Membro Upanema e CPT) representa os primeiros sedimentos depositados    fase pós-rift    [E2] Bacia [/E2] B. Geoci..
# -------------
# -------------
# sentence = 848
# Token 1 =   Membro Upanema --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_050
# Token 2 =   Formação Alagamar --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_056
# Relation Type =  part_of
# O mapa de isópacas    [E2] Formação Alagamar [/E2] ([E1] Membro Upanema [/E1] e CPT) representa os primeiros sedimentos depositados    fase pós-rift    Bacia B. Geoci..
# -------------
# -------------
# sentence = 848
# Token 1 =   Membro Upanema --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_050
# Token 2 =   Bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# O mapa de isópacas    Formação Alagamar ([E1] Membro Upanema [/E1] e CPT) representa os primeiros sedimentos depositados    fase pós-rift    [E2] Bacia [/E2] B. Geoci..
# -------------
# -------------
# sentence = 852
# Token 1 =   Membro Galinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_045
# Token 2 =   Alagamar --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_056
# Relation Type =  part_of
# A princípio mapeadas individualmente, as formações Açu (unidade Açu-1) e [E2] Alagamar [/E2] ([E1] Membro Galinhos [/E1]) apresentaram tendência bastante semelhante    distribuição     espessuras..
# -------------
# -------------
# sentence = 855
# Token 1 =   Membro Galinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_045
# Token 2 =   Alagamar --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_056
# Relation Type =  part_of
# A dificuldade    mapeamento    topo       formação fez com que se optasse      apresentação     espessuras     formações Açu (unidade Açu-1) e [E2] Alagamar [/E2] ([E1] Membro Galinhos [/E1])     único mapa de isópacas (fig. 8)..
# -------------
# -------------
# sentence = 891
# Token 1 =   Formação Pendência --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_319
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Com o final    fase rift, processos erosivos de caráter regional dominaram a [E2] Bacia Potiguar [/E2], formando a discordância    topo    [E1] Formação Pendência [/E1]..
# -------------
# -------------
# sentence = 893
# Token 1 =   Membro Upanema --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_050
# Token 2 =   Formação Alagamar --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_056
# Relation Type =  part_of
# Os primeiros sedimentos depositados                [E1] Membro Upanema [/E1]    [E2] Formação Alagamar [/E2], sobrepostos       calcilutitos e folhelhos     Camadas Ponta    Tubarão (CPT)..
# -------------
# -------------
# sentence = 893
# Token 1 =   Membro Upanema --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_050
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Os primeiros sedimentos depositados                [E1] Membro Upanema [/E1]    Formação Alagamar, sobrepostos       calcilutitos e [E2] folhelhos [/E2]     Camadas Ponta    Tubarão (CPT)..
# -------------
# -------------
# sentence = 893
# Token 1 =   Formação Alagamar --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_056
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Os primeiros sedimentos depositados                Membro Upanema    [E1] Formação Alagamar [/E1], sobrepostos       calcilutitos e [E2] folhelhos [/E2]     Camadas Ponta    Tubarão (CPT)..
# -------------
# -------------
# sentence = 893
# Token 1 =   Camadas Ponta Tubarão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_028
# Token 2 =   Formação Alagamar --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_056
# Relation Type =  part_of
# Os primeiros sedimentos depositados                Membro Upanema    [E2] Formação Alagamar [/E2], sobrepostos       calcilutitos e folhelhos     [E1] Camadas Ponta    Tubarão [/E1] (CPT)..
# -------------
# -------------
# sentence = 893
# Token 1 =   Camadas Ponta Tubarão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_028
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Os primeiros sedimentos depositados                Membro Upanema    Formação Alagamar, sobrepostos       calcilutitos e [E2] folhelhos [/E2]     [E1] Camadas Ponta    Tubarão [/E1] (CPT)..
# -------------
# -------------
# sentence = 898
# Token 1 =   embasamento --- Class 1 =  UNIDADE_LITO --- URI 1 =  #SD_000
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# O [E1] embasamento [/E1] cristalino e os sedimentos    estágio rift       porção    [E2] bacia [/E2] mergulham de oeste para leste..
# -------------
# -------------
# sentence = 931
# Token 1 =   Formação Macau --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_050
# Token 2 =   basaltos --- Class 2 =  ROCHA --- URI 2 =  #basalt
# Relation Type =  constituted_by
# Teixeira (1991), em estudo sobre a porção submersa    Bacia Potiguar, constatou a presença de fortes dobramentos de direção NE-SW afetando os [E2] basaltos [/E2]    [E1] Formação Macau [/E1], depositados    Eoceno/Oligoceno,     proximidades    Campo de Agulha..
# -------------
# -------------
# sentence = 931
# Token 1 =   Campo de Agulha --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0012
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Teixeira (1991), em estudo sobre a porção submersa    [E2] Bacia Potiguar [/E2], constatou a presença de fortes dobramentos de direção NE-SW afetando os basaltos    Formação Macau, depositados    Eoceno/Oligoceno,     proximidades    [E1] Campo de Agulha [/E1]..
# -------------
# -------------
# sentence = 932
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Lima ef al. (1993) concluíram,      análise de mecanismos focais de terremotos e breakouts (ovalização de [E1] poços [/E1]), que o campo de esforços neotectônicos para a porção submersa    [E2] Bacia Potiguar [/E2] é representado por uma tensão principal máxima (01) de direção ENE-WSW, suborizontal..
# -------------
# -------------
# sentence = 945
# Token 1 =   Formação Alagamar --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_056
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Durante o estágio pós-rift a [E2] Bacia Potiguar [/E2] passou por um período de relativa calmaria tectônica, quando foram depositados os sedimentos    [E1] Formação Alagamar [/E1], sobrepostos por uma megassequência transgressiva composta       unidades Açu-1, Açu-2, Açu-4 e Jandaíra..
# -------------
# -------------
# sentence = 945
# Token 1 =   Açu-1 --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_253
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Durante o estágio pós-rift a [E2] Bacia Potiguar [/E2] passou por um período de relativa calmaria tectônica, quando foram depositados os sedimentos    Formação Alagamar, sobrepostos por uma megassequência transgressiva composta       unidades [E1] Açu-1 [/E1], Açu-2, Açu-4 e Jandaíra..
# -------------
# -------------
# sentence = 945
# Token 1 =   Açu-2 --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_253
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Durante o estágio pós-rift a [E2] Bacia Potiguar [/E2] passou por um período de relativa calmaria tectônica, quando foram depositados os sedimentos    Formação Alagamar, sobrepostos por uma megassequência transgressiva composta       unidades Açu-1, [E1] Açu-2 [/E1], Açu-4 e Jandaíra..
# -------------
# -------------
# sentence = 945
# Token 1 =   Açu-4 --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_253
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Durante o estágio pós-rift a [E2] Bacia Potiguar [/E2] passou por um período de relativa calmaria tectônica, quando foram depositados os sedimentos    Formação Alagamar, sobrepostos por uma megassequência transgressiva composta       unidades Açu-1, Açu-2, [E1] Açu-4 [/E1] e Jandaíra..
# -------------
# -------------
# sentence = 945
# Token 1 =   Jandaíra --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_158
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Durante o estágio pós-rift a [E2] Bacia Potiguar [/E2] passou por um período de relativa calmaria tectônica, quando foram depositados os sedimentos    Formação Alagamar, sobrepostos por uma megassequência transgressiva composta       unidades Açu-1, Açu-2, Açu-4 e [E1] Jandaíra [/E1]..
# -------------
# -------------
# sentence = 950
# Token 1 =   Formações Ubarana --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_210
# Token 2 =   basaltos --- Class 2 =  ROCHA --- URI 2 =  #basalt
# Relation Type =  constituted_by
# , foram depositados em ambiente - Fegressivo os sedimentos associados    [E1] Formações Ubarana [/E1], Tibau, Guamaré e Barreiras e os [E2] basaltos [/E2]    Formação Macau..
# -------------
# -------------
# sentence = 950
# Token 1 =   Guamaré --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_003
# Token 2 =   basaltos --- Class 2 =  ROCHA --- URI 2 =  #basalt
# Relation Type =  constituted_by
# , foram depositados em ambiente - Fegressivo os sedimentos associados    Formações Ubarana, Tibau, [E1] Guamaré [/E1] e Barreiras e os [E2] basaltos [/E2]    Formação Macau..
# -------------
# -------------
# sentence = 950
# Token 1 =   Barreiras --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_016
# Token 2 =   basaltos --- Class 2 =  ROCHA --- URI 2 =  #basalt
# Relation Type =  constituted_by
# , foram depositados em ambiente - Fegressivo os sedimentos associados    Formações Ubarana, Tibau, Guamaré e [E1] Barreiras [/E1] e os [E2] basaltos [/E2]    Formação Macau..
# -------------
# -------------
# sentence = 950
# Token 1 =   Formação Macau --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_050
# Token 2 =   basaltos --- Class 2 =  ROCHA --- URI 2 =  #basalt
# Relation Type =  constituted_by
# , foram depositados em ambiente - Fegressivo os sedimentos associados    Formações Ubarana, Tibau, Guamaré e Barreiras e os [E2] basaltos [/E2]    [E1] Formação Macau [/E1]..
# -------------
# -------------
# sentence = 995
# Token 1 =   Ubarana --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0975
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# CREMONINI, O. A. Caracterização estrutural e evolução tectônica    Área de [E1] Ubarana [/E1], porção submersa    [E2] Bacia Potiguar [/E2], Brasil..
# -------------
# -------------
# sentence = 1057
# Token 1 =   Formação Ponta Mel --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_278
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# TERRA, G. J. S. Facies, modelo deposicional e diagênese    segiiência carbonática Albo-Cenomaniana ([E1] Formação Ponta    Mel [/E1])    [E2] Bacia Potiguar [/E2]..
# -------------
# -------------
# sentence = 1066
# Token 1 =   Campo de Pargo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0760
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# O objetivo, aqui, é promover uma modelagem geológica    escala adequada, incluindo as heterogeneidades inerentes    reservatório, para a compreensão    comportamento de produção de dois reservatórios    [E1] Campo de Pargo [/E1] ([E2] Bacia de Campos [/E2]), com as caracteristicas citadas..
# -------------
# -------------
# sentence = 1089
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Pargo --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0760
# Relation Type =  located_in
# Foram comparados os resultados    caso básico, versão atual     [E1] poços [/E1], com novas propostas de locação e diferentes opções de extensão de canhoneios, visando a elevar a recuperação de óleo de reservatório tão problemático como o    [E2] Campo de Pargo [/E2]..
# -------------
# -------------
# sentence = 1130
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Pargo --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0760
# Relation Type =  located_in
# Todos os [E1] poços [/E1]    [E2] Campo de Pargo [/E2] foram utilizados para a confecção    diagrama de cerca..
# -------------
# -------------
# sentence = 2034
# Token 1 =   Membro Água Grande --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_125
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# MENEZES, G. M. N. Análise faciológica ambiental e de reservatórios     [E2] arenitos [/E2]    [E1] Membro Água Grande [/E1] Formação Itaparica    Campo de Fazenda Alvorada, Bacia    Recôncavo..
# -------------
# -------------
# sentence = 2034
# Token 1 =   Formação Itaparica --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_229
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# MENEZES, G. M. N. Análise faciológica ambiental e de reservatórios     [E2] arenitos [/E2]    Membro Água Grande [E1] Formação Itaparica [/E1]    Campo de Fazenda Alvorada, Bacia    Recôncavo..
# -------------
# -------------
# sentence = 2034
# Token 1 =   Campo de Fazenda Alvorada --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0403
# Token 2 =   Bacia Recôncavo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_240
# Relation Type =  located_in
# MENEZES, G. M. N. Análise faciológica ambiental e de reservatórios     arenitos    Membro Água Grande Formação Itaparica    [E1] Campo de Fazenda Alvorada [/E1], [E2] Bacia    Recôncavo [/E2]..
# -------------
# -------------
# sentence = 2040
# Token 1 =   Campo de Namorado --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0734
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# ...
# Token 2 =   Arenitos Vila-Velha --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Segundo aqueles autores, os [E2] Arenitos Vila-Velha [/E2], aflorantes    Parque Estadual de Vila Velha, são representados por arenitos sobrepostos a ritmitos e diamictitos     formações Campo Mourão e Lagoa Azul, ou discor-dantemente sobre as formações Furnas e [E1] Ponta Grossa [/E1],    forma de platôs suborizontais..
# -------------
# -------------
# sentence = 17529
# Token 1 =   Ponta Grossa --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_157
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Segundo aqueles autores, os Arenitos Vila-Velha, aflorantes    Parque Estadual de Vila Velha, são representados por [E2] arenitos [/E2] sobrepostos a ritmitos e diamictitos     formações Campo Mourão e Lagoa Azul, ou discor-dantemente sobre as formações Furnas e [E1] Ponta Grossa [/E1],    forma de platôs suborizontais..
# -------------
# -------------
# sentence = 17535
# Token 1 =   Membro Rio Segredo --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_019
# Token 2 =   Formação Taciba --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_242
# Relation Type =  part_of
# Os melhores reservatórios              [E1] Membro Rio Segredo [/E1]    [E2] Formação Taciba [/E2] (8% de porosidade e 1% de matriz) e em camadas arenosas intercaladas a lamitos    Membro Tarabai    Formação Lagoa Azul (6% de porosidade e 2% de matriz)..
# -------------
# -------------
# sentence = 17535
# Token 1 =   Membro Tarabai --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_040
# Token 2 =   Formação Lagoa Azul --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_113
# Relation Type =  part_of
# Os melhores reservatórios              Membro Rio Segredo    Formação Taciba (8% de porosidade e 1% de matriz) e em camadas arenosas intercaladas a lamitos    [E1] Membro Tarabai [/E1]    [E2] Formação Lagoa Azul [/E2] (6% de porosidade e 2% de matriz)..
# -------------
# -------------
# sentence = 17536
# Token 1 =   Formação Campo Mourão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_259
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Em segunda ordem de importância estão os [E2] arenitos [/E2]    [E1] Formação Campo Mourão [/E1], com 8% de porosidade e 11% de matriz..
# -------------
# -------------
# sentence = 17537
# Token 1 =   Membro Cuiabá Paulista --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_075
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Os [E2] arenitos [/E2]    [E1] Membro Cuiabá Paulista [/E1]    Formação Lagoa Azul consistem em piores reservatórios, pois apresentam alto teor de matriz (45%)..
# -------------
# -------------
# sentence = 17537
# Token 1 =   Formação Lagoa Azul --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_113
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Os [E2] arenitos [/E2]    Membro Cuiabá Paulista    [E1] Formação Lagoa Azul [/E1] consistem em piores reservatórios, pois apresentam alto teor de matriz (45%)..
# -------------
# -------------
# sentence = 17543
# Token 1 =   Formação Campo Mourão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_259
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# parte média    [E1] Formação Campo Mourão [/E1] prevalecem os [E2] arenitos [/E2], porém em íntima associação com diamictitos, folhelhos e ritmitos..
# -------------
# -------------
# sentence = 17543
# Token 1 =   Formação Campo Mourão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_259
# Token 2 =   diamictitos --- Class 2 =  ROCHA --- URI 2 =  #diamictite
# Relation Type =  constituted_by
# parte média    [E1] Formação Campo Mourão [/E1] prevalecem os arenitos, porém em íntima associação com [E2] diamictitos [/E2], folhelhos e ritmitos..
# -------------
# -------------
# sentence = 17543
# Token 1 =   Formação Campo Mourão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_259
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# parte média    [E1] Formação Campo Mourão [/E1] prevalecem os arenitos, porém em íntima associação com diamictitos, [E2] folhelhos [/E2] e ritmitos..
# -------------
# -------------
# sentence = 17546
# Token 1 =   Formação Campo Mourão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_259
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# topo    [E1] Formação Campo Mourão [/E1]            um significativo intervalo argiloso marinho ([E2] folhelhos [/E2] e diamictitos), cuja posição estratigráfica é equivalente      Membro Lontras, descrito    faixa aflorante em Santa Catarina e em perfis de poços..
# -------------
# -------------
# sentence = 17546
# Token 1 =   Formação Campo Mourão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_259
# Token 2 =   diamictitos --- Class 2 =  ROCHA --- URI 2 =  #diamictite
# Relation Type =  constituted_by
# topo    [E1] Formação Campo Mourão [/E1]            um significativo intervalo argiloso marinho (folhelhos e [E2] diamictitos [/E2]), cuja posição estratigráfica é equivalente      Membro Lontras, descrito    faixa aflorante em Santa Catarina e em perfis de poços..
# -------------
# -------------
# sentence = 17546
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Formação Campo Mourão --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_259
# Relation Type =  crosses
# topo    [E2] Formação Campo Mourão [/E2]            um significativo intervalo argiloso marinho (folhelhos e diamictitos), cuja posição estratigráfica é equivalente      Membro Lontras, descrito    faixa aflorante em Santa Catarina e em perfis de [E1] poços [/E1]..
# -------------
# -------------
# sentence = 17549
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Esses horizontes também puderam ser                   variações     curvas     perfis sônico (tempo de trânsito) e raios gama (radioatividade natural) em [E1] poços [/E1] profundos    [E2] bacia [/E2]..
# -------------
# -------------
# sentence = 17562
# Token 1 =   Formação Campo Mourão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_259
# Token 2 =   Arenitos Vila Velha --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Geometría e arquitetura de fácies de lobos arenosos    [E1] Formação Campo Mourão [/E1], [E2] Arenitos Vila Velha [/E2]..
# -------------
# -------------
# sentence = 17620
# Token 1 =   formações Lagoa Azul --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_113
# Token 2 =   Grupo Itararé --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_033
# Relation Type =  part_of
# Acima       refletor, as geometrias representam corpos menos contínuos lateralmente, lenticulares e com clinoformas, indicando transporte sedimentar para WNW, relativos    [E1] formações Lagoa Azul [/E1] e Campo Mourão    [E2] Grupo Itararé [/E2]..
# -------------
# -------------
# sentence = 17620
# Token 1 =   Campo Mourão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_259
# Token 2 =   Grupo Itararé --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_033
# Relation Type =  part_of
# Acima       refletor, as geometrias representam corpos menos contínuos lateralmente, lenticulares e com clinoformas, indicando transporte sedimentar para WNW, relativos    formações Lagoa Azul e [E1] Campo Mourão [/E1]    [E2] Grupo Itararé [/E2]..
# -------------
# -------------
# sentence = 17632
# Token 1 =   Formação Campo Mourão --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_259
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Contudo, em subsuperfície, unidades correlatas, essencialmente argilosas, ocorrem como níveis capeadores, englobando tanto a porção superior    [E1] Formação Campo Mourão [/E1] como as formações Taciba (ou Rio    Sul, em alguns setores    [E2] bacia [/E2]), Palermo, Irati e Serra Alta, sobrepostas..
# -------------
# -------------
# sentence = 17632
# Token 1 =   formações Taciba --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_242
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Contudo, em subsuperfície, unidades correlatas, essencialmente argilosas, ocorrem como níveis capeadores, englobando tanto a porção superior    Formação Campo Mourão como as [E1] formações Taciba [/E1] (ou Rio    Sul, em alguns setores    [E2] bacia [/E2]), Palermo, Irati e Serra Alta, sobrepostas..
# -------------
# -------------
# sentence = 17632
# Token 1 =   Rio Sul --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_020
# Token 2 =   formações Taciba --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_242
# Relation Type =  part_of
# Contudo, em subsuperfície, unidades correlatas, essencialmente argilosas, ocorrem como níveis capeadores, englobando tanto a porção superior    Formação Campo Mourão como as [E2] formações Taciba [/E2] (ou [E1] Rio    Sul [/E1], em alguns setores    bacia), Palermo, Irati e Serra Alta, sobrepostas..
# -------------
# -------------
# sentence = 17632
# Token 1 =   Rio Sul --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_020
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Contudo, em subsuperfície, unidades correlatas, essencialmente argilosas, ocorrem como níveis capeadores, englobando tanto a porção superior    Formação Campo Mourão como as formações Taciba (ou [E1] Rio    Sul [/E1], em alguns setores    [E2] bacia [/E2]), Palermo, Irati e Serra Alta, sobrepostas..
# -------------
# -------------
# sentence = 17632
# Token 1 =   Palermo --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_116
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Contudo, em subsuperfície, unidades correlatas, essencialmente argilosas, ocorrem como níveis capeadores, englobando tanto a porção superior    Formação Campo Mourão como as formações Taciba (ou Rio    Sul, em alguns setores    [E2] bacia [/E2]), [E1] Palermo [/E1], Irati e Serra Alta, sobrepostas..
# -------------
# -------------
# sentence = 17632
# Token 1 =   Irati --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_254
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Contudo, em subsuperfície, unidades correlatas, essencialmente argilosas, ocorrem como níveis capeadores, englobando tanto a porção superior    Formação Campo Mourão como as formações Taciba (ou Rio    Sul, em alguns setores    [E2] bacia [/E2]), Palermo, [E1] Irati [/E1] e Serra Alta, sobrepostas..
# -------------
# -------------
# sentence = 17632
# Token 1 =   Serra Alta --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_066
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Contudo, em subsuperfície, unidades correlatas, essencialmente argilosas, ocorrem como níveis capeadores, englobando tanto a porção superior    Formação Campo Mourão como as formações Taciba (ou Rio    Sul, em alguns setores    [E2] bacia [/E2]), Palermo, Irati e [E1] Serra Alta [/E1], sobrepostas..
# -------------
# -------------
# sentence = 17641
# Token 1 =   Formação Rio Sul --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_020
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# figura 21            [E2] folhelhos [/E2]    [E1] Formação Rio    Sul [/E1] aflorando    cruzamento de grandes zonas de falha..
# -------------
# -------------
# sentence = 17652
# Token 1 =   Formação Ponta Grossa --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_157
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Há um consenso de que o gás gerado a partir     [E2] folhelhos [/E2] devonianos    [E1] Formação Ponta Grossa [/E1] pode alcançar os reservatórios    Grupo Itararé através de falhas regionais ou de sistemas de juntas (Milani e Catto 1998; Zalán et al. 1990)..
# -------------
# -------------
# sentence = 17652
# Token 1 =   Grupo Itararé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_033
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Há um consenso de que o gás gerado a partir     [E2] folhelhos [/E2] devonianos    Formação Ponta Grossa pode alcançar os reservatórios    [E1] Grupo Itararé [/E1] através de falhas regionais ou de sistemas de juntas (Milani e Catto 1998; Zalán et al. 1990)..
# -------------
# -------------
# sentence = 17654
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Embora seja relativamente comum a detecção de gás em vários [E1] poços [/E1]    [E2] Bacia [/E2], ainda não foi encontrada uma acumulação comercial em que a pressão seja constante por longo tempo..
# -------------
# -------------
# sentence = 17670
# Token 1 =   Subgrupo Itararé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_033
# Token 2 =   Bacia Paraná --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_300
# Relation Type =  located_in
# CANUTO, J. R.; SANTOS, P. R.; ROCHA-CAMPOS, A. C. Estratigrafia de seqüências    [E1] Subgrupo Itararé [/E1] (Neopaleozóico)    leste    [E2] Bacia    Paraná [/E2],     regiões sul    Paraná e norte de Santa Catarina, Brasil..
# -------------
# -------------
# sentence = 17672
# Token 1 =   Grupo Itararé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_033
# Token 2 =   arenito --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# D’ÁVILA, R. S. F. Análise de fácies e estratigrafia física    [E2] arenito [/E2] Lapa, [E1] Grupo Itararé [/E1], Bacia    Paraná, Brasil..
# -------------
# -------------
# sentence = 17672
# Token 1 =   Grupo Itararé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_033
# Token 2 =   Bacia Paraná --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_300
# Relation Type =  located_in
# D’ÁVILA, R. S. F. Análise de fácies e estratigrafia física    arenito Lapa, [E1] Grupo Itararé [/E1], [E2] Bacia    Paraná [/E2], Brasil..
# -------------
# -------------
# sentence = 17678
# Token 1 =   Grupo Itararé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_033
# Token 2 =   Arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# ______.; WINTER, R. B.; ASSINE, M. L. [E2] Arenitos [/E2] Lapa-Vila Velha: Um modelo de sistemas subaquosos canal-lobos sob influência glacial, [E1] Grupo Itararé [/E1] (C-P), KRAFT, R. P.; ROSTIROLLA, S. P.; RIGOTI, A.; APPI, C. J.; BARTOSZECK, M. K.; CAMPOS, A. F.; LONARDELLI, J. N. Correlações geofísicas e geológicas para a compreensão    distribuição de propriedades petrofísicas em reservatórios análogos..
# -------------
# -------------
# sentence = 17702
# Token 1 =   Grupo Itararé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_033
# Token 2 =   Arenitos Vila Velha --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# ______; APPI, C. J.; MANCINI, F.; KRAFT, R. P.; BARTOSZECK, M. K. Fraturas controladoras    migração de fluidos     [E2] Arenitos Vila Velha [/E2], [E1] Grupo Itararé [/E1], Bacia    Paraná..
# -------------
# -------------
# sentence = 17702
# Token 1 =   Grupo Itararé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_033
# Token 2 =   Bacia Paraná --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_300
# Relation Type =  located_in
# ______; APPI, C. J.; MANCINI, F.; KRAFT, R. P.; BARTOSZECK, M. K. Fraturas controladoras    migração de fluidos     Arenitos Vila Velha, [E1] Grupo Itararé [/E1], [E2] Bacia    Paraná [/E2]..
# -------------
# -------------
# sentence = 17712
# Token 1 =   Grupo Itararé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_033
# Token 2 =   Bacia Paraná --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_300
# Relation Type =  located_in
# TRZASKOS-LIPSKI, B.; ROSTIROLLA, S. P.; VESELY, F. F.; BOCARDI, L.; MANCINI, F.; APPI, C. J. Microtectônica e sua importância    estudo    circulação de fluidos em reservatórios fraturados    [E1] Grupo Itararé [/E1] – [E2] Bacia    Paraná [/E2]..
# -------------
# -------------
# Number of Jsons saved =  0

# %%
processar_sentencas_filtradas(df_filtred_sentences_valid, 
                              df_group_valid, 
                              save_csv_name_bert_valid, 
                              save_csv_name_relation_valid, 
                              save_folder_path_valid,
                              lista_relacoes_valid, 
                              lista_uris_valid, 
                              lista_classes_valid)
# Out:
# -------------
# sentence = 34
# Token 1 =   poço 7-BRG-12-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007553
# Token 2 =   Bacia de Sergipe/Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Observações:  1.a biozona foi originalmente definida em depósitos    [E2] Bacia de Sergipe/Alagoas [/E2] (testemunhos    [E1] poço 7-BRG-12-SE [/E1]), por Beurlen et al (1987)..
# -------------
# -------------
# sentence = 40
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Como esta zona passou a ser registrada em [E1] poços [/E1] de mais de uma [E2] bacia [/E2], a biounidade Nannoconus quadriangulus apertus caiu em desuso..
# -------------
# -------------
# sentence = 50
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# Cunha (1990a, b) poderia        valido para individualizar seu limite inferior    primeira ocorrência    espécie nominativa, o que a caracterizaria como uma zona de amplitude; 2. a biozona Nannoconus fragilis foi definida    [E2] Bacia    Ceará [/E2], tendo sido reconhecida posteriormente em alguns [E1] poços [/E1] de Sergipe/Alagoas e Potiguar..
# -------------
# -------------
# sentence = 50
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Cunha (1990a, b) poderia        valido para individualizar seu limite inferior    primeira ocorrência    espécie nominativa, o que a caracterizaria como uma zona de amplitude; 2. a biozona Nannoconus fragilis foi definida    Bacia    Ceará, tendo sido reconhecida posteriormente em alguns [E1] poços [/E1] de [E2] Sergipe [/E2]/Alagoas e Potiguar..
# -------------
# -------------
# sentence = 50
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Cunha (1990a, b) poderia        valido para individualizar seu limite inferior    primeira ocorrência    espécie nominativa, o que a caracterizaria como uma zona de amplitude; 2. a biozona Nannoconus fragilis foi definida    Bacia    Ceará, tendo sido reconhecida posteriormente em alguns [E1] poços [/E1] de Sergipe/[E2] Alagoas [/E2] e Potiguar..
# -------------
# -------------
# sentence = 50
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Cunha (1990a, b) poderia        valido para individualizar seu limite inferior    primeira ocorrência    espécie nominativa, o que a caracterizaria como uma zona de amplitude; 2. a biozona Nannoconus fragilis foi definida    Bacia    Ceará, tendo sido reconhecida posteriormente em alguns [E1] poços [/E1] de Sergipe/Alagoas e [E2] Potiguar [/E2]..
# -------------
# -------------
# sentence = 63
# Token 1 =   poço 7-BRG-12-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007553
# Token 2 =   Bacia de Sergipe/Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# entanto, Trôelsen e Quadros (1971) já haviam fotografado - alguns de seus - exemplares ([E2] Bacia de Sergipe/Alagoas [/E2], [E1] poço 7-BRG-12-SE [/E1])..
# -------------
# -------------
# sentence = 105
# Token 1 =   Formação Macaé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_000
# Token 2 =   Bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# É sabido; por exemplo, que a porção superior    [E1] Formação Macaé [/E1] (Albiano/Turoniano    [E2] Bacia [/E2] de (Campos) encerra níveis ricos em nanofósseis, observáveis somente com o auxílio    microscópio eletrônico de varredura (MEV, Spadini et al. 1988)..
# -------------
# -------------
# sentence = 105
# Token 1 =   Formação Macaé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_000
# Token 2 =   Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# É sabido; por exemplo, que a porção superior    [E1] Formação Macaé [/E1] (Albiano/Turoniano    Bacia de ([E2] Campos [/E2]) encerra níveis ricos em nanofósseis, observáveis somente com o auxílio    microscópio eletrônico de varredura (MEV, Spadini et al. 1988)..
# -------------
# -------------
# sentence = 140
# Token 1 =   poço 1-CES-75 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_012996
# Token 2 =   Bacia Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# [E2] Bacia    Ceará [/E2], Cunha (1990a) sugere que a espécie Nannoconus truitti truitti teria sido extinta    Turoniano ([E1] poço 1-CES-75 [/E1]), o que também pode ser verificado    perfuração 1-US-1-SE    Bacia de Sergipe/Alagoas (Cunha, informação verbal)..
# -------------
# -------------
# sentence = 140
# Token 1 =   1-US-1-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_010471
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Bacia    Ceará, Cunha (1990a) sugere que a espécie Nannoconus truitti truitti teria sido extinta    Turoniano (poço 1-CES-75), o que também pode ser verificado    perfuração [E1] 1-US-1-SE [/E1]    [E2] Bacia de Sergipe [/E2]/Alagoas (Cunha, informação verbal)..
# -------------
# -------------
# sentence = 140
# Token 1 =   1-US-1-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_010471
# Token 2 =   Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Bacia    Ceará, Cunha (1990a) sugere que a espécie Nannoconus truitti truitti teria sido extinta    Turoniano (poço 1-CES-75), o que também pode ser verificado    perfuração [E1] 1-US-1-SE [/E1]    Bacia de Sergipe/[E2] Alagoas [/E2] (Cunha, informação verbal)..
# -------------
# -------------
# sentence = 149
# Token 1 =   poço 1-CES-75 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_012996
# Token 2 =   Bacia Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# [E2] Bacia    Ceará [/E2], Cunha (1990a) sugere que a espécie Nannoconus truitti truitti teria sido extinta    Turoniano ([E1] poço 1-CES-75 [/E1]), o que também pode ser verificado    perfuração 1-US-1-SE    Bacia de Sergipe/Alagoas (Cunha, informação verbal)..
# -------------
# -------------
# sentence = 149
# Token 1 =   1-US-1-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_010471
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Bacia    Ceará, Cunha (1990a) sugere que a espécie Nannoconus truitti truitti teria sido extinta    Turoniano (poço 1-CES-75), o que também pode ser verificado    perfuração [E1] 1-US-1-SE [/E1]    [E2] Bacia de Sergipe [/E2]/Alagoas (Cunha, informação verbal)..
# -------------
# -------------
# sentence = 149
# Token 1 =   1-US-1-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_010471
# Token 2 =   Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Bacia    Ceará, Cunha (1990a) sugere que a espécie Nannoconus truitti truitti teria sido extinta    Turoniano (poço 1-CES-75), o que também pode ser verificado    perfuração [E1] 1-US-1-SE [/E1]    Bacia de Sergipe/[E2] Alagoas [/E2] (Cunha, informação verbal)..
# -------------
# -------------
# sentence = 163
# Token 1 =   Formação Itajaí --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_163
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# sítio sedimentar, raros exemplares de Nannoconus truitti têm sido observados     estratos basais    [E1] Formação Itajaí [/E1] ([E2] folhelhos [/E2] e margas) que jazem imediatamente acima    Formação Guarujá (carbonatos)..
# -------------
# -------------
# sentence = 163
# Token 1 =   Formação Itajaí --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_163
# Token 2 =   margas --- Class 2 =  ROCHA --- URI 2 =  #marlstone
# Relation Type =  constituted_by
# sítio sedimentar, raros exemplares de Nannoconus truitti têm sido observados     estratos basais    [E1] Formação Itajaí [/E1] (folhelhos e [E2] margas [/E2]) que jazem imediatamente acima    Formação Guarujá (carbonatos)..
# -------------
# -------------
# sentence = 163
# Token 1 =   Formação Guarujá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_166
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# sítio sedimentar, raros exemplares de Nannoconus truitti têm sido observados     estratos basais    Formação Itajaí ([E2] folhelhos [/E2] e margas) que jazem imediatamente acima    [E1] Formação Guarujá [/E1] (carbonatos)..
# -------------
# -------------
# sentence = 163
# Token 1 =   Formação Guarujá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_166
# Token 2 =   margas --- Class 2 =  ROCHA --- URI 2 =  #marlstone
# Relation Type =  constituted_by
# sítio sedimentar, raros exemplares de Nannoconus truitti têm sido observados     estratos basais    Formação Itajaí (folhelhos e [E2] margas [/E2]) que jazem imediatamente acima    [E1] Formação Guarujá [/E1] (carbonatos)..
# -------------
# -------------
# sentence = 166
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacias de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Assim, esta incoerência induz a formulação de duas hipóteses: b) ou os pontos de controle ([E1] poços [/E1])     [E2] Bacias de Campos [/E2] e Espirito Santo - em que o desaparecimento de Nannoconus truitti s.l..
# -------------
# -------------
# sentence = 166
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Espirito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# Assim, esta incoerência induz a formulação de duas hipóteses: b) ou os pontos de controle ([E1] poços [/E1])     Bacias de Campos e [E2] Espirito Santo [/E2] - em que o desaparecimento de Nannoconus truitti s.l..
# -------------
# -------------
# sentence = 239
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Observações:  1. a biozona em questão foi definida    [E2] Bacia Potiguar [/E2], onde Wanderley (1987, 1988) a registra em poucos [E1] poços [/E1] e com espessura modesta..
# -------------
# -------------
# sentence = 240
# Token 1 =   poço 1-CES-75 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_012996
# Token 2 =   Bacia Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# Algum tempo depois, Cunha (1990a) a reconheceu com pequena espessura    [E1] poço 1-CES-75 [/E1]    [E2] Bacia    Ceará [/E2] (Sub-bacia de Mundaú)..
# -------------
# -------------
# sentence = 240
# Token 1 =   poço 1-CES-75 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_012996
# Token 2 =   Sub-bacia de Mundaú --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# Algum tempo depois, Cunha (1990a) a reconheceu com pequena espessura    [E1] poço 1-CES-75 [/E1]    Bacia    Ceará ([E2] Sub-bacia de Mundaú [/E2])..
# -------------
# -------------
# sentence = 246
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacias --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Como se pode notar, a Zona Stoverius achylosus não é uma biounidade de fácil reconhecimento, uma vez que,     [E2] bacias [/E2] onde foi registrada, sua espessura é sempre modesta (em geral, inferior a 100 m; duas ou três amostras de calha de [E1] poços [/E1])..
# -------------
# -------------
# sentence = 483
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacias --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Com maior ou menor frequência, todas as espécies assinaladas já foram registradas em amostras provenientes de [E1] poços [/E1] exploratórios     [E2] bacias [/E2] brasileiras e constituem bioelementos importantes para a mais precisa datação bioestratigráfica de seções, principalmente, quando estas seções contam com testemunhos e amostras laterais..
# -------------
# -------------
# sentence = 576
# Token 1 =   Fazenda Cedro --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0444
# Token 2 =   Bacia Espirito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# ANTUNES, R. L. Geohistória    paleocanion de [E1] Fazenda Cedro [/E1], [E2] Bacia    Espirito Santo [/E2] - Brasil, segundo dados biocronoestratigráficos..
# -------------
# -------------
# sentence = 698
# Token 1 =   formações Monte Alegre --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_232
# Token 2 =   bacias Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# RESUMO -     [E2] bacias    Amazonas [/E2] e    Solimões, a sequência carbonifera é representada       [E1] formações Monte Alegre [/E1], Itaituba e,      menos,      parte basal    Formação Nova Olinda..
# -------------
# -------------
# sentence = 698
# Token 1 =   Itaituba --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_187
# Token 2 =   bacias Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# RESUMO -     [E2] bacias    Amazonas [/E2] e    Solimões, a sequência carbonifera é representada       formações Monte Alegre, [E1] Itaituba [/E1] e,      menos,      parte basal    Formação Nova Olinda..
# -------------
# -------------
# sentence = 698
# Token 1 =   Formação Nova Olinda --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_028
# Token 2 =   bacias Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# RESUMO -     [E2] bacias    Amazonas [/E2] e    Solimões, a sequência carbonifera é representada       formações Monte Alegre, Itaituba e,      menos,      parte basal    [E1] Formação Nova Olinda [/E1]..
# -------------
# -------------
# sentence = 699
# Token 1 =   poços 2-CA-1-AM --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_022660
# Token 2 =   Formação Itaituba --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_187
# Relation Type =  crosses
# Dentro    intervalo abrangido por essas formações, foi possivel reconhecer o limite Morrowano/Atokano     [E1] poços 2-CA-1-AM [/E1] e 1-UI-1-AM, situado    parte média    [E2] Formação Itaituba [/E2]..
# -------------
# -------------
# sentence = 705
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# , aqui, um trabalho com amostras de testemunhos de subsuperfície de [E1] poços [/E1]    PETROBRAS,    [E2] Bacia    Amazonas [/E2] (fig. 1)..
# -------------
# -------------
# sentence = 758
# Token 1 =   2-CA-1-AM --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_022660
# Token 2 =   Bacia Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# O melhor resultado foi obtido    pogo [E1] 2-CA-1-AM [/E1],    Texas Central, propuseram o nome Atokan    [E2] Bacia    Amazonas [/E2], onde foi possível estabelecer o especificamente para o que seria o intervalo pré-limite entre os andares Morrowano e Atokano (fig. 4), Desmoinesiano, pós-Morrowano..
# -------------
# -------------
# sentence = 823
# Token 1 =   Formação Monte Alegre --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_232
# Token 2 =   Bacia Alto Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# LANZARINI, W. L. Facies sedimentares e ambiente deposicional    [E1] Formação Monte Alegre [/E1]    área de Juruá, [E2] Bacia    Alto Amazonas [/E2] - diagênese e permoporosidade     arenitos reservatórios..
# -------------
# -------------
# sentence = 823
# Token 1 =   Formação Monte Alegre --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_232
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# LANZARINI, W. L. Facies sedimentares e ambiente deposicional    [E1] Formação Monte Alegre [/E1]    área de Juruá, Bacia    Alto Amazonas - diagênese e permoporosidade     [E2] arenitos [/E2] reservatórios..
# -------------
# -------------
# sentence = 843
# Token 1 =   Formação itaituba --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_187
# Token 2 =   Bacia Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# SAVINI, R., ALTINER, D. A fauna de fusulinideos    poço 1 -    -1-AM ([E2] Bacia    Amazonas [/E2]): implicações para, um novo posicionamento cronoestratigráfico    [E1] Formação itaituba [/E1]..
# -------------
# -------------
# sentence = 920
# Token 1 =   GTP-8 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_008339
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Os chevrons de halita analisados em amostras obtidas     testemunhos    perfuração [E1] GTP-8 [/E1], a porção terrestre    [E2] Bacia de Sergipe [/E2], indicam uma salmoura de composição enriquecida em cálcio e empobrecida em sulfato (tabela I), não compatível com os valores encontrados para esses elementos     oceanos modernos (Hardie, 1996)..
# -------------
# -------------
# sentence = 975
# Token 1 =   Formação Irati --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_254
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# presumir, para o caso     [E2] folhelhos [/E2] carbonosos finamente laminados e com laminação espessa,    [E1] Formação Irati [/E1], que há maior probabilidade   associação com fluxos vinculados a eventos de tempestades..
# -------------
# -------------
# sentence = 1049
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Ingressou    Petrobras em 1979, trabalhando    área de acompanhamento de [E1] poços [/E1] e operações geológicas    [E2] Bacia de Campos [/E2]..
# -------------
# -------------
# sentence = 1059
# Token 1 =   formações Monte Alegre --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_232
# Token 2 =   Grupo Tapajós --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_049
# Relation Type =  part_of
# O [E2] Grupo Tapajós [/E2], conforme proposto por Caputo (1984), é constituído, em ordem ascen-dente,       [E1] formações Monte Alegre [/E1], Itaituba, Nova Olinda e Andirá..
# -------------
# -------------
# sentence = 1059
# Token 1 =   Itaituba --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_187
# Token 2 =   Grupo Tapajós --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_049
# Relation Type =  part_of
# O [E2] Grupo Tapajós [/E2], conforme proposto por Caputo (1984), é constituído, em ordem ascen-dente,       formações Monte Alegre, [E1] Itaituba [/E1], Nova Olinda e Andirá..
# -------------
# -------------
# sentence = 1059
# Token 1 =   Nova Olinda --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_028
# Token 2 =   Grupo Tapajós --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_049
# Relation Type =  part_of
# O [E2] Grupo Tapajós [/E2], conforme proposto por Caputo (1984), é constituído, em ordem ascen-dente,       formações Monte Alegre, Itaituba, [E1] Nova Olinda [/E1] e Andirá..
# -------------
# -------------
# sentence = 1059
# Token 1 =   Andirá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_159
# Token 2 =   Grupo Tapajós --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_049
# Relation Type =  part_of
# O [E2] Grupo Tapajós [/E2], conforme proposto por Caputo (1984), é constituído, em ordem ascen-dente,       formações Monte Alegre, Itaituba, Nova Olinda e [E1] Andirá [/E1]..
# -------------
# -------------
# sentence = 1063
# Token 1 =   Formação Andirá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_159
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# A seção paleozóica    [E2] bacia [/E2] se encerra com a deposição     sedimentos    [E1] Formação Andirá [/E1], formados por siliciclásticos avermelhados, raros evaporitos e carbonatos depositados em maior parte em ambiente fluvial / lacustrino a marinho restrito..
# -------------
# -------------
# sentence = 1063
# Token 1 =   Formação Andirá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_159
# Token 2 =   sedimentos --- Class 2 =  NÃOCONSOLID --- URI 2 =  #unconsolidated_earth_material
# Relation Type =  constituted_by
# A seção paleozóica    bacia se encerra com a deposição     [E2] sedimentos [/E2]    [E1] Formação Andirá [/E1], formados por siliciclásticos avermelhados, raros evaporitos e carbonatos depositados em maior parte em ambiente fluvial / lacustrino a marinho restrito..
# -------------
# -------------
# sentence = 1085
# Token 1 =   formações Nova Olinda --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_028
# Token 2 =   conglomerados --- Class 2 =  ROCHA --- URI 2 =  #conglomerate
# Relation Type =  constituted_by
# Tais [E2] conglomerados [/E2], contidos entre as profun- considerações finais Estudos de detalhe     campos    bioestratigrafia, estratigrafia de seqüências e sismoestratigrafia, independentemente realizados, e ora integrados, permitiram estabelecer algumas conclusões de ordem estratigráfica a respeito    limite entre as [E1] formações Nova Olinda [/E1] e Andirá,    Grupo Tapajós, Bacia    Amazonas..
# -------------
# -------------
# sentence = 1085
# Token 1 =   formações Nova Olinda --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_028
# Token 2 =   Grupo Tapajós --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_049
# Relation Type =  part_of
# Tais conglomerados, contidos entre as profun- considerações finais Estudos de detalhe     campos    bioestratigrafia, estratigrafia de seqüências e sismoestratigrafia, independentemente realizados, e ora integrados, permitiram estabelecer algumas conclusões de ordem estratigráfica a respeito    limite entre as [E1] formações Nova Olinda [/E1] e Andirá,    [E2] Grupo Tapajós [/E2], Bacia    Amazonas..
# -------------
# -------------
# sentence = 1085
# Token 1 =   formações Nova Olinda --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_028
# Token 2 =   Bacia Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# Tais conglomerados, contidos entre as profun- considerações finais Estudos de detalhe     campos    bioestratigrafia, estratigrafia de seqüências e sismoestratigrafia, independentemente realizados, e ora integrados, permitiram estabelecer algumas conclusões de ordem estratigráfica a respeito    limite entre as [E1] formações Nova Olinda [/E1] e Andirá,    Grupo Tapajós, [E2] Bacia    Amazonas [/E2]..
# -------------
# -------------
# sentence = 1085
# Token 1 =   Andirá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_159
# Token 2 =   conglomerados --- Class 2 =  ROCHA --- URI 2 =  #conglomerate
# Relation Type =  constituted_by
# Tais [E2] conglomerados [/E2], contidos entre as profun- considerações finais Estudos de detalhe     campos    bioestratigrafia, estratigrafia de seqüências e sismoestratigrafia, independentemente realizados, e ora integrados, permitiram estabelecer algumas conclusões de ordem estratigráfica a respeito    limite entre as formações Nova Olinda e [E1] Andirá [/E1],    Grupo Tapajós, Bacia    Amazonas..
# -------------
# -------------
# sentence = 1085
# Token 1 =   Andirá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_159
# Token 2 =   Grupo Tapajós --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_049
# Relation Type =  part_of
# Tais conglomerados, contidos entre as profun- considerações finais Estudos de detalhe     campos    bioestratigrafia, estratigrafia de seqüências e sismoestratigrafia, independentemente realizados, e ora integrados, permitiram estabelecer algumas conclusões de ordem estratigráfica a respeito    limite entre as formações Nova Olinda e [E1] Andirá [/E1],    [E2] Grupo Tapajós [/E2], Bacia    Amazonas..
# -------------
# -------------
# sentence = 1085
# Token 1 =   Andirá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_159
# Token 2 =   Bacia Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# Tais conglomerados, contidos entre as profun- considerações finais Estudos de detalhe     campos    bioestratigrafia, estratigrafia de seqüências e sismoestratigrafia, independentemente realizados, e ora integrados, permitiram estabelecer algumas conclusões de ordem estratigráfica a respeito    limite entre as formações Nova Olinda e [E1] Andirá [/E1],    Grupo Tapajós, [E2] Bacia    Amazonas [/E2]..
# -------------
# -------------
# sentence = 1085
# Token 1 =   Grupo Tapajós --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_049
# Token 2 =   Bacia Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# Tais conglomerados, contidos entre as profun- considerações finais Estudos de detalhe     campos    bioestratigrafia, estratigrafia de seqüências e sismoestratigrafia, independentemente realizados, e ora integrados, permitiram estabelecer algumas conclusões de ordem estratigráfica a respeito    limite entre as formações Nova Olinda e Andirá,    [E1] Grupo Tapajós [/E1], [E2] Bacia    Amazonas [/E2]..
# -------------
# -------------
# sentence = 1086
# Token 1 =   poço 9-FZ-2-AM --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_023241
# Token 2 =   Formação Nova Olinda --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_028
# Relation Type =  crosses
# A [E2] Formação Nova Olinda [/E2] engloba uma expressiva discordância em sua porção superior,       modo,             aqui a questão    contato entre as formações Nova Olinda e Andirá, a partir    estudo    intervalo 1 217,00 m a 1 350,00 m    [E1] poço 9-FZ-2-AM [/E1]..
# -------------
# -------------
# sentence = 1086
# Token 1 =   poço 9-FZ-2-AM --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_023241
# Token 2 =   formações Nova Olinda --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_028
# Relation Type =  crosses
# A Formação Nova Olinda engloba uma expressiva discordância em sua porção superior,       modo,             aqui a questão    contato entre as [E2] formações Nova Olinda [/E2] e Andirá, a partir    estudo    intervalo 1 217,00 m a 1 350,00 m    [E1] poço 9-FZ-2-AM [/E1]..
# -------------
# -------------
# sentence = 1086
# Token 1 =   poço 9-FZ-2-AM --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_023241
# Token 2 =   Andirá --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_159
# Relation Type =  crosses
# A Formação Nova Olinda engloba uma expressiva discordância em sua porção superior,       modo,             aqui a questão    contato entre as formações Nova Olinda e [E2] Andirá [/E2], a partir    estudo    intervalo 1 217,00 m a 1 350,00 m    [E1] poço 9-FZ-2-AM [/E1]..
# -------------
# -------------
# sentence = 1087
# Token 1 =   Formação Nova Olinda --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_028
# Token 2 =   conglomerado --- Class 2 =  ROCHA --- URI 2 =  #conglomerate
# Relation Type =  constituted_by
# , também, que o limite superior    [E1] Formação Nova Olinda [/E1] seja posicionado    base    pacote de [E2] conglomerado [/E2] intraformacional de coloração avermelhada-escura a 1 271,50 m; sendo a seção siliciclástica sotoposta   base    Formação Andirá..
# -------------
# -------------
# sentence = 1087
# Token 1 =   Formação Andirá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_159
# Token 2 =   conglomerado --- Class 2 =  ROCHA --- URI 2 =  #conglomerate
# Relation Type =  constituted_by
# , também, que o limite superior    Formação Nova Olinda seja posicionado    base    pacote de [E2] conglomerado [/E2] intraformacional de coloração avermelhada-escura a 1 271,50 m; sendo a seção siliciclástica sotoposta   base    [E1] Formação Andirá [/E1]..
# -------------
# -------------
# sentence = 1146
# Token 1 =   Grupo Tapajós --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_049
# Token 2 =   Pensilvaniano Inferior --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Bashkirian
# Relation Type =  has_age
# Marinhos    [E1] Grupo Tapajós [/E1], [E2] Pensilvaniano Inferior [/E2] a Médio    Bacia    Amazonas com aplicação de isótopos de Sr e Nd       intervalo..
# -------------
# -------------
# sentence = 1146
# Token 1 =   Grupo Tapajós --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_049
# Token 2 =   Bacia Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# Marinhos    [E1] Grupo Tapajós [/E1], Pensilvaniano Inferior a Médio    [E2] Bacia    Amazonas [/E2] com aplicação de isótopos de Sr e Nd       intervalo..
# -------------
# -------------
# sentence = 1165
# Token 1 =   Formação Jandaíra --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_158
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# em Engenharia Geológica      Universidade Federal de Ouro Preto, em 1984, com Mestrado em Análises de Bacias Sedimentares      Universidade Federal de Ouro Preto, em 1988, com o tema: Marco radioativo    [E1] Formação Jandaíra [/E1], [E2] Bacia    Potiguar [/E2], resultado que gerou a descoberta    fosfato Campaniano..
# -------------
# -------------
# sentence = 1341
# Token 1 =   Campo de Pampo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0750
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# [E1] Campo de Pampo [/E1], [E2] Bacia de Campos [/E2], onde a profundidade de soterramento     reservatórios calcários albianos é de cerca de 1 800 m,            que packstones peloidais    base de ciclos de rasamento ascendente (shoaling-up cycles) apresentam porosidades    ordem de 30%, enquanto os grainstones oolíticos    topo     ciclos mostram porosidades menores (fig. 5)..
# -------------
# -------------
# sentence = 1440
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacias Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_030
# Relation Type =  located_in
# Em 1974 ingressou    Petrobras,    antiga Renor, em Belém    Pará, tendo atuado como geólogo de [E1] poço [/E1]     [E2] bacias    Amazonas [/E2], Foz    Amazonas, Ceará, Maranhão, Potiguar, Recôncavo, Espírito Santo e Campos..
# -------------
# -------------
# sentence = 1440
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Foz Amazonas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_051
# Relation Type =  located_in
# Em 1974 ingressou    Petrobras,    antiga Renor, em Belém    Pará, tendo atuado como geólogo de [E1] poço [/E1]     bacias    Amazonas, [E2] Foz    Amazonas [/E2], Ceará, Maranhão, Potiguar, Recôncavo, Espírito Santo e Campos..
# -------------
# -------------
# sentence = 1440
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Ceará --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_096
# Relation Type =  located_in
# Em 1974 ingressou    Petrobras,    antiga Renor, em Belém    Pará, tendo atuado como geólogo de [E1] poço [/E1]     bacias    Amazonas, Foz    Amazonas, [E2] Ceará [/E2], Maranhão, Potiguar, Recôncavo, Espírito Santo e Campos..
# -------------
# -------------
# sentence = 1440
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Maranhão --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_076
# Relation Type =  located_in
# Em 1974 ingressou    Petrobras,    antiga Renor, em Belém    Pará, tendo atuado como geólogo de [E1] poço [/E1]     bacias    Amazonas, Foz    Amazonas, Ceará, [E2] Maranhão [/E2], Potiguar, Recôncavo, Espírito Santo e Campos..
# -------------
# -------------
# sentence = 1440
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Em 1974 ingressou    Petrobras,    antiga Renor, em Belém    Pará, tendo atuado como geólogo de [E1] poço [/E1]     bacias    Amazonas, Foz    Amazonas, Ceará, Maranhão, [E2] Potiguar [/E2], Recôncavo, Espírito Santo e Campos..
# -------------
# -------------
# sentence = 1440
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Recôncavo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_240
# Relation Type =  located_in
# Em 1974 ingressou    Petrobras,    antiga Renor, em Belém    Pará, tendo atuado como geólogo de [E1] poço [/E1]     bacias    Amazonas, Foz    Amazonas, Ceará, Maranhão, Potiguar, [E2] Recôncavo [/E2], Espírito Santo e Campos..
# -------------
# -------------
# sentence = 1440
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Espírito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# Em 1974 ingressou    Petrobras,    antiga Renor, em Belém    Pará, tendo atuado como geólogo de [E1] poço [/E1]     bacias    Amazonas, Foz    Amazonas, Ceará, Maranhão, Potiguar, Recôncavo, [E2] Espírito Santo [/E2] e Campos..
# -------------
# -------------
# sentence = 1440
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Em 1974 ingressou    Petrobras,    antiga Renor, em Belém    Pará, tendo atuado como geólogo de [E1] poço [/E1]     bacias    Amazonas, Foz    Amazonas, Ceará, Maranhão, Potiguar, Recôncavo, Espírito Santo e [E2] Campos [/E2]..
# -------------
# -------------
# sentence = 1456
# Token 1 =   campo --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   Bacia de Camamu --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_266
# Relation Type =  located_in
# Com a descoberta    [E1] campo [/E1] de gás de Manati,    [E2] Bacia de Camamu [/E2], a exploração de hidrocarbonetos    plataforma continental central    Estado    Bahia recebeu um grande impulso, demandando mais conhecimentos geológicos..
# -------------
# -------------
# sentence = 1456
# Token 1 =   Manati --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0888
# Token 2 =   Bacia de Camamu --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_266
# Relation Type =  located_in
# Com a descoberta    campo de gás de [E1] Manati [/E1],    [E2] Bacia de Camamu [/E2], a exploração de hidrocarbonetos    plataforma continental central    Estado    Bahia recebeu um grande impulso, demandando mais conhecimentos geológicos..
# -------------
# -------------
# sentence = 1457
# Token 1 =   Campo de Manati --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0888
# Token 2 =   bacias de Camamu --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_266
# Relation Type =  located_in
# Em função    perspectiva de novas descobertas     [E2] bacias de Camamu [/E2] e de Almada, o presente trabalho foi realizado    sul    [E1] Campo de Manati [/E1], tendo sua área de estudo a cerca de 300 km de Salvador, entre a Ponta    Mutá e a cidade de Olivença (fig. 1)..
# -------------
# -------------
# sentence = 1457
# Token 1 =   Campo de Manati --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0888
# Token 2 =   Almada --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_266
# Relation Type =  located_in
# Em função    perspectiva de novas descobertas     bacias de Camamu e de [E2] Almada [/E2], o presente trabalho foi realizado    sul    [E1] Campo de Manati [/E1], tendo sua área de estudo a cerca de 300 km de Salvador, entre a Ponta    Mutá e a cidade de Olivença (fig. 1)..
# -------------
# -------------
# sentence = 1486
# Token 1 =   embasamento --- Class 1 =  UNIDADE_LITO --- URI 1 =  #SD_000
# Token 2 =   bacias --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Desta forma, foi possível inferir que,    maioria        [E2] bacias [/E2], os rios dissecam rochas metamórficas e ígneas ferro-magnesianas    [E1] embasamento [/E1] cristalino, forne-cendo grande aporte de lama para a plataforma..
# -------------
# -------------
# sentence = 1784
# Token 1 =   Campo de Sesmaria --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0932
# Token 2 =   Bacia Recôncavo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_240
# Relation Type =  located_in
# O [E1] Campo de Sesmaria [/E1], localizado    compartimento nordeste    [E2] Bacia    Recôncavo [/E2], foi descoberto em 1966 e é produtor de óleo, principalmente    Formação Sergi..
# -------------
# -------------
# sentence = 1786
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# Dois fatores dificultam o dimensionamento    jazida: — contato óleo-água ainda não            nem mesmo     [E1] poços [/E1]    periferia    [E2] campo [/E2]; — presença de faixas não produtoras decorrentes    obliteração localizada    meio poroso    rocha, causada pe- . la ação    diagênese e por óleo pesado (residual), que age como cimento..
# -------------
# -------------
# sentence = 1787
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# A análise     características texturais e     estruturas sedimentares de 360 m de testemunhos contínuos cortados em três [E1] poços [/E1]    [E2] campo [/E2] permitiu a identificação de sete litofácies    Formação Sergi, que se agrupam em três associações faciológicas, denominadas —    base para o topo    unidade — de Sergi Distal, Sergi Mediano e Sergi Proximal..
# -------------
# -------------
# sentence = 1787
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Formação Sergi --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_239
# Relation Type =  crosses
# A análise     características texturais e     estruturas sedimentares de 360 m de testemunhos contínuos cortados em três [E1] poços [/E1]    campo permitiu a identificação de sete litofácies    [E2] Formação Sergi [/E2], que se agrupam em três associações faciológicas, denominadas —    base para o topo    unidade — de Sergi Distal, Sergi Mediano e Sergi Proximal..
# -------------
# -------------
# sentence = 1792
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# Até o presente momento, a história    [E2] campo [/E2] retrata duas fases distintas: — Primeira fase (de 1966 até final de 1981): foram perfurados dezesseis [E1] poços [/E1],     quais seis foram abando-nados como secos e antieconômicos, e dez, revestidos para a produção de óleo..
# -------------
# -------------
# sentence = 1801
# Token 1 =   campos --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   Bacia Recôncavo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_240
# Relation Type =  located_in
# A análise de 138 lâminas delgadas mostrou que os mais altos teores de cimento    Formação Sergi,     [E1] campos [/E1]    [E2] Bacia    Recôncavo [/E2], são encontrados    Campo de Sesmaria..
# -------------
# -------------
# sentence = 1801
# Token 1 =   Campo de Sesmaria --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0932
# Token 2 =   Bacia Recôncavo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_240
# Relation Type =  located_in
# A análise de 138 lâminas delgadas mostrou que os mais altos teores de cimento    Formação Sergi,     campos    [E2] Bacia    Recôncavo [/E2], são encontrados    [E1] Campo de Sesmaria [/E1]..
# -------------
# -------------
# sentence = 1837
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Formação Sergi --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_239
# Relation Type =  crosses
# B. Geociências PETROBRAS, Rio de Janeiro, v.1(1): 103-109, maio jul B. Geociências PETROBRÁS, Rio de Janeiro, v.1(1): 103-109, maio ful, Essa metodologia permite,     [E1] poços [/E1] não testemunhados    [E2] Formação Sergi [/E2]    Campo de Sesmaria, a identificação     diversas Fácies Diagenéticas e     zonas impregnadas com óleo pesado (residual)..
# -------------
# -------------
# sentence = 1837
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Sesmaria --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0932
# Relation Type =  located_in
# B. Geociências PETROBRAS, Rio de Janeiro, v.1(1): 103-109, maio jul B. Geociências PETROBRÁS, Rio de Janeiro, v.1(1): 103-109, maio ful, Essa metodologia permite,     [E1] poços [/E1] não testemunhados    Formação Sergi    [E2] Campo de Sesmaria [/E2], a identificação     diversas Fácies Diagenéticas e     zonas impregnadas com óleo pesado (residual)..
# -------------
# -------------
# sentence = 1852
# Token 1 =   poços PIR-49 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007040
# Token 2 =   Campo de Pilar --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0773
# Relation Type =  located_in
# A partir       estudo    área sudeste    [E2] Campo de Pilar [/E2], definida       [E1] poços PIR-49 [/E1], 78, 89 e 85, foi possível constatar,    Formação Coqueito Seco, a ocorrência de feições de canal, de frente deltaica, de estratificações cruzadas e lobos de suspensão..
# -------------
# -------------
# sentence = 1852
# Token 1 =   poços PIR-49 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007040
# Token 2 =   Formação Coqueito Seco --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_009
# Relation Type =  crosses
# A partir       estudo    área sudeste    Campo de Pilar, definida       [E1] poços PIR-49 [/E1], 78, 89 e 85, foi possível constatar,    [E2] Formação Coqueito Seco [/E2], a ocorrência de feições de canal, de frente deltaica, de estratificações cruzadas e lobos de suspensão..
# -------------
# -------------
# sentence = 1930
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia Sergipe-Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# A figura 8 é um exemplo de discordância em um     [E1] poços [/E1]    [E2] Bacia Sergipe-Alagoas [/E2]..
# -------------
# -------------
# sentence = 1965
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo de Pilar --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0773
# Relation Type =  located_in
# item 3.2, que trata    interpretação estratigráfica de quatro [E1] poços [/E1]    [E2] campo de Pilar [/E2] — AL,               e              exemplos de feições estratigráficas..
# -------------
# -------------
# sentence = 1967
# Token 1 =   poços 3-PIR-49-AL --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007040
# Token 2 =   Campo de Pilar --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0773
# Relation Type =  located_in
# Visando   aplicação     conhecimentos adquiridos, foi selecionada, para interpretação estrutural e estratigráfica, uma área    extremo sudeste    [E2] Campo de Pilar [/E2] — AL, que compreende os [E1] poços 3-PIR-49-AL [/E1], 3-PIR-78-AL, 3-PIR-85-AL e 3-PIR-89-AL (fig, 12)..
# -------------
# -------------
# sentence = 1967
# Token 1 =   3-PIR-78-AL --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007020
# Token 2 =   Campo de Pilar --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0773
# Relation Type =  located_in
# Visando   aplicação     conhecimentos adquiridos, foi selecionada, para interpretação estrutural e estratigráfica, uma área    extremo sudeste    [E2] Campo de Pilar [/E2] — AL, que compreende os poços 3-PIR-49-AL, [E1] 3-PIR-78-AL [/E1], 3-PIR-85-AL e 3-PIR-89-AL (fig, 12)..
# -------------
# -------------
# sentence = 1967
# Token 1 =   3-PIR-85-AL --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007076
# Token 2 =   Campo de Pilar --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0773
# Relation Type =  located_in
# Visando   aplicação     conhecimentos adquiridos, foi selecionada, para interpretação estrutural e estratigráfica, uma área    extremo sudeste    [E2] Campo de Pilar [/E2] — AL, que compreende os poços 3-PIR-49-AL, 3-PIR-78-AL, [E1] 3-PIR-85-AL [/E1] e 3-PIR-89-AL (fig, 12)..
# -------------
# -------------
# sentence = 1967
# Token 1 =   3-PIR-89-AL --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007052
# Token 2 =   Campo de Pilar --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0773
# Relation Type =  located_in
# Visando   aplicação     conhecimentos adquiridos, foi selecionada, para interpretação estrutural e estratigráfica, uma área    extremo sudeste    [E2] Campo de Pilar [/E2] — AL, que compreende os poços 3-PIR-49-AL, 3-PIR-78-AL, 3-PIR-85-AL e [E1] 3-PIR-89-AL [/E1] (fig, 12)..
# -------------
# -------------
# sentence = 1981
# Token 1 =   Poço 3-PIR-49-AL --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007040
# Token 2 =   Formação Coqueiro --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_009
# Relation Type =  crosses
# Fig. 17 - [E1] Poço 3-PIR-49-AL [/E1]; [E2] Formação Coqueiro [/E2]
# -------------
# -------------
# sentence = 1983
# Token 1 =   Poço 3-PIR-85-AL --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007076
# Token 2 =   Formação Coqueiro --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_009
# Relation Type =  crosses
# Fig. 19 - [E1] Poço 3-PIR-85-AL [/E1]; [E2] Formação Coqueiro [/E2]
# -------------
# -------------
# sentence = 1985
# Token 1 =   Poço 3-PIR-78-AL --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007020
# Token 2 =   Formação Coqueiro --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_009
# Relation Type =  crosses
# Fig. 22 - [E1] Poço 3-PIR-78-AL [/E1]; [E2] Formação Coqueiro [/E2]
# -------------
# -------------
# sentence = 2029
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# A amostra deverá conter informações sobre procedência, posição estratigráfica, se possível, profundidade (   caso de [E1] poços [/E1]) e [E2] bacia [/E2] sedimentar (fig. 1)..
# -------------
# -------------
# sentence = 2191
# Token 1 =   Campo de Moréia --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0718
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# [E1] Campo de Moréia [/E1], parte     reservatórios    Campo de Caratinga, e vários arenitos delgados de idades diversas que aparecem preenchendo canyons    [E2] Bacia de Campos [/E2]..
# -------------
# -------------
# sentence = 2191
# Token 1 =   Campo de Caratinga --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0247
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Campo de Moréia, parte     reservatórios    [E1] Campo de Caratinga [/E1], e vários arenitos delgados de idades diversas que aparecem preenchendo canyons    [E2] Bacia de Campos [/E2]..
# -------------
# -------------
# sentence = 2192
# Token 1 =   Formação Calumbi --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_027
# Token 2 =   Bacia de Sergipe/Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# A maior parte     reservatórios    [E1] Formação Calumbi [/E1],    [E2] Bacia de Sergipe/Alagoas [/E2], também depositados em canyons ou pequenas depressões intra-talude, também se enquadram       categoria..
# -------------
# -------------
# sentence = 2197
# Token 1 =   Campo de Lagoa Parda --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0603
# Token 2 =   Bacia Espírito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# Figura Seção estratigráfica    [E1] Campo de Lagoa Parda [/E1] ([E2] Bacia    Espírito Santo [/E2]), apresentando a arquitetura típica    complexo de canais discretos que constitui os reservatórios eocênicos..
# -------------
# -------------
# sentence = 2206
# Token 1 =   campos --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Mapa sísmico de amplitude     reservatórios oligocênicos-miocênicos de [E1] campos [/E1] de águas profundas    [E2] Bacia de Campos [/E2], apresentando a morfologia típica (padrão radial) de complexos de canais distributários e lobos (L) .
# -------------
# -------------
# sentence = 2237
# Token 1 =   Formação Urucutuca --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_262
# Token 2 =   Bacia de Almada --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_266
# Relation Type =  located_in
# BRUHN, C. H. L.; MORAES, M. A. S., Turbiditos    [E1] Formação Urucutuca [/E1]    [E2] Bacia de Almada [/E2], Bahia : um laboratório de campo para o estudo de reservatórios canalizados..
# -------------
# -------------
# sentence = 2268
# Token 1 =   Fm. Carapebus --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_110
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# MACHADO, L. C. R.; KOWSMANN, R. O.; ALMEIDA JUNIOR, W.; MURAKAMI, C. Y.; SCHREINER, S.; MILLER, D. J.; PIAUILINO, P. O. V. Geometria    porção proximal    sistema deposicional turbidítico moderno    [E1] Fm. Carapebus [/E1], [E2] Bacia de Campos [/E2] : modelo para heterogeneidades de reservatório..
# -------------
# -------------
# sentence = 2360
# Token 1 =   Formação Cabiúnas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_222
# Token 2 =   basaltos --- Class 2 =  ROCHA --- URI 2 =  #basalt
# Relation Type =  constituted_by
# A composição    vidro vulcânico constituinte     vulcanoclastos originais seria equivalente     traquitos, ou seja, distinta             rochas vulcânicas    [E1] Formação Cabiúnas [/E1] (constituídas por [E2] basaltos [/E2] toleíticos com várias texturas petrográficas) e demais rochas ígneas encontradas    Bacia de Campos (fig. 1)..
# -------------
# -------------
# sentence = 2360
# Token 1 =   Formação Cabiúnas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_222
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# A composição    vidro vulcânico constituinte     vulcanoclastos originais seria equivalente     traquitos, ou seja, distinta             rochas vulcânicas    [E1] Formação Cabiúnas [/E1] (constituídas por basaltos toleíticos com várias texturas petrográficas) e demais rochas ígneas encontradas    [E2] Bacia de Campos [/E2] (fig. 1)..
# -------------
# -------------
# sentence = 2399
# Token 1 =   Formação Cabiúnas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_222
# Token 2 =   diabásio --- Class 2 =  ROCHA --- URI 2 =  #diabase
# Relation Type =  constituted_by
# Através de um reconhecimento tectono-estrutural    Faixa Colatina, entre as cidades de Vitória-ES e Nova Venécia-ES, realizado    período de 20 a 23 de outubro de 2003,              um conjunto de afloramentos de diques de [E2] diabásio [/E2] de direção geral NNW-SSE, que pode ser correlato    seqüências vulcânicas    [E1] Formação Cabiúnas [/E1]     bacias de Campos e    Espírito Santo..
# -------------
# -------------
# sentence = 2399
# Token 1 =   Formação Cabiúnas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_222
# Token 2 =   bacias de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Através de um reconhecimento tectono-estrutural    Faixa Colatina, entre as cidades de Vitória-ES e Nova Venécia-ES, realizado    período de 20 a 23 de outubro de 2003,              um conjunto de afloramentos de diques de diabásio de direção geral NNW-SSE, que pode ser correlato    seqüências vulcânicas    [E1] Formação Cabiúnas [/E1]     [E2] bacias de Campos [/E2] e    Espírito Santo..
# -------------
# -------------
# sentence = 2420
# Token 1 =   Formação Cabiúnas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_222
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Estas análises sugerem que tal evento tenha sido contemporâneo    vulcânicas    [E1] Formação Cabiúnas [/E1]    [E2] Bacia de Campos [/E2] e    vulcanismo Serra Geral    Bacia    Paraná, que é de 127/137 Ma (Teixeira e Rodarte, 2003)..
# -------------
# -------------
# sentence = 2431
# Token 1 =   Fazenda Cedro --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0444
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# As acumulações    porção sul    [E2] bacia [/E2] (Paleocanyon de Regência) e centro (Paleocanyon de [E1] Fazenda Cedro [/E1]) estão alinhadas segundo eixos NW-SE; enquanto outras acumulações    porção offshore se alinham com o trend estrutural    Faixa Colatina (NNW-SSE)..
# -------------
# -------------
# sentence = 2435
# Token 1 =   formações Rio Doce --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_122
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# , também, que os padrões de drenagem    [E2] bacia [/E2] e os sistemas de lagoas    região de Linhares são controlados por falhas reati-vadas, caracterizando movimentações neotectônicas que atingem até os sedimentos     [E1] formações Rio Doce [/E1] e Barreiras (Terciário)..
# -------------
# -------------
# sentence = 2435
# Token 1 =   Barreiras --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_016
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# , também, que os padrões de drenagem    [E2] bacia [/E2] e os sistemas de lagoas    região de Linhares são controlados por falhas reati-vadas, caracterizando movimentações neotectônicas que atingem até os sedimentos     formações Rio Doce e [E1] Barreiras [/E1] (Terciário)..
# -------------
# -------------
# Number of Jsons saved =  0

# %%
processar_sentencas_filtradas(df_filtred_sentences_teste, 
                              df_group_teste, 
                              save_csv_name_bert_teste, 
                              save_csv_name_relation_teste, 
                              save_folder_path_teste,
                              lista_relacoes_teste, 
                              lista_uris_teste, 
                              lista_classes_teste)
# Out:
# -------------
# sentence = 97
# Token 1 =   Formação Pendência --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_319
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# 2.2 - Estratigrafia de Sequências    [E1] Formação Pendência [/E1], [E2] Bacia Potiguar [/E2]  Della Favera et al. (1992) analisam a seção sin-rift    Bacia Potiguar,    qual identificaram quatro sequências balizadas por discordâncias e suas concordâncias relativas dentro    Formação Pendência..
# -------------
# -------------
# sentence = 97
# Token 1 =   Formação Pendência --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_319
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# 2.2 - Estratigrafia de Sequências    [E1] Formação Pendência [/E1], Bacia Potiguar  Della Favera et al. (1992) analisam a seção sin-rift    [E2] Bacia Potiguar [/E2],    qual identificaram quatro sequências balizadas por discordâncias e suas concordâncias relativas dentro    Formação Pendência..
# -------------
# -------------
# sentence = 97
# Token 1 =   Formação Pendência --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_319
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# 2.2 - Estratigrafia de Sequências    Formação Pendência, [E2] Bacia Potiguar [/E2]  Della Favera et al. (1992) analisam a seção sin-rift    Bacia Potiguar,    qual identificaram quatro sequências balizadas por discordâncias e suas concordâncias relativas dentro    [E1] Formação Pendência [/E1]..
# -------------
# -------------
# sentence = 97
# Token 1 =   Formação Pendência --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_319
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# 2.2 - Estratigrafia de Sequências    Formação Pendência, Bacia Potiguar  Della Favera et al. (1992) analisam a seção sin-rift    [E2] Bacia Potiguar [/E2],    qual identificaram quatro sequências balizadas por discordâncias e suas concordâncias relativas dentro    [E1] Formação Pendência [/E1]..
# -------------
# -------------
# sentence = 180
# Token 1 =   Formação Pendência --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_319
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# Della Fávera ef al. (1992), entretanto,    tentarem utilizar essa mesma terminologia para a análise    [E1] Formação Pendência [/E1] ([E2] Bacia Potiguar [/E2]), acabaram traduzindo esses termos de modo diferente..
# -------------
# -------------
# sentence = 234
# Token 1 =   Formação Pendéncia --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_319
# Token 2 =   Bacia Potiguar --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_100
# Relation Type =  located_in
# DELLA FÁVERA, J. C., ROSSETI, E. L., GUZZO, J. MATSUDA, N., SOARES, V. M., HASHIMOTO, A. T. ALVES, D. B., CASTRO, J. C., AZAMBUJA, N. C. RODRIGUES, R. Estratigrafa de seqliéncias de [E1] Formação Pendéncia [/E1], [E2] Bacia Potiguar [/E2]..
# -------------
# -------------
# sentence = 317
# Token 1 =   formações Muribeca --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_117
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# RESUMO - A abertura final    Oceano Atlântico é datada com razoável precisão a partir    análise sedimentológica e paleontológica de testemunhos contínuos obtidos     [E1] formações Muribeca [/E1] e Riachuelo, depositadas     fases transicional e marinha    [E2] Bacia de Sergipe [/E2]..
# -------------
# -------------
# sentence = 317
# Token 1 =   Riachuelo --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_130
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# RESUMO - A abertura final    Oceano Atlântico é datada com razoável precisão a partir    análise sedimentológica e paleontológica de testemunhos contínuos obtidos     formações Muribeca e [E1] Riachuelo [/E1], depositadas     fases transicional e marinha    [E2] Bacia de Sergipe [/E2]..
# -------------
# -------------
# sentence = 322
# Token 1 =   poços 5-CPB-1A-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009065
# Token 2 =   Campo de Carmópolis --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0249
# Relation Type =  located_in
# A interpretação           em análise macroscópica e microscópica (Feijó, 1980)     testemunhos contínuos     [E1] poços 5-CPB-1A-SE [/E1] e 7-CP-252-SE, situados, respectivamente,     chamadas áreas Central e    Embasamento    [E2] Campo de Carmópolis [/E2],    Bacia de Sergipe (fig. 1)..
# -------------
# -------------
# sentence = 322
# Token 1 =   poços 5-CPB-1A-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009065
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# A interpretação           em análise macroscópica e microscópica (Feijó, 1980)     testemunhos contínuos     [E1] poços 5-CPB-1A-SE [/E1] e 7-CP-252-SE, situados, respectivamente,     chamadas áreas Central e    Embasamento    Campo de Carmópolis,    [E2] Bacia de Sergipe [/E2] (fig. 1)..
# -------------
# -------------
# sentence = 322
# Token 1 =   7-CP-252-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009757
# Token 2 =   Embasamento --- Class 2 =  UNIDADE_LITO --- URI 2 =  #SD_000
# Relation Type =  crosses
# A interpretação           em análise macroscópica e microscópica (Feijó, 1980)     testemunhos contínuos     poços 5-CPB-1A-SE e [E1] 7-CP-252-SE [/E1], situados, respectivamente,     chamadas áreas Central e    [E2] Embasamento [/E2]    Campo de Carmópolis,    Bacia de Sergipe (fig. 1)..
# -------------
# -------------
# sentence = 322
# Token 1 =   7-CP-252-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009757
# Token 2 =   Campo de Carmópolis --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0249
# Relation Type =  located_in
# A interpretação           em análise macroscópica e microscópica (Feijó, 1980)     testemunhos contínuos     poços 5-CPB-1A-SE e [E1] 7-CP-252-SE [/E1], situados, respectivamente,     chamadas áreas Central e    Embasamento    [E2] Campo de Carmópolis [/E2],    Bacia de Sergipe (fig. 1)..
# -------------
# -------------
# sentence = 322
# Token 1 =   7-CP-252-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009757
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# A interpretação           em análise macroscópica e microscópica (Feijó, 1980)     testemunhos contínuos     poços 5-CPB-1A-SE e [E1] 7-CP-252-SE [/E1], situados, respectivamente,     chamadas áreas Central e    Embasamento    Campo de Carmópolis,    [E2] Bacia de Sergipe [/E2] (fig. 1)..
# -------------
# -------------
# sentence = 322
# Token 1 =   Campo de Carmópolis --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0249
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# A interpretação           em análise macroscópica e microscópica (Feijó, 1980)     testemunhos contínuos     poços 5-CPB-1A-SE e 7-CP-252-SE, situados, respectivamente,     chamadas áreas Central e    Embasamento    [E1] Campo de Carmópolis [/E1],    [E2] Bacia de Sergipe [/E2] (fig. 1)..
# -------------
# -------------
# sentence = 324
# Token 1 =   Membro Taquari --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_007
# Token 2 =   Formação Riachuelo --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_130
# Relation Type =  part_of
# A seção testemunhada (figs. 2 e 3) abrange a parte inferior    [E2] Formação Riachuelo [/E2], [E1] Membro Taquari [/E1], e boa parte    Formação Muribeca, membros Oiteirinhos e 1 - Serviço de Recursos Humanos (SEREC), Centro de Treinamento    Sul e Sudeste (CEN-SUD), Área de Geologia, Rua General Canabarro, 500, 20271-900, Maracanã, Rio de Janeiro, RJ, Brasil..
# -------------
# -------------
# sentence = 324
# Token 1 =   membros Oiteirinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_044
# Token 2 =   Formação Muribeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  part_of
# A seção testemunhada (figs. 2 e 3) abrange a parte inferior    Formação Riachuelo, Membro Taquari, e boa parte    [E2] Formação Muribeca [/E2], [E1] membros Oiteirinhos [/E1] e 1 - Serviço de Recursos Humanos (SEREC), Centro de Treinamento    Sul e Sudeste (CEN-SUD), Área de Geologia, Rua General Canabarro, 500, 20271-900, Maracanã, Rio de Janeiro, RJ, Brasil..
# -------------
# -------------
# sentence = 328
# Token 1 =   Membro Ibura --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_061
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# A transição de sedimentação continental para’ marinha    [E2] Bacia de Sergipe [/E2] teve início com a deposição em planície de sabkha     evaporitos e carbonatos laminados ou estromatolíticos    [E1] Membro Ibura [/E1]..
# -------------
# -------------
# sentence = 329
# Token 1 =   Membro Ibura --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_061
# Token 2 =   Anidrita --- Class 2 =  ROCHA --- URI 2 =  #anhydrite
# Relation Type =  constituted_by
# Este estágio se encerrou com a precipitação    chamada [E2] Anidrita [/E2] Principal, com espessura em torno de 15 m, que marca o topo    [E1] Membro Ibura [/E1]..
# -------------
# -------------
# sentence = 333
# Token 1 =   Membro Ibura --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_061
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# O clima árido que se instalou    [E2] Bacia de Sergipe [/E2]    Aptiano é evidenciado       centenas de metros de anidrita, halita, carnalita, silvinta e taquidrita componentes    [E1] Membro Ibura [/E1], preenchendo sub-O ciclo evaporítico aptiano .praticamente             com a precipitação    Anidrita Principal (fig. 2, intervalo 590-604 m),    forma de nódulos em um hospedeiro micrítico, com ampla distribuição    Alto de Aracaju..
# -------------
# -------------
# sentence = 333
# Token 1 =   Membro Ibura --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_061
# Token 2 =   anidrita --- Class 2 =  ROCHA --- URI 2 =  #anhydrite
# Relation Type =  constituted_by
# O clima árido que se instalou    Bacia de Sergipe    Aptiano é evidenciado       centenas de metros de [E2] anidrita [/E2], halita, carnalita, silvinta e taquidrita componentes    [E1] Membro Ibura [/E1], preenchendo sub-O ciclo evaporítico aptiano .praticamente             com a precipitação    Anidrita Principal (fig. 2, intervalo 590-604 m),    forma de nódulos em um hospedeiro micrítico, com ampla distribuição    Alto de Aracaju..
# -------------
# -------------
# sentence = 333
# Token 1 =   Membro Ibura --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_061
# Token 2 =   halita --- Class 2 =  ROCHA --- URI 2 =  #halite
# Relation Type =  constituted_by
# O clima árido que se instalou    Bacia de Sergipe    Aptiano é evidenciado       centenas de metros de anidrita, [E2] halita [/E2], carnalita, silvinta e taquidrita componentes    [E1] Membro Ibura [/E1], preenchendo sub-O ciclo evaporítico aptiano .praticamente             com a precipitação    Anidrita Principal (fig. 2, intervalo 590-604 m),    forma de nódulos em um hospedeiro micrítico, com ampla distribuição    Alto de Aracaju..
# -------------
# -------------
# sentence = 333
# Token 1 =   Membro Ibura --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_061
# Token 2 =   carnalita --- Class 2 =  ROCHA --- URI 2 =  #carnallite
# Relation Type =  constituted_by
# O clima árido que se instalou    Bacia de Sergipe    Aptiano é evidenciado       centenas de metros de anidrita, halita, [E2] carnalita [/E2], silvinta e taquidrita componentes    [E1] Membro Ibura [/E1], preenchendo sub-O ciclo evaporítico aptiano .praticamente             com a precipitação    Anidrita Principal (fig. 2, intervalo 590-604 m),    forma de nódulos em um hospedeiro micrítico, com ampla distribuição    Alto de Aracaju..
# -------------
# -------------
# sentence = 333
# Token 1 =   Membro Ibura --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_061
# Token 2 =   taquidrita --- Class 2 =  ROCHA --- URI 2 =  #tachyhydrite
# Relation Type =  constituted_by
# O clima árido que se instalou    Bacia de Sergipe    Aptiano é evidenciado       centenas de metros de anidrita, halita, carnalita, silvinta e [E2] taquidrita [/E2] componentes    [E1] Membro Ibura [/E1], preenchendo sub-O ciclo evaporítico aptiano .praticamente             com a precipitação    Anidrita Principal (fig. 2, intervalo 590-604 m),    forma de nódulos em um hospedeiro micrítico, com ampla distribuição    Alto de Aracaju..
# -------------
# -------------
# sentence = 333
# Token 1 =   Membro Ibura --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_061
# Token 2 =   Anidrita --- Class 2 =  ROCHA --- URI 2 =  #anhydrite
# Relation Type =  constituted_by
# O clima árido que se instalou    Bacia de Sergipe    Aptiano é evidenciado       centenas de metros de anidrita, halita, carnalita, silvinta e taquidrita componentes    [E1] Membro Ibura [/E1], preenchendo sub-O ciclo evaporítico aptiano .praticamente             com a precipitação    [E2] Anidrita [/E2] Principal (fig. 2, intervalo 590-604 m),    forma de nódulos em um hospedeiro micrítico, com ampla distribuição    Alto de Aracaju..
# -------------
# -------------
# sentence = 339
# Token 1 =   Membro Taquari --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_007
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Tal caráter fossilifero e bioturbado prossegue     calcilutitos e [E2] folhelhos [/E2] cinzentos    [E1] Membro Taquari [/E1], acima..
# -------------
# -------------
# sentence = 355
# Token 1 =   Membro Qiteirinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_044
# Token 2 =   Formação Muribeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  part_of
# [E2] Formação Muribeca [/E2], [E1] Membro Qiteirinhos [/E1]..
# -------------
# -------------
# sentence = 359
# Token 1 =   membros Ibura --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_061
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Os [E1] membros Ibura [/E1] e Oiterinhos retratam a crescente ingressão marinha    [E2] Bacia de Sergipe [/E2],    forma de decrescente presença de evaporitos..
# -------------
# -------------
# sentence = 359
# Token 1 =   Oiterinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_044
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Os membros Ibura e [E1] Oiterinhos [/E1] retratam a crescente ingressão marinha    [E2] Bacia de Sergipe [/E2],    forma de decrescente presença de evaporitos..
# -------------
# -------------
# sentence = 364
# Token 1 =   7-CP-252-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009757
# Token 2 =   Formação Muribeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  crosses
# Foto 3 - [E1] 7-CP-252-SE [/E1] #5 508.1 m. [E2] Formação Muribeca [/E2], Membro Oiteirinhos..
# -------------
# -------------
# sentence = 364
# Token 1 =   7-CP-252-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009757
# Token 2 =   Membro Oiteirinhos --- Class 2 =  UNIDADE_LITO --- URI 2 =  #membro_044
# Relation Type =  crosses
# Foto 3 - [E1] 7-CP-252-SE [/E1] #5 508.1 m. Formação Muribeca, [E2] Membro Oiteirinhos [/E2]..
# -------------
# -------------
# sentence = 364
# Token 1 =   Membro Oiteirinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_044
# Token 2 =   Formação Muribeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  part_of
# Foto 3 - 7-CP-252-SE #5 508.1 m. [E2] Formação Muribeca [/E2], [E1] Membro Oiteirinhos [/E1]..
# -------------
# -------------
# sentence = 368
# Token 1 =   Membro Oiteirinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_044
# Token 2 =   Formação Muribeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  part_of
# [E2] Formação Muribeca [/E2], [E1] Membro Oiteirinhos [/E1]..
# -------------
# -------------
# sentence = 378
# Token 1 =   Membro Oiteirinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_044
# Token 2 =   Formação Muribeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  part_of
# [E2] Formação Muribeca [/E2], [E1] Membro Oiteirinhos [/E1]..
# -------------
# -------------
# sentence = 382
# Token 1 =   Membro Oiterrinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_044
# Token 2 =   Formação Muribeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  part_of
# Foto 67-CP-252-SE #4 499,4 m. [E2] Formação Muribeca [/E2], [E1] Membro Oiterrinhos [/E1]..
# -------------
# -------------
# sentence = 387
# Token 1 =   Membro Oiteirinhos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_044
# Token 2 =   Formação Munbeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  part_of
# [E2] Formação Munbeca [/E2], [E1] Membro Oiteirinhos [/E1]..
# -------------
# -------------
# sentence = 390
# Token 1 =   5-CPB-1A-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009065
# Token 2 =   Formação Riachuelo --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_130
# Relation Type =  crosses
# PETROBRAS, Rio de Janeiro, 70 (1/4). 157-164, jan./dez, Foto 8 - [E1] 5-CPB-1A-SE [/E1] 43 354,8 m. [E2] Formação Riachuelo [/E2], Membro Taquari..
# -------------
# -------------
# sentence = 390
# Token 1 =   5-CPB-1A-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009065
# Token 2 =   Membro Taquari --- Class 2 =  UNIDADE_LITO --- URI 2 =  #membro_007
# Relation Type =  crosses
# PETROBRAS, Rio de Janeiro, 70 (1/4). 157-164, jan./dez, Foto 8 - [E1] 5-CPB-1A-SE [/E1] 43 354,8 m. Formação Riachuelo, [E2] Membro Taquari [/E2]..
# -------------
# -------------
# sentence = 390
# Token 1 =   Membro Taquari --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_007
# Token 2 =   Formação Riachuelo --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_130
# Relation Type =  part_of
# PETROBRAS, Rio de Janeiro, 70 (1/4). 157-164, jan./dez, Foto 8 - 5-CPB-1A-SE 43 354,8 m. [E2] Formação Riachuelo [/E2], [E1] Membro Taquari [/E1]..
# -------------
# -------------
# sentence = 394
# Token 1 =   7-CP-252-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009757
# Token 2 =   Formação Riachueio --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_130
# Relation Type =  crosses
# Foto 9 - [E1] 7-CP-252-SE [/E1] #4 4937 m. [E2] Formação Riachueio [/E2], Membro Taquan..
# -------------
# -------------
# sentence = 394
# Token 1 =   7-CP-252-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_009757
# Token 2 =   Membro Taquan --- Class 2 =  UNIDADE_LITO --- URI 2 =  #membro_007
# Relation Type =  crosses
# Foto 9 - [E1] 7-CP-252-SE [/E1] #4 4937 m. Formação Riachueio, [E2] Membro Taquan [/E2]..
# -------------
# -------------
# sentence = 394
# Token 1 =   Membro Taquan --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_007
# Token 2 =   Formação Riachueio --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_130
# Relation Type =  part_of
# Foto 9 - 7-CP-252-SE #4 4937 m. [E2] Formação Riachueio [/E2], [E1] Membro Taquan [/E1]..
# -------------
# -------------
# sentence = 399
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Carmópolis --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0249
# Relation Type =  located_in
# 2. - Em análise faciológica e paleontológica de testemunhos contínuos de dois [E1] poços [/E1]    [E2] Campo de Carmópolis [/E2], em Sergipe,             súbito crescimento     faunas plantônica e bentônica    topo    Formação Muribeca..
# -------------
# -------------
# sentence = 399
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Formação Muribeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  crosses
# 2. - Em análise faciológica e paleontológica de testemunhos contínuos de dois [E1] poços [/E1]    Campo de Carmópolis, em Sergipe,             súbito crescimento     faunas plantônica e bentônica    topo    [E2] Formação Muribeca [/E2]..
# -------------
# -------------
# sentence = 407
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Campo de Carmópolis --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0249
# Relation Type =  located_in
# 2. - Em análise faciológica e paleontológica de testemunhos continuos de dois [E1] poços [/E1]    [E2] Campo de Carmópolis [/E2], em Sergipe,             súbito crescimento     faunas plantônica e bentônica    topo    Formação Muribeca..
# -------------
# -------------
# sentence = 407
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Formação Muribeca --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_117
# Relation Type =  crosses
# 2. - Em análise faciológica e paleontológica de testemunhos continuos de dois [E1] poços [/E1]    Campo de Carmópolis, em Sergipe,             súbito crescimento     faunas plantônica e bentônica    topo    [E2] Formação Muribeca [/E2]..
# -------------
# falha ao tentar salvar o arquivo:  df_relation_teste.csv
# -------------
# sentence = 611
# Token 1 =   membros Gomo --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_025
# Token 2 =   Formação Candeias --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_095
# Relation Type =  part_of
# trabalho,                 as taxas de transformação     [E1] membros Gomo [/E1] e Tauá    [E2] Formação Candeias [/E2], que serviram de base para o cálculo    volume de petróleo gerado..
# -------------
# -------------
# sentence = 611
# Token 1 =   Tauá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_070
# Token 2 =   Formação Candeias --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_095
# Relation Type =  part_of
# trabalho,                 as taxas de transformação     membros Gomo e [E1] Tauá [/E1]    [E2] Formação Candeias [/E2], que serviram de base para o cálculo    volume de petróleo gerado..
# -------------
# -------------
# sentence = 620
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Para o estudo de séries naturais       seção geradora, foram selecionadas amostras de [E1] poços [/E1] situados em uma área    [E2] bacia [/E2] não afetada por soerguimento e com regime térmico relativamente homogêneo..
# -------------
# -------------
# sentence = 760
# Token 1 =   Marlim --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0682
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Os 26 testemunhos a pistão, também coletados    talude    [E2] Bacia de Campos [/E2], com o auxílio    supply-boat Salqueiro,                     taludes de [E1] Marlim [/E1] (19), Albacora (6) e Canyon São Tomé (1)..
# -------------
# -------------
# sentence = 760
# Token 1 =   Albacora --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0017
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Os 26 testemunhos a pistão, também coletados    talude    [E2] Bacia de Campos [/E2], com o auxílio    supply-boat Salqueiro,                     taludes de Marlim (19), [E1] Albacora [/E1] (6) e Canyon São Tomé (1)..
# -------------
# -------------
# sentence = 1072
# Token 1 =   Marlim --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0682
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# KOWSMANN, R. O., VIANA, A. R., CADDAH, L. F. G., COSTA, A. M., AMARAL, C. S. Integração de dados geológicos com perfis geotécnicos de resistência (Sul)    talude de [E1] Marlim [/E1], [E2] Bacia de Campos [/E2]..
# -------------
# -------------
# sentence = 1117
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Desde a descoberta pioneira de óleo em Lo-bato, em 1939, mais de 5 000 [E1] poços [/E1] foram perfurados    [E2] bacia [/E2], resultando    descoberta de cerca de 80 campos de óleo e gás..
# -------------
# -------------
# sentence = 1117
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campos --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# Desde a descoberta pioneira de óleo em Lo-bato, em 1939, mais de 5 000 [E1] poços [/E1] foram perfurados    bacia, resultando    descoberta de cerca de 80 [E2] campos [/E2] de óleo e gás..
# -------------
# -------------
# sentence = 1117
# Token 1 =   campos --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Desde a descoberta pioneira de óleo em Lo-bato, em 1939, mais de 5 000 poços foram perfurados    [E2] bacia [/E2], resultando    descoberta de cerca de 80 [E1] campos [/E1] de óleo e gás..
# -------------
# -------------
# sentence = 1119
# Token 1 =   campo --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Como introdução a este roteiro, segue uma breve discussão acerca    arcabouço tectônico e    preenchimento sedimentar    [E2] bacia [/E2],                 aspectos relacionados         feições efetivamente observáveis    [E1] campo [/E1]..
# -------------
# -------------
# sentence = 1129
# Token 1 =   Formação Afligidos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_295
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Bacia    Recôncavo, a [E1] Formação Afligidos [/E1] é constituída por [E2] arenitos [/E2] sobrepostos por folhelhos vermelhos..
# -------------
# -------------
# sentence = 1129
# Token 1 =   Formação Afligidos --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_295
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Bacia    Recôncavo, a [E1] Formação Afligidos [/E1] é constituída por arenitos sobrepostos por [E2] folhelhos [/E2] vermelhos..
# -------------
# -------------
# sentence = 1130
# Token 1 =   Formação Santa Brígida --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_305
# Token 2 =   Tucano Norte --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_215
# Relation Type =  located_in
# Sua porção basal (Membro Pedrão) é correlacionada com a [E1] Formação Santa Brígida [/E1], aflorante    margem leste    [E2] Tucano Norte [/E2], e com a Formação Aracaré    Bacia de Sergipe-Alagoas..
# -------------
# -------------
# sentence = 1130
# Token 1 =   Formação Aracaré --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_102
# Token 2 =   Bacia de Sergipe --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Sua porção basal (Membro Pedrão) é correlacionada com a Formação Santa Brígida, aflorante    margem leste    Tucano Norte, e com a [E1] Formação Aracaré [/E1]    [E2] Bacia de Sergipe [/E2]-Alagoas..
# -------------
# -------------
# sentence = 1130
# Token 1 =   Formação Aracaré --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_102
# Token 2 =   Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# Sua porção basal (Membro Pedrão) é correlacionada com a Formação Santa Brígida, aflorante    margem leste    Tucano Norte, e com a [E1] Formação Aracaré [/E1]    Bacia de Sergipe-[E2] Alagoas [/E2]..
# -------------
# -------------
# sentence = 1131
# Token 1 =   Membro Cazumba --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_027
# Token 2 =   Permiano --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Permian
# Relation Type =  has_age
# A unidade é considerada como sendo    [E2] Permiano [/E2] (Kunguriano), e há uma possibilidade de idade triássica para sua porção superior ([E1] Membro Cazumba [/E1]; Aguiar e Mato, 1990)..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Grupo Brotas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_022
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# O Andar Dom João consiste em depósitos aluviais    [E1] Grupo Brotas [/E1], representados por [E2] folhelhos [/E2] avermelhados e arenitos    Formação Aliança, sotopostos a arenitos fluviais e eólicos    Formação Sergi..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Grupo Brotas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_022
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# O Andar Dom João consiste em depósitos aluviais    [E1] Grupo Brotas [/E1], representados por folhelhos avermelhados e [E2] arenitos [/E2]    Formação Aliança, sotopostos a arenitos fluviais e eólicos    Formação Sergi..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Grupo Brotas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_022
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# O Andar Dom João consiste em depósitos aluviais    [E1] Grupo Brotas [/E1], representados por folhelhos avermelhados e arenitos    Formação Aliança, sotopostos a [E2] arenitos [/E2] fluviais e eólicos    Formação Sergi..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Formação Aliança --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_335
# Token 2 =   Andar Dom João --- Class 2 =  UNIDADE_CRONO --- URI 2 =  #Dom_Joao_Age
# Relation Type =  has_age
# O [E2] Andar Dom João [/E2] consiste em depósitos aluviais    Grupo Brotas, representados por folhelhos avermelhados e arenitos    [E1] Formação Aliança [/E1], sotopostos a arenitos fluviais e eólicos    Formação Sergi..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Formação Aliança --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_335
# Token 2 =   Grupo Brotas --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_022
# Relation Type =  part_of
# O Andar Dom João consiste em depósitos aluviais    [E2] Grupo Brotas [/E2], representados por folhelhos avermelhados e arenitos    [E1] Formação Aliança [/E1], sotopostos a arenitos fluviais e eólicos    Formação Sergi..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Formação Aliança --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_335
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# O Andar Dom João consiste em depósitos aluviais    Grupo Brotas, representados por [E2] folhelhos [/E2] avermelhados e arenitos    [E1] Formação Aliança [/E1], sotopostos a arenitos fluviais e eólicos    Formação Sergi..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Formação Aliança --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_335
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# O Andar Dom João consiste em depósitos aluviais    Grupo Brotas, representados por folhelhos avermelhados e [E2] arenitos [/E2]    [E1] Formação Aliança [/E1], sotopostos a arenitos fluviais e eólicos    Formação Sergi..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Formação Aliança --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_335
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# O Andar Dom João consiste em depósitos aluviais    Grupo Brotas, representados por folhelhos avermelhados e arenitos    [E1] Formação Aliança [/E1], sotopostos a [E2] arenitos [/E2] fluviais e eólicos    Formação Sergi..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Formação Sergi --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_239
# Token 2 =   Grupo Brotas --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_022
# Relation Type =  part_of
# O Andar Dom João consiste em depósitos aluviais    [E2] Grupo Brotas [/E2], representados por folhelhos avermelhados e arenitos    Formação Aliança, sotopostos a arenitos fluviais e eólicos    [E1] Formação Sergi [/E1]..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Formação Sergi --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_239
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# O Andar Dom João consiste em depósitos aluviais    Grupo Brotas, representados por [E2] folhelhos [/E2] avermelhados e arenitos    Formação Aliança, sotopostos a arenitos fluviais e eólicos    [E1] Formação Sergi [/E1]..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Formação Sergi --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_239
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# O Andar Dom João consiste em depósitos aluviais    Grupo Brotas, representados por folhelhos avermelhados e [E2] arenitos [/E2]    Formação Aliança, sotopostos a arenitos fluviais e eólicos    [E1] Formação Sergi [/E1]..
# -------------
# -------------
# sentence = 1143
# Token 1 =   Formação Sergi --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_239
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# O Andar Dom João consiste em depósitos aluviais    Grupo Brotas, representados por folhelhos avermelhados e arenitos    Formação Aliança, sotopostos a [E2] arenitos [/E2] fluviais e eólicos    [E1] Formação Sergi [/E1]..
# -------------
# -------------
# sentence = 1145
# Token 1 =   Formação Itaparica --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_229
# Token 2 =   Grupo Santo Amaro --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_057
# Relation Type =  part_of
# Estes red beds são sucedidos por sedimentos    [E2] Grupo Santo Amaro [/E2], cuja unidade basal ([E1] Formação Itaparica [/E1]) contém depósitos fluviais e lacustres..
# -------------
# -------------
# sentence = 1146
# Token 1 =   Formação Água Grande --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_125
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Sobrepostos a estes existem [E2] arenitos [/E2] fluviais e eólicos    [E1] Formação Água Grande [/E1], cuja área-fonte estava localizada a noroeste e a norte    Bacia    Recôncavo..
# -------------
# -------------
# sentence = 1153
# Token 1 =   Formação Salvador --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_145
# Token 2 =   conglomerados --- Class 2 =  ROCHA --- URI 2 =  #conglomerate
# Relation Type =  constituted_by
# Tradicionalmente, esta fase era marcada    primeiro aparecimento    espessa cunha de [E2] conglomerados [/E2] sintectônicos    [E1] Formação Salvador [/E1], a qual constitui parte    sistema de borda    rifte (Magnavita e Da Silva, 1995)..
# -------------
# -------------
# sentence = 1155
# Token 1 =   Membro Tauá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_070
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Assim, antes que a topografia fosse criada,      fase em que a taxa de subsidência superou a taxa de sedimentação, os [E2] folhelhos [/E2] escuros    [E1] Membro Tauá [/E1] (Formação Candeias, Rio    Serra Inferior - Berriasiano)                     depressão existente     bacias    Recôncavo e Tucano Sul, caracterizando estes o início    fase sin-rifte..
# -------------
# -------------
# sentence = 1155
# Token 1 =   Membro Tauá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_070
# Token 2 =   Formação Candeias --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_095
# Relation Type =  part_of
# Assim, antes que a topografia fosse criada,      fase em que a taxa de subsidência superou a taxa de sedimentação, os folhelhos escuros    [E1] Membro Tauá [/E1] ([E2] Formação Candeias [/E2], Rio    Serra Inferior - Berriasiano)                     depressão existente     bacias    Recôncavo e Tucano Sul, caracterizando estes o início    fase sin-rifte..
# -------------
# -------------
# sentence = 1155
# Token 1 =   Membro Tauá --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_070
# Token 2 =   Tucano Sul --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_230
# Relation Type =  located_in
# Assim, antes que a topografia fosse criada,      fase em que a taxa de subsidência superou a taxa de sedimentação, os folhelhos escuros    [E1] Membro Tauá [/E1] (Formação Candeias, Rio    Serra Inferior - Berriasiano)                     depressão existente     bacias    Recôncavo e [E2] Tucano Sul [/E2], caracterizando estes o início    fase sin-rifte..
# -------------
# -------------
# sentence = 1155
# Token 1 =   Formação Candeias --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_095
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Assim, antes que a topografia fosse criada,      fase em que a taxa de subsidência superou a taxa de sedimentação, os [E2] folhelhos [/E2] escuros    Membro Tauá ([E1] Formação Candeias [/E1], Rio    Serra Inferior - Berriasiano)                     depressão existente     bacias    Recôncavo e Tucano Sul, caracterizando estes o início    fase sin-rifte..
# -------------
# -------------
# sentence = 1157
# Token 1 =   Membro Gomo --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_025
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Durante uma fase de [E2] bacia [/E2] faminta,     depocentros foram depositados turbiditos lon-gitudinais e transversais    [E1] Membro Gomo [/E1] (Formação Candeias, Rio    Serra Médio), juntamente com folhelhos lacustres (   Silva et al. 2000), incluindo sucessões de arenitos laminados e maciços (Bruhn, 1999)..
# -------------
# -------------
# sentence = 1157
# Token 1 =   Membro Gomo --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_025
# Token 2 =   Formação Candeias --- Class 2 =  UNIDADE_LITO --- URI 2 =  #formacao_095
# Relation Type =  part_of
# Durante uma fase de bacia faminta,     depocentros foram depositados turbiditos lon-gitudinais e transversais    [E1] Membro Gomo [/E1] ([E2] Formação Candeias [/E2], Rio    Serra Médio), juntamente com folhelhos lacustres (   Silva et al. 2000), incluindo sucessões de arenitos laminados e maciços (Bruhn, 1999)..
# -------------
# -------------
# sentence = 1157
# Token 1 =   Membro Gomo --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_025
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Durante uma fase de bacia faminta,     depocentros foram depositados turbiditos lon-gitudinais e transversais    [E1] Membro Gomo [/E1] (Formação Candeias, Rio    Serra Médio), juntamente com [E2] folhelhos [/E2] lacustres (   Silva et al. 2000), incluindo sucessões de arenitos laminados e maciços (Bruhn, 1999)..
# -------------
# -------------
# sentence = 1157
# Token 1 =   Membro Gomo --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_025
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Durante uma fase de bacia faminta,     depocentros foram depositados turbiditos lon-gitudinais e transversais    [E1] Membro Gomo [/E1] (Formação Candeias, Rio    Serra Médio), juntamente com folhelhos lacustres (   Silva et al. 2000), incluindo sucessões de [E2] arenitos [/E2] laminados e maciços (Bruhn, 1999)..
# -------------
# -------------
# sentence = 1157
# Token 1 =   Formação Candeias --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_095
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Durante uma fase de [E2] bacia [/E2] faminta,     depocentros foram depositados turbiditos lon-gitudinais e transversais    Membro Gomo ([E1] Formação Candeias [/E1], Rio    Serra Médio), juntamente com folhelhos lacustres (   Silva et al. 2000), incluindo sucessões de arenitos laminados e maciços (Bruhn, 1999)..
# -------------
# -------------
# sentence = 1157
# Token 1 =   Formação Candeias --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_095
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Durante uma fase de bacia faminta,     depocentros foram depositados turbiditos lon-gitudinais e transversais    Membro Gomo ([E1] Formação Candeias [/E1], Rio    Serra Médio), juntamente com [E2] folhelhos [/E2] lacustres (   Silva et al. 2000), incluindo sucessões de arenitos laminados e maciços (Bruhn, 1999)..
# -------------
# -------------
# sentence = 1157
# Token 1 =   Formação Candeias --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_095
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Durante uma fase de bacia faminta,     depocentros foram depositados turbiditos lon-gitudinais e transversais    Membro Gomo ([E1] Formação Candeias [/E1], Rio    Serra Médio), juntamente com folhelhos lacustres (   Silva et al. 2000), incluindo sucessões de [E2] arenitos [/E2] laminados e maciços (Bruhn, 1999)..
# -------------
# -------------
# sentence = 1158
# Token 1 =   Formação Maracangalha --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_338
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# Em seguida, durante o Neo-Rio    Serra, uma contínua sedimentação de espessos [E2] arenitos [/E2] deltaicos exerceu forte sobrecarga sobre folhelhos    [E1] Formação Maracangalha [/E1],                  e resultando em diápiros de folhelhos associados a falhas de crescimento..
# -------------
# -------------
# sentence = 1158
# Token 1 =   Formação Maracangalha --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_338
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Em seguida, durante o Neo-Rio    Serra, uma contínua sedimentação de espessos arenitos deltaicos exerceu forte sobrecarga sobre [E2] folhelhos [/E2]    [E1] Formação Maracangalha [/E1],                  e resultando em diápiros de folhelhos associados a falhas de crescimento..
# -------------
# -------------
# sentence = 1158
# Token 1 =   Formação Maracangalha --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_338
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# Em seguida, durante o Neo-Rio    Serra, uma contínua sedimentação de espessos arenitos deltaicos exerceu forte sobrecarga sobre folhelhos    [E1] Formação Maracangalha [/E1],                  e resultando em diápiros de [E2] folhelhos [/E2] associados a falhas de crescimento..
# -------------
# -------------
# sentence = 1159
# Token 1 =   membros Pitanga --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_013
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# última unidade ocorrem espessos pacotes de [E2] arenitos [/E2] maciços e fluidizados     [E1] membros Pitanga [/E1] e Caruaçu, depositados    longo     depocentros mais orientais    gráben..
# -------------
# -------------
# sentence = 1159
# Token 1 =   Caruaçu --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_005
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# última unidade ocorrem espessos pacotes de [E2] arenitos [/E2] maciços e fluidizados     membros Pitanga e [E1] Caruaçu [/E1], depositados    longo     depocentros mais orientais    gráben..
# -------------
# -------------
# sentence = 1160
# Token 1 =   Grupo Ilhas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_032
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# A diminuição    taxa de subsidência,    período que inclui as idades Rio    Serra e Aratu, pos-sibilitou que        progradassem de NNW sobre as plataformas existentes    margem flexural    rifte, preenchendo os depocentros com [E2] arenitos [/E2], siltitos, folhelhos e ocasionais carbonatos    [E1] Grupo Ilhas [/E1], constituído      Formação Marfim, Membro Catu, e Formação Pojuca..
# -------------
# -------------
# sentence = 1160
# Token 1 =   Grupo Ilhas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_032
# Token 2 =   siltitos --- Class 2 =  ROCHA --- URI 2 =  #siltstone
# Relation Type =  constituted_by
# A diminuição    taxa de subsidência,    período que inclui as idades Rio    Serra e Aratu, pos-sibilitou que        progradassem de NNW sobre as plataformas existentes    margem flexural    rifte, preenchendo os depocentros com arenitos, [E2] siltitos [/E2], folhelhos e ocasionais carbonatos    [E1] Grupo Ilhas [/E1], constituído      Formação Marfim, Membro Catu, e Formação Pojuca..
# -------------
# -------------
# sentence = 1160
# Token 1 =   Grupo Ilhas --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_032
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# A diminuição    taxa de subsidência,    período que inclui as idades Rio    Serra e Aratu, pos-sibilitou que        progradassem de NNW sobre as plataformas existentes    margem flexural    rifte, preenchendo os depocentros com arenitos, siltitos, [E2] folhelhos [/E2] e ocasionais carbonatos    [E1] Grupo Ilhas [/E1], constituído      Formação Marfim, Membro Catu, e Formação Pojuca..
# -------------
# -------------
# sentence = 1160
# Token 1 =   Formação Marfim --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_217
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# A diminuição    taxa de subsidência,    período que inclui as idades Rio    Serra e Aratu, pos-sibilitou que        progradassem de NNW sobre as plataformas existentes    margem flexural    rifte, preenchendo os depocentros com [E2] arenitos [/E2], siltitos, folhelhos e ocasionais carbonatos    Grupo Ilhas, constituído      [E1] Formação Marfim [/E1], Membro Catu, e Formação Pojuca..
# -------------
# -------------
# sentence = 1160
# Token 1 =   Formação Marfim --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_217
# Token 2 =   siltitos --- Class 2 =  ROCHA --- URI 2 =  #siltstone
# Relation Type =  constituted_by
# A diminuição    taxa de subsidência,    período que inclui as idades Rio    Serra e Aratu, pos-sibilitou que        progradassem de NNW sobre as plataformas existentes    margem flexural    rifte, preenchendo os depocentros com arenitos, [E2] siltitos [/E2], folhelhos e ocasionais carbonatos    Grupo Ilhas, constituído      [E1] Formação Marfim [/E1], Membro Catu, e Formação Pojuca..
# -------------
# -------------
# sentence = 1160
# Token 1 =   Formação Marfim --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_217
# Token 2 =   folhelhos --- Class 2 =  ROCHA --- URI 2 =  #shale
# Relation Type =  constituted_by
# A diminuição    taxa de subsidência,    período que inclui as idades Rio    Serra e Aratu, pos-sibilitou que        progradassem de NNW sobre as plataformas existentes    margem flexural    rifte, preenchendo os depocentros com arenitos, siltitos, [E2] folhelhos [/E2] e ocasionais carbonatos    Grupo Ilhas, constituído      [E1] Formação Marfim [/E1], Membro Catu, e Formação Pojuca..
# -------------
# -------------
# sentence = 1160
# Token 1 =   Formação Marfim --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_217
# Token 2 =   Grupo Ilhas --- Class 2 =  UNIDADE_LITO --- URI 2 =  #grupo_032
# Relation Type =  part_of
# A diminuição    taxa de subsidência,    período que inclui as idades Rio    Serra e Aratu, pos-sibilitou que        progradassem de NNW sobre as plataformas existentes    margem flexural    rifte, preenchendo os depocentros com arenitos, siltitos, folhelhos e ocasionais carbonatos    [E2] Grupo Ilhas [/E2], constituído      [E1] Formação Marfim [/E1], Membro Catu, e Formação Pojuca..
# -------------
# -------------
# sentence = 1160
# Token 1 =   Membro Catu --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_078
# Token 2 =   arenitos --- Class 2 =  ROCHA --- URI 2 =  #sandstone
# Relation Type =  constituted_by
# A diminuição    taxa de subsidência,    período que inclui as idades Rio    Serra e Aratu, pos-sibilitou que        progradassem de NNW sobre as plataformas existentes    margem flexural    rifte, preenchendo os depocentros com [E2] arenitos [/E2], siltitos, folhelhos e ocasionais carbonatos    Grupo Ilhas, constituído      Formação Marfim, [E1] Membro Catu [/E1], e Formação Pojuca..
# -------------
# -------------
# sentence = 1160
# Token 1 =   Membro Catu --- Class 1 =  UNIDADE_LITO --- URI 1 =  #membro_078
# Token 2 =   siltitos --- Class 2 =  ROCHA --- URI 2 =  #siltstone
# Relation Type =  constituted_by
# A diminuição    taxa de subsidência,    período que inclui as idades Rio    Serra e Aratu, pos-sibilitou que        progradassem de NNW sobre as plataformas existentes    margem flexural    rifte, preenchendo os depocentros com arenitos, [E2] siltitos [/E2], folhelhos e ocasionais carbonatos    Grupo Ilhas, constituído      Formação Marfim, [E1] Membro Catu [/E1], e Formação Pojuca..
# -------------
# -------------
# sentence = 1160
# ...
# Token 2 =   Caioba --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0199
# Relation Type =  located_in
# dar Alagoas, e representados       acumulações     campos de Anin-gas, Angelim, [E2] Caioba [/E2], Robalo e       hidrocarbonetos recuperados     poços 6-PDM-8-SES, 3-PIR-7-AL, 1-SES-19D, 6-CM-37-SES, 7-CM-22D-SES e [E1] 4-SES-67 [/E1]..
# -------------
# -------------
# sentence = 3125
# Token 1 =   9-CL-4-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007748
# Token 2 =   Campo de Castanhal --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0264
# Relation Type =  located_in
# Foram observados indícios de biodegradação     óleos recuperados    [E2] Campo de Castanhal [/E2] ([E1] 9-CL-4-SE [/E1] e 9-CL-24-SE}, o que não impediu sua perfeita classificação..
# -------------
# -------------
# sentence = 3125
# Token 1 =   9-CL-24-SE --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_007746
# Token 2 =   Campo de Castanhal --- Class 2 =  CAMPO --- URI 2 =  #CAMP_CD_CAMPO_0264
# Relation Type =  located_in
# Foram observados indícios de biodegradação     óleos recuperados    [E2] Campo de Castanhal [/E2] (9-CL-4-SE e [E1] 9-CL-24-SE [/E1]}, o que não impediu sua perfeita classificação..
# -------------
# -------------
# sentence = 3149
# Token 1 =   formações Barra de Itiúba --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_153
# Token 2 =   Bacia Sergipe-Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# A integração de todos os dados geoquimicos     óleos e extratos orgânicos indica que as rochas geradoras identificadas     sedimentos de idade neocomiana ([E1] formações Barra de Itiúba [/E1], Coqueiro Seco e, secundariamente, Morro    Chaves) são as responsáveis      geração de todos os óleos continentais detectados até o momento    [E2] Bacia Sergipe-Alagoas [/E2]..
# -------------
# -------------
# sentence = 3149
# Token 1 =   Coqueiro Seco --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_009
# Token 2 =   Bacia Sergipe-Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# A integração de todos os dados geoquimicos     óleos e extratos orgânicos indica que as rochas geradoras identificadas     sedimentos de idade neocomiana (formações Barra de Itiúba, [E1] Coqueiro Seco [/E1] e, secundariamente, Morro    Chaves) são as responsáveis      geração de todos os óleos continentais detectados até o momento    [E2] Bacia Sergipe-Alagoas [/E2]..
# -------------
# -------------
# sentence = 3149
# Token 1 =   Morro Chaves --- Class 1 =  UNIDADE_LITO --- URI 1 =  #formacao_126
# Token 2 =   Bacia Sergipe-Alagoas --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_116
# Relation Type =  located_in
# A integração de todos os dados geoquimicos     óleos e extratos orgânicos indica que as rochas geradoras identificadas     sedimentos de idade neocomiana (formações Barra de Itiúba, Coqueiro Seco e, secundariamente, [E1] Morro    Chaves [/E1]) são as responsáveis      geração de todos os óleos continentais detectados até o momento    [E2] Bacia Sergipe-Alagoas [/E2]..
# -------------
# -------------
# sentence = 3191
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# RESUMO — Visando a melhor conhecer o comportamento     temperaturas    [E2] Bacia de Campos [/E2], bem como a estudar suas possíveis causas e implicações, foi realizado o mapeamento     temperaturas de 404 [E1] poços [/E1] perfurados até março de 1984..
# -------------
# -------------
# sentence = 3202
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# As primeiras investigações sobre as temperaturas    [E2] Bacia de Campos [/E2] foram realizadas por MEISTER (1973), que utilizou valores de temperatura de cinco [E1] poços [/E1] perfurados..
# -------------
# -------------
# sentence = 3214
# Token 1 =   1-RJS-203 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_025532
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# As áreas mais quentes estão situadas    região norte    [E2] bacia [/E2] — onde os gradientes variam de 44 a 560F/km — e    que se situa entre o Cabo de São Tomé e o Alto Regional de Badejo (área    [E1] 1-RJS-203 [/E1]), que apresenta gradientes entre 44 e 480F/km..
# -------------
# -------------
# sentence = 3215
# Token 1 =   campos de Pampo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0750
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# área     [E1] campos de Pampo [/E1], Badejo, Linguado e adjacên-cias, ocorrem os mais baixos gradientes geotérmicos    [E2] bacia [/E2]..
# -------------
# -------------
# sentence = 3215
# Token 1 =   Badejo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0092
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# área     campos de Pampo, [E1] Badejo [/E1], Linguado e adjacên-cias, ocorrem os mais baixos gradientes geotérmicos    [E2] bacia [/E2]..
# -------------
# -------------
# sentence = 3215
# Token 1 =   Linguado --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0634
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# área     campos de Pampo, Badejo, [E1] Linguado [/E1] e adjacên-cias, ocorrem os mais baixos gradientes geotérmicos    [E2] bacia [/E2]..
# -------------
# -------------
# sentence = 3232
# Token 1 =   campos de Pargo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0760
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# As feições tectônicas que mais influenciam a distribuição     temperaturas    [E2] bacia [/E2] são: — Baixo de São Tomé; — Alto Regional de Badejo; — Falhamento limite    Bacia Pré-Aptiana; — Falhamento terciário; — Falhas com direção NW-SE situadas    norte     [E1] campos de Pargo [/E1] e de Badejo, possíveis componentes de um sistema tectônico transcorrente..
# -------------
# -------------
# sentence = 3232
# Token 1 =   campos de Pargo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0760
# Token 2 =   Bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# As feições tectônicas que mais influenciam a distribuição     temperaturas    bacia são: — Baixo de São Tomé; — Alto Regional de Badejo; — Falhamento limite    [E2] Bacia [/E2] Pré-Aptiana; — Falhamento terciário; — Falhas com direção NW-SE situadas    norte     [E1] campos de Pargo [/E1] e de Badejo, possíveis componentes de um sistema tectônico transcorrente..
# -------------
# -------------
# sentence = 3232
# Token 1 =   Badejo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0092
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# As feições tectônicas que mais influenciam a distribuição     temperaturas    [E2] bacia [/E2] são: — Baixo de São Tomé; — Alto Regional de Badejo; — Falhamento limite    Bacia Pré-Aptiana; — Falhamento terciário; — Falhas com direção NW-SE situadas    norte     campos de Pargo e de [E1] Badejo [/E1], possíveis componentes de um sistema tectônico transcorrente..
# -------------
# -------------
# sentence = 3232
# Token 1 =   Badejo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0092
# Token 2 =   Bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# As feições tectônicas que mais influenciam a distribuição     temperaturas    bacia são: — Baixo de São Tomé; — Alto Regional de Badejo; — Falhamento limite    [E2] Bacia [/E2] Pré-Aptiana; — Falhamento terciário; — Falhas com direção NW-SE situadas    norte     campos de Pargo e de [E1] Badejo [/E1], possíveis componentes de um sistema tectônico transcorrente..
# -------------
# -------------
# sentence = 3243
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campos --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# As temperaturas em [E2] campos [/E2] com vários [E1] poços [/E1] perfurados foram plotadas quanto   acumulação de óleo,    intuito de se realizar um estudo sobre seu comportamento..
# -------------
# -------------
# sentence = 3262
# Token 1 =   1-RJS-203 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_025532
# Token 2 =   Bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# A área    [E1] 1-RJS-203 [/E1], por sua vez, está situada entre o falhamento limite    [E2] Bacia [/E2] Pré-Aptiana e o Alto Regional de Badejo, apresentando forma de faixa alongada SW-NE e contendo gradientes geotérmicos que variam de 44 a 48°F/km..
# -------------
# -------------
# sentence = 3272
# Token 1 =   campos de Pampo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0750
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Como resultado,              provável atuação de bactérias    área sul    [E2] bacia [/E2], entre os [E1] campos de Pampo [/E1], Badejo e Linguado, com possibilidade de essa atuação atingir sedimentos    Formação Macaé..
# -------------
# -------------
# sentence = 3272
# Token 1 =   Badejo --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0092
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Como resultado,              provável atuação de bactérias    área sul    [E2] bacia [/E2], entre os campos de Pampo, [E1] Badejo [/E1] e Linguado, com possibilidade de essa atuação atingir sedimentos    Formação Macaé..
# -------------
# -------------
# sentence = 3272
# Token 1 =   Linguado --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0634
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Como resultado,              provável atuação de bactérias    área sul    [E2] bacia [/E2], entre os campos de Pampo, Badejo e [E1] Linguado [/E1], com possibilidade de essa atuação atingir sedimentos    Formação Macaé..
# -------------
# -------------
# sentence = 3272
# Token 1 =   Formação Macaé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_000
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# Como resultado,              provável atuação de bactérias    área sul    [E2] bacia [/E2], entre os campos de Pampo, Badejo e Linguado, com possibilidade de essa atuação atingir sedimentos    [E1] Formação Macaé [/E1]..
# -------------
# -------------
# sentence = 3279
# Token 1 =   poços --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Em [E1] poços [/E1]    [E2] Bacia de Campos [/E2], valores de reflectância e estimativas de paleotemperaturas mostraram que os sedimentos    Terciário e Cretáceo Superior foram submetidos a temperaturas não superiores    atuais e que se encontram aquém ou    limite inferior para o int-cio de geração de óleo..
# -------------
# -------------
# sentence = 3286
# Token 1 =   1-RJS-203 --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_025532
# Token 2 =   bacia --- Class 2 =  BACIA --- URI 2 =  #basin
# Relation Type =  located_in
# anomalias positivas de temperaturas     áreas    [E1] 1-RJS-203 [/E1] e norte    [E2] bacia [/E2]..
# -------------
# -------------
# sentence = 3330
# Token 1 =   poço 2-SBST-1-BA --- Class 1 =  POÇO --- URI 1 =  #POCO_CD_POCO_005665
# Token 2 =   Bacia de Mucuri --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_260
# Relation Type =  located_in
# A interpretação destaca a ocorrência de rochas basálticas    região emersa    [E2] Bacia de Mucuri [/E2], em profundidades de cerca de 1 000 m,    [E1] poço 2-SBST-1-BA [/E1], perfurado em 1958 e que alcançou a profundidade final de 2 388 m..
# -------------
# -------------
# sentence = 3339
# Token 1 =   campos --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   bacias de Santos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_316
# Relation Type =  located_in
# Essas litologias provavelmente representam um exemplo único       tipo de sedimento aflorante    margem continental, sendo um magnífico análogo para os reservatórios     [E1] campos [/E1] de petróleo     [E2] bacias de Santos [/E2], Campos e Espírito Santo, cujos testemunhos (como, por exemplo,    Campo de Ju-barte) também indicam feições sedimentares semelhantes    observadas     afloramentos..
# -------------
# -------------
# sentence = 3339
# Token 1 =   campos --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Essas litologias provavelmente representam um exemplo único       tipo de sedimento aflorante    margem continental, sendo um magnífico análogo para os reservatórios     [E1] campos [/E1] de petróleo     bacias de Santos, [E2] Campos [/E2] e Espírito Santo, cujos testemunhos (como, por exemplo,    Campo de Ju-barte) também indicam feições sedimentares semelhantes    observadas     afloramentos..
# -------------
# -------------
# sentence = 3339
# Token 1 =   campos --- Class 1 =  CAMPO --- URI 1 =  #field
# Token 2 =   Espírito Santo --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_270
# Relation Type =  located_in
# Essas litologias provavelmente representam um exemplo único       tipo de sedimento aflorante    margem continental, sendo um magnífico análogo para os reservatórios     [E1] campos [/E1] de petróleo     bacias de Santos, Campos e [E2] Espírito Santo [/E2], cujos testemunhos (como, por exemplo,    Campo de Ju-barte) também indicam feições sedimentares semelhantes    observadas     afloramentos..
# -------------
# -------------
# sentence = 3339
# Token 1 =   Campo de Ju-barte --- Class 1 =  CAMPO --- URI 1 =  #CAMP_CD_CAMPO_0065
# Token 2 =   Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Essas litologias provavelmente representam um exemplo único       tipo de sedimento aflorante    margem continental, sendo um magnífico análogo para os reservatórios     campos de petróleo     bacias de Santos, [E2] Campos [/E2] e Espírito Santo, cujos testemunhos (como, por exemplo,    [E1] Campo de Ju-barte [/E1]) também indicam feições sedimentares semelhantes    observadas     afloramentos..
# -------------
# -------------
# sentence = 3342
# Token 1 =   poço --- Class 1 =  POÇO --- URI 1 =  #well
# Token 2 =   campo --- Class 2 =  CAMPO --- URI 2 =  #field
# Relation Type =  located_in
# Tanto    [E1] poço [/E1] quanto     afloramentos    ilha            a ocorrência de basalto e diabásio com textura mais grosseira (cumulado), preliminarmente interpretado    [E2] campo [/E2] como gabro..
# -------------
# -------------
# sentence = 3405
# Token 1 =   Formação Macaé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_000
# Token 2 =   petróleo --- Class 2 =  FLUIDODATERRA_i --- URI 2 =  #oil
# Relation Type =  constituted_by
# Todo esse quadro veio a sofrer mudanças     anos 70, com a descoberta de [E2] petróleo [/E2]    Bacia de Campos, onde a primeira unidade litoestratigráfica a ser reconhecida como portadora de petróleo foi a [E1] Formação Macaé [/E1], depositada em plataforma carbonática..
# -------------
# -------------
# sentence = 3405
# Token 1 =   Formação Macaé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_000
# Token 2 =   Bacia de Campos --- Class 2 =  BACIA --- URI 2 =  #BASE_CD_BACIA_281
# Relation Type =  located_in
# Todo esse quadro veio a sofrer mudanças     anos 70, com a descoberta de petróleo    [E2] Bacia de Campos [/E2], onde a primeira unidade litoestratigráfica a ser reconhecida como portadora de petróleo foi a [E1] Formação Macaé [/E1], depositada em plataforma carbonática..
# -------------
# -------------
# sentence = 3405
# Token 1 =   Formação Macaé --- Class 1 =  UNIDADE_LITO --- URI 1 =  #grupo_000
# Token 2 =   petróleo --- Class 2 =  FLUIDODATERRA_i --- URI 2 =  #oil
# Relation Type =  constituted_by
# Todo esse quadro veio a sofrer mudanças     anos 70, com a descoberta de petróleo    Bacia de Campos, onde a primeira unidade litoestratigráfica a ser reconhecida como portadora de [E2] petróleo [/E2] foi a [E1] Formação Macaé [/E1], depositada em plataforma carbonática..
# -------------
# -------------
# Number of Jsons saved =  0

# %% [markdown]
# ### Contabilização das relações encontradas

# %%
def contabilizar(file):
    with open(file, 'rb') as f:
        data = pickle.load(f)
    for i in range(len(data[0])):
        print(data[0][i], ' - ', data[1][i])

# %%
contabilizar(lista_relacoes_treino)
# Out:
# constituted_by  -  310
# crosses  -  83
# has_age  -  21
# located_in  -  826
# part_of  -  62

# %%
contabilizar(lista_relacoes_valid)
# Out:
# constituted_by  -  13
# crosses  -  10
# has_age  -  1
# located_in  -  80
# part_of  -  6

# %%
contabilizar(lista_relacoes_teste)
# Out:
# constituted_by  -  92
# crosses  -  10
# has_age  -  17
# located_in  -  142
# part_of  -  38

# %% [markdown]
# ### Contabilização das classes encontradas

# %%
contabilizar(lista_classes_treino)
# Out:
# BACIA  -  704
# CAMPO  -  281
# FLUIDODATERRA_i  -  8
# NÃOCONSOLID  -  4
# POÇO  -  462
# ROCHA  -  298
# UNIDADE_CRONO  -  21
# UNIDADE_LITO  -  826

# %%
contabilizar(lista_classes_valid)
# Out:
# BACIA  -  70
# CAMPO  -  24
# NÃOCONSOLID  -  1
# POÇO  -  54
# ROCHA  -  12
# UNIDADE_CRONO  -  1
# UNIDADE_LITO  -  58

# %%
contabilizar(lista_classes_teste)
# Out:
# BACIA  -  110
# CAMPO  -  65
# FLUIDODATERRA_i  -  2
# POÇO  -  60
# ROCHA  -  90
# UNIDADE_CRONO  -  17
# UNIDADE_LITO  -  254

# %% [markdown]
# ### Contabilização das URIs encontradas

# %%
contabilizar(lista_uris_treino)
# Out:
# #Alagoas_Age  -  12
# #Albian  -  4
# #Aratu_Age  -  2
# #BASE_CD_BACIA_020  -  6
# #BASE_CD_BACIA_030  -  4
# #BASE_CD_BACIA_051  -  3
# #BASE_CD_BACIA_076  -  6
# #BASE_CD_BACIA_080  -  3
# #BASE_CD_BACIA_090  -  3
# #BASE_CD_BACIA_096  -  39
# #BASE_CD_BACIA_100  -  52
# #BASE_CD_BACIA_106  -  6
# #BASE_CD_BACIA_116  -  108
# #BASE_CD_BACIA_210  -  2
# #BASE_CD_BACIA_215  -  7
# #BASE_CD_BACIA_220  -  5
# #BASE_CD_BACIA_230  -  11
# #BASE_CD_BACIA_240  -  15
# #BASE_CD_BACIA_250  -  5
# #BASE_CD_BACIA_256  -  1
# #BASE_CD_BACIA_260  -  6
# #BASE_CD_BACIA_266  -  29
# #BASE_CD_BACIA_270  -  26
# #BASE_CD_BACIA_281  -  69
# #BASE_CD_BACIA_300  -  34
# #BASE_CD_BACIA_316  -  29
# #BASE_CD_BACIA_381  -  4
# #CAMP_CD_CAMPO_0003  -  1
# #CAMP_CD_CAMPO_0004  -  1
# #CAMP_CD_CAMPO_0012  -  1
# #CAMP_CD_CAMPO_0017  -  6
# #CAMP_CD_CAMPO_0027  -  1
# #CAMP_CD_CAMPO_0065  -  3
# #CAMP_CD_CAMPO_0082  -  9
# #CAMP_CD_CAMPO_0093  -  1
# #CAMP_CD_CAMPO_0118  -  2
# #CAMP_CD_CAMPO_0128  -  1
# #CAMP_CD_CAMPO_0152  -  1
# #CAMP_CD_CAMPO_0174  -  1
# #CAMP_CD_CAMPO_0179  -  2
# #CAMP_CD_CAMPO_0234  -  5
# #CAMP_CD_CAMPO_0239  -  1
# #CAMP_CD_CAMPO_0247  -  1
# #CAMP_CD_CAMPO_0248  -  1
# #CAMP_CD_CAMPO_0249  -  2
# #CAMP_CD_CAMPO_0279  -  1
# #CAMP_CD_CAMPO_0309  -  1
# #CAMP_CD_CAMPO_0322  -  1
# #CAMP_CD_CAMPO_0352  -  19
# #CAMP_CD_CAMPO_0362  -  8
# #CAMP_CD_CAMPO_0363  -  2
# #CAMP_CD_CAMPO_0373  -  3
# #CAMP_CD_CAMPO_0383  -  4
# #CAMP_CD_CAMPO_0388  -  2
# #CAMP_CD_CAMPO_0393  -  1
# #CAMP_CD_CAMPO_0403  -  1
# #CAMP_CD_CAMPO_0444  -  3
# #CAMP_CD_CAMPO_0477  -  1
# #CAMP_CD_CAMPO_0494  -  1
# #CAMP_CD_CAMPO_0519  -  5
# #CAMP_CD_CAMPO_0523  -  4
# #CAMP_CD_CAMPO_0533  -  1
# #CAMP_CD_CAMPO_0536  -  5
# #CAMP_CD_CAMPO_0545  -  2
# #CAMP_CD_CAMPO_0575  -  6
# #CAMP_CD_CAMPO_0631  -  1
# #CAMP_CD_CAMPO_0634  -  1
# #CAMP_CD_CAMPO_0637  -  1
# #CAMP_CD_CAMPO_0668  -  1
# #CAMP_CD_CAMPO_0682  -  5
# #CAMP_CD_CAMPO_0683  -  1
# #CAMP_CD_CAMPO_0684  -  1
# #CAMP_CD_CAMPO_0725  -  3
# #CAMP_CD_CAMPO_0734  -  12
# #CAMP_CD_CAMPO_0750  -  1
# #CAMP_CD_CAMPO_0760  -  3
# #CAMP_CD_CAMPO_0773  -  9
# #CAMP_CD_CAMPO_0803  -  3
# #CAMP_CD_CAMPO_0819  -  1
# #CAMP_CD_CAMPO_0861  -  1
# #CAMP_CD_CAMPO_0880  -  1
# #CAMP_CD_CAMPO_0881  -  7
# #CAMP_CD_CAMPO_0888  -  1
# #CAMP_CD_CAMPO_0912  -  1
# #CAMP_CD_CAMPO_0916  -  2
# #CAMP_CD_CAMPO_0929  -  3
# #CAMP_CD_CAMPO_0932  -  1
# #CAMP_CD_CAMPO_0951  -  4
# #CAMP_CD_CAMPO_0970  -  3
# #CAMP_CD_CAMPO_0975  -  6
# #CAMP_CD_CAMPO_0995  -  3
# #Carboniferous  -  1
# #Dom_Joao_Age  -  1
# #POCO_CD_POCO_006088  -  1
# #POCO_CD_POCO_006789  -  3
# #POCO_CD_POCO_006882  -  1
# #POCO_CD_POCO_006960  -  2
# #POCO_CD_POCO_007140  -  1
# #POCO_CD_POCO_009032  -  1
# #POCO_CD_POCO_009422  -  1
# #POCO_CD_POCO_009908  -  1
# #POCO_CD_POCO_010831  -  2
# #POCO_CD_POCO_011890  -  1
# #POCO_CD_POCO_011894  -  1
# #POCO_CD_POCO_011907  -  2
# #POCO_CD_POCO_011911  -  2
# #POCO_CD_POCO_012020  -  4
# #POCO_CD_POCO_012040  -  2
# #POCO_CD_POCO_012091  -  1
# #POCO_CD_POCO_012097  -  5
# #POCO_CD_POCO_012120  -  5
# #POCO_CD_POCO_012153  -  1
# #POCO_CD_POCO_012155  -  1
# #POCO_CD_POCO_012186  -  1
# #POCO_CD_POCO_012864  -  1
# #POCO_CD_POCO_012914  -  1
# #POCO_CD_POCO_012983  -  2
# #POCO_CD_POCO_015948  -  2
# #POCO_CD_POCO_016511  -  2
# #POCO_CD_POCO_016933  -  5
# #POCO_CD_POCO_017402  -  1
# #POCO_CD_POCO_017478  -  2
# #POCO_CD_POCO_018470  -  3
# #POCO_CD_POCO_020490  -  2
# #POCO_CD_POCO_020738  -  1
# #POCO_CD_POCO_020848  -  2
# #POCO_CD_POCO_021472  -  1
# #POCO_CD_POCO_021725  -  1
# #POCO_CD_POCO_021906  -  1
# #POCO_CD_POCO_021985  -  2
# #POCO_CD_POCO_022451  -  1
# #POCO_CD_POCO_022687  -  1
# #POCO_CD_POCO_022866  -  1
# #POCO_CD_POCO_022975  -  1
# #POCO_CD_POCO_023049  -  2
# #POCO_CD_POCO_023087  -  2
# #POCO_CD_POCO_023104  -  2
# #POCO_CD_POCO_023169  -  1
# #POCO_CD_POCO_023172  -  2
# #POCO_CD_POCO_023376  -  2
# #POCO_CD_POCO_023401  -  1
# #POCO_CD_POCO_023745  -  2
# #POCO_CD_POCO_023746  -  1
# #POCO_CD_POCO_024176  -  2
# #POCO_CD_POCO_024234  -  1
# #POCO_CD_POCO_024384  -  1
# #POCO_CD_POCO_024465  -  1
# #POCO_CD_POCO_024505  -  2
# #POCO_CD_POCO_024918  -  3
# #POCO_CD_POCO_025010  -  1
# #POCO_CD_POCO_025253  -  2
# #Pliocene  -  1
# #SD_000  -  86
# #anhydrite  -  2
# #argillite  -  1
# #basalt  -  6
# #basin  -  231
# #clay  -  3
# #coal  -  1
# #conglomerate  -  14
# #diabase  -  4
# #diamictite  -  17
# #field  -  94
# #formacao_002  -  2
# #formacao_003  -  2
# #formacao_009  -  12
# #formacao_013  -  5
# #formacao_016  -  7
# #formacao_019  -  3
# #formacao_027  -  18
# #formacao_028  -  2
# #formacao_044  -  1
# #formacao_050  -  2
# #formacao_056  -  19
# #formacao_059  -  2
# #formacao_061  -  3
# #formacao_066  -  1
# #formacao_083  -  7
# #formacao_084  -  1
# #formacao_095  -  7
# #formacao_096  -  5
# #formacao_102  -  6
# #formacao_103  -  7
# #formacao_110  -  17
# #formacao_113  -  20
# #formacao_116  -  2
# #formacao_117  -  4
# #formacao_119  -  1
# #formacao_121  -  2
# #formacao_122  -  6
# #formacao_125  -  1
# #formacao_130  -  2
# #formacao_131  -  2
# #formacao_136  -  6
# #formacao_142  -  2
# #formacao_145  -  1
# #formacao_149  -  7
# #formacao_153  -  15
# #formacao_154  -  6
# #formacao_157  -  5
# #formacao_158  -  3
# #formacao_163  -  1
# #formacao_165  -  2
# #formacao_171  -  5
# #formacao_183  -  4
# #formacao_185  -  1
# #formacao_187  -  2
# #formacao_193  -  6
# #formacao_200  -  11
# #formacao_204  -  7
# #formacao_207  -  2
# #formacao_210  -  7
# #formacao_215  -  6
# #formacao_216  -  5
# #formacao_222  -  2
# #formacao_224  -  2
# #formacao_228  -  3
# #formacao_229  -  1
# #formacao_232  -  2
# #formacao_236  -  8
# #formacao_239  -  21
# #formacao_242  -  34
# #formacao_246  -  1
# #formacao_249  -  1
# #formacao_251  -  2
# #formacao_253  -  15
# #formacao_254  -  17
# #formacao_255  -  3
# #formacao_256  -  6
# #formacao_259  -  32
# #formacao_260  -  6
# #formacao_262  -  17
# #formacao_264  -  7
# #formacao_266  -  3
# #formacao_277  -  1
# #formacao_278  -  3
# #formacao_281  -  1
# #formacao_286  -  1
# #formacao_287  -  3
# #formacao_289  -  2
# #formacao_292  -  2
# #formacao_294  -  23
# #formacao_295  -  3
# #formacao_296  -  10
# #formacao_305  -  8
# #formacao_312  -  1
# #formacao_319  -  15
# #formacao_331  -  8
# #formacao_335  -  6
# #formacao_341  -  2
# #formacao_343  -  6
# #formacao_344  -  5
# #gipsita  -  1
# #granite  -  1
# #grupo_000  -  15
# #grupo_001  -  3
# #grupo_009  -  2
# #grupo_017  -  2
# #grupo_018  -  1
# #grupo_022  -  2
# #grupo_033  -  52
# #grupo_038  -  1
# #grupo_048  -  1
# #grupo_062  -  5
# #grupo_063  -  1
# #igneous_rock  -  1
# #limestone  -  3
# #marlstone  -  3
# #membro_000  -  4
# #membro_002  -  5
# #membro_010  -  27
# #membro_019  -  10
# #membro_020  -  11
# #membro_022  -  1
# #membro_025  -  2
# #membro_028  -  2
# #membro_032  -  2
# #membro_037  -  2
# #membro_040  -  1
# #membro_042  -  2
# #membro_045  -  6
# #membro_050  -  4
# #membro_058  -  2
# #membro_060  -  7
# #membro_070  -  3
# #membro_075  -  1
# #membro_078  -  7
# #oil  -  8
# #sand  -  1
# #sandstone  -  156
# #shale  -  73
# #siltstone  -  13
# #volcanic_rock  -  2
# #well  -  362

# %%
contabilizar(lista_uris_valid)
# Out:
# #BASE_CD_BACIA_030  -  12
# #BASE_CD_BACIA_051  -  1
# #BASE_CD_BACIA_076  -  1
# #BASE_CD_BACIA_096  -  6
# #BASE_CD_BACIA_100  -  4
# #BASE_CD_BACIA_116  -  11
# #BASE_CD_BACIA_240  -  4
# #BASE_CD_BACIA_266  -  5
# #BASE_CD_BACIA_270  -  4
# #BASE_CD_BACIA_281  -  12
# #Bashkirian  -  1
# #CAMP_CD_CAMPO_0247  -  1
# #CAMP_CD_CAMPO_0444  -  2
# #CAMP_CD_CAMPO_0603  -  1
# #CAMP_CD_CAMPO_0718  -  1
# #CAMP_CD_CAMPO_0750  -  1
# #CAMP_CD_CAMPO_0773  -  6
# #CAMP_CD_CAMPO_0888  -  3
# #CAMP_CD_CAMPO_0932  -  3
# #POCO_CD_POCO_007020  -  2
# #POCO_CD_POCO_007040  -  4
# #POCO_CD_POCO_007052  -  1
# #POCO_CD_POCO_007076  -  2
# #POCO_CD_POCO_007553  -  2
# #POCO_CD_POCO_008339  -  1
# #POCO_CD_POCO_010471  -  4
# #POCO_CD_POCO_012996  -  4
# #POCO_CD_POCO_022660  -  2
# #POCO_CD_POCO_023241  -  3
# #SD_000  -  1
# #basalt  -  1
# #basin  -  10
# #conglomerate  -  4
# #diabase  -  1
# #field  -  6
# #formacao_009  -  4
# #formacao_016  -  1
# #formacao_027  -  1
# #formacao_028  -  8
# #formacao_110  -  1
# #formacao_122  -  1
# #formacao_158  -  1
# #formacao_159  -  8
# #formacao_163  -  2
# #formacao_166  -  2
# #formacao_187  -  4
# #formacao_222  -  5
# #formacao_232  -  4
# #formacao_239  -  2
# #formacao_254  -  1
# #formacao_262  -  1
# #grupo_000  -  2
# #grupo_049  -  9
# #marlstone  -  2
# #sandstone  -  1
# #shale  -  3
# #unconsolidated_earth_material  -  1
# #well  -  29

# %%
contabilizar(lista_uris_teste)
# Out:
# #Alagoas_Age  -  3
# #Aratu_Age  -  2
# #BASE_CD_BACIA_030  -  1
# #BASE_CD_BACIA_100  -  7
# #BASE_CD_BACIA_116  -  24
# #BASE_CD_BACIA_215  -  1
# #BASE_CD_BACIA_230  -  1
# #BASE_CD_BACIA_240  -  5
# #BASE_CD_BACIA_260  -  1
# #BASE_CD_BACIA_266  -  2
# #BASE_CD_BACIA_270  -  3
# #BASE_CD_BACIA_281  -  16
# #BASE_CD_BACIA_316  -  2
# #CAMP_CD_CAMPO_0017  -  1
# #CAMP_CD_CAMPO_0065  -  1
# #CAMP_CD_CAMPO_0077  -  4
# #CAMP_CD_CAMPO_0092  -  4
# #CAMP_CD_CAMPO_0199  -  1
# #CAMP_CD_CAMPO_0214  -  4
# #CAMP_CD_CAMPO_0249  -  5
# #CAMP_CD_CAMPO_0264  -  2
# #CAMP_CD_CAMPO_0575  -  2
# #CAMP_CD_CAMPO_0634  -  2
# #CAMP_CD_CAMPO_0682  -  4
# #CAMP_CD_CAMPO_0683  -  1
# #CAMP_CD_CAMPO_0684  -  1
# #CAMP_CD_CAMPO_0750  -  2
# #CAMP_CD_CAMPO_0760  -  2
# #CAMP_CD_CAMPO_0773  -  1
# #CAMP_CD_CAMPO_0830  -  1
# #CAMP_CD_CAMPO_0881  -  1
# #CAMP_CD_CAMPO_0958  -  1
# #Dom_Joao_Age  -  8
# #POCO_CD_POCO_005665  -  1
# #POCO_CD_POCO_006838  -  1
# #POCO_CD_POCO_006870  -  2
# #POCO_CD_POCO_007746  -  1
# #POCO_CD_POCO_007748  -  1
# #POCO_CD_POCO_009065  -  4
# #POCO_CD_POCO_009757  -  7
# #POCO_CD_POCO_010491  -  1
# #POCO_CD_POCO_010526  -  4
# #POCO_CD_POCO_010643  -  2
# #POCO_CD_POCO_010669  -  2
# #POCO_CD_POCO_010670  -  1
# #POCO_CD_POCO_010683  -  1
# #POCO_CD_POCO_010689  -  2
# #POCO_CD_POCO_010691  -  4
# #POCO_CD_POCO_010726  -  1
# #POCO_CD_POCO_010746  -  1
# #POCO_CD_POCO_025532  -  3
# #Permian  -  4
# #SD_000  -  19
# #anhydrite  -  3
# #basin  -  47
# #calciarenite  -  1
# #carnallite  -  1
# #conglomerate  -  2
# #diabase  -  1
# #field  -  25
# #formacao_009  -  1
# #formacao_016  -  1
# #formacao_025  -  2
# #formacao_056  -  1
# #formacao_095  -  9
# #formacao_102  -  2
# #formacao_103  -  9
# #formacao_117  -  11
# #formacao_125  -  1
# #formacao_126  -  1
# #formacao_130  -  7
# #formacao_145  -  1
# #formacao_149  -  3
# #formacao_153  -  1
# #formacao_154  -  3
# #formacao_158  -  1
# #formacao_216  -  2
# #formacao_217  -  5
# #formacao_229  -  1
# #formacao_239  -  6
# #formacao_253  -  4
# #formacao_286  -  8
# #formacao_287  -  5
# #formacao_295  -  10
# #formacao_305  -  1
# #formacao_319  -  11
# #formacao_328  -  5
# #formacao_335  -  19
# #formacao_338  -  9
# #gneiss  -  1
# #granite  -  1
# #grupo_000  -  4
# #grupo_022  -  5
# #grupo_024  -  2
# #grupo_032  -  6
# #grupo_055  -  3
# #grupo_057  -  1
# #halite  -  1
# #membro_005  -  5
# #membro_007  -  6
# #membro_013  -  4
# #membro_025  -  7
# #membro_027  -  8
# #membro_036  -  4
# #membro_044  -  9
# #membro_052  -  10
# #membro_061  -  9
# #membro_070  -  4
# #membro_071  -  4
# #membro_078  -  4
# #mudstone  -  1
# #oil  -  2
# #sandstone  -  42
# #shale  -  30
# #siltstone  -  5
# #tachyhydrite  -  1
# #well  -  21

# %% [markdown]
# ### Verificação de pares de entidades por tipo de relação

# %%
# df_filtred = pickle.load(open('df_relation.pkl', 'rb'))
#df_relations = pd.read_csv('df_relation.csv')
#df_grp = df_relations.groupby('Relation')
#relations_groups = df_grp.groups
#relations = list(relations_groups)
#lista_pares = []
#for relation in relations:
#    df_rel = df_grp.get_group(relation)
#    list_rel = []
#    for idx_rel in range(0,len(df_rel)):
#        par = df_rel.iloc[idx_rel]['Ent1'] + ' + ' + df_rel.iloc[idx_rel]['Ent2']
#        list_rel.append(par)
#    lista_pares.append(list_rel)
#print('Number of types of relations ->', len(lista_pares))

# %% [markdown]
# ### Avaliar idx_pair de 0 ao tamanho apresentado acima para verificar os pares de entidades

# %%
#idx = 0
#pares, numb_pares = np.unique(lista_pares[idx], return_counts = True)
#print('Relation -> ',relations[idx])
#print('Entities pair -> ',pares.tolist())
#print('Number of ocorrences -> ',numb_pares.tolist())
